# %%
# https://rosettacode.org/wiki/Sorting_algorithms/Shell_sort#Python

import numpy as np
from line_profiler import LineProfiler
from pysr import PySRRegressor
import random
import os
import sys
import math
import pickle

# %% [markdown]
# ## Shell Algorithm

# %%
def shell(seq): # N log N ou N^6/5 
  inc = len(seq) // 2
  while inc:
    for i, el in enumerate(seq[inc:], inc):
      while i >= inc and seq[i - inc] > el:
        seq[i] = seq[i - inc]
        i -= inc
      seq[i] = el
    inc = 1 if inc == 2 else inc * 5 // 11

# %% [markdown]
# ## Frequency Count Method

# %%
X_y = []
i=50
for n in range(2,i+1): # started with 2 itens until 50 itens in the list
  lprofiler = LineProfiler()
  lp_wrapper = lprofiler(shell)

  # create a list with random number between 1 to 10000
  # with n number in the list
  input = random.choices(range(10000), k=n)
  lp_wrapper(input)

  stats = lprofiler.get_stats()
  line_numbers = []
  hits = []

  for line in stats.timings.values():
    for i in line:
      line_numbers.append(i[0])
      hits.append(i[1])

  X_y.append([n, sum(hits)])

dados = np.array(X_y)

X = dados[:, 0]
y = dados[:, 1]
X_reshaped = X.reshape(-1, 1)

# %%
resultados_com_menor_loss = []
repeat = 5
registros = []
unary_operators_list = ["log", "square", "cube", "sqrt", "round", "exp", "abs"]

original_stdout = sys.stdout

with open(os.devnull, 'w') as devnull:
  sys.stdout = devnull

  for i in range(repeat):

    # first combination
    reg1 = PySRRegressor(
      binary_operators=["*", "+"],
      unary_operators=unary_operators_list
    )

    fit1 = reg1.fit(X_reshaped, y)
    best_program1 = fit1.get_best()

    registro1 = []
    for index, value in enumerate(best_program1):
      registro1.append(value)
      
    registros.append(registro1)

    # second combination
    reg2 = PySRRegressor(
      binary_operators=["*"],
      unary_operators=unary_operators_list
    )

    fit2 = reg2.fit(X_reshaped, y)
    best_program2 = fit2.get_best()

    registro2 = []
    for index, value in enumerate(best_program2):
      registro2.append(value)
    registros.append(registro2)

    # third combinarion
    reg3 = PySRRegressor(
      binary_operators=["+"],
      unary_operators=unary_operators_list
    )

    fit3 = reg3.fit(X_reshaped, y)
    best_program3 = fit3.get_best()

    registro3 = []
    for index, value in enumerate(best_program3):
      registro3.append(value)
    registros.append(registro3)
    
sys.stdout = original_stdout
# Out:
# [ Info: Started!
# 0.0%┣                                              ┫ 0/600 [00:00<00:-5, -0s/it]Expressions evaluated per second: [.....]. Head worker occupation: 0.0%         Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.550e+05  1.594e+01  y = x₀                                        3           2.263e+05  5.987e-02  y = (x₀ + x₀)                                 4           1.831e+05  2.115e-01  y = (x₀ * log(x₀))                            5           2.233e+04  2.104e+00  y = (square(log(x₀)) * x₀)                    7           1.597e+03  1.319e+00  y = (x₀ * square(log(x₀ + x₀)))               9           1.226e+03  1.319e-01  y = ((x₀ * square(log(x₀ * 1.6765))) + x₀)    13          9.998e+02  5.105e-02  y = (x₀ * square(log((x₀ + 22.262) + (x₀ * (0.0065093 * x₀))))...                                                                                               )                                             ---------------------------------------------------------------------------------------------------
# 0.7%┣▎                                             ┫ 4/600 [00:00<00:14, 43it/s]Expressions evaluated per second: [.....]. Head worker occupation: 15.8%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.550e+05  1.594e+01  y = x₀                                        3           2.263e+05  5.987e-02  y = (x₀ + x₀)                                 4           8.610e+03  3.269e+00  y = square(-0.6532 * x₀)                      6           5.965e+03  1.835e-01  y = square(-0.6532 * (x₀ + 1.5647))           7           1.597e+03  1.318e+00  y = (x₀ * square(log(x₀ + x₀)))               9           1.226e+03  1.319e-01  y = ((x₀ * square(log(x₀ * 1.6765))) + x₀)    13          9.998e+02  5.105e-02  y = (x₀ * square(log((x₀ + 22.262) + (x₀ * (0.0065093 * x₀))))...                                                                                               )                                             ---------------------------------------------------------------------------------------------------
# 1.8%┣▉                                            ┫ 11/600 [00:00<00:08, 75it/s]Expressions evaluated per second: [.....]. Head worker occupation: 22.9%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.550e+05  1.594e+01  y = x₀                                        3           2.263e+05  5.987e-02  y = (x₀ + x₀)                                 4           8.439e+03  3.289e+00  y = square(0.69432 * x₀)                      6           5.965e+03  1.735e-01  y = square(-0.6532 * (x₀ + 1.5647))           7           1.597e+03  1.318e+00  y = (x₀ * square(log(x₀ + x₀)))               9           1.226e+03  1.319e-01  y = ((x₀ * square(log(x₀ * 1.6765))) + x₀)    12          8.889e+02  1.073e-01  y = ((x₀ * log((square(cube(x₀)) * 0.18161) * 0.18161)) + -0.1...                                                                                               9009)                                         13          8.805e+02  9.399e-03  y = ((x₀ * log((square(cube(x₀)) * 0.18161) * 0.18161)) + log(...                                                                                               0.18161))                                     14          8.767e+02  4.396e-03  y = ((x₀ * log((square(cube(x₀)) * 0.18161) * 0.18161)) + log(...                                                                                               square(0.18161)))                             15          8.528e+02  2.760e-02  y = ((x₀ * log((square(cube(1.4757 + x₀)) * 0.61996) * square(...                                                                                               0.18161))) + -0.25292)                        ---------------------------------------------------------------------------------------------------
# 2.7%┣█▏                                           ┫ 16/600 [00:00<00:07, 81it/s]Expressions evaluated per second: [.....]. Head worker occupation: 22.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.550e+05  1.594e+01  y = x₀                                        3           2.234e+05  6.620e-02  y = (x₀ * 2.1023)                             4           8.439e+03  3.276e+00  y = square(0.69432 * x₀)                      6           5.965e+03  1.735e-01  y = square(-0.6532 * (x₀ + 1.5647))           7           1.597e+03  1.318e+00  y = (x₀ * square(log(x₀ + x₀)))               9           8.994e+02  2.869e-01  y = (x₀ * log(cube(x₀) * (x₀ * x₀)))          12          8.889e+02  3.939e-03  y = ((x₀ * log((square(cube(x₀)) * 0.18161) * 0.18161)) + -0.1...                                                                                               9009)                                         13          8.805e+02  9.399e-03  y = ((x₀ * log((square(cube(x₀)) * 0.18161) * 0.18161)) + log(...                                                                                               0.18161))                                     14          8.767e+02  4.396e-03  y = ((x₀ * log((square(cube(x₀)) * 0.18161) * 0.18161)) + log(...                                                                                               square(0.18161)))                             15          8.528e+02  2.760e-02  y = ((x₀ * log((square(cube(1.4757 + x₀)) * 0.61996) * square(...                                                                                               0.18161))) + -0.25292)                        ---------------------------------------------------------------------------------------------------
# 3.5%┣█▋                                           ┫ 21/600 [00:00<00:07, 83it/s]Expressions evaluated per second: [.....]. Head worker occupation: 21.3%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.550e+05  1.594e+01  y = x₀                                        3           2.234e+05  6.620e-02  y = (x₀ * 2.1023)                             4           8.439e+03  3.276e+00  y = square(0.69432 * x₀)                      6           5.965e+03  1.735e-01  y = square(-0.6532 * (x₀ + 1.5647))           7           1.597e+03  1.318e+00  y = (x₀ * square(log(x₀ + x₀)))               8           9.424e+02  5.273e-01  y = (x₀ * log(square(cube(-0.52083 * x₀))))   9           8.994e+02  4.664e-02  y = (x₀ * log(cube(x₀) * (x₀ * x₀)))          10          8.772e+02  2.506e-02  y = (x₀ * log(square(cube(-0.52083 * x₀) * 1.0846)))                                                                          12          8.591e+02  1.040e-02  y = (x₀ * log((square(cube(x₀ * -0.82895)) * 0.18161) * 0.4788...                                                                                               7))                                           15          8.528e+02  2.449e-03  y = ((x₀ * log((square(cube(1.4757 + x₀)) * 0.61996) * square(...                                                                                               0.18161))) + -0.25292)                        ---------------------------------------------------------------------------------------------------
# 4.3%┣██                                           ┫ 26/600 [00:00<00:07, 82it/s]Expressions evaluated per second: [.....]. Head worker occupation: 20.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.550e+05  1.594e+01  y = x₀                                        2           9.031e+04  1.038e+00  y = square(-21.021)                           4           8.439e+03  1.185e+00  y = square(0.69432 * x₀)                      6           5.965e+03  1.735e-01  y = square(-0.6532 * (x₀ + 1.5647))           7           1.597e+03  1.318e+00  y = (x₀ * square(log(x₀ + x₀)))               8           9.424e+02  5.273e-01  y = (x₀ * log(square(cube(-0.52083 * x₀))))   9           8.994e+02  4.664e-02  y = (x₀ * log(cube(x₀) * (x₀ * x₀)))          10          8.772e+02  2.506e-02  y = (x₀ * log(square(cube(-0.52083 * x₀) * 1.0846)))                                                                          12          8.591e+02  1.040e-02  y = (x₀ * log((square(cube(x₀ * -0.82895)) * 0.18161) * 0.4788...                                                                                               7))                                           15          8.525e+02  2.581e-03  y = (x₀ * log((square(cube(1.4757 + (x₀ + 0.049739))) * 0.6199...                                                                                               6) * square(0.18161)))                        ---------------------------------------------------------------------------------------------------
# 5.3%┣██▍                                          ┫ 32/600 [00:00<00:07, 85it/s]Expressions evaluated per second: [.....]. Head worker occupation: 19.4%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.550e+05  1.594e+01  y = x₀                                        2           9.031e+04  1.038e+00  y = square(-21.021)                           4           8.439e+03  1.185e+00  y = square(0.69432 * x₀)                      6           5.765e+03  1.905e-01  y = square(-0.65273 * (x₀ + 2.0534))          7           1.597e+03  1.284e+00  y = (x₀ * square(log(x₀ + x₀)))               8           9.424e+02  5.273e-01  y = (x₀ * log(square(cube(-0.52083 * x₀))))   9           8.994e+02  4.664e-02  y = (x₀ * log(cube(x₀) * (x₀ * x₀)))          10          8.772e+02  2.506e-02  y = (x₀ * log(square(cube(-0.52083 * x₀) * 1.0846)))                                                                          12          8.591e+02  1.040e-02  y = (x₀ * log((square(cube(x₀ * -0.82895)) * 0.18161) * 0.4788...                                                                                               7))                                           15          8.525e+02  2.581e-03  y = (x₀ * log((square(cube(1.4757 + (x₀ + 0.049739))) * 0.6199...                                                                                               6) * square(0.18161)))                        ---------------------------------------------------------------------------------------------------
# 6.8%┣███                                          ┫ 41/600 [00:00<00:06, 95it/s]Expressions evaluated per second: [.....]. Head worker occupation: 21.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.550e+05  1.594e+01  y = x₀                                        2           9.031e+04  1.038e+00  y = square(-21.021)                           3           4.017e+03  3.113e+00  y = (17.928 * x₀)                             6           3.197e+03  7.603e-02  y = (square(-0.62444 * x₀) + 100.32)          7           1.597e+03  6.945e-01  y = (x₀ * square(log(x₀ + x₀)))               8           9.424e+02  5.273e-01  y = (x₀ * log(square(cube(-0.52083 * x₀))))   9           8.994e+02  4.664e-02  y = (x₀ * log(cube(x₀) * (x₀ * x₀)))          10          8.517e+02  5.451e-02  y = ((x₀ + 0.7219) * log(square(cube(-0.51699 * x₀))))                                                                        ---------------------------------------------------------------------------------------------------
# 7.5%┣███▍                                         ┫ 45/600 [00:00<00:06, 92it/s]Expressions evaluated per second: [.....]. Head worker occupation: 20.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.550e+05  1.594e+01  y = x₀                                        2           9.031e+04  1.038e+00  y = square(-21.021)                           3           4.017e+03  3.113e+00  y = (17.928 * x₀)                             6           3.197e+03  7.603e-02  y = (square(-0.62444 * x₀) + 100.32)          7           1.440e+03  7.977e-01  y = (x₀ * square(log(1.9568 * x₀)))           8           9.424e+02  4.240e-01  y = (x₀ * log(square(cube(-0.52083 * x₀))))   9           8.994e+02  4.664e-02  y = (x₀ * log(cube(x₀) * (x₀ * x₀)))          10          8.517e+02  5.451e-02  y = ((x₀ + 0.7219) * log(square(cube(-0.51699 * x₀))))                                                                        ---------------------------------------------------------------------------------------------------
# 8.7%┣████                                         ┫ 52/600 [00:01<00:06, 95it/s]Expressions evaluated per second: [.....]. Head worker occupation: 19.7%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.550e+05  1.594e+01  y = x₀                                        2           9.031e+04  1.038e+00  y = square(-21.021)                           3           4.017e+03  3.113e+00  y = (17.928 * x₀)                             6           1.596e+03  3.077e-01  y = square((-0.51558 * x₀) + -6.3974)         7           1.440e+03  1.027e-01  y = (x₀ * square(log(1.9568 * x₀)))           8           9.424e+02  4.240e-01  y = (x₀ * log(square(cube(-0.52083 * x₀))))   9           8.994e+02  4.664e-02  y = (x₀ * log(cube(x₀) * (x₀ * x₀)))          10          8.517e+02  5.451e-02  y = ((x₀ + 0.7219) * log(square(cube(-0.51699 * x₀))))                                                                        ---------------------------------------------------------------------------------------------------
# 9.7%┣████▍                                        ┫ 58/600 [00:01<00:06, 96it/s]Expressions evaluated per second: [.....]. Head worker occupation: 19.5%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.070e+05  1.594e+01  y = 100.32                                    2           9.031e+04  8.294e-01  y = square(-21.021)                           3           4.017e+03  3.113e+00  y = (17.928 * x₀)                             5           3.542e+03  6.283e-02  y = (17.928 * (x₀ + -0.75854))                6           1.596e+03  7.975e-01  y = square((-0.51558 * x₀) + -6.3974)         7           1.440e+03  1.027e-01  y = (x₀ * square(log(1.9568 * x₀)))           8           9.424e+02  4.240e-01  y = (x₀ * log(square(cube(-0.52083 * x₀))))   9           8.994e+02  4.664e-02  y = (x₀ * log(cube(x₀) * (x₀ * x₀)))          10          8.517e+02  5.451e-02  y = ((x₀ + 0.7219) * log(square(cube(-0.51699 * x₀))))                                                                        18          8.506e+02  1.570e-04  y = (x₀ * log(square(cube(0.38015 + (x₀ + 0.6377)) * (cube(0.8...                                                                                               822) + 0.018103)) * square(0.21418)))         ---------------------------------------------------------------------------------------------------
# 10.7%┣████▊                                       ┫ 64/600 [00:01<00:06, 96it/s]Expressions evaluated per second: [.....]. Head worker occupation: 19.5%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.070e+05  1.594e+01  y = 100.32                                    2           9.031e+04  8.294e-01  y = square(-21.021)                           3           4.017e+03  3.113e+00  y = (17.928 * x₀)                             5           3.542e+03  6.283e-02  y = (17.928 * (x₀ + -0.75854))                6           1.596e+03  7.975e-01  y = square((-0.51558 * x₀) + -6.3974)         7           1.440e+03  1.027e-01  y = (x₀ * square(log(1.9568 * x₀)))           8           9.424e+02  4.240e-01  y = (x₀ * log(square(cube(-0.52083 * x₀))))   9           8.994e+02  4.664e-02  y = (x₀ * log(cube(x₀) * (x₀ * x₀)))          10          8.517e+02  5.451e-02  y = ((x₀ + 0.7219) * log(square(cube(-0.51699 * x₀))))                                                                        18          8.506e+02  1.570e-04  y = (x₀ * log(square(cube(0.38015 + (x₀ + 0.6377)) * (cube(0.8...                                                                                               822) + 0.018103)) * square(0.21418)))         ---------------------------------------------------------------------------------------------------
# 11.3%┣█████                                       ┫ 68/600 [00:01<00:06, 92it/s]Expressions evaluated per second: [.....]. Head worker occupation: 18.3%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.031e+04  1.594e+01  y = 441.88                                    3           4.017e+03  1.556e+00  y = (17.928 * x₀)                             5           1.444e+03  5.116e-01  y = ((21.079 * x₀) + -106.15)                 7           1.440e+03  1.326e-03  y = (x₀ * square(log(1.9568 * x₀)))           8           9.424e+02  4.240e-01  y = (x₀ * log(square(cube(-0.52083 * x₀))))   9           8.994e+02  4.664e-02  y = (x₀ * log(cube(x₀) * (x₀ * x₀)))          10          8.517e+02  5.451e-02  y = ((x₀ + 0.7219) * log(square(cube(-0.51699 * x₀))))                                                                        18          8.506e+02  1.570e-04  y = (x₀ * log(square(cube(0.38015 + (x₀ + 0.6377)) * (cube(0.8...                                                                                               822) + 0.018103)) * square(0.21418)))         ---------------------------------------------------------------------------------------------------
# 11.8%┣█████▏                                      ┫ 71/600 [00:01<00:06, 87it/s]Expressions evaluated per second: [.....]. Head worker occupation: 17.5%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.031e+04  1.594e+01  y = 441.88                                    3           4.017e+03  1.556e+00  y = (17.928 * x₀)                             5           1.444e+03  5.116e-01  y = ((21.079 * x₀) + -106.15)                 7           1.440e+03  1.326e-03  y = (x₀ * square(log(1.9568 * x₀)))           8           9.424e+02  4.240e-01  y = (x₀ * log(square(cube(-0.52083 * x₀))))   9           8.994e+02  4.664e-02  y = (x₀ * log(cube(x₀) * (x₀ * x₀)))          10          8.517e+02  5.451e-02  y = ((x₀ + 0.7219) * log(square(cube(-0.51699 * x₀))))                                                                        12          8.514e+02  1.637e-04  y = ((x₀ + 0.7219) * log(square(cube(-0.51699 * x₀) + -0.14488...                                                                                               )))                                           13          8.510e+02  5.023e-04  y = ((x₀ + square(0.7219)) * log(square(cube(-0.51699 * (x₀ + ...                                                                                               0.54769)))))                                  18          8.506e+02  8.522e-05  y = (x₀ * log(square(cube(0.38015 + (x₀ + 0.6377)) * (cube(0.8...                                                                                               822) + 0.018103)) * square(0.21418)))         ---------------------------------------------------------------------------------------------------
# 12.8%┣█████▋                                      ┫ 77/600 [00:01<00:06, 83it/s]Expressions evaluated per second: [.....]. Head worker occupation: 16.7%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.031e+04  1.594e+01  y = 441.88                                    3           4.017e+03  1.556e+00  y = (17.928 * x₀)                             5           1.444e+03  5.116e-01  y = ((21.079 * x₀) + -106.15)                 7           1.440e+03  1.326e-03  y = (x₀ * square(log(1.9568 * x₀)))           8           9.424e+02  4.240e-01  y = (x₀ * log(square(cube(-0.52083 * x₀))))   9           8.994e+02  4.664e-02  y = (x₀ * log(cube(x₀) * (x₀ * x₀)))          10          8.517e+02  5.451e-02  y = ((x₀ + 0.7219) * log(square(cube(-0.51699 * x₀))))                                                                        12          8.506e+02  6.413e-04  y = (x₀ * log(square(cube(0.53254 * (x₀ + 1.0125))) + x₀))                                                                    ---------------------------------------------------------------------------------------------------
# 13.8%┣██████                                      ┫ 83/600 [00:01<00:06, 85it/s]Expressions evaluated per second: [.....]. Head worker occupation: 16.8%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.031e+04  1.594e+01  y = 441.88                                    3           4.017e+03  1.556e+00  y = (17.928 * x₀)                             5           1.444e+03  5.116e-01  y = ((21.079 * x₀) + -106.15)                 7           1.440e+03  1.326e-03  y = (x₀ * square(log(1.9568 * x₀)))           8           8.994e+02  4.706e-01  y = (x₀ * log(cube(x₀) * square(x₀)))         10          8.517e+02  2.725e-02  y = ((x₀ + 0.7219) * log(square(cube(-0.51699 * x₀))))                                                                        12          8.506e+02  6.413e-04  y = (x₀ * log(square(cube(0.53254 * (x₀ + 1.0125))) + x₀))                                                                    ---------------------------------------------------------------------------------------------------
# 15.0%┣██████▋                                     ┫ 90/600 [00:01<00:06, 86it/s]Expressions evaluated per second: 2.54e+05. Head worker occupation: 17.0%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.031e+04  1.594e+01  y = 441.88                                    3           4.017e+03  1.556e+00  y = (17.928 * x₀)                             5           1.444e+03  5.116e-01  y = ((21.079 * x₀) + -106.15)                 7           1.440e+03  1.326e-03  y = (x₀ * square(log(1.9568 * x₀)))           8           8.994e+02  4.706e-01  y = (x₀ * log(cube(x₀) * square(x₀)))         10          8.517e+02  2.725e-02  y = ((x₀ + 0.7219) * log(square(cube(-0.51699 * x₀))))                                                                        12          8.506e+02  6.413e-04  y = (x₀ * log(square(cube(0.53254 * (x₀ + 1.0125))) + x₀))                                                                    14          8.500e+02  3.777e-04  y = ((x₀ + 0.7219) * log(square(cube(-0.51699 * x₀) + (-0.1448...                                                                                               8 + -1.8278))))                               15          8.497e+02  2.728e-04  y = ((x₀ + 0.63888) * log(square(cube(-0.52006 * x₀) + -3.1068...                                                                                               ) + square(x₀)))                              ---------------------------------------------------------------------------------------------------
# 15.8%┣███████                                     ┫ 95/600 [00:01<00:06, 86it/s]Expressions evaluated per second: 2.54e+05. Head worker occupation: 16.8%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.031e+04  1.594e+01  y = 441.88                                    3           4.017e+03  1.556e+00  y = (17.928 * x₀)                             5           1.444e+03  5.116e-01  y = ((21.079 * x₀) + -106.15)                 7           1.440e+03  1.326e-03  y = (x₀ * square(log(1.9568 * x₀)))           8           8.580e+02  5.178e-01  y = (x₀ * log(square(cube(-0.5485 * x₀))))    10          8.517e+02  3.668e-03  y = ((x₀ + 0.7219) * log(square(cube(-0.51699 * x₀))))                                                                        12          8.506e+02  6.413e-04  y = (x₀ * log(square(cube(0.53254 * (x₀ + 1.0125))) + x₀))                                                                    14          8.500e+02  3.777e-04  y = ((x₀ + 0.7219) * log(square(cube(-0.51699 * x₀) + (-0.1448...                                                                                               8 + -1.8278))))                               15          8.497e+02  2.728e-04  y = ((x₀ + 0.63888) * log(square(cube(-0.52006 * x₀) + -3.1068...                                                                                               ) + square(x₀)))                              ---------------------------------------------------------------------------------------------------
# 17.2%┣███████▍                                   ┫ 103/600 [00:01<00:06, 88it/s]Expressions evaluated per second: 2.54e+05. Head worker occupation: 17.1%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.031e+04  1.594e+01  y = 441.88                                    3           4.017e+03  1.556e+00  y = (17.928 * x₀)                             5           1.444e+03  5.116e-01  y = ((21.079 * x₀) + -106.15)                 7           1.440e+03  1.326e-03  y = (x₀ * square(log(1.9568 * x₀)))           8           8.580e+02  5.178e-01  y = (x₀ * log(square(cube(-0.5485 * x₀))))    10          8.506e+02  4.315e-03  y = ((x₀ * log(square(cube(0.53337 * x₀)))) + 5.6518)                                                                         14          8.500e+02  1.859e-04  y = ((x₀ + 0.7219) * log(square(cube(-0.51699 * x₀) + (-0.1448...                                                                                               8 + -1.8278))))                               15          8.497e+02  2.728e-04  y = ((x₀ + 0.63888) * log(square(cube(-0.52006 * x₀) + -3.1068...                                                                                               ) + square(x₀)))                              ---------------------------------------------------------------------------------------------------
# 18.3%┣███████▉                                   ┫ 110/600 [00:01<00:05, 89it/s]Expressions evaluated per second: 2.54e+05. Head worker occupation: 18.1%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.031e+04  1.594e+01  y = 441.88                                    3           4.017e+03  1.556e+00  y = (17.928 * x₀)                             5           1.444e+03  5.116e-01  y = ((21.079 * x₀) + -106.15)                 7           1.440e+03  1.326e-03  y = (x₀ * square(log(1.9568 * x₀)))           8           8.580e+02  5.178e-01  y = (x₀ * log(square(cube(-0.5485 * x₀))))    10          8.506e+02  4.315e-03  y = ((x₀ * log(square(cube(0.53337 * x₀)))) + 5.6518)                                                                         14          8.500e+02  1.859e-04  y = ((x₀ + 0.7219) * log(square(cube(-0.51699 * x₀) + (-0.1448...                                                                                               8 + -1.8278))))                               15          8.497e+02  2.728e-04  y = ((x₀ + 0.63888) * log(square(cube(-0.52006 * x₀) + -3.1068...                                                                                               ) + square(x₀)))                              ---------------------------------------------------------------------------------------------------
# 18.8%┣████████                                   ┫ 113/600 [00:01<00:06, 86it/s]Expressions evaluated per second: 2.54e+05. Head worker occupation: 18.7%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.031e+04  1.594e+01  y = 441.88                                    3           4.017e+03  1.556e+00  y = (17.928 * x₀)                             5           1.444e+03  5.116e-01  y = ((21.079 * x₀) + -106.15)                 7           1.440e+03  1.326e-03  y = (x₀ * square(log(1.9568 * x₀)))           8           8.580e+02  5.178e-01  y = (x₀ * log(square(cube(-0.5485 * x₀))))    10          8.506e+02  4.315e-03  y = ((x₀ * log(square(cube(0.53337 * x₀)))) + 5.6518)                                                                         13          8.499e+02  2.648e-04  y = ((x₀ + 0.7219) * log(square(cube(-0.51699 * x₀)) + cube(x₀...                                                                                               )))                                           15          8.497e+02  1.111e-04  y = ((x₀ + 0.63888) * log(square(cube(-0.52006 * x₀) + -3.1068...                                                                                               ) + square(x₀)))                              ---------------------------------------------------------------------------------------------------
# 19.8%┣████████▌                                  ┫ 119/600 [00:01<00:06, 87it/s]Expressions evaluated per second: 2.54e+05. Head worker occupation: 18.6%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.031e+04  1.594e+01  y = 441.88                                    3           4.017e+03  1.556e+00  y = (17.928 * x₀)                             5           1.444e+03  5.116e-01  y = ((21.079 * x₀) + -106.15)                 7           1.440e+03  1.326e-03  y = (x₀ * square(log(1.9568 * x₀)))           8           8.580e+02  5.178e-01  y = (x₀ * log(square(cube(-0.5485 * x₀))))    10          8.506e+02  4.315e-03  y = ((x₀ * log(square(cube(0.53337 * x₀)))) + 5.6518)                                                                         13          8.499e+02  2.648e-04  y = ((x₀ + 0.7219) * log(square(cube(-0.51699 * x₀)) + cube(x₀...                                                                                               )))                                           15          8.497e+02  1.111e-04  y = ((x₀ + 0.63888) * log(square(cube(-0.52006 * x₀) + -3.1068...                                                                                               ) + square(x₀)))                              ---------------------------------------------------------------------------------------------------
# 21.3%┣█████████▏                                 ┫ 128/600 [00:01<00:05, 89it/s]Expressions evaluated per second: 2.54e+05. Head worker occupation: 18.9%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.031e+04  1.594e+01  y = 441.88                                    3           4.017e+03  1.556e+00  y = (17.928 * x₀)                             5           1.444e+03  5.116e-01  y = ((21.079 * x₀) + -106.15)                 7           1.440e+03  1.326e-03  y = (x₀ * square(log(1.9568 * x₀)))           8           8.580e+02  5.178e-01  y = (x₀ * log(square(cube(-0.5485 * x₀))))    10          8.506e+02  4.315e-03  y = ((x₀ * log(square(cube(0.53337 * x₀)))) + 5.6518)                                                                         13          8.499e+02  2.648e-04  y = ((x₀ + 0.7219) * log(square(cube(-0.51699 * x₀)) + cube(x₀...                                                                                               )))                                           15          8.497e+02  1.111e-04  y = ((x₀ + 0.63888) * log(square(cube(-0.52006 * x₀) + -3.1068...                                                                                               ) + square(x₀)))                              ---------------------------------------------------------------------------------------------------
# 22.2%┣█████████▌                                 ┫ 133/600 [00:01<00:05, 89it/s]Expressions evaluated per second: 2.54e+05. Head worker occupation: 18.7%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.031e+04  1.594e+01  y = 441.88                                    3           4.017e+03  1.556e+00  y = (17.928 * x₀)                             5           1.444e+03  5.116e-01  y = ((21.079 * x₀) + -106.15)                 7           1.440e+03  1.326e-03  y = (x₀ * square(log(1.9568 * x₀)))           8           8.580e+02  5.178e-01  y = (x₀ * log(square(cube(-0.5485 * x₀))))    10          8.506e+02  4.315e-03  y = ((x₀ * log(square(cube(0.53337 * x₀)))) + 5.6518)                                                                         13          8.499e+02  2.648e-04  y = ((x₀ + 0.7219) * log(square(cube(-0.51699 * x₀)) + cube(x₀...                                                                                               )))                                           15          8.497e+02  1.111e-04  y = ((x₀ + 0.63888) * log(square(cube(-0.52006 * x₀) + -3.1068...                                                                                               ) + square(x₀)))                              ---------------------------------------------------------------------------------------------------
# 23.3%┣██████████                                 ┫ 140/600 [00:02<00:05, 90it/s]Expressions evaluated per second: 2.54e+05. Head worker occupation: 18.8%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.031e+04  1.594e+01  y = 441.88                                    3           4.017e+03  1.556e+00  y = (17.928 * x₀)                             5           1.444e+03  5.116e-01  y = ((21.079 * x₀) + -106.15)                 7           1.440e+03  1.326e-03  y = (x₀ * square(log(1.9568 * x₀)))           8           8.580e+02  5.178e-01  y = (x₀ * log(square(cube(-0.5485 * x₀))))    10          8.506e+02  4.315e-03  y = ((x₀ * log(square(cube(0.53337 * x₀)))) + 5.6518)                                                                         13          8.499e+02  2.648e-04  y = ((x₀ + 0.7219) * log(square(cube(-0.51699 * x₀)) + cube(x₀...                                                                                               )))                                           15          8.497e+02  1.111e-04  y = ((x₀ + 0.63888) * log(square(cube(-0.52006 * x₀) + -3.1068...                                                                                               ) + square(x₀)))                              ---------------------------------------------------------------------------------------------------
# 24.7%┣██████████▋                                ┫ 148/600 [00:02<00:05, 92it/s]Expressions evaluated per second: 2.54e+05. Head worker occupation: 19.2%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.031e+04  1.594e+01  y = 441.88                                    3           4.017e+03  1.556e+00  y = (17.928 * x₀)                             5           1.444e+03  5.116e-01  y = ((21.079 * x₀) + -106.15)                 7           1.440e+03  1.326e-03  y = (x₀ * square(log(1.9568 * x₀)))           8           8.580e+02  5.178e-01  y = (x₀ * log(square(cube(-0.5485 * x₀))))    10          8.506e+02  4.315e-03  y = ((x₀ * log(square(cube(0.53337 * x₀)))) + 5.6518)                                                                         12          8.506e+02  2.781e-05  y = ((x₀ * log(square(cube(0.53337 * x₀)) + x₀)) + 5.6518)                                                                    13          8.499e+02  7.387e-04  y = ((x₀ + 0.7219) * log(square(cube(-0.51699 * x₀)) + cube(x₀...                                                                                               )))                                           15          8.497e+02  1.111e-04  y = ((x₀ + 0.63888) * log(square(cube(-0.52006 * x₀) + -3.1068...                                                                                               ) + square(x₀)))                              ---------------------------------------------------------------------------------------------------
# 25.5%┣███████████                                ┫ 153/600 [00:02<00:05, 92it/s]Expressions evaluated per second: 2.54e+05. Head worker occupation: 19.0%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.031e+04  1.594e+01  y = 441.88                                    3           4.017e+03  1.556e+00  y = (17.928 * x₀)                             5           1.444e+03  5.116e-01  y = ((21.079 * x₀) + -106.15)                 7           1.440e+03  1.326e-03  y = (x₀ * square(log(1.9568 * x₀)))           8           8.580e+02  5.178e-01  y = (x₀ * log(square(cube(-0.5485 * x₀))))    10          8.506e+02  4.315e-03  y = ((x₀ * log(square(cube(0.53337 * x₀)))) + 5.6518)                                                                         12          8.506e+02  2.781e-05  y = ((x₀ * log(square(cube(0.53337 * x₀)) + x₀)) + 5.6518)                                                                    13          8.499e+02  7.387e-04  y = ((x₀ + 0.7219) * log(square(cube(-0.51699 * x₀)) + cube(x₀...                                                                                               )))                                           15          8.497e+02  1.111e-04  y = ((x₀ + 0.63888) * log(square(cube(-0.52006 * x₀) + -3.1068...                                                                                               ) + square(x₀)))                              ---------------------------------------------------------------------------------------------------
# ...
# 95.2%┣█████████████████████████████████████████  ┫ 571/600 [00:07<00:00, 87it/s]Expressions evaluated per second: 2.33e+05. Head worker occupation: 22.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.031e+04  1.594e+01  y = 441.9                                     3           8.208e+04  4.779e-02  y = (x₀ + 415.89)                             4           5.892e+04  3.315e-01  y = cube(log(square(x₀)))                     5           3.526e+04  5.133e-01  y = square(x₀ + cube(-2.3546))                6           1.081e+04  1.182e+00  y = cube(log(square(x₀)) + 1.4001)            7           1.824e+03  1.780e+00  y = cube(log(square(square(x₀))) + -5.6416)   9           8.758e+02  3.667e-01  y = cube(log(square(square(x₀) + 81.465)) + -5.7866)                                                                          11          8.657e+02  5.806e-03  y = cube(log(square(square(x₀ + 0.57816) + 73.149)) + -5.8301)                                                                13          8.621e+02  2.038e-03  y = (cube(log(square((square(x₀) + 77.141) + x₀)) + -5.9962) +...                                                                                                x₀)                                          15          8.587e+02  2.005e-03  y = ((cube(log(square((square(x₀) + x₀) + 78.724)) + -6.1703) ...                                                                                               + x₀) + x₀)                                   17          8.573e+02  8.045e-04  y = (cube(log(square((square(x₀ + 0.63135) + (x₀ + 62.683)) + ...                                                                                               x₀)) + -6.0867) + x₀)                         19          8.573e+02  1.860e-05  y = (cube(log(square((square(x₀ + 0.63135) + (x₀ + 62.683)) + ...                                                                                               (x₀ + -0.30005))) + -6.0867) + x₀)            20          8.569e+02  4.348e-04  y = ((((cube(log(square((square(x₀) + x₀) + 78.724)) + -6.1703...                                                                                               ) + log(x₀)) + x₀) + -2.7382) + x₀)           ---------------------------------------------------------------------------------------------------
# 96.3%┣█████████████████████████████████████████▍ ┫ 578/600 [00:07<00:00, 87it/s]Expressions evaluated per second: 2.33e+05. Head worker occupation: 22.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.031e+04  1.594e+01  y = 441.9                                     3           8.208e+04  4.779e-02  y = (x₀ + 415.89)                             4           5.892e+04  3.315e-01  y = cube(log(square(x₀)))                     5           3.526e+04  5.133e-01  y = square(x₀ + cube(-2.3546))                6           1.081e+04  1.182e+00  y = cube(log(square(x₀)) + 1.4001)            7           1.824e+03  1.780e+00  y = cube(log(square(square(x₀))) + -5.6416)   9           8.758e+02  3.667e-01  y = cube(log(square(square(x₀) + 81.465)) + -5.7866)                                                                          11          8.657e+02  5.806e-03  y = cube(log(square(square(x₀ + 0.57816) + 73.149)) + -5.8301)                                                                13          8.621e+02  2.038e-03  y = (cube(log(square((square(x₀) + 77.141) + x₀)) + -5.9962) +...                                                                                                x₀)                                          15          8.587e+02  2.005e-03  y = ((cube(log(square((square(x₀) + x₀) + 78.724)) + -6.1703) ...                                                                                               + x₀) + x₀)                                   17          8.573e+02  8.045e-04  y = (cube(log(square((square(x₀ + 0.63135) + (x₀ + 62.683)) + ...                                                                                               x₀)) + -6.0867) + x₀)                         19          8.562e+02  6.472e-04  y = ((cube(log(square((square(x₀) + cube(log(x₀))) + 78.724)) ...                                                                                               + -6.1703) + x₀) + (x₀ + -1.1582))            ---------------------------------------------------------------------------------------------------
# 97.3%┣█████████████████████████████████████████▉ ┫ 584/600 [00:07<00:00, 87it/s]Expressions evaluated per second: 2.33e+05. Head worker occupation: 22.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.031e+04  1.594e+01  y = 441.9                                     3           8.208e+04  4.779e-02  y = (x₀ + 415.89)                             4           5.892e+04  3.315e-01  y = cube(log(square(x₀)))                     5           3.526e+04  5.133e-01  y = square(x₀ + cube(-2.3546))                6           1.081e+04  1.182e+00  y = cube(log(square(x₀)) + 1.4001)            7           1.824e+03  1.780e+00  y = cube(log(square(square(x₀))) + -5.6416)   9           8.758e+02  3.667e-01  y = cube(log(square(square(x₀) + 81.465)) + -5.7866)                                                                          11          8.657e+02  5.806e-03  y = cube(log(square(square(x₀ + 0.57816) + 73.149)) + -5.8301)                                                                13          8.621e+02  2.038e-03  y = (cube(log(square((square(x₀) + 77.141) + x₀)) + -5.9962) +...                                                                                                x₀)                                          15          8.587e+02  2.005e-03  y = ((cube(log(square((square(x₀) + x₀) + 78.724)) + -6.1703) ...                                                                                               + x₀) + x₀)                                   17          8.573e+02  8.045e-04  y = (cube(log(square((square(x₀ + 0.63135) + (x₀ + 62.683)) + ...                                                                                               x₀)) + -6.0867) + x₀)                         19          8.562e+02  6.472e-04  y = ((cube(log(square((square(x₀) + cube(log(x₀))) + 78.724)) ...                                                                                               + -6.1703) + x₀) + (x₀ + -1.1582))            ---------------------------------------------------------------------------------------------------
# 98.5%┣██████████████████████████████████████████▍┫ 591/600 [00:07<00:00, 87it/s]Expressions evaluated per second: 2.33e+05. Head worker occupation: 22.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.031e+04  1.594e+01  y = 441.9                                     3           8.208e+04  4.779e-02  y = (x₀ + 415.89)                             4           5.892e+04  3.315e-01  y = cube(log(square(x₀)))                     5           3.526e+04  5.133e-01  y = square(x₀ + cube(-2.3546))                6           1.081e+04  1.182e+00  y = cube(log(square(x₀)) + 1.4001)            7           1.824e+03  1.780e+00  y = cube(log(square(square(x₀))) + -5.6416)   9           8.758e+02  3.667e-01  y = cube(log(square(square(x₀) + 81.473)) + -5.7865)                                                                          11          8.657e+02  5.806e-03  y = cube(log(square(square(x₀ + 0.57816) + 73.149)) + -5.8301)                                                                13          8.621e+02  2.038e-03  y = (cube(log(square((square(x₀) + 77.141) + x₀)) + -5.9962) +...                                                                                                x₀)                                          15          8.587e+02  2.005e-03  y = ((cube(log(square((square(x₀) + x₀) + 78.724)) + -6.1703) ...                                                                                               + x₀) + x₀)                                   17          8.573e+02  8.045e-04  y = (cube(log(square((square(x₀ + 0.63135) + (x₀ + 62.683)) + ...                                                                                               x₀)) + -6.0867) + x₀)                         19          8.562e+02  6.472e-04  y = ((cube(log(square((square(x₀) + cube(log(x₀))) + 78.724)) ...                                                                                               + -6.1703) + x₀) + (x₀ + -1.1582))            ---------------------------------------------------------------------------------------------------
# 99.2%┣██████████████████████████████████████████▋┫ 595/600 [00:07<00:00, 87it/s]Expressions evaluated per second: 2.33e+05. Head worker occupation: 22.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.031e+04  1.594e+01  y = 441.9                                     3           8.208e+04  4.779e-02  y = (x₀ + 415.89)                             4           5.892e+04  3.315e-01  y = cube(log(square(x₀)))                     5           3.526e+04  5.133e-01  y = square(x₀ + cube(-2.3546))                6           1.081e+04  1.182e+00  y = cube(log(square(x₀)) + 1.4001)            7           1.824e+03  1.780e+00  y = cube(log(square(square(x₀))) + -5.6416)   9           8.758e+02  3.667e-01  y = cube(log(square(square(x₀) + 81.473)) + -5.7865)                                                                          11          8.657e+02  5.806e-03  y = cube(log(square(square(x₀ + 0.57816) + 73.149)) + -5.8301)                                                                13          8.621e+02  2.038e-03  y = (cube(log(square((square(x₀) + 77.141) + x₀)) + -5.9962) +...                                                                                                x₀)                                          15          8.587e+02  2.005e-03  y = ((cube(log(square((square(x₀) + x₀) + 78.724)) + -6.1703) ...                                                                                               + x₀) + x₀)                                   17          8.573e+02  8.045e-04  y = (cube(log(square((square(x₀ + 0.63135) + (x₀ + 62.683)) + ...                                                                                               x₀)) + -6.0867) + x₀)                         19          8.562e+02  6.472e-04  y = ((cube(log(square((square(x₀) + cube(log(x₀))) + 78.724)) ...                                                                                               + -6.1703) + x₀) + (x₀ + -1.1582))            ---------------------------------------------------------------------------------------------------
# 99.7%┣██████████████████████████████████████████▉┫ 598/600 [00:07<00:00, 86it/s]Expressions evaluated per second: 2.33e+05. Head worker occupation: 21.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.031e+04  1.594e+01  y = 441.9                                     3           8.208e+04  4.779e-02  y = (x₀ + 415.89)                             4           5.892e+04  3.315e-01  y = cube(log(square(x₀)))                     5           3.526e+04  5.133e-01  y = square(x₀ + cube(-2.3546))                6           1.081e+04  1.182e+00  y = cube(log(square(x₀)) + 1.4001)            7           1.824e+03  1.780e+00  y = cube(log(square(square(x₀))) + -5.6416)   9           8.758e+02  3.667e-01  y = cube(log(square(square(x₀) + 81.473)) + -5.7865)                                                                          11          8.657e+02  5.806e-03  y = cube(log(square(square(x₀ + 0.57816) + 73.149)) + -5.8301)                                                                13          8.621e+02  2.038e-03  y = (cube(log(square((square(x₀) + 77.141) + x₀)) + -5.9962) +...                                                                                                x₀)                                          15          8.587e+02  2.005e-03  y = ((cube(log(square((square(x₀) + x₀) + 78.724)) + -6.1703) ...                                                                                               + x₀) + x₀)                                   17          8.573e+02  8.045e-04  y = (cube(log(square((square(x₀ + 0.63135) + (x₀ + 62.683)) + ...                                                                                               x₀)) + -6.0867) + x₀)                         18          8.573e+02  3.696e-05  y = ((cube(log(square((square(x₀) + 76.335) + x₀)) + -6.1842) ...                                                                                               + (log(x₀) + x₀)) + x₀)                       19          8.562e+02  1.257e-03  y = ((cube(log(square((square(x₀) + cube(log(x₀))) + 78.724)) ...                                                                                               + -6.1703) + x₀) + (x₀ + -1.1582))            ---------------------------------------------------------------------------------------------------

# %%
registros_ = registros
file_pickle = 'dados_v2.pck'

# %%
for i in registros_:
  loss = i[1]
  score = i[2]
  complexity = i[0]
  w = (loss * score)/complexity
  if math.isnan(w):
    i.append(0)
  else:
    i.append(w)

lista_melhor_valor = max(registros_, key=lambda x: x[6])

# %% [markdown]
# ## Save result

# %%
def salvar_dados(dados, key, arquivo):
  if os.path.exists(arquivo):
    with open(arquivo, 'rb') as f:
      dados_exist = pickle.load(f)
  else:
    dados_exist = {}
    
  valor_original = dados_exist.get(key)
  if valor_original == None:
    dados_exist.update({key: [dados]})
  else:
    if isinstance(valor_original, list):
      valor_original.append(dados)
    else:
      dados_exist.update({key: [dados]})

  with open(arquivo, 'wb') as f:
    pickle.dump(dados_exist, f)
  
caminho_arquivo = file_pickle
novos_dados = lista_melhor_valor[0:3] + [lista_melhor_valor[4]]

salvar_dados(novos_dados, 'shellsort_NlogN', caminho_arquivo)

# %%
def carregar_dados(arquivo):
    # Carrega os dados do arquivo pickle
    with open(arquivo, 'rb') as f:
        dados = pickle.load(f)
    return dados

caminho_arquivo = file_pickle
dados_carregados = carregar_dados(caminho_arquivo)

print("Conteúdo do arquivo pickle:")
for k, v in dados_carregados.items():
  print(k,v)
  print('\u25CF', k)
  for index, item in enumerate(v):
    if index == len(v)-1:
       print('└─', item)
    else:
      print('├─', item)
  print('==========================')
# Out:
# Conteúdo do arquivo pickle:
# binary_search_logx [[6, 1.2914093, 1.37589542429269, log(x0**6) + 5.574131], [5, 1.5291592, 2.19479656667366, log(x0)**2 + 13.966276]]
# ● binary_search_logx
# ├─ [6, 1.2914093, 1.37589542429269, log(x0**6) + 5.574131]
# └─ [5, 1.5291592, 2.19479656667366, log(x0)**2 + 13.966276]
# ==========================
# boyer_moore_M_plus_N [[9, 1729031400.0, 0.1972007458935316, 752018330.701125*(0.00603869219560025*x0 + 0.00603869219560025*x1 - 1)**4 + 601415.75], [5, 15754614000.0, 0.3055240605113849, 3621132.2 - 28185.828*x1]]
# ● boyer_moore_M_plus_N
# ├─ [9, 1729031400.0, 0.1972007458935316, 752018330.701125*(0.00603869219560025*x0 + 0.00603869219560025*x1 - 1)**4 + 601415.75]
# └─ [5, 15754614000.0, 0.3055240605113849, 3621132.2 - 28185.828*x1]
# ==========================
# bubblesort_N^2 [[4, 5910.4966, 3.4645076652491285, 1.5253483*x0**2], [4, 8542.308, 3.303255717418494, 1.5552218*x0**2]]
# ● bubblesort_N^2
# ├─ [4, 5910.4966, 3.4645076652491285, 1.5253483*x0**2]
# └─ [4, 8542.308, 3.303255717418494, 1.5552218*x0**2]
# ==========================
# fibonacci_interative_N [[3, 0.20818244, 3.412549040667958, 2.058653*x0], [3, 0.20818244, 3.412549040667958, 2.058653*x0]]
# ● fibonacci_interative_N
# ├─ [3, 0.20818244, 3.412549040667958, 2.058653*x0]
# └─ [3, 0.20818244, 3.412549040667958, 2.058653*x0]
# ==========================
# fibonacci_recursive_2^N [[15, 111113150.0, 0.37865996607381686, x0**4*(0.0022606994*x0**2 - 0.714783)], [15, 77371830.0, 0.38657145558895856, x0**2*(x0**2*(0.16452532*x0 - 3.8766947) + 297.9323)]]
# ● fibonacci_recursive_2^N
# ├─ [15, 111113150.0, 0.37865996607381686, x0**4*(0.0022606994*x0**2 - 0.714783)]
# └─ [15, 77371830.0, 0.38657145558895856, x0**2*(x0**2*(0.16452532*x0 - 3.8766947) + 297.9323)]
# ==========================
# heapsort_NlogN [[9, 0.24989581, 1.1851428541960574, 4*x0 - 1.4897935], [9, 0.24989575, 1.185128414350167, 4*x0 - 1.4897884]]
# ● heapsort_NlogN
# ├─ [9, 0.24989581, 1.1851428541960574, 4*x0 - 1.4897935]
# └─ [9, 0.24989575, 1.185128414350167, 4*x0 - 1.4897884]
# ==========================
# insertionsort_N^2 [[4, 12514.81, 0.5204699193332855, 7.19343672459889*(0.372847972767781*x0 - 1)**2], [4, 11070.262, 0.6554198140129509, 9.54380044013764*(0.323697485019442*x0 - 1)**2]]
# ● insertionsort_N^2
# ├─ [4, 12514.81, 0.5204699193332855, 7.19343672459889*(0.372847972767781*x0 - 1)**2]
# └─ [4, 11070.262, 0.6554198140129509, 9.54380044013764*(0.323697485019442*x0 - 1)**2]
# ==========================
# tower_hanoi_2^N [[13, 4607.291, 0.98801217824901, 0.0050468594*x0**6], [13, 4607.2915, 0.988012078856794, 0.005046889*x0**6]]
# ● tower_hanoi_2^N
# ├─ [13, 4607.291, 0.98801217824901, 0.0050468594*x0**6]
# └─ [13, 4607.2915, 0.988012078856794, 0.005046889*x0**6]
# ==========================
# karatsuba_N^1.585 [[4, 535.7578, 1.123614036379079, 3.66931686122521*x0**2]]
# ● karatsuba_N^1.585
# └─ [4, 535.7578, 1.123614036379079, 3.66931686122521*x0**2]
# ==========================
# levenshtein_distance_MN [[4, 1058.5413, 9.647410674646242, 3.52554060674929*x1**2]]
# ● levenshtein_distance_MN
# └─ [4, 1058.5413, 9.647410674646242, 3.52554060674929*x1**2]
# ==========================
# linear_search_x [[14, 0.26546365, 0.9472618119882181, x0*log(log(log(1.97671752435621e-50*x0**18)**2))]]
# ● linear_search_x
# └─ [14, 0.26546365, 0.9472618119882181, x0*log(log(log(1.97671752435621e-50*x0**18)**2))]
# ==========================
# mergesort_NlogN [[8, 40.208347, 0.542941641791251, (log(x0 + 4.4829993)**2 + 0.71281224)**2]]
# ● mergesort_NlogN
# └─ [8, 40.208347, 0.542941641791251, (log(x0 + 4.4829993)**2 + 0.71281224)**2]
# ==========================
# quicksort_x^2 [[5, 4191.8745, 0.5370400329213452, 31.022936*x0 - 114.24918]]
# ● quicksort_x^2
# └─ [5, 4191.8745, 0.5370400329213452, 31.022936*x0 - 114.24918]
# ==========================
# selectsort_N^2 [[7, 492.61688, 0.8252641931074596, 0.91222733*x0*log(x0)**3]]
# ● selectsort_N^2
# └─ [7, 492.61688, 0.8252641931074596, 0.91222733*x0*log(x0)**3]
# ==========================
# shellsort_NlogN [[6, 2333.781, 2.6158456057911406, 9.6421651223277*(0.469831154898539*log(x0**3) - 1)**3], [6, 899.3794, 1.4964888960073477, 5.0019417*x0*log(x0)]]
# ● shellsort_NlogN
# ├─ [6, 2333.781, 2.6158456057911406, 9.6421651223277*(0.469831154898539*log(x0**3) - 1)**3]
# └─ [6, 899.3794, 1.4964888960073477, 5.0019417*x0*log(x0)]
# ==========================
# strassen_N^2.81 [[9, 31317.309, 0.2847589231536684, log(2407.45008008753*(0.0372501681530186*(0.817895287156492*x0 + 1)**3 - 1)**2)**3], [9, 33064.902, 0.11522887698339954, 1.80036936911294*(0.82201446811225*log(225.511129952784*(0.066591072481186*x0**3 - 1)**2) + 1)**3]]
# ● strassen_N^2.81
# ├─ [9, 31317.309, 0.2847589231536684, log(2407.45008008753*(0.0372501681530186*(0.817895287156492*x0 + 1)**3 - 1)**2)**3]
# └─ [9, 33064.902, 0.11522887698339954, 1.80036936911294*(0.82201446811225*log(225.511129952784*(0.066591072481186*x0**3 - 1)**2) + 1)**3]
# ==========================
