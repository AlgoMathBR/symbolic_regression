# %%
# https://www.geeksforgeeks.org/python-program-to-print-the-fibonacci-sequence/?ref=header_search

import numpy as np
from line_profiler import LineProfiler
from pysr import PySRRegressor
import os
import sys
import math
import pickle

# %% [markdown]
# ## Fibonacci Interative Algorithm

# %%
def fibonacci_interative(n): # N
  fib = [0, 1]
  for i in range(2, n+1):
    fib.append(fib[i-1] + fib[i-2])
  return fib[n]

# %% [markdown]
# ## Frequency Count Method

# %%
X_y = []
i=25
for n in range(2,i+1):
  lprofiler = LineProfiler()
  lp_wrapper = lprofiler(fibonacci_interative)

  lp_wrapper(n)

  stats = lprofiler.get_stats()
  line_numbers = []
  hits = []

  for line in stats.timings.values():
    for i in line:
      line_numbers.append(i[0])
      hits.append(i[1])

  X_y.append([n, sum(hits)])

dados = np.array(X_y)

X = dados[:, 0]
y = dados[:, 1]
X_reshaped = X.reshape(-1, 1)

# %%
resultados_com_menor_loss = []
repeat = 5
registros = []

original_stdout = sys.stdout

with open(os.devnull, 'w') as devnull:
  sys.stdout = devnull

  for i in range(repeat):

    # first combination
    reg1 = PySRRegressor(
      binary_operators=["*", "+"],
      unary_operators=[],
    )

    fit1 = reg1.fit(X_reshaped, y)
    best_program1 = fit1.get_best()

    registro1 = []
    for index, value in enumerate(best_program1):
      registro1.append(value)
      
    registros.append(registro1)

    # second combination
    reg2 = PySRRegressor(
      binary_operators=["*"],
      unary_operators=[],
    )

    fit2 = reg2.fit(X_reshaped, y)
    best_program2 = fit2.get_best()

    registro2 = []
    for index, value in enumerate(best_program2):
      registro2.append(value)
    registros.append(registro2)

    # third combinarion
    reg3 = PySRRegressor(
      binary_operators=["+"],
      unary_operators=[],
    )

    fit3 = reg3.fit(X_reshaped, y)
    best_program3 = fit3.get_best()

    registro3 = []
    for index, value in enumerate(best_program3):
      registro3.append(value)
    registros.append(registro3)
    
sys.stdout = original_stdout
# Out:
# [ Info: Started!
# 0.0%┣                                              ┫ 0/600 [00:00<00:-5, -0s/it]Expressions evaluated per second: [.....]. Head worker occupation: 0.0%         Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.582e+02  1.594e+01  y = x₀                                        3           1.000e+00  2.777e+00  y = (x₀ + x₀)                                 5           1.138e-03  3.389e+00  y = ((1.0337 + x₀) + x₀)                      ---------------------------------------------------------------------------------------------------
# 0.8%┣▍                                             ┫ 5/600 [00:00<00:14, 42it/s]Expressions evaluated per second: [.....]. Head worker occupation: 25.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.582e+02  1.594e+01  y = x₀                                        3           1.000e+00  2.777e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 1.5%┣▊                                             ┫ 9/600 [00:00<00:12, 51it/s]Expressions evaluated per second: [.....]. Head worker occupation: 15.1%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.582e+02  1.594e+01  y = x₀                                        3           1.000e+00  2.777e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 2.3%┣█                                            ┫ 14/600 [00:00<00:09, 62it/s]Expressions evaluated per second: [.....]. Head worker occupation: 16.8%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.582e+02  1.594e+01  y = x₀                                        3           1.000e+00  2.777e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 3.2%┣█▍                                           ┫ 19/600 [00:00<00:09, 65it/s]Expressions evaluated per second: [.....]. Head worker occupation: 19.5%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 4.0%┣█▉                                           ┫ 24/600 [00:00<00:08, 69it/s]Expressions evaluated per second: [.....]. Head worker occupation: 21.5%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 5.0%┣██▎                                          ┫ 30/600 [00:00<00:08, 74it/s]Expressions evaluated per second: [.....]. Head worker occupation: 23.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 5.5%┣██▌                                          ┫ 33/600 [00:00<00:08, 71it/s]Expressions evaluated per second: [.....]. Head worker occupation: 25.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 6.5%┣███                                          ┫ 39/600 [00:01<00:08, 73it/s]Expressions evaluated per second: [.....]. Head worker occupation: 25.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 7.3%┣███▎                                         ┫ 44/600 [00:01<00:07, 75it/s]Expressions evaluated per second: [.....]. Head worker occupation: 23.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 8.5%┣███▉                                         ┫ 51/600 [00:01<00:07, 78it/s]Expressions evaluated per second: [.....]. Head worker occupation: 26.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 9.7%┣████▍                                        ┫ 58/600 [00:01<00:07, 81it/s]Expressions evaluated per second: [.....]. Head worker occupation: 27.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 10.7%┣████▊                                       ┫ 64/600 [00:01<00:06, 83it/s]Expressions evaluated per second: [.....]. Head worker occupation: 28.3%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 11.3%┣█████                                       ┫ 68/600 [00:01<00:06, 82it/s]Expressions evaluated per second: [.....]. Head worker occupation: 29.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 12.5%┣█████▌                                      ┫ 75/600 [00:01<00:06, 84it/s]Expressions evaluated per second: [.....]. Head worker occupation: 28.9%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 13.7%┣██████                                      ┫ 82/600 [00:01<00:06, 87it/s]Expressions evaluated per second: [.....]. Head worker occupation: 28.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 14.7%┣██████▌                                     ┫ 88/600 [00:01<00:06, 87it/s]Expressions evaluated per second: [.....]. Head worker occupation: 26.5%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 15.8%┣███████                                     ┫ 95/600 [00:01<00:06, 89it/s]Expressions evaluated per second: 1.98e+05. Head worker occupation: 26.4%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 16.7%┣███████▏                                   ┫ 100/600 [00:01<00:06, 89it/s]Expressions evaluated per second: 1.98e+05. Head worker occupation: 26.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 17.3%┣███████▌                                   ┫ 104/600 [00:01<00:06, 87it/s]Expressions evaluated per second: 1.98e+05. Head worker occupation: 25.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 18.0%┣███████▊                                   ┫ 108/600 [00:01<00:06, 87it/s]Expressions evaluated per second: 1.98e+05. Head worker occupation: 25.5%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 19.2%┣████████▎                                  ┫ 115/600 [00:01<00:05, 88it/s]Expressions evaluated per second: 1.98e+05. Head worker occupation: 25.5%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 20.0%┣████████▋                                  ┫ 120/600 [00:01<00:05, 87it/s]Expressions evaluated per second: 1.98e+05. Head worker occupation: 25.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 21.0%┣█████████                                  ┫ 126/600 [00:01<00:05, 88it/s]Expressions evaluated per second: 1.98e+05. Head worker occupation: 24.9%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 21.8%┣█████████▍                                 ┫ 131/600 [00:01<00:05, 88it/s]Expressions evaluated per second: 1.98e+05. Head worker occupation: 25.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 22.5%┣█████████▊                                 ┫ 135/600 [00:02<00:05, 88it/s]Expressions evaluated per second: 1.98e+05. Head worker occupation: 24.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 23.5%┣██████████                                 ┫ 141/600 [00:02<00:05, 88it/s]Expressions evaluated per second: 1.98e+05. Head worker occupation: 25.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 24.5%┣██████████▌                                ┫ 147/600 [00:02<00:05, 88it/s]Expressions evaluated per second: 1.98e+05. Head worker occupation: 25.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 25.7%┣███████████                                ┫ 154/600 [00:02<00:05, 89it/s]Expressions evaluated per second: 1.98e+05. Head worker occupation: 26.4%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 27.2%┣███████████▊                               ┫ 163/600 [00:02<00:05, 91it/s]Expressions evaluated per second: 1.98e+05. Head worker occupation: 27.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 28.3%┣████████████▏                              ┫ 170/600 [00:02<00:05, 92it/s]Expressions evaluated per second: 1.98e+05. Head worker occupation: 26.9%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 29.2%┣████████████▌                              ┫ 175/600 [00:02<00:05, 91it/s]Expressions evaluated per second: 1.98e+05. Head worker occupation: 26.5%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 30.3%┣█████████████                              ┫ 182/600 [00:02<00:05, 92it/s]Expressions evaluated per second: 1.98e+05. Head worker occupation: 26.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 31.7%┣█████████████▋                             ┫ 190/600 [00:02<00:04, 93it/s]Expressions evaluated per second: 2.14e+05. Head worker occupation: 26.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 32.8%┣██████████████▏                            ┫ 197/600 [00:02<00:04, 94it/s]Expressions evaluated per second: 2.14e+05. Head worker occupation: 25.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 33.8%┣██████████████▌                            ┫ 203/600 [00:02<00:04, 94it/s]Expressions evaluated per second: 2.14e+05. Head worker occupation: 25.3%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.083e-01  3.412e+00  y = (x₀ * 2.0593)                             5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 35.3%┣███████████████▏                           ┫ 212/600 [00:02<00:04, 95it/s]Expressions evaluated per second: 2.14e+05. Head worker occupation: 25.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.083e-01  3.412e+00  y = (x₀ * 2.0593)                             5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 36.5%┣███████████████▊                           ┫ 219/600 [00:02<00:04, 96it/s]Expressions evaluated per second: 2.14e+05. Head worker occupation: 25.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.083e-01  3.412e+00  y = (x₀ * 2.0593)                             5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 37.8%┣████████████████▎                          ┫ 227/600 [00:02<00:04, 97it/s]Expressions evaluated per second: 2.14e+05. Head worker occupation: 24.9%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.083e-01  3.412e+00  y = (x₀ * 2.0593)                             5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 38.7%┣████████████████▋                          ┫ 232/600 [00:02<00:04, 97it/s]Expressions evaluated per second: 2.14e+05. Head worker occupation: 24.5%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.083e-01  3.412e+00  y = (x₀ * 2.0593)                             5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 39.7%┣█████████████████                          ┫ 238/600 [00:02<00:04, 97it/s]Expressions evaluated per second: 2.14e+05. Head worker occupation: 24.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.083e-01  3.412e+00  y = (x₀ * 2.0593)                             5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 40.7%┣█████████████████▌                         ┫ 244/600 [00:03<00:04, 97it/s]Expressions evaluated per second: 2.14e+05. Head worker occupation: 24.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 41.7%┣██████████████████                         ┫ 250/600 [00:03<00:04, 97it/s]Expressions evaluated per second: 2.14e+05. Head worker occupation: 24.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 42.7%┣██████████████████▍                        ┫ 256/600 [00:03<00:04, 97it/s]Expressions evaluated per second: 2.14e+05. Head worker occupation: 24.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# 43.7%┣██████████████████▊                        ┫ 262/600 [00:03<00:03, 97it/s]Expressions evaluated per second: 2.14e+05. Head worker occupation: 25.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = (1 + (x₀ + x₀))                           ---------------------------------------------------------------------------------------------------
# ...
# 89.3%┣██████████████████████████████████████▍    ┫ 536/600 [00:08<00:01, 63it/s]Expressions evaluated per second: 1.40e+05. Head worker occupation: 24.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           1.895e-14  7.971e+00  y = ((x₀ + 1) + x₀)                           7           0.000e+00  7.971e+00  y = (((x₀ + -0.1415) + x₀) + 1.1415)          ---------------------------------------------------------------------------------------------------
# 90.0%┣██████████████████████████████████████▊    ┫ 540/600 [00:09<00:01, 63it/s]Expressions evaluated per second: 1.40e+05. Head worker occupation: 24.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           1.895e-14  7.971e+00  y = ((x₀ + 1) + x₀)                           7           0.000e+00  7.971e+00  y = (((x₀ + -0.1415) + x₀) + 1.1415)          ---------------------------------------------------------------------------------------------------
# 91.2%┣███████████████████████████████████████▏   ┫ 547/600 [00:09<00:01, 63it/s]Expressions evaluated per second: 1.40e+05. Head worker occupation: 23.9%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           1.895e-14  7.971e+00  y = ((x₀ + 1) + x₀)                           7           0.000e+00  7.971e+00  y = (((x₀ + -0.1415) + x₀) + 1.1415)          ---------------------------------------------------------------------------------------------------
# 92.0%┣███████████████████████████████████████▋   ┫ 552/600 [00:09<00:01, 63it/s]Expressions evaluated per second: 1.40e+05. Head worker occupation: 23.9%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           1.895e-14  7.971e+00  y = ((x₀ + 1) + x₀)                           7           0.000e+00  7.971e+00  y = (((x₀ + -0.1415) + x₀) + 1.1415)          ---------------------------------------------------------------------------------------------------
# 92.8%┣████████████████████████████████████████   ┫ 557/600 [00:09<00:01, 63it/s]Expressions evaluated per second: 1.40e+05. Head worker occupation: 23.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           1.895e-14  7.971e+00  y = ((x₀ + 1) + x₀)                           7           0.000e+00  7.971e+00  y = (((x₀ + -0.1415) + x₀) + 1.1415)          ---------------------------------------------------------------------------------------------------
# 93.5%┣████████████████████████████████████████▏  ┫ 561/600 [00:09<00:01, 63it/s]Expressions evaluated per second: 1.40e+05. Head worker occupation: 23.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           1.895e-14  7.971e+00  y = ((x₀ + 1) + x₀)                           7           0.000e+00  7.971e+00  y = (((x₀ + -0.1415) + x₀) + 1.1415)          ---------------------------------------------------------------------------------------------------
# 94.0%┣████████████████████████████████████████▍  ┫ 564/600 [00:09<00:01, 63it/s]Expressions evaluated per second: 1.40e+05. Head worker occupation: 23.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           1.895e-14  7.971e+00  y = ((x₀ + 1) + x₀)                           7           0.000e+00  7.971e+00  y = (((x₀ + -0.1415) + x₀) + 1.1415)          ---------------------------------------------------------------------------------------------------
# 94.7%┣████████████████████████████████████████▊  ┫ 568/600 [00:09<00:01, 63it/s]Expressions evaluated per second: 1.40e+05. Head worker occupation: 23.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           1.895e-14  7.971e+00  y = ((x₀ + 1) + x₀)                           7           0.000e+00  7.971e+00  y = (((x₀ + -0.1415) + x₀) + 1.1415)          ---------------------------------------------------------------------------------------------------
# 95.5%┣█████████████████████████████████████████  ┫ 573/600 [00:09<00:00, 63it/s]Expressions evaluated per second: 1.40e+05. Head worker occupation: 23.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           1.895e-14  7.971e+00  y = ((x₀ + 1) + x₀)                           7           0.000e+00  7.971e+00  y = (((x₀ + -0.1415) + x₀) + 1.1415)          ---------------------------------------------------------------------------------------------------
# 96.2%┣█████████████████████████████████████████▍ ┫ 577/600 [00:09<00:00, 63it/s]Expressions evaluated per second: 1.40e+05. Head worker occupation: 23.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           1.895e-14  7.971e+00  y = ((x₀ + 1) + x₀)                           7           0.000e+00  7.971e+00  y = (((x₀ + -0.1415) + x₀) + 1.1415)          ---------------------------------------------------------------------------------------------------
# 97.0%┣█████████████████████████████████████████▊ ┫ 582/600 [00:09<00:00, 63it/s]Expressions evaluated per second: 1.40e+05. Head worker occupation: 23.5%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           1.895e-14  7.971e+00  y = ((x₀ + 1) + x₀)                           7           0.000e+00  7.971e+00  y = (((x₀ + -0.1415) + x₀) + 1.1415)          ---------------------------------------------------------------------------------------------------
# 97.8%┣██████████████████████████████████████████ ┫ 587/600 [00:09<00:00, 63it/s]Expressions evaluated per second: 1.40e+05. Head worker occupation: 23.5%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           1.895e-14  7.971e+00  y = ((x₀ + 1) + x₀)                           7           0.000e+00  7.971e+00  y = (((x₀ + -0.1415) + x₀) + 1.1415)          ---------------------------------------------------------------------------------------------------
# 98.5%┣██████████████████████████████████████████▍┫ 591/600 [00:09<00:00, 63it/s]Expressions evaluated per second: 1.40e+05. Head worker occupation: 23.4%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           1.895e-14  7.971e+00  y = ((x₀ + 1) + x₀)                           7           0.000e+00  7.971e+00  y = (((x₀ + -0.1415) + x₀) + 1.1415)          ---------------------------------------------------------------------------------------------------
# 99.7%┣██████████████████████████████████████████▉┫ 598/600 [00:09<00:00, 63it/s]Expressions evaluated per second: 1.40e+05. Head worker occupation: 23.3%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           1.000e+00  2.628e+00  y = (x₀ + x₀)                                 5           1.895e-14  7.971e+00  y = ((x₀ + 1) + x₀)                           7           0.000e+00  7.971e+00  y = (((x₀ + -0.1415) + x₀) + 1.1415)          ---------------------------------------------------------------------------------------------------

# %%
registros_ = registros

# %%
for i in registros_:
  loss = i[1]
  score = i[2]
  complexity = i[0]
  w = (loss * score)/complexity
  if math.isnan(w):
    i.append(0)
  else:
    i.append(w)

lista_melhor_valor = max(registros_, key=lambda x: x[6])
# Out:
# C:\Users\rafae\AppData\Local\Temp\ipykernel_6120\2759937347.py:5: RuntimeWarning: invalid value encountered in scalar multiply
#   w = (loss * score)/complexity

# %% [markdown]
# ## Save result

# %%
def salvar_dados(dados, key, arquivo):
  if os.path.exists(arquivo):
    with open(arquivo, 'rb') as f:
      dados_exist = pickle.load(f)
  else:
    dados_exist = {}
    
  valor_original = dados_exist.get(key)
  if valor_original == None:
    dados_exist.update({key: [dados]})
  else:
    if isinstance(valor_original, list):
      valor_original.append(dados)
    else:
      dados_exist.update({key: [dados]})

  with open(arquivo, 'wb') as f:
    pickle.dump(dados_exist, f)
  
caminho_arquivo = 'dados.pickle'
novos_dados = lista_melhor_valor[0:3] + [lista_melhor_valor[4]]

salvar_dados(novos_dados, 'fibonacci_interative_N', caminho_arquivo)

# %%
def carregar_dados(arquivo):
    # Carrega os dados do arquivo pickle
    with open(arquivo, 'rb') as f:
        dados = pickle.load(f)
    return dados

caminho_arquivo = 'dados.pickle'
dados_carregados = carregar_dados(caminho_arquivo)

print("Conteúdo do arquivo pickle:")
for k, v in dados_carregados.items():
  print('\u25CF', k)
  for index, item in enumerate(v):
    if index == len(v)-1:
       print('└─', item)
    else:
      print('├─', item)
  print('==========================')
# Out:
# Conteúdo do arquivo pickle:
# ● binary_search_logx
# ├─ [6, 1.2914093, 1.37589542429269, log(x0**6) + 5.574131]
# └─ [5, 1.5291592, 2.19479656667366, log(x0)**2 + 13.966276]
# ==========================
# ● boyer_moore_M_plus_N
# ├─ [9, 1729031400.0, 0.1972007458935316, 752018330.701125*(0.00603869219560025*x0 + 0.00603869219560025*x1 - 1)**4 + 601415.75]
# └─ [5, 15754614000.0, 0.3055240605113849, 3621132.2 - 28185.828*x1]
# ==========================
# ● bubblesort_N^2
# ├─ [4, 5910.4966, 3.4645076652491285, 1.5253483*x0**2]
# └─ [4, 8542.308, 3.303255717418494, 1.5552218*x0**2]
# ==========================
# ● fibonacci_interative_N
# ├─ [3, 0.20818244, 3.412549040667958, 2.058653*x0]
# └─ [3, 0.20818244, 3.412549040667958, 2.058653*x0]
# ==========================
