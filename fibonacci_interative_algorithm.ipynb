# %%
# https://www.geeksforgeeks.org/python-program-to-print-the-fibonacci-sequence/?ref=header_search

import numpy as np
from line_profiler import LineProfiler
from pysr import PySRRegressor
import os
import sys
import math
import pickle

# %% [markdown]
# ## Fibonacci Interative Algorithm

# %%
def fibonacci_interative(n): # N
  fib = [0, 1]
  for i in range(2, n+1):
    fib.append(fib[i-1] + fib[i-2])
  return fib[n]

# %% [markdown]
# ## Frequency Count Method

# %%
X_y = []
i=25
for n in range(2,i+1):
  lprofiler = LineProfiler()
  lp_wrapper = lprofiler(fibonacci_interative)

  lp_wrapper(n)

  stats = lprofiler.get_stats()
  line_numbers = []
  hits = []

  for line in stats.timings.values():
    for i in line:
      line_numbers.append(i[0])
      hits.append(i[1])

  X_y.append([n, sum(hits)])

dados = np.array(X_y)

X = dados[:, 0]
y = dados[:, 1]
X_reshaped = X.reshape(-1, 1)

# %%
resultados_com_menor_loss = []
repeat = 5
registros = []
unary_operators_list = ["log", "square", "cube", "sqrt", "round", "exp", "abs"]

original_stdout = sys.stdout

with open(os.devnull, 'w') as devnull:
  sys.stdout = devnull

  for i in range(repeat):

    # first combination
    reg1 = PySRRegressor(
      #binary_operators=["*", "+"],
      unary_operators=unary_operators_list
    )

    fit1 = reg1.fit(X_reshaped, y)
    best_program1 = fit1.get_best()

    registro1 = []
    for index, value in enumerate(best_program1):
      registro1.append(value)
      
    registros.append(registro1)

    # second combination
    #reg2 = PySRRegressor(
    #  binary_operators=["*"],
    #  unary_operators=unary_operators_list
    #)
#
    #fit2 = reg2.fit(X_reshaped, y)
    #best_program2 = fit2.get_best()
#
    #registro2 = []
    #for index, value in enumerate(best_program2):
    #  registro2.append(value)
    #registros.append(registro2)
#
    ## third combinarion
    #reg3 = PySRRegressor(
    #  binary_operators=["+"],
    #  unary_operators=unary_operators_list
    #)
#
    #fit3 = reg3.fit(X_reshaped, y)
    #best_program3 = fit3.get_best()
#
    #registro3 = []
    #for index, value in enumerate(best_program3):
    #  registro3.append(value)
    #registros.append(registro3)
    
sys.stdout = original_stdout
# Out:
# [ Info: Started!
# 0.0%┣                                             ┫ 0/600 [00:00<00:-19, -0s/it]Expressions evaluated per second: [.....]. Head worker occupation: 0.0%         Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.582e+02  1.594e+01  y = x₀                                        3           2.398e-01  3.491e+00  y = (x₀ * 2.0704)                             6           2.392e-01  9.436e-04  y = sqrt(round(square(x₀ * 2.0704)))          7           1.647e-01  3.727e-01  y = ((x₀ * abs(round(2.0704))) + 1.4059)      9           2.272e-02  9.905e-01  y = (sqrt(square(round(x₀) * round(2.0704))) - -1.1507)                                                                       12          1.248e-04  1.735e+00  y = (sqrt(square(x₀ * round(2.0704)) - 0.28055) - cube(round(-...                                                                                               1.1507)))                                     13          0.000e+00  1.594e+01  y = (sqrt(round(square(x₀ * round(2.0704)) - 0.28055)) - cube(...                                                                                               round(-1.1507)))                              ---------------------------------------------------------------------------------------------------
# 0.3%┣▏                                             ┫ 2/600 [00:00<00:56, 11it/s]Expressions evaluated per second: [.....]. Head worker occupation: 6.3%         Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.582e+02  1.594e+01  y = x₀                                        3           2.398e-01  3.491e+00  y = (x₀ * 2.0704)                             5           8.088e-03  1.695e+00  y = ((x₀ + x₀) + 1.0899)                      6           0.000e+00  1.594e+01  y = round((x₀ - -0.62803) + x₀)               ---------------------------------------------------------------------------------------------------
# 1.3%┣▋                                             ┫ 8/600 [00:00<00:13, 46it/s]Expressions evaluated per second: [.....]. Head worker occupation: 18.3%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.582e+02  1.594e+01  y = x₀                                        3           2.398e-01  3.491e+00  y = (x₀ * 2.0704)                             5           1.540e-03  2.524e+00  y = ((x₀ + x₀) - -1.0392)                     6           0.000e+00  1.594e+01  y = round((x₀ - -0.62803) + x₀)               ---------------------------------------------------------------------------------------------------
# 2.3%┣█                                            ┫ 14/600 [00:00<00:09, 62it/s]Expressions evaluated per second: [.....]. Head worker occupation: 21.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.582e+02  1.594e+01  y = x₀                                        3           2.398e-01  3.491e+00  y = (x₀ * 2.0704)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 3.2%┣█▍                                           ┫ 19/600 [00:00<00:09, 65it/s]Expressions evaluated per second: [.....]. Head worker occupation: 20.0%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.582e+02  1.594e+01  y = x₀                                        3           2.398e-01  3.491e+00  y = (x₀ * 2.0704)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 4.3%┣██                                           ┫ 26/600 [00:00<00:08, 73it/s]Expressions evaluated per second: [.....]. Head worker occupation: 20.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.398e-01  3.342e+00  y = (x₀ * 2.0704)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 5.8%┣██▋                                          ┫ 35/600 [00:00<00:07, 85it/s]Expressions evaluated per second: [.....]. Head worker occupation: 22.4%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 6.7%┣███                                          ┫ 40/600 [00:00<00:07, 82it/s]Expressions evaluated per second: [.....]. Head worker occupation: 21.4%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 8.0%┣███▋                                         ┫ 48/600 [00:01<00:06, 89it/s]Expressions evaluated per second: [.....]. Head worker occupation: 22.4%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 9.0%┣████                                         ┫ 54/600 [00:01<00:06, 90it/s]Expressions evaluated per second: [.....]. Head worker occupation: 22.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 10.0%┣████▍                                       ┫ 60/600 [00:01<00:06, 91it/s]Expressions evaluated per second: [.....]. Head worker occupation: 22.4%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 11.0%┣████▉                                       ┫ 66/600 [00:01<00:06, 91it/s]Expressions evaluated per second: [.....]. Head worker occupation: 21.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 11.8%┣█████▏                                      ┫ 71/600 [00:01<00:06, 91it/s]Expressions evaluated per second: [.....]. Head worker occupation: 21.4%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 12.7%┣█████▋                                      ┫ 76/600 [00:01<00:06, 88it/s]Expressions evaluated per second: [.....]. Head worker occupation: 20.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 13.3%┣█████▉                                      ┫ 80/600 [00:01<00:06, 83it/s]Expressions evaluated per second: [.....]. Head worker occupation: 20.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 14.2%┣██████▎                                     ┫ 85/600 [00:01<00:06, 83it/s]Expressions evaluated per second: 1.96e+05. Head worker occupation: 19.9%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 15.2%┣██████▊                                     ┫ 91/600 [00:01<00:06, 85it/s]Expressions evaluated per second: 1.96e+05. Head worker occupation: 20.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 16.2%┣███████▏                                    ┫ 97/600 [00:01<00:06, 84it/s]Expressions evaluated per second: 1.96e+05. Head worker occupation: 19.8%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 17.3%┣███████▌                                   ┫ 104/600 [00:01<00:06, 86it/s]Expressions evaluated per second: 1.96e+05. Head worker occupation: 20.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 18.5%┣████████                                   ┫ 111/600 [00:01<00:06, 87it/s]Expressions evaluated per second: 1.96e+05. Head worker occupation: 20.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 19.3%┣████████▎                                  ┫ 116/600 [00:01<00:06, 86it/s]Expressions evaluated per second: 1.96e+05. Head worker occupation: 19.5%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 20.3%┣████████▊                                  ┫ 122/600 [00:01<00:06, 86it/s]Expressions evaluated per second: 1.96e+05. Head worker occupation: 19.7%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 21.2%┣█████████                                  ┫ 127/600 [00:01<00:05, 86it/s]Expressions evaluated per second: 1.96e+05. Head worker occupation: 19.5%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 22.5%┣█████████▊                                 ┫ 135/600 [00:02<00:05, 88it/s]Expressions evaluated per second: 1.96e+05. Head worker occupation: 20.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 23.7%┣██████████▏                                ┫ 142/600 [00:02<00:05, 90it/s]Expressions evaluated per second: 1.96e+05. Head worker occupation: 20.4%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 24.3%┣██████████▌                                ┫ 146/600 [00:02<00:05, 88it/s]Expressions evaluated per second: 1.96e+05. Head worker occupation: 20.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 25.8%┣███████████                                ┫ 155/600 [00:02<00:05, 90it/s]Expressions evaluated per second: 1.96e+05. Head worker occupation: 20.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 26.8%┣███████████▌                               ┫ 161/600 [00:02<00:05, 90it/s]Expressions evaluated per second: 1.96e+05. Head worker occupation: 20.5%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 27.3%┣███████████▊                               ┫ 164/600 [00:02<00:05, 89it/s]Expressions evaluated per second: 1.96e+05. Head worker occupation: 20.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 28.2%┣████████████▏                              ┫ 169/600 [00:02<00:05, 89it/s]Expressions evaluated per second: 1.96e+05. Head worker occupation: 20.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 29.0%┣████████████▌                              ┫ 174/600 [00:02<00:05, 88it/s]Expressions evaluated per second: 1.96e+05. Head worker occupation: 20.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 29.7%┣████████████▊                              ┫ 178/600 [00:02<00:05, 88it/s]Expressions evaluated per second: 1.96e+05. Head worker occupation: 20.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 30.7%┣█████████████▏                             ┫ 184/600 [00:02<00:05, 88it/s]Expressions evaluated per second: 2.08e+05. Head worker occupation: 20.0%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 31.8%┣█████████████▊                             ┫ 191/600 [00:02<00:05, 89it/s]Expressions evaluated per second: 2.08e+05. Head worker occupation: 20.3%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 32.7%┣██████████████                             ┫ 196/600 [00:02<00:05, 90it/s]Expressions evaluated per second: 2.08e+05. Head worker occupation: 20.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 33.3%┣██████████████▍                            ┫ 200/600 [00:02<00:04, 89it/s]Expressions evaluated per second: 2.08e+05. Head worker occupation: 21.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 34.5%┣██████████████▉                            ┫ 207/600 [00:02<00:04, 90it/s]Expressions evaluated per second: 2.08e+05. Head worker occupation: 21.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 35.5%┣███████████████▎                           ┫ 213/600 [00:02<00:04, 90it/s]Expressions evaluated per second: 2.08e+05. Head worker occupation: 21.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 36.5%┣███████████████▊                           ┫ 219/600 [00:02<00:04, 90it/s]Expressions evaluated per second: 2.08e+05. Head worker occupation: 21.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 37.8%┣████████████████▎                          ┫ 227/600 [00:02<00:04, 91it/s]Expressions evaluated per second: 2.08e+05. Head worker occupation: 21.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 39.3%┣█████████████████                          ┫ 236/600 [00:03<00:04, 93it/s]Expressions evaluated per second: 2.08e+05. Head worker occupation: 21.4%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 40.8%┣█████████████████▋                         ┫ 245/600 [00:03<00:04, 92it/s]Expressions evaluated per second: 2.08e+05. Head worker occupation: 21.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 42.0%┣██████████████████                         ┫ 252/600 [00:03<00:04, 93it/s]Expressions evaluated per second: 2.08e+05. Head worker occupation: 21.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 43.2%┣██████████████████▋                        ┫ 259/600 [00:03<00:04, 93it/s]Expressions evaluated per second: 2.08e+05. Head worker occupation: 21.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# 44.3%┣███████████████████                        ┫ 266/600 [00:03<00:04, 94it/s]Expressions evaluated per second: 2.08e+05. Head worker occupation: 21.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28                                        3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             5           0.000e+00  7.971e+00  y = ((x₀ + 1) + x₀)                           ---------------------------------------------------------------------------------------------------
# ...
# 86.8%┣█████████████████████████████████████▍     ┫ 521/600 [00:05<00:01, 95it/s]Expressions evaluated per second: 2.14e+05. Head worker occupation: 20.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28.001                                    3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             4           2.082e-01  1.192e-07  y = abs(x₀ * 2.0587)                          5           0.000e+00  1.594e+01  y = ((x₀ + x₀) + 1)                           ---------------------------------------------------------------------------------------------------
# 88.0%┣█████████████████████████████████████▉     ┫ 528/600 [00:06<00:01, 95it/s]Expressions evaluated per second: 2.14e+05. Head worker occupation: 20.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28.001                                    3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             4           2.082e-01  1.192e-07  y = abs(x₀ * 2.0587)                          5           0.000e+00  1.594e+01  y = ((x₀ + x₀) + 1)                           ---------------------------------------------------------------------------------------------------
# 88.5%┣██████████████████████████████████████     ┫ 531/600 [00:06<00:01, 95it/s]Expressions evaluated per second: 2.14e+05. Head worker occupation: 20.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28.001                                    3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             4           2.082e-01  1.192e-07  y = abs(x₀ * 2.0587)                          5           0.000e+00  1.594e+01  y = ((x₀ + x₀) + 1)                           ---------------------------------------------------------------------------------------------------
# 89.5%┣██████████████████████████████████████▌    ┫ 537/600 [00:06<00:01, 95it/s]Expressions evaluated per second: 2.14e+05. Head worker occupation: 19.9%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28.001                                    3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             4           2.082e-01  1.192e-07  y = abs(x₀ * 2.0587)                          5           0.000e+00  1.594e+01  y = ((x₀ + x₀) + 1)                           ---------------------------------------------------------------------------------------------------
# 90.5%┣███████████████████████████████████████    ┫ 543/600 [00:06<00:01, 95it/s]Expressions evaluated per second: 2.14e+05. Head worker occupation: 20.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28.001                                    3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             4           2.082e-01  1.192e-07  y = abs(x₀ * 2.0587)                          5           0.000e+00  1.594e+01  y = ((x₀ + x₀) + 1)                           ---------------------------------------------------------------------------------------------------
# 91.3%┣███████████████████████████████████████▎   ┫ 548/600 [00:06<00:01, 94it/s]Expressions evaluated per second: 2.14e+05. Head worker occupation: 20.0%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28.001                                    3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             4           2.082e-01  1.192e-07  y = abs(x₀ * 2.0587)                          5           0.000e+00  1.594e+01  y = ((x₀ + x₀) + 1)                           ---------------------------------------------------------------------------------------------------
# 92.3%┣███████████████████████████████████████▊   ┫ 554/600 [00:06<00:00, 94it/s]Expressions evaluated per second: 2.14e+05. Head worker occupation: 19.9%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28.001                                    3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             4           2.082e-01  1.192e-07  y = abs(x₀ * 2.0587)                          5           0.000e+00  1.594e+01  y = ((x₀ + x₀) + 1)                           ---------------------------------------------------------------------------------------------------
# 93.2%┣████████████████████████████████████████   ┫ 559/600 [00:06<00:00, 94it/s]Expressions evaluated per second: 2.14e+05. Head worker occupation: 19.8%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28.001                                    3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             4           2.082e-01  1.192e-07  y = abs(x₀ * 2.0587)                          5           0.000e+00  1.594e+01  y = ((x₀ + x₀) + 1)                           ---------------------------------------------------------------------------------------------------
# 94.0%┣████████████████████████████████████████▍  ┫ 564/600 [00:06<00:00, 94it/s]Expressions evaluated per second: 2.14e+05. Head worker occupation: 20.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28.001                                    3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             4           2.082e-01  1.192e-07  y = abs(x₀ * 2.0587)                          5           0.000e+00  1.594e+01  y = ((x₀ + x₀) + 1)                           ---------------------------------------------------------------------------------------------------
# 95.0%┣████████████████████████████████████████▉  ┫ 570/600 [00:06<00:00, 94it/s]Expressions evaluated per second: 2.14e+05. Head worker occupation: 20.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28.001                                    3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             4           2.082e-01  1.192e-07  y = abs(x₀ * 2.0587)                          5           0.000e+00  1.594e+01  y = ((x₀ + x₀) + 1)                           ---------------------------------------------------------------------------------------------------
# 96.2%┣█████████████████████████████████████████▍ ┫ 577/600 [00:06<00:00, 95it/s]Expressions evaluated per second: 2.19e+05. Head worker occupation: 20.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28.001                                    3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             4           2.082e-01  1.192e-07  y = abs(x₀ * 2.0587)                          5           0.000e+00  1.594e+01  y = ((x₀ + x₀) + 1)                           ---------------------------------------------------------------------------------------------------
# 97.3%┣█████████████████████████████████████████▉ ┫ 584/600 [00:06<00:00, 95it/s]Expressions evaluated per second: 2.19e+05. Head worker occupation: 20.4%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28.001                                    3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             4           2.082e-01  1.192e-07  y = abs(x₀ * 2.0587)                          5           0.000e+00  1.594e+01  y = ((x₀ + x₀) + 1)                           ---------------------------------------------------------------------------------------------------
# 97.8%┣██████████████████████████████████████████ ┫ 587/600 [00:06<00:00, 94it/s]Expressions evaluated per second: 2.19e+05. Head worker occupation: 20.3%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28.001                                    3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             4           2.082e-01  1.192e-07  y = abs(x₀ * 2.0587)                          5           0.000e+00  1.594e+01  y = ((x₀ + x₀) + 1)                           ---------------------------------------------------------------------------------------------------
# 99.0%┣██████████████████████████████████████████▋┫ 594/600 [00:06<00:00, 95it/s]Expressions evaluated per second: 2.19e+05. Head worker occupation: 20.3%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.917e+02  1.594e+01  y = 28.001                                    3           2.082e-01  3.412e+00  y = (x₀ * 2.0587)                             4           2.082e-01  1.192e-07  y = abs(x₀ * 2.0587)                          5           0.000e+00  1.594e+01  y = ((x₀ + x₀) + 1)                           ---------------------------------------------------------------------------------------------------

# %%
registros_ = registros
file_pickle = 'dados_v3.pck'

# %%
for i in registros_:
  loss = i[1]
  score = i[2]
  complexity = i[0]
  w = (loss * score)/complexity
  if math.isnan(w):
    i.append(0)
  else:
    i.append(w)

lista_melhor_valor = max(registros_, key=lambda x: x[6])
# Out:
# C:\Users\rafae\AppData\Local\Temp\ipykernel_12832\2759937347.py:5: RuntimeWarning: invalid value encountered in scalar multiply
#   w = (loss * score)/complexity

# %% [markdown]
# ## Save result

# %%
def salvar_dados(dados, key, arquivo):
  if os.path.exists(arquivo):
    with open(arquivo, 'rb') as f:
      dados_exist = pickle.load(f)
  else:
    dados_exist = {}
    
  valor_original = dados_exist.get(key)
  if valor_original == None:
    dados_exist.update({key: [dados]})
  else:
    if isinstance(valor_original, list):
      valor_original.append(dados)
    else:
      dados_exist.update({key: [dados]})

  with open(arquivo, 'wb') as f:
    pickle.dump(dados_exist, f)
  
caminho_arquivo = file_pickle
novos_dados = lista_melhor_valor[0:3] + [lista_melhor_valor[4]]

salvar_dados(novos_dados, 'fibonacci_interative_N', caminho_arquivo)

# %%
def carregar_dados(arquivo):
    # Carrega os dados do arquivo pickle
    with open(arquivo, 'rb') as f:
        dados = pickle.load(f)
    return dados

caminho_arquivo = file_pickle
dados_carregados = carregar_dados(caminho_arquivo)

print("Conteúdo do arquivo pickle:")
for k, v in dados_carregados.items():
  if k == 'fibonacci_interative_N':
    print('\u25CF', k)
    for index, item in enumerate(v):
      if index == len(v)-1:
        print('└─', item)
      else:
        print('├─', item)
    print('==========================')
# Out:
# Conteúdo do arquivo pickle:
# ● binary_search_logx
# ├─ [5, 1.2686663, 2.221314141492738, 10.9540097681169*x0**(1/4)]
# ├─ [5, 1.2686663, 2.221314226989192, 10.953988*x0**(1/4)]
# ├─ [5, 1.2686664, 2.221314062669807, 10.9540015519444*x0**(1/4)]
# ├─ [5, 1.2686663, 2.221314141492738, 10.9539924228566*x0**(1/4)]
# ├─ [5, 1.529159, 1.8543049601950847, log(x0)**2 + 13.966406]
# ├─ [6, 1.2914093, 1.37589542429269, log(x0**6) + 5.574101]
# ├─ [6, 1.2914089, 2.2426865508550637, log(263.542115096131*x0**6)]
# ├─ [5, 1.529159, 2.1947966974644983, log(x0)**2 + 13.966284]
# ├─ [6, 1.1680324, 1.0235737900855137, 5.549138*log(x0) + 6.9403343]
# ├─ [6, 1.1680324, 1.0235737900855137, log(x0**5.54914) + 6.9403296]
# ├─ [6, 1.1680324, 1.0235737285617819, log(x0**5.5494156) + 6.939477]
# ├─ [6, 1.1680325, 1.023573642947722, 5.5491385*log(x0) + 6.9403334]
# ├─ [5, 1.2575216, 0.6898708588950153, 10.73528*x0**0.25614613]
# ├─ [5, 1.2573884, 0.6898973409560284, 10.721785*x0**0.25653192]
# ├─ [5, 1.2574341, 0.6898882548276822, 10.728042*x0**0.25637504]
# ├─ [5, 1.5291592, 1.926918133635409, log(x0)**2 + 13.966279]
# ├─ [6, 1.2914094, 1.7561717269086738, log(263.534084566108*x0**6)]
# ├─ [5, 1.529159, 0.9995292924809458, log(x0)**2 + 13.96628]
# ├─ [5, 1.5291587, 2.0927697036128956, log(x0)**2 + 13.966388]
# ├─ [5, 1.2686663, 2.221314226989192, 10.953958*x0**(1/4)]
# ├─ [5, 1.268667, 2.221313931718125, 10.953733947166*x0**(1/4)]
# ├─ [6, 1.2914094, 1.3637020620294669, log(263.483322383443*x0**6)]
# └─ [6, 1.2914089, 2.5034278126835927, log(263.542115096131*x0**6)]
# ==========================
# ● boyer_moore_M_plus_N
# ├─ [5, 41023510000.0, 0.4794504369070467, 8175646.5 - 142375.69*x0]
# ├─ [4, 94650974000.0, 0.0881588594086032, x1**3 - 259378.23]
# ├─ [12, 3321374200.0, 0.9673029464629557, -470330.78 + 90396593.4757658/ceiling(0.084435575*x1 - 0.5)**2]
# └─ [6, 45754343000.0, 0.2338013971269299, -x1**3 + 100798770.0/x0]
# ==========================
# ● bubblesort_N^2
# ├─ [4, 8852.063, 3.0590604362839233, 1.50680191334596*x0**2]
# ├─ [4, 5128.0835, 3.642640187153609, 1.52424506145024*x0**2]
# └─ [4, 4277.703, 3.8711305169312804, 1.52647621087573*x0**2]
# ==========================
# ● fibonacci_interative_N
# ├─ [5, 0.0, inf, 2*x0 + 1.0]
# └─ [5, 0.0, inf, 2*x0 + 1.0]
# ==========================
