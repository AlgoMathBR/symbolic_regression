# %%
# https://rosettacode.org/wiki/Sorting_algorithms/Quicksort#Python

import numpy as np
from line_profiler import LineProfiler
from pysr import PySRRegressor
import random
import os
import sys
import math
import pickle

# %% [markdown]
# ## Quicksort Algorithm

# %%
def quick_sort(sequence): # x^2
    lesser = []
    equal = []
    greater = []
    if len(sequence) <= 1:
        return sequence
    pivot = sequence[0]
    for element in sequence:
        if element < pivot:
            lesser.append(element)
        elif element > pivot:
            greater.append(element)
        else:
            equal.append(element)
    lesser = quick_sort(lesser)
    greater = quick_sort(greater)

# %% [markdown]
# ## Frequency Count Method

# %%
X_y = []
i=50
for n in range(2,i+1): # started with 2 itens until 50 itens in the list
  lprofiler = LineProfiler()
  lp_wrapper = lprofiler(quick_sort)

  # create a list with random number between 1 to 10000
  # with n number in the list
  input = random.choices(range(10000), k=n)
  lp_wrapper(input)

  stats = lprofiler.get_stats()
  line_numbers = []
  hits = []

  for line in stats.timings.values():
    for i in line:
      line_numbers.append(i[0])
      hits.append(i[1])

  X_y.append([n, sum(hits)])

dados = np.array(X_y)

X = dados[:, 0]
y = dados[:, 1]
X_reshaped = X.reshape(-1, 1)

# %%
resultados_com_menor_loss = []
repeat = 5
registros = []

original_stdout = sys.stdout

with open(os.devnull, 'w') as devnull:
  sys.stdout = devnull

  for i in range(repeat):

    # first combination
    reg1 = PySRRegressor(
      binary_operators=["*", "+"],
      unary_operators=["log", "square", "cube"],
    )

    fit1 = reg1.fit(X_reshaped, y)
    best_program1 = fit1.get_best()

    registro1 = []
    for index, value in enumerate(best_program1):
      registro1.append(value)
      
    registros.append(registro1)

    # second combination
    reg2 = PySRRegressor(
      binary_operators=["*"],
      unary_operators=["log", "square", "cube"],
    )

    fit2 = reg2.fit(X_reshaped, y)
    best_program2 = fit2.get_best()

    registro2 = []
    for index, value in enumerate(best_program2):
      registro2.append(value)
    registros.append(registro2)

    # third combinarion
    reg3 = PySRRegressor(
      binary_operators=["+"],
      unary_operators=["log", "square", "cube"],
    )

    fit3 = reg3.fit(X_reshaped, y)
    best_program3 = fit3.get_best()

    registro3 = []
    for index, value in enumerate(best_program3):
      registro3.append(value)
    registros.append(registro3)
    
sys.stdout = original_stdout
# Out:
# [ Info: Started!
# 0.0%┣                                              ┫ 0/600 [00:00<00:-4, -0s/it]Expressions evaluated per second: [.....]. Head worker occupation: 0.0%         Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.080e+05  1.594e+01  y = x₀                                        2           1.607e+05  1.331e+00  y = square(x₀)                                4           4.071e+04  6.866e-01  y = (square(x₀) * 0.78489)                    5           3.340e+04  1.978e-01  y = (square(x₀) * square(0.78489))            7           2.749e+04  9.744e-02  y = ((square(x₀) * square(0.78489)) + x₀)     9           2.332e+04  8.209e-02  y = (((square(x₀) * square(0.78489)) + x₀) + x₀)                                                                              11          2.092e+04  5.453e-02  y = ((((square(x₀) * square(0.78489)) + x₀) + x₀) + x₀)                                                                       12          2.087e+04  2.303e-03  y = ((((square(x₀) * cube(square(0.9209))) + x₀) + x₀) + x₀)                                                                  13          9.081e+03  8.319e-01  y = (((((square(x₀) * square(0.70816)) + 166.07) + x₀) + x₀) +...                                                                                                x₀)                                          15          8.594e+03  2.760e-02  y = ((((((square(x₀) * square(-0.69523)) + 155.97) + x₀) + x₀)...                                                                                                + x₀) + x₀)                                  ---------------------------------------------------------------------------------------------------
# 1.0%┣▌                                             ┫ 6/600 [00:00<00:07, 83it/s]Expressions evaluated per second: [.....]. Head worker occupation: 16.1%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.080e+05  1.594e+01  y = x₀                                        2           1.607e+05  1.331e+00  y = square(x₀)                                4           4.071e+04  6.866e-01  y = (square(x₀) * 0.78489)                    5           2.772e+04  3.841e-01  y = square(x₀ * cube(-0.93397))               7           1.581e+04  2.807e-01  y = (square(square(-2.3917) * 0.96542) * x₀)  8           5.458e+03  1.064e+00  y = (log(square(cube(x₀ + x₀))) * x₀)         10          3.484e+03  2.245e-01  y = (log(square(cube(x₀ + x₀) * -2.3731)) * x₀)                                                                               12          3.469e+03  2.135e-03  y = (log(square(cube(x₀ + (x₀ + -1.3831)) * -2.3731)) * x₀)                                                                   16          3.435e+03  2.411e-03  y = (log(square(cube((((x₀ + x₀) + 1.199) + x₀) + 1.199)) * 0....                                                                                               33681) * x₀)                                  18          3.435e+03  6.775e-05  y = (log(square(cube((((x₀ + x₀) + 1.199) + (x₀ + 0.095252)) +...                                                                                                1.199)) * 0.33681) * x₀)                     20          3.434e+03  1.830e-04  y = ((((log(square(cube(x₀ + x₀)) + 0.81333) * x₀) + 2.3985) +...                                                                                                (4.3516 + x₀)) + (0.3159 * x₀))              ---------------------------------------------------------------------------------------------------
# 2.2%┣█                                           ┫ 13/600 [00:00<00:06, 101it/s]Expressions evaluated per second: [.....]. Head worker occupation: 17.5%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.080e+05  1.594e+01  y = x₀                                        2           1.607e+05  1.331e+00  y = square(x₀)                                4           3.579e+04  7.509e-01  y = square(x₀ * 0.77721)                      5           2.738e+04  2.678e-01  y = (square(x₀) * square(0.81931))            6           9.179e+03  1.093e+00  y = (cube(log(cube(x₀))) * 0.78242)           8           5.458e+03  2.599e-01  y = (log(square(cube(x₀ + x₀))) * x₀)         9           3.799e+03  3.622e-01  y = (((x₀ + (x₀ * 1.0488)) * 14.801) + -105.03)                                                                               10          3.484e+03  8.678e-02  y = (log(square(cube(x₀ + x₀) * -2.3731)) * x₀)                                                                               12          3.469e+03  2.135e-03  y = (log(square(cube(x₀ + (x₀ + -1.3831)) * -2.3731)) * x₀)                                                                   16          3.435e+03  2.411e-03  y = (log(square(cube((((x₀ + x₀) + 1.199) + x₀) + 1.199)) * 0....                                                                                               33681) * x₀)                                  18          3.435e+03  6.775e-05  y = (log(square(cube((((x₀ + x₀) + 1.199) + (x₀ + 0.095252)) +...                                                                                                1.199)) * 0.33681) * x₀)                     20          3.434e+03  1.830e-04  y = ((((log(square(cube(x₀ + x₀)) + 0.81333) * x₀) + 2.3985) +...                                                                                                (4.3516 + x₀)) + (0.3159 * x₀))              ---------------------------------------------------------------------------------------------------
# 3.3%┣█▌                                          ┫ 20/600 [00:00<00:05, 107it/s]Expressions evaluated per second: [.....]. Head worker occupation: 18.6%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.080e+05  1.594e+01  y = x₀                                        2           1.607e+05  1.331e+00  y = square(x₀)                                4           3.579e+04  7.509e-01  y = square(x₀ * 0.77721)                      5           2.738e+04  2.678e-01  y = (square(x₀) * square(0.81931))            6           9.179e+03  1.093e+00  y = (cube(log(cube(x₀))) * 0.78242)           8           5.458e+03  2.599e-01  y = (log(square(cube(x₀ + x₀))) * x₀)         9           3.799e+03  3.622e-01  y = (((x₀ + (x₀ * 1.0488)) * 14.801) + -105.03)                                                                               10          3.484e+03  8.678e-02  y = (log(square(cube(x₀ + x₀) * -2.3731)) * x₀)                                                                               12          3.469e+03  2.135e-03  y = (log(square(cube(x₀ + (x₀ + -1.3831)) * -2.3731)) * x₀)                                                                   16          3.435e+03  2.411e-03  y = (log(square(cube((((x₀ + x₀) + 1.199) + x₀) + 1.199)) * 0....                                                                                               33681) * x₀)                                  18          3.434e+03  2.508e-04  y = ((((log(square(cube(x₀ + x₀))) * x₀) + 2.3985) + (4.3516 +...                                                                                                x₀)) + (0.3159 * x₀))                        ---------------------------------------------------------------------------------------------------
# 4.5%┣██                                          ┫ 27/600 [00:00<00:05, 111it/s]Expressions evaluated per second: [.....]. Head worker occupation: 19.3%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.080e+05  1.594e+01  y = x₀                                        2           1.607e+05  1.331e+00  y = square(x₀)                                4           3.252e+04  7.989e-01  y = square(x₀ * 0.78809)                      5           2.738e+04  1.718e-01  y = (square(x₀) * square(0.81931))            6           9.179e+03  1.093e+00  y = (cube(log(cube(x₀))) * 0.78242)           7           4.256e+03  7.685e-01  y = (((x₀ + x₀) * 14.801) + -105.03)          9           3.799e+03  5.679e-02  y = (((x₀ + (x₀ * 1.0488)) * 14.801) + -105.03)                                                                               10          3.484e+03  8.678e-02  y = (log(square(cube(x₀ + x₀) * -2.3731)) * x₀)                                                                               12          3.469e+03  2.135e-03  y = (log(square(cube(x₀ + (x₀ + -1.3831)) * -2.3731)) * x₀)                                                                   14          3.459e+03  1.429e-03  y = ((((log(square(cube(x₀ + x₀))) + 0.18611) + 0.45966) * x₀)...                                                                                                + x₀)                                        16          3.435e+03  3.392e-03  y = (log(square(cube((((x₀ + x₀) + 1.199) + x₀) + 1.199)) * 0....                                                                                               33681) * x₀)                                  18          3.434e+03  2.508e-04  y = ((((log(square(cube(x₀ + x₀))) * x₀) + 2.3985) + (4.3516 +...                                                                                                x₀)) + (0.3159 * x₀))                        ---------------------------------------------------------------------------------------------------
# 5.8%┣██▋                                         ┫ 35/600 [00:00<00:05, 115it/s]Expressions evaluated per second: [.....]. Head worker occupation: 20.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.080e+05  1.594e+01  y = x₀                                        2           1.607e+05  1.331e+00  y = square(x₀)                                3           1.025e+04  2.752e+00  y = (29.326 * x₀)                             5           6.321e+03  2.419e-01  y = (x₀ + (26.207 * x₀))                      7           4.256e+03  1.977e-01  y = (((x₀ + x₀) * 14.801) + -105.03)          9           3.799e+03  5.679e-02  y = (((x₀ + (x₀ * 1.0488)) * 14.801) + -105.03)                                                                               10          3.484e+03  8.678e-02  y = (log(square(cube(x₀ + x₀) * -2.3731)) * x₀)                                                                               12          3.469e+03  2.135e-03  y = (log(square(cube(x₀ + (x₀ + -1.3831)) * -2.3731)) * x₀)                                                                   14          3.459e+03  1.429e-03  y = ((((log(square(cube(x₀ + x₀))) + 0.18611) + 0.45966) * x₀)...                                                                                                + x₀)                                        16          3.435e+03  3.392e-03  y = (log(square(cube((((x₀ + x₀) + 1.199) + x₀) + 1.199)) * 0....                                                                                               33681) * x₀)                                  18          3.434e+03  2.508e-04  y = ((((log(square(cube(x₀ + x₀))) * x₀) + 2.3985) + (4.3516 +...                                                                                                x₀)) + (0.3159 * x₀))                        ---------------------------------------------------------------------------------------------------
# 6.8%┣███                                         ┫ 41/600 [00:00<00:05, 113it/s]Expressions evaluated per second: [.....]. Head worker occupation: 19.5%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.080e+05  1.594e+01  y = x₀                                        2           1.607e+05  1.331e+00  y = square(x₀)                                3           6.431e+03  3.218e+00  y = (x₀ * 26.852)                             5           3.799e+03  2.632e-01  y = ((x₀ + -3.4652) * 30.326)                 10          3.484e+03  1.736e-02  y = (log(square(cube(x₀ + x₀) * -2.3731)) * x₀)                                                                               12          3.469e+03  2.135e-03  y = (log(square(cube(x₀ + (x₀ + -1.3831)) * -2.3731)) * x₀)                                                                   14          3.434e+03  5.083e-03  y = ((((log(square(cube(x₀ + x₀))) * 0.98077) * x₀) + x₀) + x₀...                                                                                               )                                             ---------------------------------------------------------------------------------------------------
# 8.2%┣███▋                                        ┫ 49/600 [00:00<00:05, 118it/s]Expressions evaluated per second: [.....]. Head worker occupation: 22.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.080e+05  1.594e+01  y = x₀                                        2           1.607e+05  1.331e+00  y = square(x₀)                                3           6.431e+03  3.218e+00  y = (x₀ * 26.852)                             5           3.799e+03  2.632e-01  y = ((x₀ + -3.4652) * 30.326)                 10          3.484e+03  1.736e-02  y = (log(square(cube(x₀ + x₀) * -2.3731)) * x₀)                                                                               12          3.444e+03  5.658e-03  y = ((log(square(cube((x₀ * 1.1858) + x₀))) * x₀) + x₀)                                                                       14          3.434e+03  1.560e-03  y = ((((log(square(cube(x₀ + x₀))) * 0.98077) * x₀) + x₀) + x₀...                                                                                               )                                             17          3.430e+03  3.545e-04  y = ((log(square(cube((x₀ + log(x₀ * x₀)) + x₀) + x₀)) * x₀) +...                                                                                                x₀)                                          18          3.430e+03  1.192e-05  y = ((log(square(cube(x₀ + (x₀ + log(x₀ * x₀))) + square(-0.51...                                                                                               747))) * x₀) + x₀)                            19          3.426e+03  1.029e-03  y = ((log(square(cube((x₀ + (log(x₀ * x₀) + -0.46957)) + x₀) +...                                                                                                x₀)) * x₀) + x₀)                             ---------------------------------------------------------------------------------------------------
# 9.2%┣████                                        ┫ 55/600 [00:00<00:05, 117it/s]Expressions evaluated per second: [.....]. Head worker occupation: 21.3%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.080e+05  1.594e+01  y = x₀                                        2           1.607e+05  1.331e+00  y = square(x₀)                                3           6.321e+03  3.236e+00  y = (x₀ * 27.207)                             5           3.799e+03  2.545e-01  y = ((x₀ + -3.4652) * 30.326)                 10          3.444e+03  1.963e-02  y = ((log(square(cube(x₀ + x₀))) + 1.5162) * x₀)                                                                              12          3.444e+03  2.682e-06  y = ((log(square(cube(x₀ + x₀) + 0.93295)) + 1.5162) * x₀)                                                                    13          3.444e+03  1.431e-06  y = ((log(square(cube(x₀ + x₀) + log(x₀))) + 1.5162) * x₀)                                                                    14          3.434e+03  3.039e-03  y = ((((log(square(cube(x₀ + x₀))) * 0.98077) * x₀) + x₀) + x₀...                                                                                               )                                             16          3.431e+03  3.460e-04  y = ((log(square(cube(x₀ + x₀) * 1.0819)) * x₀) + (x₀ + square...                                                                                               (log(x₀))))                                   17          3.430e+03  3.712e-04  y = ((log(square(cube((x₀ + log(x₀ * x₀)) + x₀) + x₀)) * x₀) +...                                                                                                x₀)                                          18          3.430e+03  1.192e-05  y = ((log(square(cube(x₀ + (x₀ + log(x₀ * x₀))) + square(-0.51...                                                                                               747))) * x₀) + x₀)                            19          3.426e+03  1.029e-03  y = ((log(square(cube((x₀ + (log(x₀ * x₀) + -0.46957)) + x₀) +...                                                                                                x₀)) * x₀) + x₀)                             ---------------------------------------------------------------------------------------------------
# 10.3%┣████▍                                      ┫ 62/600 [00:01<00:05, 117it/s]Expressions evaluated per second: [.....]. Head worker occupation: 21.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           5.950e+05  1.594e+01  y = 45.192                                    2           1.607e+05  1.309e+00  y = square(x₀)                                3           6.321e+03  3.236e+00  y = (x₀ * 27.207)                             5           3.799e+03  2.545e-01  y = ((x₀ + -3.4652) * 30.326)                 10          3.444e+03  1.963e-02  y = ((log(square(cube(x₀ + x₀))) + 1.5162) * x₀)                                                                              12          3.444e+03  2.751e-05  y = ((log(square(cube(x₀ + (x₀ + 5.6004)))) * x₀) + x₀)                                                                       14          3.434e+03  1.496e-03  y = ((((log(square(cube(x₀ + x₀))) * 0.98077) * x₀) + x₀) + x₀...                                                                                               )                                             16          3.431e+03  3.460e-04  y = ((log(square(cube(x₀ + x₀) * 1.0819)) * x₀) + (x₀ + square...                                                                                               (log(x₀))))                                   17          3.430e+03  3.712e-04  y = ((log(square(cube((x₀ + log(x₀ * x₀)) + x₀) + x₀)) * x₀) +...                                                                                                x₀)                                          18          3.430e+03  1.192e-05  y = ((log(square(cube(x₀ + (x₀ + log(x₀ * x₀))) + square(-0.51...                                                                                               747))) * x₀) + x₀)                            19          3.426e+03  1.029e-03  y = ((log(square(cube((x₀ + (log(x₀ * x₀) + -0.46957)) + x₀) +...                                                                                                x₀)) * x₀) + x₀)                             ---------------------------------------------------------------------------------------------------
# 11.7%┣█████                                      ┫ 70/600 [00:01<00:04, 120it/s]Expressions evaluated per second: [.....]. Head worker occupation: 21.5%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.877e+05  1.594e+01  y = 683.38                                    2           1.607e+05  1.555e-01  y = square(x₀)                                3           6.321e+03  3.236e+00  y = (x₀ * 27.207)                             5           3.799e+03  2.545e-01  y = ((x₀ + -3.4652) * 30.326)                 10          3.444e+03  1.963e-02  y = ((log(square(cube(x₀ + x₀))) + 1.5162) * x₀)                                                                              12          3.444e+03  2.751e-05  y = ((log(square(cube(x₀ + (x₀ + 5.6004)))) * x₀) + x₀)                                                                       14          3.434e+03  1.496e-03  y = ((((log(square(cube(x₀ + x₀))) * 0.98077) * x₀) + x₀) + x₀...                                                                                               )                                             15          3.398e+03  1.047e-02  y = (log(square(cube(x₀ + cube(log(x₀ + (square(-0.56334) * x₀...                                                                                               )))))) * x₀)                                  ---------------------------------------------------------------------------------------------------
# 12.7%┣█████▌                                     ┫ 76/600 [00:01<00:04, 119it/s]Expressions evaluated per second: [.....]. Head worker occupation: 22.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.877e+05  1.594e+01  y = 683.38                                    2           1.607e+05  1.555e-01  y = square(x₀)                                3           6.321e+03  3.236e+00  y = (x₀ * 27.207)                             5           3.799e+03  2.545e-01  y = ((x₀ + -3.4652) * 30.326)                 10          3.444e+03  1.963e-02  y = ((log(square(cube(x₀ + x₀))) + 1.5162) * x₀)                                                                              12          3.444e+03  2.933e-05  y = ((log(square(cube((x₀ * 1.5849) + x₀))) * x₀) + 0.47145)                                                                  14          3.434e+03  1.494e-03  y = ((((log(square(cube(x₀ + x₀))) * 0.98077) * x₀) + x₀) + x₀...                                                                                               )                                             15          3.398e+03  1.047e-02  y = (log(square(cube(x₀ + cube(log(x₀ + (square(-0.56334) * x₀...                                                                                               )))))) * x₀)                                  ---------------------------------------------------------------------------------------------------
# 13.8%┣██████                                     ┫ 83/600 [00:01<00:04, 118it/s]Expressions evaluated per second: [.....]. Head worker occupation: 21.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.877e+05  1.594e+01  y = 683.38                                    2           1.607e+05  1.555e-01  y = square(x₀)                                3           6.321e+03  3.236e+00  y = (x₀ * 27.207)                             5           3.799e+03  2.545e-01  y = ((x₀ + -3.4652) * 30.326)                 10          3.444e+03  1.963e-02  y = ((log(square(cube(x₀ + x₀))) + 1.5162) * x₀)                                                                              12          3.444e+03  2.933e-05  y = ((log(square(cube((x₀ * 1.5849) + x₀))) * x₀) + 0.47145)                                                                  14          3.434e+03  1.494e-03  y = ((((log(square(cube(x₀ + x₀))) * 0.98077) * x₀) + x₀) + x₀...                                                                                               )                                             15          3.398e+03  1.047e-02  y = (log(square(cube(x₀ + cube(log(x₀ + (square(-0.56334) * x₀...                                                                                               )))))) * x₀)                                  ---------------------------------------------------------------------------------------------------
# 15.0%┣██████▌                                    ┫ 90/600 [00:01<00:04, 118it/s]Expressions evaluated per second: [.....]. Head worker occupation: 21.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.877e+05  1.594e+01  y = 683.38                                    2           1.607e+05  1.555e-01  y = square(x₀)                                3           6.321e+03  3.236e+00  y = (x₀ * 27.207)                             5           3.799e+03  2.545e-01  y = ((x₀ + -3.4652) * 30.326)                 7           3.799e+03  -0.000e+00  y = (((x₀ + -4.9277) * 30.326) + 44.349)     10          3.444e+03  3.272e-02  y = ((log(square(cube(x₀ + x₀))) + 1.5162) * x₀)                                                                              12          3.444e+03  2.933e-05  y = ((log(square(cube((x₀ * 1.5849) + x₀))) * x₀) + 0.47145)                                                                  13          3.443e+03  1.452e-04  y = ((log(square(cube(x₀ + x₀) + square(x₀))) + 1.5162) * x₀)                                                                 14          3.434e+03  2.842e-03  y = ((((log(square(cube(x₀ + x₀))) * 0.98077) * x₀) + x₀) + x₀...                                                                                               )                                             15          3.398e+03  1.047e-02  y = (log(square(cube(x₀ + cube(log(x₀ + (square(-0.56334) * x₀...                                                                                               )))))) * x₀)                                  ---------------------------------------------------------------------------------------------------
# 16.7%┣███████                                   ┫ 100/600 [00:01<00:04, 121it/s]Expressions evaluated per second: [.....]. Head worker occupation: 22.3%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.877e+05  1.594e+01  y = 683.38                                    2           1.607e+05  1.555e-01  y = square(x₀)                                3           6.321e+03  3.236e+00  y = (x₀ * 27.207)                             5           3.799e+03  2.545e-01  y = ((x₀ + -3.4652) * 30.326)                 7           3.799e+03  -0.000e+00  y = (((x₀ + -4.9277) * 30.326) + 44.349)     9           3.799e+03  -0.000e+00  y = (((x₀ * 30.325) + cube(square(-1.0417))) + -106.36)                                                                      10          3.444e+03  9.817e-02  y = ((log(square(cube(x₀ + x₀))) + 1.5162) * x₀)                                                                              12          3.442e+03  2.762e-04  y = ((log(square(cube((x₀ + x₀) + 0.73702))) + 1.5162) * x₀)                                                                  14          3.434e+03  1.247e-03  y = ((((log(square(cube(x₀ + x₀))) * 0.98077) * x₀) + x₀) + x₀...                                                                                               )                                             15          3.398e+03  1.047e-02  y = (log(square(cube(x₀ + cube(log(x₀ + (square(-0.56334) * x₀...                                                                                               )))))) * x₀)                                  ---------------------------------------------------------------------------------------------------
# 17.8%┣███████▌                                  ┫ 107/600 [00:01<00:04, 121it/s]Expressions evaluated per second: [.....]. Head worker occupation: 22.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.877e+05  1.594e+01  y = 683.38                                    2           1.607e+05  1.555e-01  y = square(x₀)                                3           6.321e+03  3.236e+00  y = (x₀ * 27.207)                             5           3.799e+03  2.545e-01  y = ((x₀ + -3.4652) * 30.326)                 7           3.799e+03  -0.000e+00  y = (((x₀ + -4.9277) * 30.326) + 44.349)     9           3.799e+03  -0.000e+00  y = (((x₀ * 30.325) + cube(square(-1.0417))) + -106.36)                                                                      10          3.444e+03  9.817e-02  y = ((log(square(cube(x₀ + x₀))) + 1.5162) * x₀)                                                                              12          3.442e+03  2.762e-04  y = ((log(square(cube((x₀ + x₀) + 0.73702))) + 1.5162) * x₀)                                                                  14          3.434e+03  1.247e-03  y = ((((log(square(cube(x₀ + x₀))) * 0.98077) * x₀) + x₀) + x₀...                                                                                               )                                             15          3.398e+03  1.047e-02  y = (log(square(cube(x₀ + cube(log(x₀ + (square(-0.56334) * x₀...                                                                                               )))))) * x₀)                                  ---------------------------------------------------------------------------------------------------
# 18.8%┣████████                                  ┫ 113/600 [00:01<00:04, 120it/s]Expressions evaluated per second: [.....]. Head worker occupation: 21.9%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.877e+05  1.594e+01  y = 683.38                                    2           1.607e+05  1.555e-01  y = square(x₀)                                3           6.321e+03  3.236e+00  y = (x₀ * 27.207)                             5           3.799e+03  2.545e-01  y = ((x₀ + -3.4652) * 30.326)                 7           3.799e+03  -0.000e+00  y = (((x₀ + -4.9277) * 30.326) + 44.349)     9           3.799e+03  -0.000e+00  y = (((x₀ * 30.325) + cube(square(-1.0417))) + -106.36)                                                                      10          3.444e+03  9.817e-02  y = ((log(square(cube(x₀ + x₀))) + 1.5162) * x₀)                                                                              12          3.442e+03  2.762e-04  y = ((log(square(cube((x₀ + x₀) + 0.73702))) + 1.5162) * x₀)                                                                  14          3.434e+03  1.247e-03  y = ((((log(square(cube(x₀ + x₀))) * 0.98077) * x₀) + x₀) + x₀...                                                                                               )                                             15          3.398e+03  1.047e-02  y = (log(square(cube(x₀ + cube(log(x₀ + (square(-0.56334) * x₀...                                                                                               )))))) * x₀)                                  ---------------------------------------------------------------------------------------------------
# 19.7%┣████████▎                                 ┫ 118/600 [00:01<00:04, 118it/s]Expressions evaluated per second: [.....]. Head worker occupation: 21.4%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.877e+05  1.594e+01  y = 683.38                                    2           1.607e+05  1.555e-01  y = square(x₀)                                3           6.321e+03  3.236e+00  y = (x₀ * 27.207)                             5           3.799e+03  2.545e-01  y = ((x₀ + -3.4652) * 30.326)                 7           3.799e+03  -0.000e+00  y = (((x₀ + -4.9277) * 30.326) + 44.349)     9           3.799e+03  -0.000e+00  y = (((x₀ * 30.325) + cube(square(-1.0417))) + -106.36)                                                                      10          3.444e+03  9.817e-02  y = ((log(square(cube(x₀ + x₀))) + 1.5162) * x₀)                                                                              12          3.425e+03  2.742e-03  y = ((log(square(cube(-2.0876 * x₀))) * x₀) + cube(log(x₀)))                                                                  15          3.398e+03  2.676e-03  y = (log(square(cube(x₀ + cube(log(x₀ + (square(-0.56334) * x₀...                                                                                               )))))) * x₀)                                  ---------------------------------------------------------------------------------------------------
# 21.2%┣█████████                                 ┫ 127/600 [00:01<00:04, 120it/s]Expressions evaluated per second: 3.24e+05. Head worker occupation: 22.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.877e+05  1.594e+01  y = 683.38                                    2           1.607e+05  1.555e-01  y = square(x₀)                                3           6.321e+03  3.236e+00  y = (x₀ * 27.207)                             5           3.799e+03  2.545e-01  y = ((x₀ + -3.4652) * 30.326)                 7           3.799e+03  -0.000e+00  y = (((x₀ + -4.9277) * 30.326) + 44.349)     9           3.799e+03  -0.000e+00  y = (((x₀ * 30.325) + cube(square(-1.0417))) + -106.36)                                                                      10          3.444e+03  9.817e-02  y = ((log(square(cube(x₀ + x₀))) + 1.5162) * x₀)                                                                              12          3.425e+03  2.742e-03  y = ((log(square(cube(-2.0876 * x₀))) * x₀) + cube(log(x₀)))                                                                  15          3.398e+03  2.676e-03  y = (log(square(cube(x₀ + cube(log(x₀ + (square(-0.56334) * x₀...                                                                                               )))))) * x₀)                                  17          3.398e+03  3.219e-06  y = (log(square(cube(x₀ + cube(log(x₀ + (square(-0.56334) * x₀...                                                                                               )))) + 0.2473)) * x₀)                         ---------------------------------------------------------------------------------------------------
# 22.2%┣█████████▎                                ┫ 133/600 [00:01<00:04, 120it/s]Expressions evaluated per second: 3.24e+05. Head worker occupation: 22.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.877e+05  1.594e+01  y = 683.38                                    2           1.607e+05  1.555e-01  y = square(x₀)                                3           6.321e+03  3.236e+00  y = (x₀ * 27.207)                             5           3.799e+03  2.545e-01  y = ((x₀ + -3.4652) * 30.326)                 7           3.799e+03  -0.000e+00  y = (((x₀ + -4.9277) * 30.326) + 44.349)     9           3.799e+03  -0.000e+00  y = (((x₀ * 30.325) + cube(square(-1.0417))) + -106.36)                                                                      10          3.444e+03  9.817e-02  y = ((log(square(cube(x₀ + x₀))) + 1.5162) * x₀)                                                                              12          3.425e+03  2.742e-03  y = ((log(square(cube(-2.0876 * x₀))) * x₀) + cube(log(x₀)))                                                                  14          3.423e+03  2.681e-04  y = ((log(square(cube(-2.0876 * x₀))) * x₀) + cube(log(x₀ + 0....                                                                                               54867)))                                      15          3.398e+03  7.493e-03  y = (log(square(cube(x₀ + cube(log(x₀ + (square(-0.56334) * x₀...                                                                                               )))))) * x₀)                                  17          3.398e+03  3.219e-06  y = (log(square(cube(x₀ + cube(log(x₀ + (square(-0.56334) * x₀...                                                                                               )))) + 0.2473)) * x₀)                         ---------------------------------------------------------------------------------------------------
# 23.2%┣█████████▊                                ┫ 139/600 [00:01<00:04, 119it/s]Expressions evaluated per second: 3.24e+05. Head worker occupation: 21.9%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.877e+05  1.594e+01  y = 683.38                                    2           1.607e+05  1.555e-01  y = square(x₀)                                3           6.321e+03  3.236e+00  y = (x₀ * 27.207)                             5           3.799e+03  2.545e-01  y = ((x₀ + -3.4652) * 30.326)                 7           3.799e+03  -0.000e+00  y = (((x₀ + -4.9277) * 30.326) + 44.349)     9           3.799e+03  -0.000e+00  y = (((x₀ * 30.325) + cube(square(-1.0417))) + -106.36)                                                                      10          3.444e+03  9.817e-02  y = ((log(square(cube(x₀ + x₀))) + 1.5162) * x₀)                                                                              12          3.425e+03  2.742e-03  y = ((log(square(cube(-2.0876 * x₀))) * x₀) + cube(log(x₀)))                                                                  14          3.423e+03  2.681e-04  y = ((log(square(cube(-2.0876 * x₀))) * x₀) + cube(log(x₀ + 0....                                                                                               54867)))                                      15          3.398e+03  7.493e-03  y = (log(square(cube(x₀ + cube(log(x₀ + (square(-0.56334) * x₀...                                                                                               )))))) * x₀)                                  17          3.398e+03  2.813e-05  y = (log(square(cube(x₀ + cube(log(x₀ + (square(-0.56334) * x₀...                                                                                               )))) + x₀)) * x₀)                             ---------------------------------------------------------------------------------------------------
# ...
# 93.2%┣████████████████████████████████████████   ┫ 559/600 [00:07<00:00, 82it/s]Expressions evaluated per second: 2.24e+05. Head worker occupation: 21.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.877e+05  1.594e+01  y = 683.46                                    2           1.607e+05  1.555e-01  y = square(x₀)                                4           5.031e+04  5.807e-01  y = cube(log(cube(x₀)))                       5           3.421e+04  3.857e-01  y = square(log(cube(cube(x₀))))               6           6.473e+03  1.665e+00  y = cube(log(cube(x₀)) + -0.78763)            8           5.434e+03  8.752e-02  y = cube(log(cube(x₀ + -1.5949)) + -0.60477)  9           3.837e+03  3.481e-01  y = (cube(log(cube(x₀) + square(29.209))) + -252.26)                                                                          11          3.611e+03  3.029e-02  y = ((cube(log(cube(x₀) + square(-33.659))) + -288.89) + x₀)                                                                  13          3.475e+03  1.918e-02  y = ((cube(log(cube(x₀) + square(-38.43))) + (x₀ + x₀)) + -326...                                                                                               .58)                                          15          3.413e+03  8.988e-03  y = (((cube(log(cube(x₀) + square(-43.532))) + (-365.35 + x₀))...                                                                                                + x₀) + x₀)                                  17          3.384e+03  4.355e-03  y = ((cube(log(cube(x₀) + square(41.074 + x₀))) + x₀) + (-397....                                                                                               25 + (x₀ + x₀)))                              19          3.302e+03  1.221e-02  y = (((cube(log(cube(x₀) + square(46.88 + x₀))) + x₀) + (-439....                                                                                               7 + (x₀ + x₀))) + x₀)                         ---------------------------------------------------------------------------------------------------
# 94.3%┣████████████████████████████████████████▋  ┫ 566/600 [00:07<00:00, 83it/s]Expressions evaluated per second: 2.24e+05. Head worker occupation: 21.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.877e+05  1.594e+01  y = 683.46                                    2           1.607e+05  1.555e-01  y = square(x₀)                                4           5.031e+04  5.807e-01  y = cube(log(cube(x₀)))                       5           3.421e+04  3.857e-01  y = square(log(cube(cube(x₀))))               6           6.473e+03  1.665e+00  y = cube(log(cube(x₀)) + -0.78763)            8           5.434e+03  8.752e-02  y = cube(log(cube(x₀ + -1.5949)) + -0.60477)  9           3.837e+03  3.481e-01  y = (cube(log(cube(x₀) + square(29.209))) + -252.26)                                                                          11          3.611e+03  3.029e-02  y = ((cube(log(cube(x₀) + square(-33.659))) + -288.89) + x₀)                                                                  13          3.475e+03  1.918e-02  y = ((cube(log(cube(x₀) + square(-38.43))) + (x₀ + x₀)) + -326...                                                                                               .58)                                          15          3.413e+03  8.988e-03  y = (((cube(log(cube(x₀) + square(-43.532))) + (-365.35 + x₀))...                                                                                                + x₀) + x₀)                                  17          3.384e+03  4.355e-03  y = ((cube(log(cube(x₀) + square(41.074 + x₀))) + x₀) + (-397....                                                                                               25 + (x₀ + x₀)))                              19          3.302e+03  1.221e-02  y = (((cube(log(cube(x₀) + square(46.88 + x₀))) + x₀) + (-439....                                                                                               7 + (x₀ + x₀))) + x₀)                         ---------------------------------------------------------------------------------------------------
# 95.2%┣█████████████████████████████████████████  ┫ 571/600 [00:07<00:00, 83it/s]Expressions evaluated per second: 2.24e+05. Head worker occupation: 21.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.877e+05  1.594e+01  y = 683.46                                    2           1.607e+05  1.555e-01  y = square(x₀)                                4           5.031e+04  5.807e-01  y = cube(log(cube(x₀)))                       5           3.421e+04  3.857e-01  y = square(log(cube(cube(x₀))))               6           6.473e+03  1.665e+00  y = cube(log(cube(x₀)) + -0.78763)            8           5.434e+03  8.752e-02  y = cube(log(cube(x₀ + -1.5949)) + -0.60477)  9           3.837e+03  3.481e-01  y = (cube(log(cube(x₀) + square(29.209))) + -252.26)                                                                          11          3.611e+03  3.029e-02  y = ((cube(log(cube(x₀) + square(-33.659))) + -288.89) + x₀)                                                                  13          3.475e+03  1.918e-02  y = ((cube(log(cube(x₀) + square(-38.43))) + (x₀ + x₀)) + -326...                                                                                               .58)                                          15          3.413e+03  8.988e-03  y = (((cube(log(cube(x₀) + square(-43.532))) + (-365.35 + x₀))...                                                                                                + x₀) + x₀)                                  17          3.384e+03  4.355e-03  y = ((cube(log(cube(x₀) + square(41.074 + x₀))) + x₀) + (-397....                                                                                               25 + (x₀ + x₀)))                              19          3.302e+03  1.221e-02  y = (((cube(log(cube(x₀) + square(46.88 + x₀))) + x₀) + (-439....                                                                                               7 + (x₀ + x₀))) + x₀)                         ---------------------------------------------------------------------------------------------------
# 96.5%┣█████████████████████████████████████████▌ ┫ 579/600 [00:07<00:00, 83it/s]Expressions evaluated per second: 2.24e+05. Head worker occupation: 21.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.877e+05  1.594e+01  y = 683.46                                    2           1.607e+05  1.555e-01  y = square(x₀)                                4           5.031e+04  5.807e-01  y = cube(log(cube(x₀)))                       5           3.421e+04  3.857e-01  y = square(log(cube(cube(x₀))))               6           6.473e+03  1.665e+00  y = cube(log(cube(x₀)) + -0.78763)            8           5.434e+03  8.752e-02  y = cube(log(cube(x₀ + -1.5949)) + -0.60477)  9           3.837e+03  3.481e-01  y = (cube(log(cube(x₀) + square(29.209))) + -252.26)                                                                          11          3.611e+03  3.029e-02  y = ((cube(log(cube(x₀) + square(-33.659))) + -288.89) + x₀)                                                                  13          3.475e+03  1.918e-02  y = ((cube(log(cube(x₀) + square(-38.43))) + (x₀ + x₀)) + -326...                                                                                               .58)                                          15          3.413e+03  8.988e-03  y = (((cube(log(cube(x₀) + square(-43.532))) + (-365.35 + x₀))...                                                                                                + x₀) + x₀)                                  17          3.384e+03  4.355e-03  y = ((cube(log(cube(x₀) + square(41.074 + x₀))) + x₀) + (-397....                                                                                               25 + (x₀ + x₀)))                              19          3.302e+03  1.221e-02  y = (((cube(log(cube(x₀) + square(46.88 + x₀))) + x₀) + (-439....                                                                                               7 + (x₀ + x₀))) + x₀)                         ---------------------------------------------------------------------------------------------------
# 97.8%┣██████████████████████████████████████████ ┫ 587/600 [00:07<00:00, 83it/s]Expressions evaluated per second: 2.27e+05. Head worker occupation: 21.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.877e+05  1.594e+01  y = 683.46                                    2           1.607e+05  1.555e-01  y = square(x₀)                                4           5.031e+04  5.807e-01  y = cube(log(cube(x₀)))                       5           3.421e+04  3.857e-01  y = square(log(cube(cube(x₀))))               6           6.473e+03  1.665e+00  y = cube(log(cube(x₀)) + -0.78763)            8           5.434e+03  8.752e-02  y = cube(log(cube(x₀ + -1.5949)) + -0.60477)  9           3.837e+03  3.481e-01  y = (cube(log(cube(x₀) + square(29.209))) + -252.26)                                                                          11          3.611e+03  3.029e-02  y = ((cube(log(cube(x₀) + square(-33.659))) + -288.89) + x₀)                                                                  13          3.475e+03  1.918e-02  y = ((cube(log(cube(x₀) + square(-38.43))) + (x₀ + x₀)) + -326...                                                                                               .58)                                          15          3.413e+03  8.988e-03  y = (((cube(log(cube(x₀) + square(-43.532))) + (-365.35 + x₀))...                                                                                                + x₀) + x₀)                                  17          3.384e+03  4.355e-03  y = ((cube(log(cube(x₀) + square(41.074 + x₀))) + x₀) + (-397....                                                                                               25 + (x₀ + x₀)))                              19          3.302e+03  1.221e-02  y = (((cube(log(cube(x₀) + square(46.88 + x₀))) + x₀) + (-439....                                                                                               7 + (x₀ + x₀))) + x₀)                         ---------------------------------------------------------------------------------------------------
# 99.0%┣██████████████████████████████████████████▋┫ 594/600 [00:07<00:00, 83it/s]Expressions evaluated per second: 2.27e+05. Head worker occupation: 21.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.877e+05  1.594e+01  y = 683.46                                    2           1.607e+05  1.555e-01  y = square(x₀)                                4           5.031e+04  5.807e-01  y = cube(log(cube(x₀)))                       5           3.421e+04  3.857e-01  y = square(log(cube(cube(x₀))))               6           6.473e+03  1.665e+00  y = cube(log(cube(x₀)) + -0.78763)            8           5.434e+03  8.752e-02  y = cube(log(cube(x₀ + -1.5949)) + -0.60477)  9           3.837e+03  3.481e-01  y = (cube(log(cube(x₀) + square(29.209))) + -252.26)                                                                          11          3.611e+03  3.029e-02  y = ((cube(log(cube(x₀) + square(-33.659))) + -288.89) + x₀)                                                                  13          3.475e+03  1.918e-02  y = (((cube(log(cube(x₀) + square(-38.422))) + x₀) + -326.54) ...                                                                                               + x₀)                                         15          3.413e+03  8.988e-03  y = (((cube(log(cube(x₀) + square(-43.532))) + (-365.35 + x₀))...                                                                                                + x₀) + x₀)                                  17          3.384e+03  4.355e-03  y = ((cube(log(cube(x₀) + square(41.074 + x₀))) + x₀) + (-397....                                                                                               25 + (x₀ + x₀)))                              19          3.302e+03  1.221e-02  y = (((cube(log(cube(x₀) + square(46.88 + x₀))) + x₀) + (-439....                                                                                               7 + (x₀ + x₀))) + x₀)                         ---------------------------------------------------------------------------------------------------

# %%
registros_ = registros

# %%
for i in registros_:
  loss = i[1]
  score = i[2]
  complexity = i[0]
  w = (loss * score)/complexity
  if math.isnan(w):
    i.append(0)
  else:
    i.append(w)

lista_melhor_valor = max(registros_, key=lambda x: x[6])

# %% [markdown]
# ## Save result

# %%
def salvar_dados(dados, key, arquivo):
  if os.path.exists(arquivo):
    with open(arquivo, 'rb') as f:
      dados_exist = pickle.load(f)
  else:
    dados_exist = {}
    
  valor_original = dados_exist.get(key)
  if valor_original == None:
    dados_exist.update({key: [dados]})
  else:
    if isinstance(valor_original, list):
      valor_original.append(dados)
    else:
      dados_exist.update({key: [dados]})

  with open(arquivo, 'wb') as f:
    pickle.dump(dados_exist, f)

caminho_arquivo = 'dados.pickle'
novos_dados = lista_melhor_valor[0:3] + [lista_melhor_valor[4]]

salvar_dados(novos_dados, 'quicksort_x^2', caminho_arquivo)

# %%
def carregar_dados(arquivo):
    # Carrega os dados do arquivo pickle
    with open(arquivo, 'rb') as f:
        dados = pickle.load(f)
    return dados

caminho_arquivo = 'dados.pickle'
dados_carregados = carregar_dados(caminho_arquivo)

print("Conteúdo do arquivo pickle:")
for k, v in dados_carregados.items():
  print('\u25CF', k)
  for index, item in enumerate(v):
    if index == len(v)-1:
       print('└─', item)
    else:
      print('├─', item)
  print('==========================')
# Out:
# Conteúdo do arquivo pickle:
# ● binary_search_logx
# ├─ [6, 1.2914093, 1.37589542429269, log(x0**6) + 5.574131]
# └─ [5, 1.5291592, 2.19479656667366, log(x0)**2 + 13.966276]
# ==========================
# ● boyer_moore_M_plus_N
# ├─ [9, 1729031400.0, 0.1972007458935316, 752018330.701125*(0.00603869219560025*x0 + 0.00603869219560025*x1 - 1)**4 + 601415.75]
# └─ [5, 15754614000.0, 0.3055240605113849, 3621132.2 - 28185.828*x1]
# ==========================
# ● bubblesort_N^2
# ├─ [4, 5910.4966, 3.4645076652491285, 1.5253483*x0**2]
# └─ [4, 8542.308, 3.303255717418494, 1.5552218*x0**2]
# ==========================
# ● fibonacci_interative_N
# ├─ [3, 0.20818244, 3.412549040667958, 2.058653*x0]
# └─ [3, 0.20818244, 3.412549040667958, 2.058653*x0]
# ==========================
# ● fibonacci_recursive_2^N
# ├─ [15, 111113150.0, 0.37865996607381686, x0**4*(0.0022606994*x0**2 - 0.714783)]
# └─ [15, 77371830.0, 0.38657145558895856, x0**2*(x0**2*(0.16452532*x0 - 3.8766947) + 297.9323)]
# ==========================
# ● heapsort_NlogN
# ├─ [9, 0.24989581, 1.1851428541960574, 4*x0 - 1.4897935]
# └─ [9, 0.24989575, 1.185128414350167, 4*x0 - 1.4897884]
# ==========================
# ● insertionsort_N^2
# ├─ [4, 12514.81, 0.5204699193332855, 7.19343672459889*(0.372847972767781*x0 - 1)**2]
# └─ [4, 11070.262, 0.6554198140129509, 9.54380044013764*(0.323697485019442*x0 - 1)**2]
# ==========================
# ● tower_hanoi_2^N
# ├─ [13, 4607.291, 0.98801217824901, 0.0050468594*x0**6]
# └─ [13, 4607.2915, 0.988012078856794, 0.005046889*x0**6]
# ==========================
# ● karatsuba_N^1.585
# └─ [4, 535.7578, 1.123614036379079, 3.66931686122521*x0**2]
# ==========================
# ● levenshtein_distance_MN
# └─ [4, 1058.5413, 9.647410674646242, 3.52554060674929*x1**2]
# ==========================
# ● linear_search_x
# └─ [14, 0.26546365, 0.9472618119882181, x0*log(log(log(1.97671752435621e-50*x0**18)**2))]
# ==========================
# ● mergesort_NlogN
# └─ [8, 40.208347, 0.542941641791251, (log(x0 + 4.4829993)**2 + 0.71281224)**2]
# ==========================
# ● quicksort_x^2
# ├─ [5, 4191.8745, 0.5370400329213452, 31.022936*x0 - 114.24918]
# └─ [5, 3799.3462, 0.5090052338906941, 30.326008*x0 - 105.0883]
# ==========================
# ● selectsort_N^2
# ├─ [7, 492.61688, 0.8252641931074596, 0.91222733*x0*log(x0)**3]
# └─ [7, 529.9843, 0.7728385969753846, 0.9116503*x0*log(x0)**3]
# ==========================
# ● shellsort_NlogN
# ├─ [6, 2333.781, 2.6158456057911406, 9.6421651223277*(0.469831154898539*log(x0**3) - 1)**3]
# └─ [6, 899.3794, 1.4964888960073477, 5.0019417*x0*log(x0)]
# ==========================
# ● strassen_N^2.81
# ├─ [9, 31317.309, 0.2847589231536684, log(2407.45008008753*(0.0372501681530186*(0.817895287156492*x0 + 1)**3 - 1)**2)**3]
# └─ [9, 33064.902, 0.11522887698339954, 1.80036936911294*(0.82201446811225*log(225.511129952784*(0.066591072481186*x0**3 - 1)**2) + 1)**3]
# ==========================
