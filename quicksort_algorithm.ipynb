# %%
# https://rosettacode.org/wiki/Sorting_algorithms/Quicksort#Python

import numpy as np
from line_profiler import LineProfiler
from pysr import PySRRegressor
import random
import os
import sys
import math
import pickle
# Out:
# Detected Jupyter notebook. Loading juliacall extension. Set `PYSR_AUTOLOAD_EXTENSIONS=no` to disable.

# %% [markdown]
# ## Quicksort Algorithm

# %%
def quick_sort(sequence): # x^2
    lesser = []
    equal = []
    greater = []
    if len(sequence) <= 1:
        return sequence
    pivot = sequence[0]
    for element in sequence:
        if element < pivot:
            lesser.append(element)
        elif element > pivot:
            greater.append(element)
        else:
            equal.append(element)
    lesser = quick_sort(lesser)
    greater = quick_sort(greater)

# %% [markdown]
# ## Frequency Count Method

# %%
X_y = []
i=50
for n in range(2,i+1): # started with 2 itens until 50 itens in the list
  lprofiler = LineProfiler()
  lp_wrapper = lprofiler(quick_sort)

  # create a list with random number between 1 to 10000
  # with n number in the list
  input = random.choices(range(10000), k=n)
  lp_wrapper(input)

  stats = lprofiler.get_stats()
  line_numbers = []
  hits = []

  for line in stats.timings.values():
    for i in line:
      line_numbers.append(i[0])
      hits.append(i[1])

  X_y.append([n, sum(hits)])

dados = np.array(X_y)

X = dados[:, 0]
y = dados[:, 1]
X_reshaped = X.reshape(-1, 1)

# %%
resultados_com_menor_loss = []
repeat = 5
registros = []

original_stdout = sys.stdout

with open(os.devnull, 'w') as devnull:
  sys.stdout = devnull

  for i in range(repeat):

    # first combination
    reg1 = PySRRegressor(
      binary_operators=["*", "+"],
      unary_operators=["log", "square", "cube"],
    )

    fit1 = reg1.fit(X_reshaped, y)
    best_program1 = fit1.get_best()

    registro1 = []
    for index, value in enumerate(best_program1):
      registro1.append(value)
      
    registros.append(registro1)

    # second combination
    reg2 = PySRRegressor(
      binary_operators=["*"],
      unary_operators=["log", "square", "cube"],
    )

    fit2 = reg2.fit(X_reshaped, y)
    best_program2 = fit2.get_best()

    registro2 = []
    for index, value in enumerate(best_program2):
      registro2.append(value)
    registros.append(registro2)

    # third combinarion
    reg3 = PySRRegressor(
      binary_operators=["+"],
      unary_operators=["log", "square", "cube"],
    )

    fit3 = reg3.fit(X_reshaped, y)
    best_program3 = fit3.get_best()

    registro3 = []
    for index, value in enumerate(best_program3):
      registro3.append(value)
    registros.append(registro3)
    
sys.stdout = original_stdout
# Out:
# [ Info: Started!
# 0.0%┣                                             ┫ 0/600 [00:00<-1:-19, -0s/it]Expressions evaluated per second: [.....]. Head worker occupation: 0.0%         Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.147e+05  1.594e+01  y = x₀                                        2           1.547e+05  1.380e+00  y = square(x₀)                                4           1.167e+05  1.411e-01  y = square(x₀ + -1.1711)                      5           1.050e+05  1.049e-01  y = square(x₀ + cube(-1.1711))                6           3.318e+04  1.152e+00  y = square(x₀ + (-0.21761 * x₀))              8           2.532e+04  1.351e-01  y = (square((x₀ * 0.84056) + -0.21761) + x₀)  ---------------------------------------------------------------------------------------------------
# 0.7%┣▎                                             ┫ 4/600 [00:00<00:49, 12it/s]Expressions evaluated per second: [.....]. Head worker occupation: 16.9%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.147e+05  1.594e+01  y = x₀                                        2           1.547e+05  1.380e+00  y = square(x₀)                                4           4.966e+04  5.682e-01  y = cube(log(cube(x₀)))                       5           3.199e+04  4.398e-01  y = (square(square(-2.3917)) * x₀)            6           2.816e+04  1.275e-01  y = ((cube(0.90285) * x₀) * x₀)               7           7.682e+03  1.299e+00  y = (square(square(-2.3917 * 0.96542)) * x₀)  8           6.746e+03  1.300e-01  y = cube(log(cube(x₀ + -0.55819)) + -0.7271)  9           6.661e+03  1.268e-02  y = ((square(square(0.40539)) * x₀) + (27.319 * x₀))                                                                          12          5.302e+03  7.603e-02  y = ((square(square(-2.3917) * square(0.96542)) * (x₀ + -1.130...                                                                                               6)) + -0.22678)                               14          5.247e+03  5.269e-03  y = ((square(square(-2.3917) * square(0.96542)) * (x₀ + -1.283...                                                                                               )) + square(square(-1.283)))                  15          4.984e+03  5.142e-02  y = ((square(square(-2.3917) * square(0.96542)) * ((x₀ + -0.37...                                                                                               314) + -1.1306)) + square(-0.22678))          16          4.958e+03  5.208e-03  y = ((square(square(-2.3917) * square(0.96542)) * (x₀ + ((-1.1...                                                                                               306 * 0.59792) + -1.4549))) + -1.283)         ---------------------------------------------------------------------------------------------------
# 1.5%┣▊                                             ┫ 9/600 [00:00<00:23, 26it/s]Expressions evaluated per second: [.....]. Head worker occupation: 16.1%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.147e+05  1.594e+01  y = x₀                                        2           1.547e+05  1.380e+00  y = square(x₀)                                4           4.966e+04  5.682e-01  y = cube(log(cube(x₀)))                       5           2.745e+04  5.927e-01  y = ((x₀ * 0.72995) * x₀)                     6           7.634e+03  1.280e+00  y = cube(log(cube(x₀)) + -0.69429)            8           6.494e+03  8.084e-02  y = cube(log(cube(x₀ + -0.87776)) + -0.69429) 10          6.404e+03  6.963e-03  y = cube(log(cube((x₀ + -0.29464) + -0.76502)) + -0.69429)                                                                    12          5.302e+03  9.440e-02  y = ((square(square(-2.3917) * square(0.96542)) * (x₀ + -1.130...                                                                                               6)) + -0.22678)                               14          5.247e+03  5.269e-03  y = ((square(square(-2.3917) * square(0.96542)) * (x₀ + -1.283...                                                                                               )) + square(square(-1.283)))                  15          4.984e+03  5.142e-02  y = ((square(square(-2.3917) * square(0.96542)) * ((x₀ + -0.37...                                                                                               314) + -1.1306)) + square(-0.22678))          16          4.958e+03  5.208e-03  y = ((square(square(-2.3917) * square(0.96542)) * (x₀ + ((-1.1...                                                                                               306 * 0.59792) + -1.4549))) + -1.283)         ---------------------------------------------------------------------------------------------------
# 3.0%┣█▍                                           ┫ 18/600 [00:00<00:13, 46it/s]Expressions evaluated per second: [.....]. Head worker occupation: 20.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.147e+05  1.594e+01  y = x₀                                        2           1.547e+05  1.380e+00  y = square(x₀)                                3           6.661e+03  3.145e+00  y = (27.319 * x₀)                             5           6.597e+03  4.875e-03  y = (-1.3761 + (27.319 * x₀))                 6           6.542e+03  8.305e-03  y = (cube(-1.3761) + (27.319 * x₀))           8           6.494e+03  3.700e-03  y = cube(log(cube(x₀ + -0.87776)) + -0.69429) 10          6.404e+03  6.963e-03  y = cube(log(cube((x₀ + -0.29464) + -0.76502)) + -0.69429)                                                                    12          5.302e+03  9.440e-02  y = ((square(square(-2.3917) * square(0.96542)) * (x₀ + -1.130...                                                                                               6)) + -0.22678)                               14          5.247e+03  5.269e-03  y = ((square(square(-2.3917) * square(0.96542)) * (x₀ + -1.283...                                                                                               )) + square(square(-1.283)))                  15          4.984e+03  5.142e-02  y = ((square(square(-2.3917) * square(0.96542)) * ((x₀ + -0.37...                                                                                               314) + -1.1306)) + square(-0.22678))          16          4.958e+03  5.208e-03  y = ((square(square(-2.3917) * square(0.96542)) * (x₀ + ((-1.1...                                                                                               306 * 0.59792) + -1.4549))) + -1.283)         ---------------------------------------------------------------------------------------------------
# 4.3%┣██                                           ┫ 26/600 [00:00<00:10, 59it/s]Expressions evaluated per second: [.....]. Head worker occupation: 26.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.147e+05  1.594e+01  y = x₀                                        2           1.547e+05  1.380e+00  y = square(x₀)                                3           6.661e+03  3.145e+00  y = (27.319 * x₀)                             5           6.597e+03  4.875e-03  y = (-1.3761 + (27.319 * x₀))                 6           6.542e+03  8.305e-03  y = (cube(-1.3761) + (27.319 * x₀))           8           6.462e+03  6.188e-03  y = cube(log(cube(x₀ + -0.95955)) + -0.70033) 10          6.404e+03  4.476e-03  y = cube(log(cube((x₀ + -0.29464) + -0.76502)) + -0.69429)                                                                    11          5.821e+03  9.557e-02  y = (square(x₀ + 1.3956) + (-0.00020745 * square(x₀ * x₀)))                                                                   12          5.302e+03  9.324e-02  y = ((square(square(-2.3917) * square(0.96542)) * (x₀ + -1.130...                                                                                               6)) + -0.22678)                               14          5.247e+03  5.269e-03  y = ((square(square(-2.3917) * square(0.96542)) * (x₀ + -1.283...                                                                                               )) + square(square(-1.283)))                  15          4.984e+03  5.142e-02  y = ((square(square(-2.3917) * square(0.96542)) * ((x₀ + -0.37...                                                                                               314) + -1.1306)) + square(-0.22678))          16          4.958e+03  5.208e-03  y = ((square(square(-2.3917) * square(0.96542)) * (x₀ + ((-1.1...                                                                                               306 * 0.59792) + -1.4549))) + -1.283)         ---------------------------------------------------------------------------------------------------
# 5.8%┣██▋                                          ┫ 35/600 [00:00<00:08, 69it/s]Expressions evaluated per second: [.....]. Head worker occupation: 24.3%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.147e+05  1.594e+01  y = x₀                                        2           1.547e+05  1.380e+00  y = square(x₀)                                3           6.661e+03  3.145e+00  y = (27.319 * x₀)                             4           6.661e+03  9.591e-05  y = (x₀ * cube(3.0127))                       5           6.081e+03  9.112e-02  y = (27.319 * (x₀ + -0.81593))                7           5.299e+03  6.877e-02  y = (log(square(square(square(x₀)))) * x₀)    13          3.951e+03  4.894e-02  y = ((29.578 * (((x₀ + cube(square(-0.24738))) + -1.8533) + -1...                                                                                               .8288)) + x₀)                                 ---------------------------------------------------------------------------------------------------
# 7.3%┣███▎                                         ┫ 44/600 [00:01<00:07, 78it/s]Expressions evaluated per second: [.....]. Head worker occupation: 23.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.147e+05  1.594e+01  y = x₀                                        2           1.547e+05  1.380e+00  y = square(x₀)                                3           6.661e+03  3.145e+00  y = (27.346 * x₀)                             5           6.081e+03  4.556e-02  y = (27.319 * (x₀ + -0.81593))                7           5.085e+03  8.942e-02  y = ((27.319 * (x₀ + -2.224)) + x₀)           10          5.013e+03  4.750e-03  y = (square(square(-2.3917) * square(0.96542)) * (x₀ + -1.4549...                                                                                               ))                                            11          4.736e+03  5.690e-02  y = (square(square(-2.3917) * 0.96542) * (x₀ + (-1.1306 + -1.4...                                                                                               549)))                                        13          3.951e+03  9.061e-02  y = ((29.578 * (((x₀ + cube(square(-0.24738))) + -1.8533) + -1...                                                                                               .8288)) + x₀)                                 ---------------------------------------------------------------------------------------------------
# 8.5%┣███▉                                         ┫ 51/600 [00:01<00:07, 82it/s]Expressions evaluated per second: [.....]. Head worker occupation: 21.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           4.401e+05  1.594e+01  y = 186.98                                    2           1.547e+05  1.046e+00  y = square(x₀)                                3           6.661e+03  3.145e+00  y = (27.346 * x₀)                             5           6.081e+03  4.556e-02  y = (27.319 * (x₀ + -0.81593))                7           3.464e+03  2.813e-01  y = (((0.19543 * x₀) + 19.944) * x₀)          ---------------------------------------------------------------------------------------------------
# 9.8%┣████▍                                        ┫ 59/600 [00:01<00:06, 86it/s]Expressions evaluated per second: [.....]. Head worker occupation: 22.9%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.910e+05  1.594e+01  y = 686.05                                    2           1.547e+05  2.107e-01  y = square(x₀)                                3           6.661e+03  3.145e+00  y = (27.346 * x₀)                             5           6.080e+03  4.561e-02  y = (27.319 * (x₀ + -0.94787))                7           3.464e+03  2.813e-01  y = (((0.19543 * x₀) + 19.944) * x₀)          9           3.313e+03  2.236e-02  y = ((((x₀ * 0.14127) + 23.234) * x₀) + -41.73)                                                                               ---------------------------------------------------------------------------------------------------
# 11.0%┣████▉                                       ┫ 66/600 [00:01<00:06, 89it/s]Expressions evaluated per second: [.....]. Head worker occupation: 22.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.910e+05  1.594e+01  y = 686.05                                    2           1.547e+05  2.107e-01  y = square(x₀)                                3           6.661e+03  3.145e+00  y = (27.346 * x₀)                             5           6.080e+03  4.561e-02  y = (27.319 * (x₀ + -0.94787))                7           3.464e+03  2.813e-01  y = (((0.19543 * x₀) + 19.944) * x₀)          9           3.313e+03  2.236e-02  y = ((((x₀ * 0.14127) + 23.234) * x₀) + -41.73)                                                                               ---------------------------------------------------------------------------------------------------
# 12.2%┣█████▍                                      ┫ 73/600 [00:01<00:06, 92it/s]Expressions evaluated per second: [.....]. Head worker occupation: 23.3%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.910e+05  1.594e+01  y = 686.05                                    2           1.547e+05  2.107e-01  y = square(x₀)                                3           6.661e+03  3.145e+00  y = (27.346 * x₀)                             5           6.043e+03  4.871e-02  y = (27.346 * (x₀ + -0.88579))                7           3.464e+03  2.782e-01  y = (((0.19543 * x₀) + 19.944) * x₀)          9           3.313e+03  2.236e-02  y = ((((x₀ * 0.14127) + 23.234) * x₀) + -41.73)                                                                               ---------------------------------------------------------------------------------------------------
# 13.2%┣█████▉                                      ┫ 79/600 [00:01<00:06, 93it/s]Expressions evaluated per second: [.....]. Head worker occupation: 22.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.910e+05  1.594e+01  y = 686.05                                    2           1.547e+05  2.107e-01  y = square(x₀)                                3           6.661e+03  3.145e+00  y = (27.346 * x₀)                             5           6.043e+03  4.871e-02  y = (27.346 * (x₀ + -0.88579))                7           3.464e+03  2.782e-01  y = (((0.19543 * x₀) + 19.944) * x₀)          9           3.313e+03  2.236e-02  y = ((((x₀ * 0.14127) + 23.234) * x₀) + -41.73)                                                                               ---------------------------------------------------------------------------------------------------
# 14.3%┣██████▎                                     ┫ 86/600 [00:01<00:05, 95it/s]Expressions evaluated per second: [.....]. Head worker occupation: 22.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.910e+05  1.594e+01  y = 686.05                                    2           1.547e+05  2.107e-01  y = square(x₀)                                3           6.661e+03  3.145e+00  y = (27.346 * x₀)                             5           3.951e+03  2.612e-01  y = ((30.58 * x₀) + -108.94)                  7           3.464e+03  6.573e-02  y = (((0.19543 * x₀) + 19.944) * x₀)          9           3.313e+03  2.236e-02  y = ((((x₀ * 0.14127) + 23.234) * x₀) + -41.73)                                                                               ---------------------------------------------------------------------------------------------------
# 15.7%┣███████                                     ┫ 94/600 [00:01<00:05, 98it/s]Expressions evaluated per second: [.....]. Head worker occupation: 22.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.910e+05  1.594e+01  y = 686.05                                    2           1.547e+05  2.107e-01  y = square(x₀)                                3           6.661e+03  3.145e+00  y = (27.346 * x₀)                             5           3.951e+03  2.612e-01  y = ((30.58 * x₀) + -108.94)                  7           3.464e+03  6.573e-02  y = (((0.19543 * x₀) + 19.944) * x₀)          9           3.313e+03  2.236e-02  y = ((((x₀ * 0.14127) + 23.234) * x₀) + -41.73)                                                                               ---------------------------------------------------------------------------------------------------
# 16.5%┣███████▎                                    ┫ 99/600 [00:01<00:05, 98it/s]Expressions evaluated per second: [.....]. Head worker occupation: 21.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.910e+05  1.594e+01  y = 686.05                                    2           1.547e+05  2.107e-01  y = square(x₀)                                3           6.661e+03  3.145e+00  y = (27.346 * x₀)                             5           3.951e+03  2.612e-01  y = ((30.58 * x₀) + -108.94)                  7           3.464e+03  6.573e-02  y = (((0.19543 * x₀) + 19.944) * x₀)          9           3.313e+03  2.236e-02  y = ((((x₀ * 0.14127) + 23.234) * x₀) + -41.73)                                                                               ---------------------------------------------------------------------------------------------------
# 17.7%┣███████▍                                  ┫ 106/600 [00:01<00:05, 100it/s]Expressions evaluated per second: 2.83e+05. Head worker occupation: 21.3%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.910e+05  1.594e+01  y = 686.05                                    2           1.547e+05  2.107e-01  y = square(x₀)                                3           6.661e+03  3.145e+00  y = (27.346 * x₀)                             5           3.951e+03  2.612e-01  y = ((30.58 * x₀) + -108.94)                  7           3.464e+03  6.573e-02  y = (((0.19543 * x₀) + 19.944) * x₀)          9           3.313e+03  2.236e-02  y = ((((x₀ * 0.14127) + 23.234) * x₀) + -41.73)                                                                               ---------------------------------------------------------------------------------------------------
# 18.7%┣███████▉                                  ┫ 112/600 [00:01<00:05, 100it/s]Expressions evaluated per second: 2.83e+05. Head worker occupation: 20.9%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.910e+05  1.594e+01  y = 686.05                                    2           1.547e+05  2.107e-01  y = square(x₀)                                3           6.661e+03  3.145e+00  y = (27.346 * x₀)                             5           3.951e+03  2.612e-01  y = ((30.58 * x₀) + -108.94)                  7           3.464e+03  6.573e-02  y = (((0.19543 * x₀) + 19.944) * x₀)          9           3.313e+03  2.236e-02  y = ((((x₀ * 0.14127) + 23.234) * x₀) + -41.73)                                                                               ---------------------------------------------------------------------------------------------------
# 19.3%┣████████▎                                  ┫ 116/600 [00:01<00:05, 98it/s]Expressions evaluated per second: 2.83e+05. Head worker occupation: 20.4%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.910e+05  1.594e+01  y = 686.05                                    2           1.547e+05  2.107e-01  y = square(x₀)                                3           6.661e+03  3.145e+00  y = (27.346 * x₀)                             5           3.951e+03  2.612e-01  y = ((30.58 * x₀) + -108.94)                  7           3.464e+03  6.573e-02  y = (((0.19543 * x₀) + 19.944) * x₀)          9           3.313e+03  2.236e-02  y = ((((x₀ * 0.14127) + 23.234) * x₀) + -41.73)                                                                               ---------------------------------------------------------------------------------------------------
# 20.0%┣████████▋                                  ┫ 120/600 [00:01<00:05, 96it/s]Expressions evaluated per second: 2.83e+05. Head worker occupation: 19.8%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.910e+05  1.594e+01  y = 686.05                                    2           1.547e+05  2.107e-01  y = square(x₀)                                3           6.661e+03  3.145e+00  y = (27.346 * x₀)                             5           3.951e+03  2.612e-01  y = ((30.58 * x₀) + -108.94)                  7           3.464e+03  6.573e-02  y = (((0.19543 * x₀) + 19.944) * x₀)          9           3.313e+03  2.236e-02  y = ((((x₀ * 0.14127) + 23.234) * x₀) + -41.73)                                                                               ---------------------------------------------------------------------------------------------------
# 21.2%┣█████████                                  ┫ 127/600 [00:01<00:05, 97it/s]Expressions evaluated per second: 2.83e+05. Head worker occupation: 19.8%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.910e+05  1.594e+01  y = 686.05                                    2           1.547e+05  2.107e-01  y = square(x₀)                                3           6.661e+03  3.145e+00  y = (27.346 * x₀)                             5           3.951e+03  2.612e-01  y = ((30.58 * x₀) + -108.94)                  7           3.464e+03  6.573e-02  y = (((0.19543 * x₀) + 19.944) * x₀)          9           3.313e+03  2.236e-02  y = ((((x₀ * 0.14127) + 23.234) * x₀) + -41.73)                                                                               ---------------------------------------------------------------------------------------------------
# 22.2%┣█████████▌                                 ┫ 133/600 [00:01<00:05, 97it/s]Expressions evaluated per second: 2.83e+05. Head worker occupation: 21.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.910e+05  1.594e+01  y = 686.05                                    2           1.547e+05  2.107e-01  y = square(x₀)                                3           6.661e+03  3.145e+00  y = (27.346 * x₀)                             5           3.951e+03  2.612e-01  y = ((30.58 * x₀) + -108.94)                  7           3.464e+03  6.573e-02  y = (((0.19543 * x₀) + 19.944) * x₀)          9           3.313e+03  2.236e-02  y = ((((x₀ * 0.14127) + 23.234) * x₀) + -41.73)                                                                               ---------------------------------------------------------------------------------------------------
# 23.3%┣██████████                                 ┫ 140/600 [00:01<00:05, 97it/s]Expressions evaluated per second: 2.83e+05. Head worker occupation: 20.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.910e+05  1.594e+01  y = 686.05                                    2           1.547e+05  2.107e-01  y = square(x₀)                                3           6.661e+03  3.145e+00  y = (27.346 * x₀)                             5           3.951e+03  2.612e-01  y = ((30.58 * x₀) + -108.94)                  7           3.464e+03  6.573e-02  y = (((0.19543 * x₀) + 19.944) * x₀)          9           3.313e+03  2.236e-02  y = ((((x₀ * 0.14127) + 23.234) * x₀) + -41.73)                                                                               ---------------------------------------------------------------------------------------------------
# 24.3%┣██████████▌                                ┫ 146/600 [00:01<00:05, 98it/s]Expressions evaluated per second: 2.83e+05. Head worker occupation: 20.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.910e+05  1.594e+01  y = 686.05                                    2           1.547e+05  2.107e-01  y = square(x₀)                                3           6.661e+03  3.145e+00  y = (27.346 * x₀)                             5           3.951e+03  2.612e-01  y = ((30.58 * x₀) + -108.94)                  7           3.464e+03  6.573e-02  y = (((0.19543 * x₀) + 19.944) * x₀)          9           3.313e+03  2.236e-02  y = ((((x₀ * 0.14127) + 23.234) * x₀) + -41.73)                                                                               ---------------------------------------------------------------------------------------------------
# 25.3%┣███████████                                ┫ 152/600 [00:02<00:05, 98it/s]Expressions evaluated per second: 2.83e+05. Head worker occupation: 20.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.910e+05  1.594e+01  y = 686.05                                    2           1.547e+05  2.107e-01  y = square(x₀)                                3           6.661e+03  3.145e+00  y = (27.346 * x₀)                             5           3.951e+03  2.612e-01  y = ((30.58 * x₀) + -108.94)                  7           3.464e+03  6.573e-02  y = (((0.19543 * x₀) + 19.944) * x₀)          9           3.313e+03  2.236e-02  y = ((((x₀ * 0.14127) + 23.234) * x₀) + -41.73)                                                                               ---------------------------------------------------------------------------------------------------
# 26.5%┣███████████▍                               ┫ 159/600 [00:02<00:04, 99it/s]Expressions evaluated per second: 2.83e+05. Head worker occupation: 20.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.910e+05  1.594e+01  y = 686.05                                    2           1.547e+05  2.107e-01  y = square(x₀)                                3           6.661e+03  3.145e+00  y = (27.346 * x₀)                             5           3.951e+03  2.612e-01  y = ((30.58 * x₀) + -108.94)                  7           3.464e+03  6.573e-02  y = (((0.19543 * x₀) + 19.944) * x₀)          9           3.313e+03  2.236e-02  y = ((((x₀ * 0.14127) + 23.234) * x₀) + -41.73)                                                                               ---------------------------------------------------------------------------------------------------
# 27.8%┣███████████▊                              ┫ 167/600 [00:02<00:04, 100it/s]Expressions evaluated per second: 2.83e+05. Head worker occupation: 20.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.910e+05  1.594e+01  y = 686.05                                    2           1.547e+05  2.107e-01  y = square(x₀)                                3           6.661e+03  3.145e+00  y = (27.346 * x₀)                             5           3.951e+03  2.612e-01  y = ((30.58 * x₀) + -108.94)                  7           3.464e+03  6.573e-02  y = (((0.19543 * x₀) + 19.944) * x₀)          9           3.313e+03  2.236e-02  y = ((((x₀ * 0.14127) + 23.234) * x₀) + -41.73)                                                                               ---------------------------------------------------------------------------------------------------
# 29.0%┣████████████▏                             ┫ 174/600 [00:02<00:04, 101it/s]Expressions evaluated per second: 2.83e+05. Head worker occupation: 21.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.910e+05  1.594e+01  y = 686.05                                    2           1.547e+05  2.107e-01  y = square(x₀)                                3           6.661e+03  3.145e+00  y = (27.346 * x₀)                             5           3.951e+03  2.612e-01  y = ((30.58 * x₀) + -108.94)                  7           3.464e+03  6.573e-02  y = (((0.19543 * x₀) + 19.944) * x₀)          9           3.313e+03  2.236e-02  y = ((((x₀ * 0.14127) + 23.234) * x₀) + -41.73)                                                                               ---------------------------------------------------------------------------------------------------
# 30.3%┣████████████▊                             ┫ 182/600 [00:02<00:04, 103it/s]Expressions evaluated per second: 2.83e+05. Head worker occupation: 21.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.910e+05  1.594e+01  y = 686.05                                    2           1.547e+05  2.107e-01  y = square(x₀)                                3           6.661e+03  3.145e+00  y = (27.346 * x₀)                             5           3.951e+03  2.612e-01  y = ((30.58 * x₀) + -108.94)                  7           3.464e+03  6.573e-02  y = (((0.19543 * x₀) + 19.944) * x₀)          9           3.313e+03  2.236e-02  y = ((((x₀ * 0.14127) + 23.234) * x₀) + -41.73)                                                                               ---------------------------------------------------------------------------------------------------
# 31.5%┣█████████████▎                            ┫ 189/600 [00:02<00:04, 103it/s]Expressions evaluated per second: 2.83e+05. Head worker occupation: 21.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.910e+05  1.594e+01  y = 686.05                                    2           1.547e+05  2.107e-01  y = square(x₀)                                3           6.661e+03  3.145e+00  y = (27.346 * x₀)                             5           3.951e+03  2.612e-01  y = ((30.58 * x₀) + -108.94)                  7           3.464e+03  6.573e-02  y = (((0.19543 * x₀) + 19.944) * x₀)          9           3.313e+03  2.236e-02  y = ((((x₀ * 0.14127) + 23.234) * x₀) + -41.73)                                                                               ---------------------------------------------------------------------------------------------------
# 32.5%┣█████████████▋                            ┫ 195/600 [00:02<00:04, 103it/s]Expressions evaluated per second: 2.83e+05. Head worker occupation: 21.4%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.910e+05  1.594e+01  y = 686.05                                    2           1.547e+05  2.107e-01  y = square(x₀)                                3           6.661e+03  3.145e+00  y = (27.346 * x₀)                             5           3.951e+03  2.612e-01  y = ((30.58 * x₀) + -108.94)                  7           3.464e+03  6.573e-02  y = (((0.19543 * x₀) + 19.944) * x₀)          9           3.313e+03  2.236e-02  y = ((((x₀ * 0.14127) + 23.234) * x₀) + -41.73)                                                                               ---------------------------------------------------------------------------------------------------
# 33.5%┣██████████████                            ┫ 201/600 [00:02<00:04, 103it/s]Expressions evaluated per second: 2.83e+05. Head worker occupation: 21.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.910e+05  1.594e+01  y = 686.05                                    2           1.547e+05  2.107e-01  y = square(x₀)                                3           6.661e+03  3.145e+00  y = (27.346 * x₀)                             5           3.951e+03  2.612e-01  y = ((30.58 * x₀) + -108.94)                  7           3.464e+03  6.573e-02  y = (((0.19543 * x₀) + 19.944) * x₀)          9           3.313e+03  2.236e-02  y = ((((x₀ * 0.14127) + 23.234) * x₀) + -41.73)                                                                               19          3.313e+03  -0.000e+00  y = (((((0.14131 * x₀) + cube(cube(0.0016692 * (0.10796 * x₀))...                                                                                              )) + (22.389 + 0.84272)) * x₀) + -41.693)     ---------------------------------------------------------------------------------------------------
# ...
# 96.0%┣█████████████████████████████████████████▎ ┫ 576/600 [00:06<00:00, 97it/s]Expressions evaluated per second: 2.88e+05. Head worker occupation: 20.4%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.910e+05  1.594e+01  y = 686.12                                    2           1.547e+05  2.107e-01  y = square(x₀)                                4           4.966e+04  5.682e-01  y = cube(log(cube(x₀)))                       5           3.533e+04  3.405e-01  y = square(log(cube(cube(x₀))))               6           7.248e+03  1.584e+00  y = cube(log(cube(x₀)) + -0.77356)            8           6.097e+03  8.639e-02  y = cube(log(cube(-1.583 + x₀)) + -0.61348)   10          5.515e+03  5.017e-02  y = cube(log(cube(x₀ + -3.1774) + x₀) + -0.4517)                                                                              11          5.433e+03  1.513e-02  y = cube(log(cube(x₀ + -3.1773) + square(x₀)) + -0.50545)                                                                     12          5.134e+03  5.650e-02  y = cube(log(cube(x₀ + cube(-1.5177)) + cube(3.1842)) + -0.419...                                                                                               94)                                           13          4.866e+03  5.364e-02  y = cube(log(cube(x₀ + cube(-1.5177)) + square(square(3.1842))...                                                                                               ) + -0.41994)                                 14          4.863e+03  5.763e-04  y = cube(log(cube(x₀ + cube(-1.5177)) + square(cube(square(-1....                                                                                               4764)))) + -0.43525)                          15          4.081e+03  1.753e-01  y = cube(log(cube(x₀ + 1.5564)) + ((-2.1892 + -0.29419) + squa...                                                                                               re(log(log(x₀)))))                            17          4.079e+03  2.848e-04  y = cube(log(cube(x₀ + 1.5564) + x₀) + ((-2.1892 + -0.29419) +...                                                                                                square(log(log(x₀)))))                       19          4.063e+03  1.989e-03  y = cube(log((cube(x₀ + 1.47) + x₀) + x₀) + ((-2.1892 + -0.293...                                                                                               95) + square(log(log(x₀)))))                  20          3.782e+03  7.168e-02  y = ((cube(log(cube(x₀)) + (((-5.364 + cube(-0.21248)) + squar...                                                                                               e(log(log(x₀)))) + 2.7261)) + 42.811) + x₀)   ---------------------------------------------------------------------------------------------------
# 96.7%┣█████████████████████████████████████████▋ ┫ 580/600 [00:06<00:00, 97it/s]Expressions evaluated per second: 2.88e+05. Head worker occupation: 20.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.910e+05  1.594e+01  y = 686.12                                    2           1.547e+05  2.107e-01  y = square(x₀)                                4           4.966e+04  5.682e-01  y = cube(log(cube(x₀)))                       5           3.533e+04  3.405e-01  y = square(log(cube(cube(x₀))))               6           7.248e+03  1.584e+00  y = cube(log(cube(x₀)) + -0.77356)            8           6.097e+03  8.639e-02  y = cube(log(cube(-1.583 + x₀)) + -0.61348)   10          5.515e+03  5.017e-02  y = cube(log(cube(x₀ + -3.1774) + x₀) + -0.4517)                                                                              11          5.433e+03  1.513e-02  y = cube(log(cube(x₀ + -3.1773) + square(x₀)) + -0.50545)                                                                     12          5.134e+03  5.650e-02  y = cube(log(cube(x₀ + cube(-1.5177)) + cube(3.1842)) + -0.419...                                                                                               94)                                           13          4.866e+03  5.364e-02  y = cube(log(cube(x₀ + cube(-1.5177)) + square(square(3.1842))...                                                                                               ) + -0.41994)                                 14          4.863e+03  5.763e-04  y = cube(log(cube(x₀ + cube(-1.5177)) + square(cube(square(-1....                                                                                               4764)))) + -0.43525)                          15          4.081e+03  1.753e-01  y = cube(log(cube(x₀ + 1.5564)) + ((-2.1892 + -0.29419) + squa...                                                                                               re(log(log(x₀)))))                            17          4.079e+03  2.848e-04  y = cube(log(cube(x₀ + 1.5564) + x₀) + ((-2.1892 + -0.29419) +...                                                                                                square(log(log(x₀)))))                       19          4.063e+03  1.989e-03  y = cube(log((cube(x₀ + 1.47) + x₀) + x₀) + ((-2.1892 + -0.293...                                                                                               95) + square(log(log(x₀)))))                  20          3.782e+03  7.168e-02  y = ((cube(log(cube(x₀)) + (((-5.364 + cube(-0.21248)) + squar...                                                                                               e(log(log(x₀)))) + 2.7261)) + 42.811) + x₀)   ---------------------------------------------------------------------------------------------------
# 98.0%┣██████████████████████████████████████████▏┫ 588/600 [00:06<00:00, 97it/s]Expressions evaluated per second: 2.84e+05. Head worker occupation: 20.3%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.910e+05  1.594e+01  y = 686.12                                    2           1.547e+05  2.107e-01  y = square(x₀)                                4           4.966e+04  5.682e-01  y = cube(log(cube(x₀)))                       5           3.533e+04  3.405e-01  y = square(log(cube(cube(x₀))))               6           7.248e+03  1.584e+00  y = cube(log(cube(x₀)) + -0.77356)            8           6.097e+03  8.639e-02  y = cube(log(cube(-1.583 + x₀)) + -0.61348)   10          5.515e+03  5.017e-02  y = cube(log(cube(x₀ + -3.1774) + x₀) + -0.4517)                                                                              11          5.433e+03  1.513e-02  y = cube(log(cube(x₀ + -3.1773) + square(x₀)) + -0.50545)                                                                     12          5.134e+03  5.650e-02  y = cube(log(cube(x₀ + cube(-1.5177)) + cube(3.1842)) + -0.419...                                                                                               94)                                           13          4.866e+03  5.364e-02  y = cube(log(cube(x₀ + cube(-1.5177)) + square(square(3.1842))...                                                                                               ) + -0.41994)                                 14          4.863e+03  5.763e-04  y = cube(log(cube(x₀ + cube(-1.5177)) + square(cube(square(-1....                                                                                               4764)))) + -0.43525)                          15          4.081e+03  1.753e-01  y = cube(log(cube(x₀ + 1.5564)) + ((-2.1892 + -0.29419) + squa...                                                                                               re(log(log(x₀)))))                            17          4.079e+03  2.848e-04  y = cube(log(cube(x₀ + 1.5564) + x₀) + ((-2.1892 + -0.29419) +...                                                                                                square(log(log(x₀)))))                       19          4.063e+03  1.989e-03  y = cube(log((cube(x₀ + 1.47) + x₀) + x₀) + ((-2.1892 + -0.293...                                                                                               95) + square(log(log(x₀)))))                  20          3.782e+03  7.168e-02  y = ((cube(log(cube(x₀)) + (((-5.364 + cube(-0.21248)) + squar...                                                                                               e(log(log(x₀)))) + 2.7261)) + 42.811) + x₀)   ---------------------------------------------------------------------------------------------------
# 98.8%┣██████████████████████████████████████████▌┫ 593/600 [00:06<00:00, 96it/s]Expressions evaluated per second: 2.84e+05. Head worker occupation: 20.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.910e+05  1.594e+01  y = 686.12                                    2           1.547e+05  2.107e-01  y = square(x₀)                                4           4.966e+04  5.682e-01  y = cube(log(cube(x₀)))                       5           3.533e+04  3.405e-01  y = square(log(cube(cube(x₀))))               6           7.248e+03  1.584e+00  y = cube(log(cube(x₀)) + -0.77356)            8           6.097e+03  8.639e-02  y = cube(log(cube(-1.583 + x₀)) + -0.61348)   10          5.515e+03  5.017e-02  y = cube(log(cube(x₀ + -3.1774) + x₀) + -0.4517)                                                                              11          5.433e+03  1.513e-02  y = cube(log(cube(x₀ + -3.1773) + square(x₀)) + -0.50545)                                                                     12          5.134e+03  5.650e-02  y = cube(log(cube(x₀ + cube(-1.5177)) + cube(3.1842)) + -0.419...                                                                                               94)                                           13          4.866e+03  5.364e-02  y = cube(log(cube(x₀ + cube(-1.5177)) + square(square(3.1842))...                                                                                               ) + -0.41994)                                 14          4.863e+03  5.763e-04  y = cube(log(cube(x₀ + cube(-1.5177)) + square(cube(square(-1....                                                                                               4764)))) + -0.43525)                          15          4.081e+03  1.753e-01  y = cube(log(cube(x₀ + 1.5564)) + ((-2.1892 + -0.29419) + squa...                                                                                               re(log(log(x₀)))))                            17          4.079e+03  2.848e-04  y = cube(log(cube(x₀ + 1.5564) + x₀) + ((-2.1892 + -0.29419) +...                                                                                                square(log(log(x₀)))))                       18          4.075e+03  8.531e-04  y = cube(log(cube(x₀ + 1.5564) + square(-2.1892)) + ((-2.1892 ...                                                                                               + -0.29419) + square(log(log(x₀)))))          19          4.063e+03  3.125e-03  y = cube(log((cube(x₀ + 1.47) + x₀) + x₀) + ((-2.1892 + -0.293...                                                                                               95) + square(log(log(x₀)))))                  20          3.782e+03  7.168e-02  y = ((cube(log(cube(x₀)) + (((-5.364 + cube(-0.21248)) + squar...                                                                                               e(log(log(x₀)))) + 2.7261)) + 42.811) + x₀)   ---------------------------------------------------------------------------------------------------

# %%
registros_ = registros

# %%
for i in registros_:
  loss = i[1]
  score = i[2]
  complexity = i[0]
  w = (loss * score)/complexity
  if math.isnan(w):
    i.append(0)
  else:
    i.append(w)

lista_melhor_valor = max(registros_, key=lambda x: x[6])

# %% [markdown]
# ## Save result

# %%
def salvar_dados(dados, arquivo):
  if os.path.exists(arquivo):
    with open(arquivo, 'rb') as f:
      dados_exist = pickle.load(f)

    dados_exist.update(dados)
  else:
    dados_exist = dados
  
  with open(arquivo, 'wb') as f:
    pickle.dump(dados_exist, f)
  
novos_dados = {'quicksort_x^2': lista_melhor_valor[4]}
caminho_arquivo = 'dados.pickle'

salvar_dados(novos_dados, caminho_arquivo)

# %%
def carregar_dados(arquivo):
    # Carrega os dados do arquivo pickle
    with open(arquivo, 'rb') as f:
        dados = pickle.load(f)
    return dados

caminho_arquivo = 'dados.pickle'
dados_carregados = carregar_dados(caminho_arquivo)

print("Conteúdo do arquivo pickle:")
for k, v in dados_carregados.items(): print(k, ' = ',v)
# Out:
# Conteúdo do arquivo pickle:
# shellsort_NlogN  =  4.862569*x0*log(x0)
# mergesort_NlogN  =  5.5040717*x0 + 8.03698770358715
# bubblesort_x^2  =  1.517833856016*x0**2
# levenshtein_distance_MN  =  3.52552934090449*x1**2
# selectsort_x^2  =  1.13491224207076*x0**2
# insertionsort_x^2  =  0.84217347354001*x0**2
# quicksort_x^2  =  7.605706*x0*log(x0)
