# %%
# https://www.geeksforgeeks.org/bubble-sort/

import numpy as np
from line_profiler import LineProfiler
from pysr import PySRRegressor
import random
import os
import sys
import math
import pickle

# %% [markdown]
# ## Bubblesort Algorithm

# %%
def bubble_sort(arr): # x^2
  n = len(arr)
  for i in range(n):
    swapped = False
    for j in range(0, n-i-1):
      if arr[j] > arr[j+1]:
        arr[j], arr[j+1] = arr[j+1], arr[j]
        swapped = True
    if (swapped == False):
      break

# %% [markdown]
# ## Frequency Count Method

# %%
X_y = []
i=50
for n in range(2,i+1): # started with 2 itens until 50 itens in the list
  lprofiler = LineProfiler()
  lp_wrapper = lprofiler(bubble_sort)

  # create a list with random number between 1 to 10000
  # with n number in the list
  input = random.choices(range(10000), k=n)
  lp_wrapper(input)

  stats = lprofiler.get_stats()
  line_numbers = []
  hits = []

  for line in stats.timings.values():
    for i in line:
      line_numbers.append(i[0])
      hits.append(i[1])

  X_y.append([n, sum(hits)])

dados = np.array(X_y)

X = dados[:, 0]
y = dados[:, 1]
X_reshaped = X.reshape(-1, 1)

# %%
resultados_com_menor_loss = []
repeat = 5
registros = []

original_stdout = sys.stdout

with open(os.devnull, 'w') as devnull:
  sys.stdout = devnull

  for i in range(repeat):

    # first combination
    reg1 = PySRRegressor(
      binary_operators=["*", "+"],
      unary_operators=["log", "square", "cube"],
    )

    fit1 = reg1.fit(X_reshaped, y)
    best_program1 = fit1.get_best()

    registro1 = []
    for index, value in enumerate(best_program1):
      registro1.append(value)
      
    registros.append(registro1)

    # second combination
    reg2 = PySRRegressor(
      binary_operators=["*"],
      unary_operators=["log", "square", "cube"],
    )

    fit2 = reg2.fit(X_reshaped, y)
    best_program2 = fit2.get_best()

    registro2 = []
    for index, value in enumerate(best_program2):
      registro2.append(value)
    registros.append(registro2)

    # third combinarion
    reg3 = PySRRegressor(
      binary_operators=["+"],
      unary_operators=["log", "square", "cube"],
    )

    fit3 = reg3.fit(X_reshaped, y)
    best_program3 = fit3.get_best()

    registro3 = []
    for index, value in enumerate(best_program3):
      registro3.append(value)
    registros.append(registro3)
    
sys.stdout = original_stdout
# Out:
# [ Info: Started!
# 0.0%┣                                              ┫ 0/600 [00:00<00:-3, -0s/it]Expressions evaluated per second: [.....]. Head worker occupation: 0.0%         Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.996e+06  1.594e+01  y = x₀                                        2           3.684e+05  2.096e+00  y = square(x₀)                                4           3.345e+05  4.817e-02  y = (square(x₀) + x₀)                         5           1.524e+05  7.861e-01  y = square(log(x₀) + x₀)                      6           3.161e+04  1.573e+00  y = square(log(square(x₀)) + x₀)              7           1.826e+04  5.484e-01  y = ((square(x₀) * 0.60107) + square(x₀))     ---------------------------------------------------------------------------------------------------
# 0.7%┣▎                                             ┫ 4/600 [00:00<00:13, 47it/s]Expressions evaluated per second: [.....]. Head worker occupation: 14.9%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.996e+06  1.594e+01  y = x₀                                        2           3.684e+05  2.096e+00  y = square(x₀)                                4           2.194e+04  1.410e+00  y = (square(x₀) * 1.6162)                     6           2.192e+04  2.811e-04  y = (-0.084123 + (square(x₀) * 1.6162))       7           9.599e+03  8.259e-01  y = ((x₀ * (0.79605 + 0.70037)) * x₀)         8           9.253e+03  3.672e-02  y = (((square(x₀) * 2.1152) * 0.72431) + 0.42172)                                                                             9           8.976e+03  3.036e-02  y = ((x₀ * (0.77376 + 0.70037)) * (x₀ + 0.77376))                                                                             10          8.629e+03  3.938e-02  y = ((x₀ * (0.77376 + 0.70037)) * (x₀ + log(2.7965)))                                                                         11          8.626e+03  4.208e-04  y = ((x₀ * (0.77376 + 0.70037)) * (x₀ + log(log(x₀))))                                                                        12          8.406e+03  2.581e-02  y = ((x₀ * (0.7872 + 0.60452)) * (x₀ + log(-0.4254 + x₀)))                                                                    ---------------------------------------------------------------------------------------------------
# 1.7%┣▊                                            ┫ 10/600 [00:00<00:08, 73it/s]Expressions evaluated per second: [.....]. Head worker occupation: 31.9%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.996e+06  1.594e+01  y = x₀                                        2           3.684e+05  2.096e+00  y = square(x₀)                                4           1.739e+04  1.527e+00  y = cube(square(log(x₀)))                     6           8.983e+03  3.301e-01  y = square((x₀ * 0.88958) * -1.3849)          7           8.983e+03  1.192e-07  y = (0.066444 * square(square(2.1862) * x₀))  8           8.426e+03  6.403e-02  y = square((x₀ * log(cube(1.4917))) + 1.2984) 11          8.423e+03  1.427e-04  y = ((x₀ * ((0.43857 * x₀) + x₀)) + (3.2024 * x₀))                                                                            12          8.406e+03  1.987e-03  y = ((x₀ * (0.7872 + 0.60452)) * (x₀ + log(-0.4254 + x₀)))                                                                    ---------------------------------------------------------------------------------------------------
# 2.8%┣█▎                                           ┫ 17/600 [00:00<00:07, 84it/s]Expressions evaluated per second: [.....]. Head worker occupation: 32.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.996e+06  1.594e+01  y = x₀                                        2           3.684e+05  2.096e+00  y = square(x₀)                                4           1.739e+04  1.527e+00  y = cube(square(log(x₀)))                     6           8.983e+03  3.301e-01  y = square((x₀ * 0.88958) * -1.3849)          7           8.983e+03  1.192e-07  y = (0.066444 * square(square(2.1862) * x₀))  8           8.426e+03  6.403e-02  y = square((x₀ * log(cube(1.4917))) + 1.2984) 11          8.423e+03  1.427e-04  y = ((x₀ * ((0.43857 * x₀) + x₀)) + (3.2024 * x₀))                                                                            12          8.406e+03  1.987e-03  y = ((x₀ * (0.7872 + 0.60452)) * (x₀ + log(-0.4254 + x₀)))                                                                    ---------------------------------------------------------------------------------------------------
# 3.5%┣█▋                                           ┫ 21/600 [00:00<00:07, 78it/s]Expressions evaluated per second: [.....]. Head worker occupation: 37.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.294e+06  1.594e+01  y = 1342.5                                    2           3.684e+05  1.257e+00  y = square(x₀)                                4           8.983e+03  1.857e+00  y = (square(x₀) * 1.5178)                     6           8.983e+03  -0.000e+00  y = square((x₀ * 0.88958) * -1.3849)         7           8.983e+03  1.192e-07  y = (0.066444 * square(square(2.1862) * x₀))  8           8.426e+03  6.403e-02  y = square((x₀ * log(cube(1.4917))) + 1.2984) 11          8.423e+03  1.427e-04  y = ((x₀ * ((0.43857 * x₀) + x₀)) + (3.2024 * x₀))                                                                            12          8.406e+03  1.987e-03  y = ((x₀ * (0.7872 + 0.60452)) * (x₀ + log(-0.4254 + x₀)))                                                                    ---------------------------------------------------------------------------------------------------
# 4.3%┣██                                           ┫ 26/600 [00:00<00:07, 80it/s]Expressions evaluated per second: [.....]. Head worker occupation: 29.9%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.294e+06  1.594e+01  y = 1342.5                                    2           3.684e+05  1.257e+00  y = square(x₀)                                4           8.983e+03  1.857e+00  y = (square(x₀) * 1.5178)                     6           8.983e+03  -0.000e+00  y = square((x₀ * 0.88958) * -1.3849)         7           8.720e+03  2.975e-02  y = ((x₀ + square(x₀)) * square(1.213))       8           8.426e+03  3.428e-02  y = square((x₀ * log(cube(1.4917))) + 1.2984) 11          8.423e+03  1.427e-04  y = ((x₀ * ((0.43857 * x₀) + x₀)) + (3.2024 * x₀))                                                                            12          8.406e+03  1.987e-03  y = ((x₀ * (0.7872 + 0.60452)) * (x₀ + log(-0.4254 + x₀)))                                                                    ---------------------------------------------------------------------------------------------------
# 5.3%┣██▍                                          ┫ 32/600 [00:00<00:07, 84it/s]Expressions evaluated per second: [.....]. Head worker occupation: 30.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.294e+06  1.594e+01  y = 1342.5                                    2           3.684e+05  1.257e+00  y = square(x₀)                                4           8.983e+03  1.857e+00  y = (square(x₀) * 1.5178)                     6           8.688e+03  1.673e-02  y = ((square(x₀) * 1.4931) + x₀)              8           8.426e+03  1.529e-02  y = square((x₀ * log(cube(1.4917))) + 1.2984) 10          8.425e+03  8.175e-05  y = ((((square(x₀) * 1.4436) + x₀) + x₀) + x₀)                                                                                11          8.423e+03  2.646e-04  y = ((x₀ * ((0.43857 * x₀) + x₀)) + (3.2024 * x₀))                                                                            12          8.406e+03  1.987e-03  y = ((x₀ * (0.7872 + 0.60452)) * (x₀ + log(-0.4254 + x₀)))                                                                    ---------------------------------------------------------------------------------------------------
# 6.5%┣███                                          ┫ 39/600 [00:00<00:07, 86it/s]Expressions evaluated per second: [.....]. Head worker occupation: 32.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.294e+06  1.594e+01  y = 1342.5                                    2           3.684e+05  1.257e+00  y = square(x₀)                                3           1.816e+05  7.071e-01  y = (x₀ * 57.684)                             4           8.983e+03  3.007e+00  y = (square(x₀) * 1.5178)                     6           8.688e+03  1.673e-02  y = ((square(x₀) * 1.4931) + x₀)              8           8.426e+03  1.529e-02  y = square((x₀ * log(cube(1.4917))) + 1.2984) 10          8.425e+03  8.807e-05  y = (square((x₀ * log(cube(1.4917))) + 1.2984) + -1.0715)                                                                     11          8.423e+03  2.519e-04  y = ((x₀ * ((0.43857 * x₀) + x₀)) + (3.2024 * x₀))                                                                            12          8.406e+03  1.987e-03  y = ((x₀ * (0.7872 + 0.60452)) * (x₀ + log(-0.4254 + x₀)))                                                                    ---------------------------------------------------------------------------------------------------
# 7.7%┣███▌                                         ┫ 46/600 [00:00<00:06, 90it/s]Expressions evaluated per second: [.....]. Head worker occupation: 33.3%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.294e+06  1.594e+01  y = 1342.5                                    2           3.684e+05  1.257e+00  y = square(x₀)                                3           1.816e+05  7.071e-01  y = (x₀ * 57.684)                             4           8.983e+03  3.007e+00  y = (square(x₀) * 1.5178)                     6           8.597e+03  2.199e-02  y = ((square(x₀) + 20.056) * 1.4982)          7           8.585e+03  1.425e-03  y = ((x₀ + square(x₀)) * square(1.2171))      8           8.426e+03  1.862e-02  y = square((x₀ * log(cube(1.4917))) + 1.2984) 10          8.425e+03  8.807e-05  y = (square((x₀ * log(cube(1.4917))) + 1.2984) + -1.0715)                                                                     11          8.423e+03  2.519e-04  y = ((x₀ * ((0.43857 * x₀) + x₀)) + (3.2024 * x₀))                                                                            12          8.406e+03  1.987e-03  y = ((x₀ * (0.7872 + 0.60452)) * (x₀ + log(-0.4254 + x₀)))                                                                    ---------------------------------------------------------------------------------------------------
# 8.8%┣████                                         ┫ 53/600 [00:01<00:06, 94it/s]Expressions evaluated per second: [.....]. Head worker occupation: 33.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.294e+06  1.594e+01  y = 1342.5                                    2           3.684e+05  1.257e+00  y = square(x₀)                                3           1.816e+05  7.071e-01  y = (x₀ * 57.684)                             4           8.983e+03  3.007e+00  y = (square(x₀) * 1.5178)                     6           8.597e+03  2.199e-02  y = ((square(x₀) + 20.056) * 1.4982)          7           8.585e+03  1.425e-03  y = ((x₀ + square(x₀)) * square(1.2171))      8           8.426e+03  1.862e-02  y = square((x₀ * log(cube(1.4917))) + 1.2984) 10          8.406e+03  1.187e-03  y = ((x₀ * (0.7872 + 0.60452)) * (x₀ + log(x₀)))                                                                              12          8.406e+03  2.080e-05  y = ((x₀ * (0.7872 + 0.60452)) * (x₀ + log(-0.4254 + x₀)))                                                                    ---------------------------------------------------------------------------------------------------
# 9.5%┣████▎                                        ┫ 57/600 [00:01<00:06, 92it/s]Expressions evaluated per second: [.....]. Head worker occupation: 32.5%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.294e+06  1.594e+01  y = 1342.5                                    2           3.684e+05  1.257e+00  y = square(x₀)                                3           1.816e+05  7.071e-01  y = (x₀ * 57.684)                             4           8.983e+03  3.007e+00  y = (square(x₀) * 1.5178)                     6           8.597e+03  2.199e-02  y = ((square(x₀) * 1.4982) + 30.069)          7           8.585e+03  1.425e-03  y = ((x₀ + square(x₀)) * square(1.2171))      8           8.426e+03  1.862e-02  y = square((x₀ * log(cube(1.4917))) + 1.2984) 10          8.406e+03  1.187e-03  y = ((x₀ * (0.7872 + 0.60452)) * (x₀ + log(x₀)))                                                                              12          8.406e+03  2.080e-05  y = ((x₀ * (0.7872 + 0.60452)) * (x₀ + log(-0.4254 + x₀)))                                                                    ---------------------------------------------------------------------------------------------------
# 10.5%┣████▋                                       ┫ 63/600 [00:01<00:06, 93it/s]Expressions evaluated per second: [.....]. Head worker occupation: 33.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.294e+06  1.594e+01  y = 1342.5                                    2           3.684e+05  1.257e+00  y = square(x₀)                                3           1.816e+05  7.071e-01  y = (x₀ * 57.684)                             4           8.983e+03  3.007e+00  y = (square(x₀) * 1.5178)                     6           8.426e+03  3.203e-02  y = (square(x₀ + 1.06) * 1.4412)              10          8.406e+03  5.860e-04  y = ((x₀ * (0.7872 + 0.60452)) * (x₀ + log(x₀)))                                                                              12          8.406e+03  2.080e-05  y = ((x₀ * (0.7872 + 0.60452)) * (x₀ + log(-0.4254 + x₀)))                                                                    ---------------------------------------------------------------------------------------------------
# 11.7%┣█████▏                                      ┫ 70/600 [00:01<00:06, 94it/s]Expressions evaluated per second: [.....]. Head worker occupation: 33.4%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.294e+06  1.594e+01  y = 1342.5                                    2           3.684e+05  1.257e+00  y = square(x₀)                                3           1.816e+05  7.071e-01  y = (x₀ * 57.684)                             4           8.983e+03  3.007e+00  y = (square(x₀) * 1.5178)                     6           8.426e+03  3.203e-02  y = (square(x₀ + 1.06) * 1.4412)              10          8.406e+03  5.860e-04  y = ((x₀ * (0.7872 + 0.60452)) * (x₀ + log(x₀)))                                                                              12          8.406e+03  2.080e-05  y = ((x₀ * (0.7872 + 0.60452)) * (x₀ + log(-0.4254 + x₀)))                                                                    ---------------------------------------------------------------------------------------------------
# 12.3%┣█████▍                                      ┫ 74/600 [00:01<00:06, 92it/s]Expressions evaluated per second: [.....]. Head worker occupation: 32.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.294e+06  1.594e+01  y = 1342.5                                    2           3.684e+05  1.257e+00  y = square(x₀)                                3           1.816e+05  7.071e-01  y = (x₀ * 57.684)                             4           8.983e+03  3.007e+00  y = (square(x₀) * 1.5178)                     6           8.426e+03  3.203e-02  y = (square(x₀ + 1.06) * 1.4412)              10          8.406e+03  5.965e-04  y = (((x₀ * 1.3917) * (x₀ + log(x₀))) + -0.60971)                                                                             ---------------------------------------------------------------------------------------------------
# 13.3%┣█████▉                                      ┫ 80/600 [00:01<00:06, 93it/s]Expressions evaluated per second: [.....]. Head worker occupation: 33.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.294e+06  1.594e+01  y = 1342.5                                    2           3.684e+05  1.257e+00  y = square(x₀)                                3           1.816e+05  7.071e-01  y = (x₀ * 57.684)                             4           8.983e+03  3.007e+00  y = (square(x₀) * 1.5178)                     6           8.426e+03  3.203e-02  y = (square(x₀ + 1.06) * 1.4412)              8           8.426e+03  2.417e-05  y = ((square(x₀ + 1.06) + -0.15614) * 1.4412) 10          8.406e+03  1.169e-03  y = (((x₀ * 1.3917) * (x₀ + log(x₀))) + -0.60971)                                                                             ---------------------------------------------------------------------------------------------------
# 14.3%┣██████▎                                     ┫ 86/600 [00:01<00:06, 93it/s]Expressions evaluated per second: [.....]. Head worker occupation: 33.3%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.294e+06  1.594e+01  y = 1342.5                                    2           3.684e+05  1.257e+00  y = square(x₀)                                3           1.816e+05  7.071e-01  y = (x₀ * 57.684)                             4           8.983e+03  3.007e+00  y = (square(x₀) * 1.5178)                     6           8.426e+03  3.203e-02  y = (square(x₀ + 1.06) * 1.4412)              8           8.425e+03  5.088e-05  y = ((square(x₀ + 1.06) + -0.41298) * 1.4412) 9           8.424e+03  1.768e-04  y = ((square(x₀ + log(1.8125)) + x₀) * 1.4395)                                                                                10          8.406e+03  2.107e-03  y = (((x₀ * 1.3917) * (x₀ + log(x₀))) + -0.60971)                                                                             ---------------------------------------------------------------------------------------------------
# 15.2%┣██████▊                                     ┫ 91/600 [00:01<00:06, 92it/s]Expressions evaluated per second: [.....]. Head worker occupation: 34.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.294e+06  1.594e+01  y = 1342.5                                    2           3.684e+05  1.257e+00  y = square(x₀)                                3           1.816e+05  7.071e-01  y = (x₀ * 57.684)                             4           8.983e+03  3.007e+00  y = (square(x₀) * 1.5178)                     6           8.426e+03  3.203e-02  y = (square(x₀ + 1.06) * 1.4412)              8           8.425e+03  6.056e-05  y = ((square(x₀ + 1.06) * 1.4412) + -0.89643) 9           8.424e+03  1.574e-04  y = ((square(x₀ + log(1.8125)) + x₀) * 1.4395)                                                                                10          8.406e+03  2.107e-03  y = (((x₀ * 1.3917) * (x₀ + log(x₀))) + -0.60971)                                                                             ---------------------------------------------------------------------------------------------------
# 16.2%┣███████▏                                    ┫ 97/600 [00:01<00:06, 91it/s]Expressions evaluated per second: 2.60e+05. Head worker occupation: 32.9%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.294e+06  1.594e+01  y = 1342.5                                    2           3.684e+05  1.257e+00  y = square(x₀)                                3           1.816e+05  7.071e-01  y = (x₀ * 57.684)                             4           8.983e+03  3.007e+00  y = (square(x₀) * 1.5178)                     6           8.426e+03  3.203e-02  y = (square(x₀ + 1.06) * 1.4412)              8           8.393e+03  1.958e-03  y = (square(x₀) * ((-0.0029525 * x₀) + 1.6421))                                                                               ---------------------------------------------------------------------------------------------------
# 17.0%┣███████▎                                   ┫ 102/600 [00:01<00:05, 91it/s]Expressions evaluated per second: 2.60e+05. Head worker occupation: 32.4%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.294e+06  1.594e+01  y = 1342.5                                    2           3.684e+05  1.257e+00  y = square(x₀)                                3           1.816e+05  7.071e-01  y = (x₀ * 57.684)                             4           8.983e+03  3.007e+00  y = (square(x₀) * 1.5178)                     6           8.426e+03  3.203e-02  y = (square(x₀ + 1.06) * 1.4412)              8           8.393e+03  1.958e-03  y = (square(x₀) * ((-0.0029525 * x₀) + 1.6421))                                                                               ---------------------------------------------------------------------------------------------------
# 17.8%┣███████▊                                   ┫ 107/600 [00:01<00:05, 91it/s]Expressions evaluated per second: 2.60e+05. Head worker occupation: 32.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.294e+06  1.594e+01  y = 1342.5                                    2           3.684e+05  1.257e+00  y = square(x₀)                                3           1.816e+05  7.071e-01  y = (x₀ * 57.684)                             4           8.983e+03  3.007e+00  y = (square(x₀) * 1.5178)                     6           8.426e+03  3.203e-02  y = (square(x₀ + 1.06) * 1.4412)              7           8.426e+03  1.192e-07  y = (square(x₀ + square(1.0291)) * 1.4412)    8           8.393e+03  3.916e-03  y = (square(x₀) * ((-0.0029525 * x₀) + 1.6421))                                                                               ---------------------------------------------------------------------------------------------------
# 19.0%┣████████▏                                  ┫ 114/600 [00:01<00:05, 92it/s]Expressions evaluated per second: 2.60e+05. Head worker occupation: 31.9%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.294e+06  1.594e+01  y = 1342.5                                    2           3.684e+05  1.257e+00  y = square(x₀)                                3           1.816e+05  7.071e-01  y = (x₀ * 57.683)                             4           8.983e+03  3.007e+00  y = (square(x₀) * 1.5178)                     6           8.426e+03  3.203e-02  y = (square(x₀ + 1.06) * 1.4412)              7           8.426e+03  1.192e-07  y = (square(x₀ + square(1.0291)) * 1.4412)    8           8.393e+03  3.916e-03  y = (square(x₀) * ((-0.0029525 * x₀) + 1.6421))                                                                               ---------------------------------------------------------------------------------------------------
# 20.0%┣████████▋                                  ┫ 120/600 [00:01<00:05, 93it/s]Expressions evaluated per second: 2.60e+05. Head worker occupation: 32.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.294e+06  1.594e+01  y = 1342.5                                    2           3.684e+05  1.257e+00  y = square(x₀)                                3           1.816e+05  7.071e-01  y = (x₀ * 57.683)                             4           8.983e+03  3.007e+00  y = (square(x₀) * 1.5178)                     6           8.426e+03  3.203e-02  y = (square(x₀ + 1.06) * 1.4412)              7           8.426e+03  1.192e-07  y = (square(x₀ + square(1.0291)) * 1.4412)    8           8.393e+03  3.916e-03  y = (square(x₀) * ((-0.0029525 * x₀) + 1.6421))                                                                               ---------------------------------------------------------------------------------------------------
# 21.0%┣█████████                                  ┫ 126/600 [00:01<00:05, 92it/s]Expressions evaluated per second: 2.60e+05. Head worker occupation: 32.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.294e+06  1.594e+01  y = 1342.5                                    2           3.684e+05  1.257e+00  y = square(x₀)                                3           1.816e+05  7.071e-01  y = (x₀ * 57.683)                             4           8.983e+03  3.007e+00  y = (square(x₀) * 1.5178)                     6           8.426e+03  3.203e-02  y = (square(x₀ + 1.06) * 1.4412)              7           8.426e+03  1.192e-07  y = (square(x₀ + square(1.0291)) * 1.4412)    8           8.393e+03  3.916e-03  y = (square(x₀) * ((-0.0029525 * x₀) + 1.6421))                                                                               ---------------------------------------------------------------------------------------------------
# 22.3%┣█████████▋                                 ┫ 134/600 [00:01<00:05, 93it/s]Expressions evaluated per second: 2.60e+05. Head worker occupation: 32.5%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.294e+06  1.594e+01  y = 1342.5                                    2           3.684e+05  1.257e+00  y = square(x₀)                                3           1.816e+05  7.071e-01  y = (x₀ * 57.683)                             4           8.983e+03  3.007e+00  y = (square(x₀) * 1.5178)                     6           8.426e+03  3.203e-02  y = (square(x₀ + 1.0595) * 1.4412)            8           8.393e+03  1.958e-03  y = (square(x₀) * ((-0.0029525 * x₀) + 1.6421))                                                                               ---------------------------------------------------------------------------------------------------
# 23.7%┣██████████▏                                ┫ 142/600 [00:01<00:05, 95it/s]Expressions evaluated per second: 2.60e+05. Head worker occupation: 32.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.294e+06  1.594e+01  y = 1342.5                                    2           3.684e+05  1.257e+00  y = square(x₀)                                3           1.816e+05  7.071e-01  y = (x₀ * 57.683)                             4           8.983e+03  3.007e+00  y = (square(x₀) * 1.5178)                     6           8.426e+03  3.203e-02  y = (square(x₀ + 1.0595) * 1.4412)            8           8.393e+03  1.958e-03  y = (square(x₀) * ((-0.0029525 * x₀) + 1.6421))                                                                               ---------------------------------------------------------------------------------------------------
# 24.3%┣██████████▌                                ┫ 146/600 [00:02<00:05, 94it/s]Expressions evaluated per second: 2.60e+05. Head worker occupation: 33.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.294e+06  1.594e+01  y = 1342.5                                    2           3.684e+05  1.257e+00  y = square(x₀)                                3           1.816e+05  7.071e-01  y = (x₀ * 57.683)                             4           8.983e+03  3.007e+00  y = (square(x₀) * 1.5178)                     6           8.426e+03  3.203e-02  y = (square(x₀ + 1.0595) * 1.4412)            8           8.393e+03  1.958e-03  y = (square(x₀) * ((-0.0029525 * x₀) + 1.6421))                                                                               ---------------------------------------------------------------------------------------------------
# 25.3%┣███████████                                ┫ 152/600 [00:02<00:05, 95it/s]Expressions evaluated per second: 2.60e+05. Head worker occupation: 34.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.294e+06  1.594e+01  y = 1342.5                                    2           3.684e+05  1.257e+00  y = square(x₀)                                3           1.816e+05  7.071e-01  y = (x₀ * 57.683)                             4           8.983e+03  3.007e+00  y = (square(x₀) * 1.5178)                     6           8.426e+03  3.203e-02  y = (square(x₀ + 1.0595) * 1.4412)            8           8.393e+03  1.958e-03  y = (square(x₀) * ((-0.0029525 * x₀) + 1.6421))                                                                               ---------------------------------------------------------------------------------------------------
# 26.2%┣███████████▎                               ┫ 157/600 [00:02<00:05, 95it/s]Expressions evaluated per second: 2.60e+05. Head worker occupation: 34.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.294e+06  1.594e+01  y = 1342.5                                    2           3.684e+05  1.257e+00  y = square(x₀)                                3           1.816e+05  7.071e-01  y = (x₀ * 57.683)                             4           8.983e+03  3.007e+00  y = (square(x₀) * 1.5178)                     6           8.426e+03  3.203e-02  y = (square(x₀ + 1.0595) * 1.4412)            8           8.393e+03  1.958e-03  y = (square(x₀) * ((-0.0029525 * x₀) + 1.6421))                                                                               ---------------------------------------------------------------------------------------------------
# 27.0%┣███████████▋                               ┫ 162/600 [00:02<00:05, 94it/s]Expressions evaluated per second: 2.60e+05. Head worker occupation: 32.9%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.294e+06  1.594e+01  y = 1342.5                                    2           3.684e+05  1.257e+00  y = square(x₀)                                3           1.816e+05  7.071e-01  y = (x₀ * 57.683)                             4           8.983e+03  3.007e+00  y = (square(x₀) * 1.5178)                     6           8.426e+03  3.203e-02  y = (square(x₀ + 1.0595) * 1.4412)            8           8.393e+03  1.958e-03  y = (square(x₀) * ((-0.0029525 * x₀) + 1.6421))                                                                               ---------------------------------------------------------------------------------------------------
# 28.0%┣████████████                               ┫ 168/600 [00:02<00:05, 94it/s]Expressions evaluated per second: 2.60e+05. Head worker occupation: 32.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.294e+06  1.594e+01  y = 1342.5                                    2           3.684e+05  1.257e+00  y = square(x₀)                                3           1.816e+05  7.071e-01  y = (x₀ * 57.683)                             4           8.983e+03  3.007e+00  y = (square(x₀) * 1.5178)                     6           8.426e+03  3.203e-02  y = (square(x₀ + 1.0595) * 1.4412)            8           8.393e+03  1.958e-03  y = (square(x₀) * ((-0.0029525 * x₀) + 1.6421))                                                                               ---------------------------------------------------------------------------------------------------
# 28.7%┣████████████▎                              ┫ 172/600 [00:02<00:05, 93it/s]Expressions evaluated per second: 2.60e+05. Head worker occupation: 31.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.294e+06  1.594e+01  y = 1342.5                                    2           3.684e+05  1.257e+00  y = square(x₀)                                3           1.816e+05  7.071e-01  y = (x₀ * 57.683)                             4           8.983e+03  3.007e+00  y = (square(x₀) * 1.5178)                     6           8.426e+03  3.203e-02  y = (square(x₀ + 1.0595) * 1.4412)            8           8.393e+03  1.958e-03  y = (square(x₀) * ((-0.0029525 * x₀) + 1.6421))                                                                               10          8.381e+03  7.199e-04  y = ((square(x₀) * ((-0.0021287 * x₀) + 1.5827)) + x₀)                                                                        ---------------------------------------------------------------------------------------------------
# ...
# 95.3%┣█████████████████████████████████████████  ┫ 572/600 [00:08<00:00, 75it/s]Expressions evaluated per second: 2.02e+05. Head worker occupation: 27.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.294e+06  1.594e+01  y = 1342.5                                    2           3.684e+05  1.257e+00  y = square(x₀)                                4           1.739e+04  1.527e+00  y = cube(square(log(x₀)))                     6           1.417e+04  1.024e-01  y = (square(x₀ + 13.066) + -383.66)           8           8.789e+03  2.387e-01  y = square(square(log(x₀) + -0.62777) + x₀)   10          8.533e+03  1.480e-02  y = (square((square(log(x₀)) + x₀) + -4.6154) + 40.517)                                                                       12          8.533e+03  -0.000e+00  y = ((square((square(log(x₀)) + x₀) + -4.6154) + 40.517) + 0.0...                                                                                              1852)                                         13          8.533e+03  4.381e-05  y = (square((square(log(cube(0.38054) + x₀)) + x₀) + -4.6154) ...                                                                                               + 40.517)                                     14          8.478e+03  6.405e-03  y = square((square(log(((x₀ + x₀) + 56.766) + x₀)) + x₀) + -17...                                                                                               .395)                                         19          8.464e+03  3.379e-04  y = (square((square(log((x₀ + (log(x₀) + x₀)) + 18.125)) + x₀)...                                                                                                + -12.284) + (15.777 + 13.555))              ---------------------------------------------------------------------------------------------------
# 96.2%┣█████████████████████████████████████████▍ ┫ 577/600 [00:08<00:00, 75it/s]Expressions evaluated per second: 2.02e+05. Head worker occupation: 27.5%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.294e+06  1.594e+01  y = 1342.5                                    2           3.684e+05  1.257e+00  y = square(x₀)                                4           1.739e+04  1.527e+00  y = cube(square(log(x₀)))                     6           1.417e+04  1.024e-01  y = (square(x₀ + 13.066) + -383.66)           8           8.789e+03  2.387e-01  y = square(square(log(x₀) + -0.62777) + x₀)   10          8.533e+03  1.480e-02  y = (square((square(log(x₀)) + x₀) + -4.6154) + 40.517)                                                                       12          8.533e+03  -0.000e+00  y = ((square((square(log(x₀)) + x₀) + -4.6154) + 40.517) + 0.0...                                                                                              1852)                                         13          8.533e+03  4.381e-05  y = (square((square(log(cube(0.38054) + x₀)) + x₀) + -4.6154) ...                                                                                               + 40.517)                                     14          8.478e+03  6.405e-03  y = square((square(log(((x₀ + x₀) + 56.766) + x₀)) + x₀) + -17...                                                                                               .395)                                         19          8.464e+03  3.379e-04  y = (square((square(log((x₀ + (log(x₀) + x₀)) + 18.125)) + x₀)...                                                                                                + -12.284) + (15.777 + 13.555))              ---------------------------------------------------------------------------------------------------
# 96.7%┣█████████████████████████████████████████▋ ┫ 580/600 [00:08<00:00, 74it/s]Expressions evaluated per second: 2.02e+05. Head worker occupation: 27.4%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.294e+06  1.594e+01  y = 1342.5                                    2           3.684e+05  1.257e+00  y = square(x₀)                                4           1.739e+04  1.527e+00  y = cube(square(log(x₀)))                     6           1.417e+04  1.024e-01  y = (square(x₀ + 13.066) + -383.66)           8           8.789e+03  2.387e-01  y = square(square(log(x₀) + -0.62777) + x₀)   10          8.533e+03  1.480e-02  y = (square((square(log(x₀)) + x₀) + -4.6154) + 40.517)                                                                       12          8.533e+03  -0.000e+00  y = ((square((square(log(x₀)) + x₀) + -4.6154) + 40.517) + 0.0...                                                                                              1852)                                         13          8.533e+03  4.381e-05  y = (square((square(log(cube(0.38054) + x₀)) + x₀) + -4.6154) ...                                                                                               + 40.517)                                     14          8.478e+03  6.405e-03  y = square((square(log(((x₀ + x₀) + 56.766) + x₀)) + x₀) + -17...                                                                                               .395)                                         19          8.464e+03  3.379e-04  y = (square((square(log((x₀ + (log(x₀) + x₀)) + 18.125)) + x₀)...                                                                                                + -12.284) + (15.777 + 13.555))              ---------------------------------------------------------------------------------------------------
# 97.3%┣█████████████████████████████████████████▉ ┫ 584/600 [00:08<00:00, 74it/s]Expressions evaluated per second: 2.02e+05. Head worker occupation: 27.3%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.294e+06  1.594e+01  y = 1342.5                                    2           3.684e+05  1.257e+00  y = square(x₀)                                4           1.739e+04  1.527e+00  y = cube(square(log(x₀)))                     6           1.417e+04  1.024e-01  y = (square(x₀ + 13.066) + -383.66)           8           8.789e+03  2.387e-01  y = square(square(log(x₀) + -0.62777) + x₀)   10          8.533e+03  1.480e-02  y = (square((square(log(x₀)) + x₀) + -4.6154) + 40.517)                                                                       12          8.533e+03  -0.000e+00  y = ((square((square(log(x₀)) + x₀) + -4.6154) + 40.517) + 0.0...                                                                                              1852)                                         13          8.533e+03  4.381e-05  y = (square((square(log(cube(0.38054) + x₀)) + x₀) + -4.6154) ...                                                                                               + 40.517)                                     14          8.478e+03  6.405e-03  y = square((square(log(((x₀ + x₀) + 56.766) + x₀)) + x₀) + -17...                                                                                               .395)                                         19          8.464e+03  3.379e-04  y = (square((square(log((x₀ + (log(x₀) + x₀)) + 18.125)) + x₀)...                                                                                                + -12.284) + (15.777 + 13.555))              ---------------------------------------------------------------------------------------------------
# 98.3%┣██████████████████████████████████████████▎┫ 590/600 [00:08<00:00, 75it/s]Expressions evaluated per second: 2.02e+05. Head worker occupation: 27.4%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.294e+06  1.594e+01  y = 1342.5                                    2           3.684e+05  1.257e+00  y = square(x₀)                                4           1.739e+04  1.527e+00  y = cube(square(log(x₀)))                     6           1.417e+04  1.024e-01  y = (square(x₀ + 13.066) + -383.66)           8           8.789e+03  2.387e-01  y = square(square(log(x₀) + -0.62777) + x₀)   10          8.533e+03  1.480e-02  y = (square((square(log(x₀)) + x₀) + -4.6154) + 40.517)                                                                       12          8.533e+03  -0.000e+00  y = ((square((square(log(x₀)) + x₀) + -4.6154) + 40.517) + 0.0...                                                                                              1852)                                         13          8.533e+03  4.381e-05  y = (square((square(log(cube(0.38054) + x₀)) + x₀) + -4.6154) ...                                                                                               + 40.517)                                     14          8.478e+03  6.405e-03  y = square((square(log(((x₀ + x₀) + 56.766) + x₀)) + x₀) + -17...                                                                                               .395)                                         19          8.464e+03  3.379e-04  y = (square((square(log((x₀ + (log(x₀) + x₀)) + 18.125)) + x₀)...                                                                                                + -12.284) + (15.777 + 13.555))              ---------------------------------------------------------------------------------------------------
# 99.0%┣██████████████████████████████████████████▋┫ 594/600 [00:08<00:00, 74it/s]Expressions evaluated per second: 2.02e+05. Head worker occupation: 27.5%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.294e+06  1.594e+01  y = 1342.5                                    2           3.684e+05  1.257e+00  y = square(x₀)                                4           1.739e+04  1.527e+00  y = cube(square(log(x₀)))                     6           1.417e+04  1.024e-01  y = (square(x₀ + 13.066) + -383.66)           8           8.789e+03  2.387e-01  y = square(square(log(x₀) + -0.62777) + x₀)   10          8.533e+03  1.480e-02  y = (square((square(log(x₀)) + x₀) + -4.6154) + 40.517)                                                                       12          8.533e+03  -0.000e+00  y = ((square((square(log(x₀)) + x₀) + -4.6154) + 40.517) + 0.0...                                                                                              1852)                                         13          8.533e+03  4.381e-05  y = (square((square(log(cube(0.38054) + x₀)) + x₀) + -4.6154) ...                                                                                               + 40.517)                                     14          8.478e+03  6.405e-03  y = square((square(log(((x₀ + x₀) + 56.766) + x₀)) + x₀) + -17...                                                                                               .395)                                         19          8.464e+03  3.379e-04  y = (square((square(log((x₀ + (log(x₀) + x₀)) + 18.125)) + x₀)...                                                                                                + -12.284) + (15.777 + 13.555))              ---------------------------------------------------------------------------------------------------

# %%
registros_ = registros

# %%
for i in registros_:
  loss = i[1]
  score = i[2]
  complexity = i[0]
  w = (loss * score)/complexity
  if math.isnan(w):
    i.append(0)
  else:
    i.append(w)

lista_melhor_valor = max(registros_, key=lambda x: x[6])

# %% [markdown]
# ## Save result

# %%
def salvar_dados(dados, arquivo):
  if os.path.exists(arquivo):
    with open(arquivo, 'rb') as f:
      dados_exist = pickle.load(f)

    dados_exist.update(dados)
  else:
    dados_exist = dados
  
  with open(arquivo, 'wb') as f:
    pickle.dump(dados_exist, f)
  
novos_dados = {'bubblesort_N^2': lista_melhor_valor[4]}
caminho_arquivo = 'dados.pickle'

salvar_dados(novos_dados, caminho_arquivo)

# %%
def carregar_dados(arquivo):
    # Carrega os dados do arquivo pickle
    with open(arquivo, 'rb') as f:
        dados = pickle.load(f)
    return dados

caminho_arquivo = 'dados.pickle'
dados_carregados = carregar_dados(caminho_arquivo)

print("Conteúdo do arquivo pickle:")
for k, v in dados_carregados.items(): print(k, ' = ',v)
# Out:
# Conteúdo do arquivo pickle:
# {'shellsort_NlogN': 4.862569*x0*log(x0), 'mergesort_NlogN': 5.5040717*x0 + 8.03698770358715, 'bubblesort_x^2': 1.517833856016*x0**2}
