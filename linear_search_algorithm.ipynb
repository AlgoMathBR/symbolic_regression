# %%
# https://www.geeksforgeeks.org/linear-search/?ref=outind

import numpy as np
from line_profiler import LineProfiler
from pysr import PySRRegressor
import random
import os
import sys
import math
import pickle

# %% [markdown]
# ## Linear Search Algorithm

# %%
def linear_search(arr, N, x): # N
  for i in range(0, N):
    if (arr[i] == x):
      return i
  return -1

# %% [markdown]
# ## Frequency Count Method

# %%
X_y = []
i=50
for n in range(2,i+1): # started with 2 itens until 50 itens in the list
  lprofiler = LineProfiler()
  lp_wrapper = lprofiler(linear_search)

  # create a list with random number between 1 to 10000
  # with n number in the list
  input = random.choices(range(10000), k=n)
  arr = sorted(input)
  lp_wrapper(arr, len(arr), arr[-1]+1)

  stats = lprofiler.get_stats()
  line_numbers = []
  hits = []

  for line in stats.timings.values():
    for i in line:
      line_numbers.append(i[0])
      hits.append(i[1])

  X_y.append([n, sum(hits)])

dados = np.array(X_y)

X = dados[:, 0]
y = dados[:, 1]
X_reshaped = X.reshape(-1, 1)

# %%
resultados_com_menor_loss = []
repeat = 5
registros = []

original_stdout = sys.stdout

with open(os.devnull, 'w') as devnull:
  sys.stdout = devnull

  for i in range(repeat):

    # first combination
    reg1 = PySRRegressor(
      binary_operators=["*", "+"],
      unary_operators=["log", "square", "cube"],
    )

    fit1 = reg1.fit(X_reshaped, y)
    best_program1 = fit1.get_best()

    registro1 = []
    for index, value in enumerate(best_program1):
      registro1.append(value)
      
    registros.append(registro1)

    # second combination
    reg2 = PySRRegressor(
      binary_operators=["*"],
      unary_operators=["log", "square", "cube"],
    )

    fit2 = reg2.fit(X_reshaped, y)
    best_program2 = fit2.get_best()

    registro2 = []
    for index, value in enumerate(best_program2):
      registro2.append(value)
    registros.append(registro2)

    # third combinarion
    reg3 = PySRRegressor(
      binary_operators=["+"],
      unary_operators=["log", "square", "cube"],
    )

    fit3 = reg3.fit(X_reshaped, y)
    best_program3 = fit3.get_best()

    registro3 = []
    for index, value in enumerate(best_program3):
      registro3.append(value)
    registros.append(registro3)
    
sys.stdout = original_stdout
# Out:
# [ Info: Started!
# 0.0%┣                                              ┫ 0/600 [00:00<-1:00, -0s/it]Expressions evaluated per second: [.....]. Head worker occupation: 0.0%         Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       2           3.357e+03  7.971e+00  y = log(x₀)                                   3           2.699e+03  2.183e-01  y = log(cube(x₀))                             4           1.858e+03  3.732e-01  y = log(cube(square(x₀)))                     5           2.579e+02  1.975e+00  y = log(cube(square(cube(x₀))))               7           2.538e+02  8.046e-03  y = log(cube(square(cube(x₀ + -0.17674))))    9           2.517e+02  3.984e-03  y = log((cube(square(cube(x₀))) + x₀) * x₀)   11          2.514e+02  7.390e-04  y = log((cube(square(cube(x₀) + -0.72134)) + x₀) * x₀)                                                                        12          2.346e+02  6.891e-02  y = log(cube(square(cube(x₀) + (square(x₀ + x₀) * -0.72134))))                                                                14          2.151e+02  4.337e-02  y = log(cube(square(cube(x₀) + (square((x₀ + x₀) + x₀) * -0.72...                                                                                               134))))                                       16          1.947e+02  4.992e-02  y = log(cube(square(cube(x₀) + (square((x₀ + x₀) + x₀) * -0.72...                                                                                               134))) * x₀)                                  18          1.938e+02  2.230e-03  y = log((cube(square(cube(x₀) + (square((x₀ + x₀) + x₀) * -0.7...                                                                                               2134))) * x₀) * x₀)                           20          1.916e+02  5.766e-03  y = log(cube(square(cube(x₀) + (square(((x₀ + x₀) + x₀) * -1.1...                                                                                               332) * -0.72134)) + 0.22226) * x₀)            ---------------------------------------------------------------------------------------------------
# 1.2%┣▌                                             ┫ 7/600 [00:00<00:16, 38it/s]Expressions evaluated per second: [.....]. Head worker occupation: 25.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.840e+02  1.594e+01  y = x₀                                        3           4.000e+00  2.753e+00  y = (x₀ + x₀)                                 5           1.174e-04  5.216e+00  y = (x₀ + (x₀ + 2.0108))                      8           3.712e-14  5.313e+00  y = ((x₀ + (x₀ + log(4.0409))) + 0.60353)     ---------------------------------------------------------------------------------------------------
# 2.2%┣█                                            ┫ 13/600 [00:00<00:10, 57it/s]Expressions evaluated per second: [.....]. Head worker occupation: 21.3%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 3.5%┣█▋                                           ┫ 21/600 [00:00<00:08, 75it/s]Expressions evaluated per second: [.....]. Head worker occupation: 20.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 5.0%┣██▎                                          ┫ 30/600 [00:00<00:07, 87it/s]Expressions evaluated per second: [.....]. Head worker occupation: 18.3%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 6.7%┣███                                          ┫ 40/600 [00:00<00:06, 99it/s]Expressions evaluated per second: [.....]. Head worker occupation: 19.1%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 8.0%┣███▌                                        ┫ 48/600 [00:00<00:05, 105it/s]Expressions evaluated per second: [.....]. Head worker occupation: 19.3%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 9.7%┣████▎                                       ┫ 58/600 [00:01<00:05, 113it/s]Expressions evaluated per second: [.....]. Head worker occupation: 19.1%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 10.7%┣████▋                                      ┫ 64/600 [00:01<00:05, 112it/s]Expressions evaluated per second: [.....]. Head worker occupation: 18.2%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 11.2%┣████▉                                      ┫ 67/600 [00:01<00:05, 106it/s]Expressions evaluated per second: [.....]. Head worker occupation: 16.9%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 12.2%┣█████▎                                     ┫ 73/600 [00:01<00:05, 105it/s]Expressions evaluated per second: [.....]. Head worker occupation: 17.9%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 13.5%┣█████▉                                     ┫ 81/600 [00:01<00:05, 107it/s]Expressions evaluated per second: [.....]. Head worker occupation: 18.7%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 14.7%┣██████▎                                    ┫ 88/600 [00:01<00:05, 108it/s]Expressions evaluated per second: [.....]. Head worker occupation: 18.3%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 16.2%┣███████                                    ┫ 97/600 [00:01<00:05, 111it/s]Expressions evaluated per second: [.....]. Head worker occupation: 18.5%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 17.2%┣███████▏                                  ┫ 103/600 [00:01<00:04, 111it/s]Expressions evaluated per second: [.....]. Head worker occupation: 18.4%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 18.8%┣████████                                  ┫ 113/600 [00:01<00:04, 115it/s]Expressions evaluated per second: [.....]. Head worker occupation: 18.6%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 20.0%┣████████▍                                 ┫ 120/600 [00:01<00:04, 115it/s]Expressions evaluated per second: 2.90e+05. Head worker occupation: 18.2%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 21.7%┣█████████                                 ┫ 130/600 [00:01<00:04, 118it/s]Expressions evaluated per second: 2.90e+05. Head worker occupation: 18.6%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             4           9.132e-01  1.192e-07  y = (x₀ * log(7.8409))                        5           0.000e+00  1.594e+01  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 23.0%┣█████████▋                                ┫ 138/600 [00:01<00:04, 120it/s]Expressions evaluated per second: 2.90e+05. Head worker occupation: 19.1%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             4           9.132e-01  1.192e-07  y = (x₀ * log(7.8409))                        5           0.000e+00  1.594e+01  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 24.2%┣██████████▏                               ┫ 145/600 [00:01<00:04, 119it/s]Expressions evaluated per second: 2.90e+05. Head worker occupation: 19.6%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             4           9.132e-01  1.192e-07  y = (x₀ * log(7.8409))                        5           0.000e+00  1.594e+01  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 25.5%┣██████████▊                               ┫ 153/600 [00:01<00:04, 121it/s]Expressions evaluated per second: 2.90e+05. Head worker occupation: 19.4%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             4           9.132e-01  1.192e-07  y = (x₀ * log(7.8409))                        5           0.000e+00  1.594e+01  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 27.0%┣███████████▍                              ┫ 162/600 [00:01<00:04, 122it/s]Expressions evaluated per second: 2.90e+05. Head worker occupation: 20.5%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             4           9.132e-01  1.192e-07  y = (x₀ * log(7.8409))                        5           0.000e+00  1.594e+01  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 28.3%┣████████████                              ┫ 170/600 [00:01<00:03, 123it/s]Expressions evaluated per second: 2.90e+05. Head worker occupation: 20.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             4           9.132e-01  1.192e-07  y = (x₀ * log(7.8409))                        5           0.000e+00  1.594e+01  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 29.3%┣████████████▎                             ┫ 176/600 [00:01<00:03, 123it/s]Expressions evaluated per second: 2.90e+05. Head worker occupation: 19.8%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             4           9.132e-01  1.192e-07  y = (x₀ * log(7.8409))                        5           0.000e+00  1.594e+01  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 30.5%┣████████████▉                             ┫ 183/600 [00:01<00:03, 123it/s]Expressions evaluated per second: 2.90e+05. Head worker occupation: 19.6%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             4           9.132e-01  1.192e-07  y = (x₀ * log(7.8409))                        5           0.000e+00  1.594e+01  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 31.7%┣█████████████▎                            ┫ 190/600 [00:02<00:03, 123it/s]Expressions evaluated per second: 2.90e+05. Head worker occupation: 19.4%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             4           9.132e-01  1.192e-07  y = (x₀ * log(7.8409))                        5           0.000e+00  1.594e+01  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 33.0%┣█████████████▉                            ┫ 198/600 [00:02<00:03, 124it/s]Expressions evaluated per second: 2.90e+05. Head worker occupation: 19.3%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             4           9.132e-01  1.192e-07  y = (x₀ * log(7.8409))                        5           0.000e+00  1.594e+01  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 34.3%┣██████████████▍                           ┫ 206/600 [00:02<00:03, 124it/s]Expressions evaluated per second: 2.90e+05. Head worker occupation: 19.5%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             4           9.132e-01  1.192e-07  y = (x₀ * log(7.8409))                        5           0.000e+00  1.594e+01  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 35.7%┣███████████████                           ┫ 214/600 [00:02<00:03, 125it/s]Expressions evaluated per second: 2.90e+05. Head worker occupation: 19.5%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             4           9.132e-01  1.192e-07  y = (x₀ * log(7.8409))                        5           0.000e+00  1.594e+01  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 36.7%┣███████████████▍                          ┫ 220/600 [00:02<00:03, 124it/s]Expressions evaluated per second: 2.90e+05. Head worker occupation: 19.3%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             4           9.132e-01  1.192e-07  y = (x₀ * log(7.8409))                        5           0.000e+00  1.594e+01  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 38.0%┣████████████████                          ┫ 228/600 [00:02<00:03, 124it/s]Expressions evaluated per second: 2.90e+05. Head worker occupation: 19.0%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             4           9.132e-01  1.192e-07  y = (x₀ * log(7.8409))                        5           0.000e+00  1.594e+01  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 39.3%┣████████████████▌                         ┫ 236/600 [00:02<00:03, 125it/s]Expressions evaluated per second: 2.90e+05. Head worker occupation: 19.3%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             4           9.132e-01  1.192e-07  y = (x₀ * log(7.8409))                        5           0.000e+00  1.594e+01  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 40.5%┣█████████████████                         ┫ 243/600 [00:02<00:03, 124it/s]Expressions evaluated per second: 2.90e+05. Head worker occupation: 19.4%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             4           9.132e-01  1.192e-07  y = (x₀ * log(7.8409))                        5           0.000e+00  1.594e+01  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 42.2%┣█████████████████▊                        ┫ 253/600 [00:02<00:03, 126it/s]Expressions evaluated per second: 2.90e+05. Head worker occupation: 19.5%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             4           9.132e-01  1.192e-07  y = (x₀ * log(7.8409))                        5           0.000e+00  1.594e+01  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 43.0%┣██████████████████                        ┫ 258/600 [00:02<00:03, 125it/s]Expressions evaluated per second: 3.10e+05. Head worker occupation: 19.2%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             4           9.132e-01  1.192e-07  y = (x₀ * log(7.8409))                        5           0.000e+00  1.594e+01  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 44.3%┣██████████████████▋                       ┫ 266/600 [00:02<00:03, 125it/s]Expressions evaluated per second: 3.10e+05. Head worker occupation: 19.2%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             4           9.132e-01  1.192e-07  y = (x₀ * log(7.8409))                        5           0.000e+00  1.594e+01  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 45.7%┣███████████████████▏                      ┫ 274/600 [00:02<00:03, 126it/s]Expressions evaluated per second: 3.10e+05. Head worker occupation: 19.6%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             4           9.132e-01  1.192e-07  y = (x₀ * log(7.8409))                        5           0.000e+00  1.594e+01  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 47.0%┣███████████████████▊                      ┫ 282/600 [00:02<00:03, 126it/s]Expressions evaluated per second: 3.10e+05. Head worker occupation: 19.5%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             4           9.132e-01  1.192e-07  y = (x₀ * log(7.8409))                        5           0.000e+00  1.594e+01  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 48.3%┣████████████████████▎                     ┫ 290/600 [00:02<00:02, 126it/s]Expressions evaluated per second: 3.10e+05. Head worker occupation: 19.2%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             4           9.132e-01  1.192e-07  y = (x₀ * log(7.8409))                        5           0.000e+00  1.594e+01  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 49.8%┣█████████████████████                     ┫ 299/600 [00:02<00:02, 127it/s]Expressions evaluated per second: 3.10e+05. Head worker occupation: 19.2%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             4           9.132e-01  1.192e-07  y = (x₀ * log(7.8409))                        5           0.000e+00  1.594e+01  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 51.2%┣█████████████████████▌                    ┫ 307/600 [00:02<00:02, 127it/s]Expressions evaluated per second: 3.10e+05. Head worker occupation: 19.1%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             4           9.132e-01  1.192e-07  y = (x₀ * log(7.8409))                        5           0.000e+00  1.594e+01  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 52.7%┣██████████████████████▏                   ┫ 316/600 [00:02<00:02, 128it/s]Expressions evaluated per second: 3.10e+05. Head worker occupation: 19.0%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             4           9.132e-01  1.192e-07  y = (x₀ * log(7.8409))                        5           0.000e+00  1.594e+01  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 54.0%┣██████████████████████▊                   ┫ 324/600 [00:03<00:02, 128it/s]Expressions evaluated per second: 3.10e+05. Head worker occupation: 18.9%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             4           9.132e-01  1.192e-07  y = (x₀ * log(7.8409))                        5           0.000e+00  1.594e+01  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 55.3%┣███████████████████████▎                  ┫ 332/600 [00:03<00:02, 128it/s]Expressions evaluated per second: 3.10e+05. Head worker occupation: 18.7%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             4           9.132e-01  1.192e-07  y = (x₀ * log(7.8409))                        5           0.000e+00  1.594e+01  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 56.7%┣███████████████████████▉                  ┫ 340/600 [00:03<00:02, 128it/s]Expressions evaluated per second: 3.10e+05. Head worker occupation: 18.5%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             4           9.132e-01  1.192e-07  y = (x₀ * log(7.8409))                        5           0.000e+00  1.594e+01  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 58.2%┣████████████████████████▍                 ┫ 349/600 [00:03<00:02, 128it/s]Expressions evaluated per second: 3.10e+05. Head worker occupation: 18.5%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             4           9.132e-01  1.192e-07  y = (x₀ * log(7.8409))                        5           0.000e+00  1.594e+01  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 59.5%┣█████████████████████████                 ┫ 357/600 [00:03<00:02, 128it/s]Expressions evaluated per second: 3.10e+05. Head worker occupation: 18.4%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             4           9.132e-01  1.192e-07  y = (x₀ * log(7.8409))                        5           0.000e+00  1.594e+01  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# ...
# 82.8%┣██████████████████████████████████▉       ┫ 497/600 [00:04<00:01, 118it/s]Expressions evaluated per second: 2.87e+05. Head worker occupation: 28.4%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (2 + x₀))                           ---------------------------------------------------------------------------------------------------
# 84.3%┣███████████████████████████████████▍      ┫ 506/600 [00:04<00:01, 119it/s]Expressions evaluated per second: 2.87e+05. Head worker occupation: 28.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (2 + x₀))                           ---------------------------------------------------------------------------------------------------
# 85.2%┣███████████████████████████████████▊      ┫ 511/600 [00:04<00:01, 118it/s]Expressions evaluated per second: 2.87e+05. Head worker occupation: 28.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (2 + x₀))                           ---------------------------------------------------------------------------------------------------
# 85.8%┣████████████████████████████████████      ┫ 515/600 [00:04<00:01, 116it/s]Expressions evaluated per second: 2.87e+05. Head worker occupation: 27.9%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (2 + x₀))                           ---------------------------------------------------------------------------------------------------
# 87.0%┣████████████████████████████████████▌     ┫ 522/600 [00:04<00:01, 116it/s]Expressions evaluated per second: 2.87e+05. Head worker occupation: 27.9%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (2 + x₀))                           ---------------------------------------------------------------------------------------------------
# 88.0%┣█████████████████████████████████████     ┫ 528/600 [00:05<00:01, 116it/s]Expressions evaluated per second: 2.87e+05. Head worker occupation: 27.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (2 + x₀))                           ---------------------------------------------------------------------------------------------------
# 89.0%┣█████████████████████████████████████▍    ┫ 534/600 [00:05<00:01, 116it/s]Expressions evaluated per second: 2.87e+05. Head worker occupation: 27.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (2 + x₀))                           ---------------------------------------------------------------------------------------------------
# 90.0%┣█████████████████████████████████████▉    ┫ 540/600 [00:05<00:01, 116it/s]Expressions evaluated per second: 2.87e+05. Head worker occupation: 27.5%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (2 + x₀))                           ---------------------------------------------------------------------------------------------------
# 91.5%┣██████████████████████████████████████▍   ┫ 549/600 [00:05<00:00, 116it/s]Expressions evaluated per second: 2.87e+05. Head worker occupation: 27.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (2 + x₀))                           ---------------------------------------------------------------------------------------------------
# 92.5%┣██████████████████████████████████████▉   ┫ 555/600 [00:05<00:00, 116it/s]Expressions evaluated per second: 2.87e+05. Head worker occupation: 27.4%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (2 + x₀))                           ---------------------------------------------------------------------------------------------------
# 93.8%┣███████████████████████████████████████▍  ┫ 563/600 [00:05<00:00, 117it/s]Expressions evaluated per second: 2.87e+05. Head worker occupation: 27.3%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (2 + x₀))                           ---------------------------------------------------------------------------------------------------
# 95.0%┣████████████████████████████████████████  ┫ 570/600 [00:05<00:00, 117it/s]Expressions evaluated per second: 2.87e+05. Head worker occupation: 27.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (2 + x₀))                           ---------------------------------------------------------------------------------------------------
# 96.5%┣████████████████████████████████████████▌ ┫ 579/600 [00:05<00:00, 117it/s]Expressions evaluated per second: 2.87e+05. Head worker occupation: 27.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (2 + x₀))                           ---------------------------------------------------------------------------------------------------
# 97.5%┣█████████████████████████████████████████ ┫ 585/600 [00:05<00:00, 117it/s]Expressions evaluated per second: 2.87e+05. Head worker occupation: 27.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (2 + x₀))                           ---------------------------------------------------------------------------------------------------
# 98.8%┣█████████████████████████████████████████▌┫ 593/600 [00:05<00:00, 117it/s]Expressions evaluated per second: 2.83e+05. Head worker occupation: 26.9%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (2 + x₀))                           ---------------------------------------------------------------------------------------------------

# %%
registros_ = registros

# %%
for i in registros_:
  loss = i[1]
  score = i[2]
  complexity = i[0]
  w = (loss * score)/complexity
  if math.isnan(w):
    i.append(0)
  else:
    i.append(w)

lista_melhor_valor = max(registros_, key=lambda x: x[6])
# Out:
# C:\Users\rafae\AppData\Local\Temp\ipykernel_13568\2759937347.py:5: RuntimeWarning: invalid value encountered in scalar multiply
#   w = (loss * score)/complexity

# %% [markdown]
# ## Save result

# %%
def salvar_dados(dados, arquivo):
  if os.path.exists(arquivo):
    with open(arquivo, 'rb') as f:
      dados_exist = pickle.load(f)

    dados_exist.update(dados)
  else:
    dados_exist = dados
  
  with open(arquivo, 'wb') as f:
    pickle.dump(dados_exist, f)
  
novos_dados = {'linear_search_x': lista_melhor_valor[4]}
caminho_arquivo = 'dados.pickle'

salvar_dados(novos_dados, caminho_arquivo)

# %%
def carregar_dados(arquivo):
    # Carrega os dados do arquivo pickle
    with open(arquivo, 'rb') as f:
        dados = pickle.load(f)
    return dados

caminho_arquivo = 'dados.pickle'
dados_carregados = carregar_dados(caminho_arquivo)

print("Conteúdo do arquivo pickle:")
for k, v in dados_carregados.items(): print(k, ' = ',v)
# Out:
# Conteúdo do arquivo pickle:
# shellsort_NlogN  =  4.862569*x0*log(x0)
# mergesort_NlogN  =  5.5040717*x0 + 8.03698770358715
# bubblesort_x^2  =  1.517833856016*x0**2
# levenshtein_distance_MN  =  3.52552934090449*x1**2
# selectsort_x^2  =  1.13491224207076*x0**2
# insertionsort_x^2  =  0.84217347354001*x0**2
# quicksort_x^2  =  7.605706*x0*log(x0)
# linear_search_x  =  2.0593596*x0
