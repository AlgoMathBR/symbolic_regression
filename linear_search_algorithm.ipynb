# %%
# https://www.geeksforgeeks.org/linear-search/?ref=outind

import numpy as np
from line_profiler import LineProfiler
from pysr import PySRRegressor
import random
import os
import sys
import math
import pickle

# %% [markdown]
# ## Linear Search Algorithm

# %%
def linear_search(arr, N, x): # N
  for i in range(0, N):
    if (arr[i] == x):
      return i
  return -1

# %% [markdown]
# ## Frequency Count Method

# %%
X_y = []
i=50
for n in range(2,i+1): # started with 2 itens until 50 itens in the list
  lprofiler = LineProfiler()
  lp_wrapper = lprofiler(linear_search)

  # create a list with random number between 1 to 10000
  # with n number in the list
  input = random.choices(range(10000), k=n)
  arr = sorted(input)
  lp_wrapper(arr, len(arr), arr[-1]+1)

  stats = lprofiler.get_stats()
  line_numbers = []
  hits = []

  for line in stats.timings.values():
    for i in line:
      line_numbers.append(i[0])
      hits.append(i[1])

  X_y.append([n, sum(hits)])

dados = np.array(X_y)

X = dados[:, 0]
y = dados[:, 1]
X_reshaped = X.reshape(-1, 1)

# %%
resultados_com_menor_loss = []
repeat = 5
registros = []
unary_operators_list = ["log", "square", "cube", "sqrt", "round", "exp", "abs"]

original_stdout = sys.stdout

with open(os.devnull, 'w') as devnull:
  sys.stdout = devnull

  for i in range(repeat):

    # first combination
    reg1 = PySRRegressor(
      binary_operators=["*", "+"],
      unary_operators=unary_operators_list
    )

    fit1 = reg1.fit(X_reshaped, y)
    best_program1 = fit1.get_best()

    registro1 = []
    for index, value in enumerate(best_program1):
      registro1.append(value)
      
    registros.append(registro1)

    # second combination
    reg2 = PySRRegressor(
      binary_operators=["*"],
      unary_operators=unary_operators_list
    )

    fit2 = reg2.fit(X_reshaped, y)
    best_program2 = fit2.get_best()

    registro2 = []
    for index, value in enumerate(best_program2):
      registro2.append(value)
    registros.append(registro2)

    # third combinarion
    reg3 = PySRRegressor(
      binary_operators=["+"],
      unary_operators=unary_operators_list
    )

    fit3 = reg3.fit(X_reshaped, y)
    best_program3 = fit3.get_best()

    registro3 = []
    for index, value in enumerate(best_program3):
      registro3.append(value)
    registros.append(registro3)
    
sys.stdout = original_stdout
# Out:
# [ Info: Started!
# 0.0%┣                                              ┫ 0/600 [00:00<00:-4, -0s/it]Expressions evaluated per second: [.....]. Head worker occupation: 0.0%         Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.840e+02  1.594e+01  y = x₀                                        3           4.000e+00  2.753e+00  y = (x₀ + x₀)                                 5           3.463e-01  1.223e+00  y = ((x₀ + x₀) + 1.4115)                      ---------------------------------------------------------------------------------------------------
# 0.8%┣▍                                             ┫ 5/600 [00:00<00:09, 64it/s]Expressions evaluated per second: [.....]. Head worker occupation: 18.2%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.840e+02  1.594e+01  y = x₀                                        3           4.000e+00  2.753e+00  y = (x₀ + x₀)                                 5           5.597e-03  3.286e+00  y = (2.0748 + (x₀ + x₀))                      7           3.875e-04  1.335e+00  y = (2.0748 + (x₀ + (x₀ + -0.055126)))        9           0.000e+00  7.971e+00  y = (((x₀ + 0.8625) + (x₀ + 0.69378)) + 0.44373)                                                                              ---------------------------------------------------------------------------------------------------
# 1.8%┣▉                                            ┫ 11/600 [00:00<00:07, 85it/s]Expressions evaluated per second: [.....]. Head worker occupation: 20.9%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.840e+02  1.594e+01  y = x₀                                        3           4.000e+00  2.753e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 2.8%┣█▎                                           ┫ 17/600 [00:00<00:06, 92it/s]Expressions evaluated per second: [.....]. Head worker occupation: 21.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.840e+02  1.594e+01  y = x₀                                        3           4.000e+00  2.753e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 4.0%┣█▊                                          ┫ 24/600 [00:00<00:06, 101it/s]Expressions evaluated per second: [.....]. Head worker occupation: 21.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.840e+02  1.594e+01  y = x₀                                        3           4.000e+00  2.753e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 5.3%┣██▍                                         ┫ 32/600 [00:00<00:05, 104it/s]Expressions evaluated per second: [.....]. Head worker occupation: 21.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.840e+02  1.594e+01  y = x₀                                        3           4.000e+00  2.753e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 6.3%┣██▉                                         ┫ 38/600 [00:00<00:05, 105it/s]Expressions evaluated per second: [.....]. Head worker occupation: 20.9%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.840e+02  1.594e+01  y = x₀                                        3           4.000e+00  2.753e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 7.5%┣███▎                                        ┫ 45/600 [00:00<00:05, 106it/s]Expressions evaluated per second: [.....]. Head worker occupation: 22.5%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.840e+02  1.594e+01  y = x₀                                        3           4.000e+00  2.753e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 8.7%┣███▉                                        ┫ 52/600 [00:00<00:05, 108it/s]Expressions evaluated per second: [.....]. Head worker occupation: 22.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.840e+02  1.594e+01  y = x₀                                        3           4.000e+00  2.753e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 10.3%┣████▍                                      ┫ 62/600 [00:01<00:05, 115it/s]Expressions evaluated per second: [.....]. Head worker occupation: 22.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.840e+02  1.594e+01  y = x₀                                        3           4.000e+00  2.753e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 11.7%┣█████                                      ┫ 70/600 [00:01<00:05, 117it/s]Expressions evaluated per second: [.....]. Head worker occupation: 22.3%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.840e+02  1.594e+01  y = x₀                                        3           4.000e+00  2.753e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 13.3%┣█████▊                                     ┫ 80/600 [00:01<00:04, 120it/s]Expressions evaluated per second: [.....]. Head worker occupation: 22.4%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.840e+02  1.594e+01  y = x₀                                        3           4.000e+00  2.753e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 14.3%┣██████▏                                    ┫ 86/600 [00:01<00:04, 119it/s]Expressions evaluated per second: [.....]. Head worker occupation: 22.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.840e+02  1.594e+01  y = x₀                                        3           4.000e+00  2.753e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 15.5%┣██████▋                                    ┫ 93/600 [00:01<00:05, 103it/s]Expressions evaluated per second: [.....]. Head worker occupation: 19.3%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.840e+02  1.594e+01  y = x₀                                        3           4.000e+00  2.753e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 16.5%┣███████                                    ┫ 99/600 [00:01<00:05, 104it/s]Expressions evaluated per second: [.....]. Head worker occupation: 19.3%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.840e+02  1.594e+01  y = x₀                                        3           4.000e+00  2.753e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 17.8%┣███████▌                                  ┫ 107/600 [00:01<00:05, 106it/s]Expressions evaluated per second: 2.63e+05. Head worker occupation: 20.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.840e+02  1.594e+01  y = x₀                                        3           4.000e+00  2.753e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 19.0%┣████████                                  ┫ 114/600 [00:01<00:05, 107it/s]Expressions evaluated per second: 2.63e+05. Head worker occupation: 20.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.840e+02  1.594e+01  y = x₀                                        3           4.000e+00  2.753e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 20.7%┣████████▊                                 ┫ 124/600 [00:01<00:04, 110it/s]Expressions evaluated per second: 2.63e+05. Head worker occupation: 20.9%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.840e+02  1.594e+01  y = x₀                                        2           8.000e+02  2.070e-01  y = square(-7.3484)                           3           4.000e+00  5.298e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 21.8%┣█████████▏                                ┫ 131/600 [00:01<00:04, 111it/s]Expressions evaluated per second: 2.63e+05. Head worker occupation: 20.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.840e+02  1.594e+01  y = x₀                                        2           8.000e+02  2.070e-01  y = square(-7.3484)                           3           4.000e+00  5.298e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 22.8%┣█████████▋                                ┫ 137/600 [00:01<00:04, 111it/s]Expressions evaluated per second: 2.63e+05. Head worker occupation: 20.4%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.840e+02  1.594e+01  y = x₀                                        2           8.000e+02  2.070e-01  y = square(-7.3484)                           3           4.000e+00  5.298e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 24.0%┣██████████                                ┫ 144/600 [00:01<00:04, 112it/s]Expressions evaluated per second: 2.63e+05. Head worker occupation: 20.9%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           9.840e+02  1.594e+01  y = x₀                                        2           8.000e+02  2.070e-01  y = square(-7.3484)                           3           4.000e+00  5.298e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 24.7%┣██████████▍                               ┫ 148/600 [00:01<00:04, 110it/s]Expressions evaluated per second: 2.63e+05. Head worker occupation: 20.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 26.0%┣███████████                               ┫ 156/600 [00:01<00:04, 112it/s]Expressions evaluated per second: 2.63e+05. Head worker occupation: 21.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 27.3%┣███████████▌                              ┫ 164/600 [00:01<00:04, 113it/s]Expressions evaluated per second: 2.63e+05. Head worker occupation: 21.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 28.5%┣████████████                              ┫ 171/600 [00:02<00:04, 113it/s]Expressions evaluated per second: 2.63e+05. Head worker occupation: 21.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 29.3%┣████████████▎                             ┫ 176/600 [00:02<00:04, 112it/s]Expressions evaluated per second: 2.63e+05. Head worker occupation: 21.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        2           8.000e+02  -0.000e+00  y = square(-7.3484)                          3           4.000e+00  5.298e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 30.5%┣████████████▉                             ┫ 183/600 [00:02<00:04, 113it/s]Expressions evaluated per second: 2.63e+05. Head worker occupation: 21.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        2           8.000e+02  -0.000e+00  y = square(-7.3484)                          3           4.000e+00  5.298e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 32.2%┣█████████████▌                            ┫ 193/600 [00:02<00:04, 115it/s]Expressions evaluated per second: 2.63e+05. Head worker occupation: 21.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        2           8.000e+02  -0.000e+00  y = square(-7.3484)                          3           4.000e+00  5.298e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 33.3%┣██████████████                            ┫ 200/600 [00:02<00:03, 115it/s]Expressions evaluated per second: 2.63e+05. Head worker occupation: 21.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        2           8.000e+02  -0.000e+00  y = square(-7.3484)                          3           4.000e+00  5.298e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 34.5%┣██████████████▌                           ┫ 207/600 [00:02<00:03, 115it/s]Expressions evaluated per second: 2.63e+05. Head worker occupation: 21.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        2           8.000e+02  -0.000e+00  y = square(-7.3484)                          3           4.000e+00  5.298e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 35.7%┣███████████████                           ┫ 214/600 [00:02<00:03, 116it/s]Expressions evaluated per second: 2.63e+05. Head worker occupation: 21.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        2           8.000e+02  -0.000e+00  y = square(-7.3484)                          3           4.000e+00  5.298e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 37.2%┣███████████████▋                          ┫ 223/600 [00:02<00:03, 117it/s]Expressions evaluated per second: 2.63e+05. Head worker occupation: 21.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        2           8.000e+02  -0.000e+00  y = square(-7.3484)                          3           4.000e+00  5.298e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 38.3%┣████████████████                          ┫ 230/600 [00:02<00:03, 117it/s]Expressions evaluated per second: 2.63e+05. Head worker occupation: 21.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        2           8.000e+02  -0.000e+00  y = square(-7.3484)                          3           4.000e+00  5.298e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 39.7%┣████████████████▋                         ┫ 238/600 [00:02<00:03, 118it/s]Expressions evaluated per second: 2.88e+05. Head worker occupation: 21.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        2           8.000e+02  -0.000e+00  y = square(-7.3484)                          3           9.132e-01  6.775e+00  y = (x₀ * 2.0594)                             5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 41.5%┣█████████████████▍                        ┫ 249/600 [00:02<00:03, 120it/s]Expressions evaluated per second: 2.88e+05. Head worker occupation: 21.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        2           8.000e+02  -0.000e+00  y = square(-7.3484)                          3           9.132e-01  6.775e+00  y = (x₀ * 2.0594)                             5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 42.8%┣██████████████████                        ┫ 257/600 [00:02<00:03, 120it/s]Expressions evaluated per second: 2.88e+05. Head worker occupation: 21.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        2           8.000e+02  -0.000e+00  y = square(-7.3484)                          3           9.132e-01  6.775e+00  y = (x₀ * 2.0594)                             5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 44.0%┣██████████████████▌                       ┫ 264/600 [00:02<00:03, 120it/s]Expressions evaluated per second: 2.88e+05. Head worker occupation: 21.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        2           8.000e+02  -0.000e+00  y = square(-7.3484)                          3           9.132e-01  6.775e+00  y = (x₀ * 2.0594)                             5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 45.2%┣███████████████████                       ┫ 271/600 [00:02<00:03, 120it/s]Expressions evaluated per second: 2.88e+05. Head worker occupation: 21.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 46.3%┣███████████████████▌                      ┫ 278/600 [00:02<00:03, 120it/s]Expressions evaluated per second: 2.88e+05. Head worker occupation: 21.5%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 47.3%┣███████████████████▉                      ┫ 284/600 [00:02<00:03, 120it/s]Expressions evaluated per second: 2.88e+05. Head worker occupation: 21.4%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 48.3%┣████████████████████▎                     ┫ 290/600 [00:02<00:03, 120it/s]Expressions evaluated per second: 2.88e+05. Head worker occupation: 21.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 49.8%┣█████████████████████                     ┫ 299/600 [00:02<00:02, 120it/s]Expressions evaluated per second: 2.88e+05. Head worker occupation: 21.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 51.2%┣█████████████████████▌                    ┫ 307/600 [00:03<00:02, 121it/s]Expressions evaluated per second: 2.88e+05. Head worker occupation: 21.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 52.8%┣██████████████████████▏                   ┫ 317/600 [00:03<00:02, 122it/s]Expressions evaluated per second: 2.88e+05. Head worker occupation: 22.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           9.132e-01  3.388e+00  y = (x₀ * 2.0594)                             5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# ...
# 84.3%┣███████████████████████████████████▍      ┫ 506/600 [00:05<00:01, 109it/s]Expressions evaluated per second: 2.61e+05. Head worker occupation: 24.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 85.3%┣███████████████████████████████████▉      ┫ 512/600 [00:05<00:01, 109it/s]Expressions evaluated per second: 2.61e+05. Head worker occupation: 24.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 86.7%┣████████████████████████████████████▍     ┫ 520/600 [00:05<00:01, 109it/s]Expressions evaluated per second: 2.61e+05. Head worker occupation: 24.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 88.0%┣█████████████████████████████████████     ┫ 528/600 [00:05<00:01, 109it/s]Expressions evaluated per second: 2.61e+05. Head worker occupation: 24.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 89.2%┣█████████████████████████████████████▌    ┫ 535/600 [00:05<00:01, 110it/s]Expressions evaluated per second: 2.61e+05. Head worker occupation: 24.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 90.3%┣██████████████████████████████████████    ┫ 542/600 [00:05<00:01, 110it/s]Expressions evaluated per second: 2.61e+05. Head worker occupation: 24.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 91.5%┣██████████████████████████████████████▍   ┫ 549/600 [00:05<00:00, 110it/s]Expressions evaluated per second: 2.61e+05. Head worker occupation: 24.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 92.5%┣██████████████████████████████████████▉   ┫ 555/600 [00:05<00:00, 110it/s]Expressions evaluated per second: 2.64e+05. Head worker occupation: 24.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 93.8%┣███████████████████████████████████████▍  ┫ 563/600 [00:05<00:00, 110it/s]Expressions evaluated per second: 2.64e+05. Head worker occupation: 24.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 94.7%┣███████████████████████████████████████▊  ┫ 568/600 [00:05<00:00, 110it/s]Expressions evaluated per second: 2.64e+05. Head worker occupation: 24.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 96.2%┣████████████████████████████████████████▍ ┫ 577/600 [00:05<00:00, 111it/s]Expressions evaluated per second: 2.64e+05. Head worker occupation: 24.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 97.3%┣████████████████████████████████████████▉ ┫ 584/600 [00:05<00:00, 111it/s]Expressions evaluated per second: 2.64e+05. Head worker occupation: 24.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 97.8%┣█████████████████████████████████████████ ┫ 587/600 [00:05<00:00, 110it/s]Expressions evaluated per second: 2.64e+05. Head worker occupation: 23.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 98.3%┣█████████████████████████████████████████▎┫ 590/600 [00:05<00:00, 109it/s]Expressions evaluated per second: 2.64e+05. Head worker occupation: 24.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------
# 99.0%┣█████████████████████████████████████████▋┫ 594/600 [00:05<00:00, 108it/s]Expressions evaluated per second: 2.64e+05. Head worker occupation: 24.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           8.000e+02  1.594e+01  y = 54                                        3           4.000e+00  2.649e+00  y = (x₀ + x₀)                                 5           0.000e+00  7.971e+00  y = (x₀ + (x₀ + 2))                           ---------------------------------------------------------------------------------------------------

# %%
registros_ = registros
file_pickle = 'dados_v2.pck'

# %%
for i in registros_:
  loss = i[1]
  score = i[2]
  complexity = i[0]
  w = (loss * score)/complexity
  if math.isnan(w):
    i.append(0)
  else:
    i.append(w)

lista_melhor_valor = max(registros_, key=lambda x: x[6])
# Out:
# C:\Users\rafae\AppData\Local\Temp\ipykernel_17572\2759937347.py:5: RuntimeWarning: invalid value encountered in scalar multiply
#   w = (loss * score)/complexity

# %% [markdown]
# ## Save result

# %%
def salvar_dados(dados, key, arquivo):
  if os.path.exists(arquivo):
    with open(arquivo, 'rb') as f:
      dados_exist = pickle.load(f)
  else:
    dados_exist = {}
    
  valor_original = dados_exist.get(key)
  if valor_original == None:
    dados_exist.update({key: [dados]})
  else:
    if isinstance(valor_original, list):
      valor_original.append(dados)
    else:
      dados_exist.update({key: [dados]})

  with open(arquivo, 'wb') as f:
    pickle.dump(dados_exist, f)

caminho_arquivo = file_pickle
novos_dados = lista_melhor_valor[0:3] + [lista_melhor_valor[4]]

salvar_dados(novos_dados, 'linear_search_x', caminho_arquivo)

# %%
def carregar_dados(arquivo):
    # Carrega os dados do arquivo pickle
    with open(arquivo, 'rb') as f:
        dados = pickle.load(f)
    return dados

caminho_arquivo = file_pickle
dados_carregados = carregar_dados(caminho_arquivo)

print("Conteúdo do arquivo pickle:")
for k, v in dados_carregados.items():
  print('\u25CF', k)
  for index, item in enumerate(v):
    if index == len(v)-1:
       print('└─', item)
    else:
      print('├─', item)
  print('==========================')
# Out:
# Conteúdo do arquivo pickle:
# ● binary_search_logx
# ├─ [6, 1.2914093, 1.37589542429269, log(x0**6) + 5.574131]
# └─ [5, 1.5291592, 2.19479656667366, log(x0)**2 + 13.966276]
# ==========================
# ● boyer_moore_M_plus_N
# ├─ [9, 1729031400.0, 0.1972007458935316, 752018330.701125*(0.00603869219560025*x0 + 0.00603869219560025*x1 - 1)**4 + 601415.75]
# └─ [5, 15754614000.0, 0.3055240605113849, 3621132.2 - 28185.828*x1]
# ==========================
# ● bubblesort_N^2
# ├─ [4, 5910.4966, 3.4645076652491285, 1.5253483*x0**2]
# └─ [4, 8542.308, 3.303255717418494, 1.5552218*x0**2]
# ==========================
# ● fibonacci_interative_N
# ├─ [3, 0.20818244, 3.412549040667958, 2.058653*x0]
# └─ [3, 0.20818244, 3.412549040667958, 2.058653*x0]
# ==========================
# ● fibonacci_recursive_2^N
# ├─ [15, 111113150.0, 0.37865996607381686, x0**4*(0.0022606994*x0**2 - 0.714783)]
# └─ [15, 77371830.0, 0.38657145558895856, x0**2*(x0**2*(0.16452532*x0 - 3.8766947) + 297.9323)]
# ==========================
# ● heapsort_NlogN
# ├─ [9, 0.24989581, 1.1851428541960574, 4*x0 - 1.4897935]
# └─ [9, 0.24989575, 1.185128414350167, 4*x0 - 1.4897884]
# ==========================
# ● insertionsort_N^2
# ├─ [4, 12514.81, 0.5204699193332855, 7.19343672459889*(0.372847972767781*x0 - 1)**2]
# └─ [4, 11070.262, 0.6554198140129509, 9.54380044013764*(0.323697485019442*x0 - 1)**2]
# ==========================
# ● tower_hanoi_2^N
# ├─ [13, 4607.291, 0.98801217824901, 0.0050468594*x0**6]
# └─ [13, 4607.2915, 0.988012078856794, 0.005046889*x0**6]
# ==========================
# ● karatsuba_N^1.585
# └─ [4, 535.7578, 1.123614036379079, 3.66931686122521*x0**2]
# ==========================
# ● levenshtein_distance_MN
# └─ [4, 1058.5413, 9.647410674646242, 3.52554060674929*x1**2]
# ==========================
# ● linear_search_x
# ├─ [14, 0.26546365, 0.9472618119882181, x0*log(log(log(1.97671752435621e-50*x0**18)**2))]
# └─ [3, 0.91324174, 3.3876830428181948, 2.0593598*x0]
# ==========================
# ● mergesort_NlogN
# ├─ [8, 40.208347, 0.542941641791251, (log(x0 + 4.4829993)**2 + 0.71281224)**2]
# └─ [8, 40.208347, 0.5429418585508976, (log(x0 + 4.4826865)**2 + 0.71286815)**2]
# ==========================
# ● quicksort_x^2
# ├─ [5, 4191.8745, 0.5370400329213452, 31.022936*x0 - 114.24918]
# └─ [5, 3799.3462, 0.5090052338906941, 30.326008*x0 - 105.0883]
# ==========================
# ● selectsort_N^2
# ├─ [7, 492.61688, 0.8252641931074596, 0.91222733*x0*log(x0)**3]
# └─ [7, 529.9843, 0.7728385969753846, 0.9116503*x0*log(x0)**3]
# ==========================
# ● shellsort_NlogN
# ├─ [6, 2333.781, 2.6158456057911406, 9.6421651223277*(0.469831154898539*log(x0**3) - 1)**3]
# └─ [6, 899.3794, 1.4964888960073477, 5.0019417*x0*log(x0)]
# ==========================
# ● strassen_N^2.81
# ├─ [9, 31317.309, 0.2847589231536684, log(2407.45008008753*(0.0372501681530186*(0.817895287156492*x0 + 1)**3 - 1)**2)**3]
# └─ [9, 33064.902, 0.11522887698339954, 1.80036936911294*(0.82201446811225*log(225.511129952784*(0.066591072481186*x0**3 - 1)**2) + 1)**3]
# ==========================
