# %%
# https://the-algorithms.com/algorithm/karatsuba

import numpy as np
from line_profiler import LineProfiler
from pysr import PySRRegressor
import random
import os
import sys
import math
import pickle

# %% [markdown]
# ## karatsuba Algorithm

# %%
def generate_random_numbers(num_digits):
    # Gerar o limite superior e inferior com base no número de dígitos
    lower_bound = 10 ** (num_digits - 1)
    upper_bound = (10 ** num_digits) - 1
    
    # Gerar dois números aleatórios dentro do intervalo especificado
    random_number1 = random.randint(lower_bound, upper_bound)
    random_number2 = random.randint(lower_bound, upper_bound)
    
    return random_number1, random_number2

def karatsuba(a: int, b: int) -> int:
    """
    >>> karatsuba(15463, 23489) == 15463 * 23489
    True
    >>> karatsuba(3, 9) == 3 * 9
    True
    """
    if len(str(a)) == 1 or len(str(b)) == 1:
        return a * b

    m1 = max(len(str(a)), len(str(b)))
    m2 = m1 // 2

    a1, a2 = divmod(a, 10**m2)
    b1, b2 = divmod(b, 10**m2)

    x = karatsuba(a2, b2)
    y = karatsuba((a1 + a2), (b1 + b2))
    z = karatsuba(a1, b1)

    return (z * 10 ** (2 * m2)) + ((y - z - x) * 10 ** (m2)) + (x)

# %% [markdown]
# ## Frequency Count Method

# %%
X_y = []
i=10
for n in range(2,i+1):
  lprofiler = LineProfiler()
  lp_wrapper = lprofiler(karatsuba)
  
  # create numbers with length n
  num1, num2 = generate_random_numbers(n)
  lp_wrapper(num1, num2)

  stats = lprofiler.get_stats()
  line_numbers = []
  hits = []

  for line in stats.timings.values():
    for i in line:
      line_numbers.append(i[0])
      hits.append(i[1])

  X_y.append([n, sum(hits)])

dados = np.array(X_y)

X = dados[:, 0]
y = dados[:, 1]
X_reshaped = X.reshape(-1, 1)

# %%
resultados_com_menor_loss = []
repeat = 4
registros = []
unary_operators_list = ["log", "square", "cube", "sqrt", "round", "exp", "abs"]

original_stdout = sys.stdout

with open(os.devnull, 'w') as devnull:
  sys.stdout = devnull

  for i in range(repeat):

    # first combination
    reg1 = PySRRegressor(
      binary_operators=["*", "+"],
      unary_operators=unary_operators_list
    )

    fit1 = reg1.fit(X_reshaped, y)
    best_program1 = fit1.get_best()

    registro1 = []
    for index, value in enumerate(best_program1):
      registro1.append(value)
      
    registros.append(registro1)

    # second combination
    reg2 = PySRRegressor(
      binary_operators=["*"],
      unary_operators=unary_operators_list
    )

    fit2 = reg2.fit(X_reshaped, y)
    best_program2 = fit2.get_best()

    registro2 = []
    for index, value in enumerate(best_program2):
      registro2.append(value)
    registros.append(registro2)

    # third combinarion
    reg3 = PySRRegressor(
      binary_operators=["+"],
      unary_operators=unary_operators_list
    )

    fit3 = reg3.fit(X_reshaped, y)
    best_program3 = fit3.get_best()

    registro3 = []
    for index, value in enumerate(best_program3):
      registro3.append(value)
    registros.append(registro3)
    
sys.stdout = original_stdout
# Out:
# [ Info: Started!
# 0.0%┣                                             ┫ 0/600 [00:00<00:-10, -0s/it]Expressions evaluated per second: [.....]. Head worker occupation: 0.0%         Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       2           2.718e+04  7.971e+00  y = square(x₀)                                4           2.521e+04  3.757e-02  y = (square(x₀) + x₀)                         5           1.352e+04  6.232e-01  y = (square(x₀) + square(x₀))                 6           7.957e+03  5.301e-01  y = (square(x₀) * square(log(x₀)))            8           7.011e+03  6.329e-02  y = (square(x₀) * square(log(-0.82342 + x₀))) 10          4.575e+03  2.134e-01  y = ((square(x₀) + 2.2979) * log(square(-0.82342 + x₀)))                                                                      13          4.387e+03  1.398e-02  y = ((((-0.94501 * x₀) + square(x₀)) + square(-1.1255)) * log(...                                                                                               square(x₀)))                                  17          4.340e+03  2.728e-03  y = ((((cube(-0.94501) * x₀) + (square(x₀) + -0.42962)) + cube...                                                                                               (square(-1.1255))) * log(square(x₀)))         20          4.166e+03  1.363e-02  y = ((((cube(-0.94501) * x₀) + (square(x₀) + -0.42962)) + cube...                                                                                               (square(square(-1.1255)))) * (log(square(x₀)) + -0.20134))                                                                    ---------------------------------------------------------------------------------------------------
# 0.2%┣                                          ┫ 1/600 [00:00<Inf:Inf, InfGs/it]Expressions evaluated per second: [.....]. Head worker occupation: NaN%         Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           4.383e+04  1.594e+01  y = x₀                                        2           2.718e+04  4.779e-01  y = square(x₀)                                4           2.521e+04  3.757e-02  y = (square(x₀) + x₀)                         5           1.352e+04  6.232e-01  y = (square(x₀) + square(x₀))                 6           2.840e+03  1.560e+00  y = cube(log(square(x₀) * x₀))                8           2.598e+03  4.449e-02  y = cube(log(square(x₀) * cube(log(x₀))))     10          2.505e+03  1.818e-02  y = cube(log(square(x₀ + 0.32589) * cube(log(x₀))))                                                                           12          2.503e+03  5.039e-04  y = cube(log((square(x₀ + 0.32589) + 0.30713) * cube(log(x₀)))...                                                                                               )                                             13          2.500e+03  9.433e-04  y = (cube(log(square(x₀ + 0.32589) * cube(log(x₀)))) + square(...                                                                                               -0.81991))                                    15          2.485e+03  2.962e-03  y = (cube(log((square(x₀ + 0.32589) * cube(log(x₀))) + x₀)) + ...                                                                                               square(-0.81991))                             ---------------------------------------------------------------------------------------------------
# 1.3%┣▋                                             ┫ 8/600 [00:00<00:15, 40it/s]Expressions evaluated per second: [.....]. Head worker occupation: 13.4%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           4.383e+04  1.594e+01  y = x₀                                        2           2.718e+04  4.779e-01  y = square(x₀)                                4           2.840e+03  1.129e+00  y = cube(log(cube(x₀)))                       6           2.671e+03  3.064e-02  y = (cube(log(cube(x₀))) + x₀)                8           2.574e+03  1.847e-02  y = (cube(log(cube(x₀) * 1.1346)) + x₀)       10          2.505e+03  1.356e-02  y = cube(log(square(x₀ + 0.32589) * cube(log(x₀))))                                                                           12          2.503e+03  5.039e-04  y = cube(log((square(x₀ + 0.32589) + 0.30713) * cube(log(x₀)))...                                                                                               )                                             13          2.500e+03  9.433e-04  y = (cube(log(square(x₀ + 0.32589) * cube(log(x₀)))) + square(...                                                                                               -0.81991))                                    15          2.485e+03  2.962e-03  y = (cube(log((square(x₀ + 0.32589) * cube(log(x₀))) + x₀)) + ...                                                                                               square(-0.81991))                             ---------------------------------------------------------------------------------------------------
# 2.5%┣█▏                                           ┫ 15/600 [00:00<00:10, 58it/s]Expressions evaluated per second: [.....]. Head worker occupation: 15.5%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           4.383e+04  1.594e+01  y = x₀                                        2           2.718e+04  4.779e-01  y = square(x₀)                                4           2.840e+03  1.129e+00  y = cube(log(cube(x₀)))                       6           2.671e+03  3.064e-02  y = (cube(log(cube(x₀))) + x₀)                8           2.574e+03  1.847e-02  y = (cube(log(cube(x₀) * 1.1346)) + x₀)       10          2.505e+03  1.356e-02  y = cube(log(square(x₀ + 0.32589) * cube(log(x₀))))                                                                           12          2.503e+03  5.039e-04  y = cube(log((square(x₀ + 0.32589) + 0.30713) * cube(log(x₀)))...                                                                                               )                                             13          2.500e+03  9.433e-04  y = (cube(log(square(x₀ + 0.32589) * cube(log(x₀)))) + square(...                                                                                               -0.81991))                                    15          2.485e+03  2.962e-03  y = (cube(log((square(x₀ + 0.32589) * cube(log(x₀))) + x₀)) + ...                                                                                               square(-0.81991))                             ---------------------------------------------------------------------------------------------------
# 3.5%┣█▋                                           ┫ 21/600 [00:00<00:09, 67it/s]Expressions evaluated per second: [.....]. Head worker occupation: 17.0%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           4.383e+04  1.594e+01  y = x₀                                        2           2.718e+04  4.779e-01  y = square(x₀)                                4           2.840e+03  1.129e+00  y = cube(log(cube(x₀)))                       6           2.671e+03  3.064e-02  y = (cube(log(cube(x₀))) + x₀)                8           2.574e+03  1.847e-02  y = (cube(log(cube(x₀) * 1.1346)) + x₀)       10          2.505e+03  1.356e-02  y = cube(log(square(x₀ + 0.32589) * cube(log(x₀))))                                                                           12          2.503e+03  5.039e-04  y = cube(log((square(x₀ + 0.32589) + 0.30713) * cube(log(x₀)))...                                                                                               )                                             13          2.500e+03  9.433e-04  y = (cube(log(square(x₀ + 0.32589) * cube(log(x₀)))) + square(...                                                                                               -0.81991))                                    15          2.485e+03  2.962e-03  y = (cube(log((square(x₀ + 0.32589) * cube(log(x₀))) + x₀)) + ...                                                                                               square(-0.81991))                             ---------------------------------------------------------------------------------------------------
# 4.5%┣██                                           ┫ 27/600 [00:00<00:08, 71it/s]Expressions evaluated per second: [.....]. Head worker occupation: 18.8%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           4.383e+04  1.594e+01  y = x₀                                        2           2.718e+04  4.779e-01  y = square(x₀)                                4           2.840e+03  1.129e+00  y = cube(log(cube(x₀)))                       6           2.671e+03  3.064e-02  y = (cube(log(cube(x₀))) + x₀)                7           2.664e+03  2.666e-03  y = cube(log(cube(x₀) + square(x₀)))          8           2.574e+03  3.427e-02  y = (cube(log(cube(x₀) * 1.1346)) + x₀)       10          2.505e+03  1.356e-02  y = cube(log(square(x₀ + 0.32589) * cube(log(x₀))))                                                                           12          2.487e+03  3.594e-03  y = cube(log((square(x₀ + 0.32589) * cube(log(x₀))) + x₀))                                                                    15          2.485e+03  2.288e-04  y = (cube(log((square(x₀ + 0.32589) * cube(log(x₀))) + x₀)) + ...                                                                                               square(-0.81991))                             17          2.485e+03  1.015e-04  y = (cube(log((square(x₀ + 0.32589) * cube(log(x₀))) + x₀)) + ...                                                                                               (square(-0.81991) + 1.5391))                  ---------------------------------------------------------------------------------------------------
# 5.7%┣██▌                                          ┫ 34/600 [00:00<00:07, 78it/s]Expressions evaluated per second: [.....]. Head worker occupation: 19.6%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           4.383e+04  1.594e+01  y = x₀                                        2           2.718e+04  4.779e-01  y = square(x₀)                                4           2.840e+03  1.129e+00  y = cube(log(cube(x₀)))                       6           2.671e+03  3.064e-02  y = (cube(log(cube(x₀))) + x₀)                7           2.664e+03  2.666e-03  y = cube(log(cube(x₀) + square(x₀)))          8           2.574e+03  3.427e-02  y = (cube(log(cube(x₀) * 1.1346)) + x₀)       10          2.505e+03  1.356e-02  y = cube(log(square(x₀ + 0.32589) * cube(log(x₀))))                                                                           12          2.487e+03  3.594e-03  y = cube(log((square(x₀ + 0.32589) * cube(log(x₀))) + x₀))                                                                    15          2.485e+03  2.288e-04  y = (cube(log((square(x₀ + 0.32589) * cube(log(x₀))) + x₀)) + ...                                                                                               square(-0.81991))                             17          2.485e+03  1.015e-04  y = (cube(log((square(x₀ + 0.32589) * cube(log(x₀))) + x₀)) + ...                                                                                               (square(-0.81991) + 1.5391))                  ---------------------------------------------------------------------------------------------------
# 6.7%┣███                                          ┫ 40/600 [00:00<00:07, 80it/s]Expressions evaluated per second: [.....]. Head worker occupation: 19.0%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           4.186e+04  1.594e+01  y = 13.908                                    2           2.718e+04  4.320e-01  y = square(x₀)                                4           2.840e+03  1.129e+00  y = cube(log(cube(x₀)))                       6           2.671e+03  3.064e-02  y = (cube(log(cube(x₀))) + x₀)                7           2.651e+03  7.344e-03  y = (cube(log(cube(x₀))) * square(-1.0173))   8           2.551e+03  3.838e-02  y = (cube(log(cube(x₀))) * square(square(-1.0173)))                                                                           9           2.537e+03  5.771e-03  y = (cube(log(cube(x₀))) + square(square(log(x₀))))                                                                           10          2.505e+03  1.256e-02  y = cube(log(square(x₀ + 0.32589) * cube(log(x₀))))                                                                           12          2.487e+03  3.594e-03  y = cube(log((square(x₀ + 0.32589) * cube(log(x₀))) + x₀))                                                                    15          2.485e+03  2.288e-04  y = (cube(log((square(x₀ + 0.32589) * cube(log(x₀))) + x₀)) + ...                                                                                               square(-0.81991))                             17          2.485e+03  1.015e-04  y = (cube(log((square(x₀ + 0.32589) * cube(log(x₀))) + x₀)) + ...                                                                                               (square(-0.81991) + 1.5391))                  ---------------------------------------------------------------------------------------------------
# 7.7%┣███▌                                         ┫ 46/600 [00:01<00:07, 82it/s]Expressions evaluated per second: [.....]. Head worker occupation: 18.9%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           4.186e+04  1.594e+01  y = 13.908                                    2           2.718e+04  4.320e-01  y = square(x₀)                                4           2.840e+03  1.129e+00  y = cube(log(cube(x₀)))                       6           2.626e+03  3.912e-02  y = cube(log(cube(x₀)) + 0.24985)             8           2.551e+03  1.438e-02  y = (cube(log(cube(x₀))) * square(square(-1.0173)))                                                                           9           2.537e+03  5.771e-03  y = (cube(log(cube(x₀))) + square(square(log(x₀))))                                                                           10          2.505e+03  1.256e-02  y = cube(log(square(x₀ + 0.32589) * cube(log(x₀))))                                                                           12          2.487e+03  3.594e-03  y = cube(log((square(x₀ + 0.32589) * cube(log(x₀))) + x₀))                                                                    15          2.485e+03  2.288e-04  y = (cube(log((square(x₀ + 0.32589) * cube(log(x₀))) + x₀)) + ...                                                                                               square(-0.81991))                             17          2.485e+03  1.015e-04  y = (cube(log((square(x₀ + 0.32589) * cube(log(x₀))) + x₀)) + ...                                                                                               (square(-0.81991) + 1.5391))                  18          2.480e+03  2.032e-03  y = (cube(log(((square(x₀ + 0.32496) * cube(log(x₀))) + x₀) + ...                                                                                               x₀)) + log(square(-0.81991)))                 20          2.480e+03  1.928e-05  y = (cube(log(((square(x₀ + 0.32589) * cube(log(x₀))) + x₀) + ...                                                                                               (x₀ * 1.1585))) + log(square(-0.81991)))      ---------------------------------------------------------------------------------------------------
# 8.7%┣████                                         ┫ 52/600 [00:01<00:07, 84it/s]Expressions evaluated per second: [.....]. Head worker occupation: 19.3%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           4.186e+04  1.594e+01  y = 13.908                                    2           2.718e+04  4.320e-01  y = square(x₀)                                4           2.840e+03  1.129e+00  y = cube(log(cube(x₀)))                       6           2.566e+03  5.064e-02  y = cube(log(cube(x₀) * 1.192))               8           2.520e+03  8.989e-03  y = ((cube(log(cube(x₀))) + -6.7196) * 1.1231)                                                                                10          2.505e+03  3.039e-03  y = cube(log(square(x₀ + 0.32589) * cube(log(x₀))))                                                                           12          2.485e+03  4.038e-03  y = cube(log((square(x₀) * cube(log(x₀))) + (x₀ * x₀)))                                                                       13          2.483e+03  8.026e-04  y = cube(log(square(x₀ + cube(-0.71379)) * (cube(log(x₀)) + 1....                                                                                               5417)))                                       14          2.477e+03  2.530e-03  y = cube(log((square(x₀ + 0.32589) * cube(log(x₀))) + (x₀ + 1....                                                                                               8286)))                                       15          2.472e+03  2.008e-03  y = cube(log((square(x₀ + 0.32589) * cube(log(x₀))) + (x₀ + sq...                                                                                               uare(-1.7617))))                              20          2.466e+03  4.292e-04  y = (cube(log((square(x₀) * cube(log(x₀))) + x₀)) + (square(lo...                                                                                               g(square(square(-0.37491)) * x₀)) + 1.5391))  ---------------------------------------------------------------------------------------------------
# 10.0%┣████▍                                       ┫ 60/600 [00:01<00:06, 89it/s]Expressions evaluated per second: [.....]. Head worker occupation: 20.0%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           4.186e+04  1.594e+01  y = 13.908                                    2           2.718e+04  4.320e-01  y = square(x₀)                                4           2.840e+03  1.129e+00  y = cube(log(cube(x₀)))                       6           2.566e+03  5.064e-02  y = cube(log(cube(x₀) * 1.192))               8           2.520e+03  8.989e-03  y = ((cube(log(cube(x₀))) + -6.7196) * 1.1231)                                                                                10          2.505e+03  3.039e-03  y = cube(log(square(x₀ + 0.32589) * cube(log(x₀))))                                                                           12          2.485e+03  4.038e-03  y = cube(log((square(x₀) * cube(log(x₀))) + (x₀ * x₀)))                                                                       13          2.483e+03  8.026e-04  y = cube(log(square(x₀ + cube(-0.71379)) * (cube(log(x₀)) + 1....                                                                                               5417)))                                       14          2.467e+03  6.266e-03  y = ((cube(log(square(x₀ + -0.45013) * cube(log(x₀)))) + x₀) +...                                                                                                15.99)                                       20          2.466e+03  6.975e-05  y = (cube(log((square(x₀) * cube(log(x₀))) + x₀)) + (square(lo...                                                                                               g(square(square(-0.37491)) * x₀)) + 1.5391))  ---------------------------------------------------------------------------------------------------
# 10.8%┣████▊                                       ┫ 65/600 [00:01<00:06, 90it/s]Expressions evaluated per second: [.....]. Head worker occupation: 19.3%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.673e+04  1.594e+01  y = 172.46                                    4           2.840e+03  5.912e-01  y = cube(log(cube(x₀)))                       6           2.566e+03  5.064e-02  y = cube(log(cube(x₀) * 1.192))               8           2.520e+03  8.989e-03  y = ((cube(log(cube(x₀))) + -6.7196) * 1.1231)                                                                                10          2.505e+03  3.039e-03  y = cube(log(square(x₀ + 0.32589) * cube(log(x₀))))                                                                           12          2.485e+03  4.038e-03  y = cube(log((square(x₀) * cube(log(x₀))) + (x₀ * x₀)))                                                                       13          2.483e+03  8.026e-04  y = cube(log(square(x₀ + cube(-0.71379)) * (cube(log(x₀)) + 1....                                                                                               5417)))                                       14          2.467e+03  6.266e-03  y = ((cube(log(square(x₀ + -0.45013) * cube(log(x₀)))) + x₀) +...                                                                                                15.99)                                       20          2.466e+03  6.975e-05  y = (cube(log((square(x₀) * cube(log(x₀))) + x₀)) + (square(lo...                                                                                               g(square(square(-0.37491)) * x₀)) + 1.5391))  ---------------------------------------------------------------------------------------------------
# 12.0%┣█████▎                                      ┫ 72/600 [00:01<00:06, 92it/s]Expressions evaluated per second: [.....]. Head worker occupation: 20.3%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.673e+04  1.594e+01  y = 172.46                                    4           2.840e+03  5.912e-01  y = cube(log(cube(x₀)))                       6           2.566e+03  5.064e-02  y = cube(log(cube(x₀) * 1.192))               8           2.520e+03  8.989e-03  y = ((cube(log(cube(x₀))) + -6.7196) * 1.1231)                                                                                10          2.505e+03  3.039e-03  y = cube(log(square(x₀ + 0.32589) * cube(log(x₀))))                                                                           11          2.485e+03  8.075e-03  y = cube(log((square(x₀) * cube(log(x₀))) + square(x₀)))                                                                      13          2.483e+03  4.013e-04  y = cube(log(square(x₀ + cube(-0.71379)) * (cube(log(x₀)) + 1....                                                                                               5417)))                                       14          2.465e+03  7.137e-03  y = (cube(log(square(x₀ + -0.018978) * cube(log(x₀)))) + squar...                                                                                               e(square(1.8925)))                            ---------------------------------------------------------------------------------------------------
# 12.8%┣█████▋                                      ┫ 77/600 [00:01<00:06, 92it/s]Expressions evaluated per second: [.....]. Head worker occupation: 19.5%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.673e+04  1.594e+01  y = 172.46                                    4           2.840e+03  5.912e-01  y = cube(log(cube(x₀)))                       6           2.566e+03  5.064e-02  y = cube(log(cube(x₀) * 1.192))               8           2.520e+03  8.989e-03  y = ((cube(log(cube(x₀))) + -6.7196) * 1.1231)                                                                                10          2.492e+03  5.592e-03  y = cube(log(square(x₀) * cube(log(x₀ + 0.46453))))                                                                           11          2.485e+03  2.968e-03  y = cube(log((square(x₀) * cube(log(x₀))) + square(x₀)))                                                                      12          2.482e+03  1.232e-03  y = cube(log((square(x₀) * cube(log(x₀ + 0.46453))) + x₀))                                                                    14          2.465e+03  3.354e-03  y = (cube(log(square(x₀ + -0.018978) * cube(log(x₀)))) + squar...                                                                                               e(square(1.8925)))                            ---------------------------------------------------------------------------------------------------
# 14.0%┣██████▏                                     ┫ 84/600 [00:01<00:05, 94it/s]Expressions evaluated per second: [.....]. Head worker occupation: 19.5%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.673e+04  1.594e+01  y = 172.46                                    4           2.840e+03  5.912e-01  y = cube(log(cube(x₀)))                       6           2.566e+03  5.066e-02  y = cube(log(cube(x₀)) + 0.17239)             8           2.520e+03  8.969e-03  y = ((cube(log(cube(x₀))) + -6.7196) * 1.1231)                                                                                10          2.492e+03  5.592e-03  y = cube(log(square(x₀) * cube(log(x₀ + 0.46453))))                                                                           11          2.485e+03  2.968e-03  y = cube(log((square(x₀) * cube(log(x₀))) + square(x₀)))                                                                      12          2.482e+03  1.232e-03  y = cube(log((square(x₀) * cube(log(x₀ + 0.46453))) + x₀))                                                                    13          2.481e+03  3.903e-04  y = cube(log((square(x₀) * cube(log(x₀))) + (square(x₀) + 2.43...                                                                                               31)))                                         14          2.465e+03  6.317e-03  y = (cube(log(square(x₀ + -0.018978) * cube(log(x₀)))) + squar...                                                                                               e(square(1.8925)))                            ---------------------------------------------------------------------------------------------------
# 15.2%┣██████▊                                     ┫ 91/600 [00:01<00:05, 96it/s]Expressions evaluated per second: [.....]. Head worker occupation: 20.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.673e+04  1.594e+01  y = 172.46                                    4           2.840e+03  5.912e-01  y = cube(log(cube(x₀)))                       6           2.566e+03  5.066e-02  y = cube(log(cube(x₀)) + 0.17239)             8           2.520e+03  8.969e-03  y = ((cube(log(cube(x₀))) + -6.7196) * 1.1231)                                                                                10          2.491e+03  5.843e-03  y = cube(log(square(x₀) * cube(log(x₀ + 0.49683))))                                                                           11          2.485e+03  2.468e-03  y = cube(log((square(x₀) * cube(log(x₀))) + square(x₀)))                                                                      12          2.482e+03  1.232e-03  y = cube(log((square(x₀) * cube(log(x₀ + 0.46453))) + x₀))                                                                    13          2.479e+03  1.156e-03  y = cube(log((square(x₀ * -0.99116) * cube(log(x₀))) + square(...                                                                                               x₀)))                                         14          2.465e+03  5.551e-03  y = (cube(log(square(x₀ + -0.018978) * cube(log(x₀)))) + squar...                                                                                               e(square(1.8925)))                            ---------------------------------------------------------------------------------------------------
# 16.0%┣███████                                     ┫ 96/600 [00:01<00:05, 95it/s]Expressions evaluated per second: [.....]. Head worker occupation: 19.7%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.673e+04  1.594e+01  y = 172.46                                    4           2.840e+03  5.912e-01  y = cube(log(cube(x₀)))                       6           2.566e+03  5.066e-02  y = cube(log(cube(x₀)) + 0.17239)             8           2.520e+03  8.969e-03  y = ((cube(log(cube(x₀))) + -6.7196) * 1.1231)                                                                                10          2.491e+03  5.843e-03  y = cube(log(square(x₀) * cube(log(x₀ + 0.49683))))                                                                           11          2.485e+03  2.468e-03  y = cube(log((square(x₀) * cube(log(x₀))) + square(x₀)))                                                                      12          2.482e+03  1.232e-03  y = cube(log((square(x₀) * cube(log(x₀ + 0.46453))) + x₀))                                                                    13          2.479e+03  1.156e-03  y = cube(log((square(x₀ * -0.99116) * cube(log(x₀))) + square(...                                                                                               x₀)))                                         14          2.465e+03  5.551e-03  y = (cube(log(square(x₀ + -0.018978) * cube(log(x₀)))) + squar...                                                                                               e(square(1.8925)))                            ---------------------------------------------------------------------------------------------------
# 17.3%┣███████▌                                   ┫ 104/600 [00:01<00:05, 98it/s]Expressions evaluated per second: 2.56e+05. Head worker occupation: 20.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.673e+04  1.594e+01  y = 172.46                                    3           1.616e+04  1.732e-02  y = (172.46 + x₀)                             4           2.840e+03  1.739e+00  y = cube(log(cube(x₀)))                       6           2.566e+03  5.066e-02  y = cube(log(cube(x₀)) + 0.17239)             8           2.520e+03  8.969e-03  y = ((cube(log(cube(x₀))) + -6.7196) * 1.1231)                                                                                10          2.491e+03  5.938e-03  y = cube(log(square(x₀) * cube(log(x₀ + 0.54419))))                                                                           11          2.485e+03  2.277e-03  y = cube(log((square(x₀) * cube(log(x₀))) + square(x₀)))                                                                      12          2.482e+03  1.232e-03  y = cube(log((square(x₀) * cube(log(x₀ + 0.46453))) + x₀))                                                                    13          2.479e+03  1.156e-03  y = cube(log((square(x₀ * -0.99116) * cube(log(x₀))) + square(...                                                                                               x₀)))                                         14          2.465e+03  5.551e-03  y = (cube(log(square(x₀ + -0.018978) * cube(log(x₀)))) + squar...                                                                                               e(square(1.8925)))                            ---------------------------------------------------------------------------------------------------
# 18.0%┣███████▊                                   ┫ 108/600 [00:01<00:05, 95it/s]Expressions evaluated per second: 2.56e+05. Head worker occupation: 20.5%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.673e+04  1.594e+01  y = 172.46                                    3           1.616e+04  1.732e-02  y = (172.46 + x₀)                             4           2.840e+03  1.739e+00  y = cube(log(cube(x₀)))                       6           2.566e+03  5.066e-02  y = cube(log(cube(x₀)) + 0.17239)             7           2.551e+03  5.802e-03  y = (cube(log(cube(x₀))) * square(1.0533))    8           2.520e+03  1.214e-02  y = ((cube(log(cube(x₀))) + -6.7196) * 1.1231)                                                                                10          2.491e+03  5.938e-03  y = cube(log(square(x₀) * cube(log(x₀ + 0.54419))))                                                                           11          2.485e+03  2.277e-03  y = cube(log((square(x₀) * cube(log(x₀))) + square(x₀)))                                                                      12          2.482e+03  1.232e-03  y = cube(log((square(x₀) * cube(log(x₀ + 0.46453))) + x₀))                                                                    13          2.479e+03  1.156e-03  y = cube(log((square(x₀ * -0.99116) * cube(log(x₀))) + square(...                                                                                               x₀)))                                         14          2.465e+03  5.551e-03  y = (cube(log(square(x₀ + -0.018978) * cube(log(x₀)))) + squar...                                                                                               e(square(1.8925)))                            ---------------------------------------------------------------------------------------------------
# 19.7%┣████████▌                                  ┫ 118/600 [00:01<00:05, 99it/s]Expressions evaluated per second: 2.56e+05. Head worker occupation: 20.9%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.673e+04  1.594e+01  y = 172.46                                    3           1.616e+04  1.732e-02  y = (172.46 + x₀)                             4           2.840e+03  1.739e+00  y = cube(log(cube(x₀)))                       6           2.566e+03  5.066e-02  y = cube(log(cube(x₀)) + 0.17239)             7           2.551e+03  5.802e-03  y = (cube(log(cube(x₀))) * square(1.0533))    8           2.520e+03  1.214e-02  y = ((cube(log(cube(x₀))) + -6.7196) * 1.1231)                                                                                10          2.491e+03  5.938e-03  y = cube(log(square(x₀) * cube(log(x₀ + 0.54419))))                                                                           11          2.485e+03  2.277e-03  y = cube(log((square(x₀) * cube(log(x₀))) + square(x₀)))                                                                      12          2.482e+03  1.232e-03  y = cube(log((square(x₀) * cube(log(x₀ + 0.46453))) + x₀))                                                                    13          2.479e+03  1.156e-03  y = cube(log((square(x₀ * -0.99116) * cube(log(x₀))) + square(...                                                                                               x₀)))                                         14          2.465e+03  5.551e-03  y = (cube(log(square(x₀ + -0.018978) * cube(log(x₀)))) + squar...                                                                                               e(square(1.8925)))                            ---------------------------------------------------------------------------------------------------
# 20.7%┣████████▉                                  ┫ 124/600 [00:01<00:05, 99it/s]Expressions evaluated per second: 2.56e+05. Head worker occupation: 20.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.673e+04  1.594e+01  y = 172.46                                    3           1.616e+04  1.732e-02  y = (172.46 + x₀)                             4           2.840e+03  1.739e+00  y = cube(log(cube(x₀)))                       6           2.566e+03  5.066e-02  y = cube(log(cube(x₀)) + 0.17239)             7           2.551e+03  5.802e-03  y = (cube(log(cube(x₀))) * square(1.0533))    8           2.520e+03  1.214e-02  y = ((cube(log(cube(x₀))) + -6.7196) * 1.1231)                                                                                10          2.491e+03  5.938e-03  y = cube(log(square(x₀) * cube(log(x₀ + 0.54419))))                                                                           11          2.485e+03  2.277e-03  y = cube(log((square(x₀) * cube(log(x₀))) + square(x₀)))                                                                      12          2.482e+03  1.232e-03  y = cube(log((square(x₀) * cube(log(x₀ + 0.46453))) + x₀))                                                                    13          2.479e+03  1.156e-03  y = cube(log((square(x₀ * -0.99116) * cube(log(x₀))) + square(...                                                                                               x₀)))                                         14          2.465e+03  5.551e-03  y = (cube(log(square(x₀ + -0.018978) * cube(log(x₀)))) + squar...                                                                                               e(square(1.8925)))                            ---------------------------------------------------------------------------------------------------
# 21.8%┣█████████▏                                ┫ 131/600 [00:01<00:05, 100it/s]Expressions evaluated per second: 2.56e+05. Head worker occupation: 20.5%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.673e+04  1.594e+01  y = 172.46                                    3           1.616e+04  1.732e-02  y = (172.46 + x₀)                             4           2.840e+03  1.739e+00  y = cube(log(cube(x₀)))                       6           2.566e+03  5.066e-02  y = cube(log(cube(x₀)) + 0.17239)             7           2.551e+03  5.802e-03  y = (cube(log(cube(x₀))) * square(1.0533))    8           2.520e+03  1.214e-02  y = ((cube(log(cube(x₀))) + -6.7196) * 1.1231)                                                                                10          2.491e+03  5.938e-03  y = cube(log(square(x₀) * cube(log(x₀ + 0.54419))))                                                                           11          2.485e+03  2.277e-03  y = cube(log((square(x₀) * cube(log(x₀))) + square(x₀)))                                                                      12          2.482e+03  1.232e-03  y = cube(log((square(x₀) * cube(log(x₀ + 0.46453))) + x₀))                                                                    13          2.479e+03  1.156e-03  y = cube(log((square(x₀ * -0.99116) * cube(log(x₀))) + square(...                                                                                               x₀)))                                         14          2.465e+03  5.551e-03  y = (cube(log(square(x₀ + -0.018978) * cube(log(x₀)))) + squar...                                                                                               e(square(1.8925)))                            ---------------------------------------------------------------------------------------------------
# ...
# 92.8%┣████████████████████████████████████████   ┫ 557/600 [00:06<00:00, 99it/s]Expressions evaluated per second: 2.52e+05. Head worker occupation: 22.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.673e+04  1.594e+01  y = 172.44                                    3           1.612e+04  1.844e-02  y = (x₀ + 166.45)                             4           2.840e+03  1.737e+00  y = cube(log(cube(x₀)))                       6           2.566e+03  5.066e-02  y = cube(log(cube(x₀)) + 0.17239)             7           2.566e+03  -0.000e+00  y = cube(log(cube(x₀)) + square(0.41523))    8           2.498e+03  2.704e-02  y = cube(log(cube(x₀ + -0.60784)) + 0.42834)  10          2.477e+03  4.158e-03  y = cube(log(cube(-0.97281 + x₀) + 5.2748) + 0.56238)                                                                         12          2.477e+03  3.278e-07  y = (cube(log(cube(-0.97281 + x₀) + 5.2748) + 0.56238) + 0.012...                                                                                               354)                                          ---------------------------------------------------------------------------------------------------
# 93.5%┣████████████████████████████████████████▏  ┫ 561/600 [00:06<00:00, 99it/s]Expressions evaluated per second: 2.52e+05. Head worker occupation: 22.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.673e+04  1.594e+01  y = 172.44                                    3           1.612e+04  1.844e-02  y = (x₀ + 166.45)                             4           2.840e+03  1.737e+00  y = cube(log(cube(x₀)))                       6           2.566e+03  5.066e-02  y = cube(log(cube(x₀)) + 0.17239)             7           2.566e+03  -0.000e+00  y = cube(log(cube(x₀)) + square(0.41523))    8           2.498e+03  2.704e-02  y = cube(log(cube(x₀ + -0.60784)) + 0.42834)  10          2.477e+03  4.158e-03  y = cube(log(cube(-0.97281 + x₀) + 5.2748) + 0.56238)                                                                         12          2.477e+03  3.278e-07  y = (cube(log(cube(-0.97281 + x₀) + 5.2748) + 0.56238) + 0.012...                                                                                               354)                                          ---------------------------------------------------------------------------------------------------
# 94.5%┣████████████████████████████████████████▋  ┫ 567/600 [00:06<00:00, 99it/s]Expressions evaluated per second: 2.52e+05. Head worker occupation: 22.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.673e+04  1.594e+01  y = 172.44                                    3           1.612e+04  1.844e-02  y = (x₀ + 166.45)                             4           2.840e+03  1.737e+00  y = cube(log(cube(x₀)))                       6           2.566e+03  5.066e-02  y = cube(log(cube(x₀)) + 0.17239)             7           2.566e+03  -0.000e+00  y = cube(log(cube(x₀)) + square(0.41523))    8           2.498e+03  2.704e-02  y = cube(log(cube(x₀ + -0.60784)) + 0.42834)  10          2.477e+03  4.158e-03  y = cube(log(cube(-0.97281 + x₀) + 5.2748) + 0.56238)                                                                         12          2.477e+03  3.278e-07  y = (cube(log(cube(-0.97281 + x₀) + 5.2748) + 0.56238) + 0.012...                                                                                               354)                                          17          2.477e+03  3.338e-07  y = (cube(log((cube(-0.97281 + x₀) + 0.07669) + (5.2748 + cube...                                                                                               (-0.44174))) + 0.56238) + 0.07669)            19          2.477e+03  1.669e-06  y = (cube(log((cube(-0.97281 + x₀) + 0.07669) + (5.2748 + (-0....                                                                                               44174 + 0.24157))) + 0.56238) + log(1.1969))  ---------------------------------------------------------------------------------------------------
# 95.3%┣█████████████████████████████████████████  ┫ 572/600 [00:06<00:00, 99it/s]Expressions evaluated per second: 2.52e+05. Head worker occupation: 22.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.673e+04  1.594e+01  y = 172.44                                    3           1.612e+04  1.844e-02  y = (x₀ + 166.45)                             4           2.840e+03  1.737e+00  y = cube(log(cube(x₀)))                       6           2.566e+03  5.066e-02  y = cube(log(cube(x₀)) + 0.17239)             7           2.566e+03  -0.000e+00  y = cube(log(cube(x₀)) + square(0.41523))    8           2.498e+03  2.704e-02  y = cube(log(cube(x₀ + -0.60784)) + 0.42834)  10          2.477e+03  4.158e-03  y = cube(log(cube(-0.97281 + x₀) + 5.2748) + 0.56238)                                                                         12          2.477e+03  3.278e-07  y = (cube(log(cube(-0.97281 + x₀) + 5.2748) + 0.56238) + 0.012...                                                                                               354)                                          17          2.477e+03  3.338e-07  y = (cube(log((cube(-0.97281 + x₀) + 0.07669) + (5.2748 + cube...                                                                                               (-0.44174))) + 0.56238) + 0.07669)            19          2.477e+03  1.669e-06  y = (cube(log((cube(-0.97281 + x₀) + 0.07669) + (5.2748 + (-0....                                                                                               44174 + 0.24157))) + 0.56238) + log(1.1969))  ---------------------------------------------------------------------------------------------------
# 96.7%┣█████████████████████████████████████████▋ ┫ 580/600 [00:06<00:00, 99it/s]Expressions evaluated per second: 2.52e+05. Head worker occupation: 22.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.673e+04  1.594e+01  y = 172.43                                    3           1.612e+04  1.844e-02  y = (x₀ + 166.45)                             4           2.840e+03  1.737e+00  y = cube(log(cube(x₀)))                       6           2.566e+03  5.066e-02  y = cube(log(cube(x₀)) + 0.17239)             7           2.566e+03  -0.000e+00  y = cube(log(cube(x₀)) + square(0.41523))    8           2.498e+03  2.704e-02  y = cube(log(cube(x₀ + -0.60784)) + 0.42834)  10          2.477e+03  4.158e-03  y = cube(log(cube(-0.97281 + x₀) + 5.2748) + 0.56238)                                                                         12          2.477e+03  1.431e-06  y = (cube(log(cube(-0.97281 + x₀) + 5.2748) + 0.56238) + 0.076...                                                                                               69)                                           19          2.477e+03  4.172e-07  y = (cube(log((cube(-0.97281 + x₀) + 0.07669) + (5.2748 + (-0....                                                                                               44174 + 0.24157))) + 0.56238) + log(1.1969))  ---------------------------------------------------------------------------------------------------
# 97.5%┣██████████████████████████████████████████ ┫ 585/600 [00:06<00:00, 99it/s]Expressions evaluated per second: 2.52e+05. Head worker occupation: 22.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.673e+04  1.594e+01  y = 172.43                                    3           1.612e+04  1.844e-02  y = (x₀ + 166.45)                             4           2.840e+03  1.737e+00  y = cube(log(cube(x₀)))                       6           2.566e+03  5.066e-02  y = cube(log(cube(x₀)) + 0.17239)             7           2.566e+03  -0.000e+00  y = cube(log(cube(x₀)) + square(0.41523))    8           2.498e+03  2.704e-02  y = cube(log(cube(x₀ + -0.60784)) + 0.42834)  10          2.477e+03  4.158e-03  y = cube(log(cube(-0.97281 + x₀) + 5.2748) + 0.56238)                                                                         12          2.477e+03  1.431e-06  y = (cube(log(cube(-0.97281 + x₀) + 5.2748) + 0.56238) + 0.076...                                                                                               69)                                           19          2.477e+03  4.172e-07  y = (cube(log((cube(-0.97281 + x₀) + 0.07669) + (5.2748 + (-0....                                                                                               44174 + 0.24157))) + 0.56238) + log(1.1969))  ---------------------------------------------------------------------------------------------------
# 98.5%┣██████████████████████████████████████████▍┫ 591/600 [00:06<00:00, 99it/s]Expressions evaluated per second: 2.52e+05. Head worker occupation: 22.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.673e+04  1.594e+01  y = 172.43                                    3           1.612e+04  1.844e-02  y = (x₀ + 166.45)                             4           2.840e+03  1.737e+00  y = cube(log(cube(x₀)))                       6           2.566e+03  5.066e-02  y = cube(log(cube(x₀)) + 0.17239)             7           2.566e+03  -0.000e+00  y = cube(log(cube(x₀)) + square(0.41523))    8           2.498e+03  2.704e-02  y = cube(log(cube(x₀ + -0.60784)) + 0.42834)  10          2.477e+03  4.158e-03  y = cube(log(cube(-0.97281 + x₀) + 5.2748) + 0.56238)                                                                         12          2.477e+03  1.431e-06  y = (cube(log(cube(-0.97281 + x₀) + 5.2748) + 0.56238) + 0.076...                                                                                               69)                                           19          2.477e+03  4.172e-07  y = (cube(log((cube(-0.97281 + x₀) + 0.07669) + (5.2748 + (-0....                                                                                               44174 + 0.24157))) + 0.56238) + log(1.1969))  ---------------------------------------------------------------------------------------------------
# 99.7%┣██████████████████████████████████████████▉┫ 598/600 [00:06<00:00, 99it/s]Expressions evaluated per second: 2.52e+05. Head worker occupation: 22.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.673e+04  1.594e+01  y = 172.43                                    3           1.612e+04  1.844e-02  y = (x₀ + 166.45)                             4           2.840e+03  1.737e+00  y = cube(log(cube(x₀)))                       6           2.566e+03  5.066e-02  y = cube(log(cube(x₀)) + 0.17239)             7           2.566e+03  -0.000e+00  y = cube(log(cube(x₀)) + square(0.41523))    8           2.498e+03  2.704e-02  y = cube(log(cube(x₀ + -0.60784)) + 0.42834)  10          2.477e+03  4.158e-03  y = cube(log(cube(-0.97281 + x₀) + 5.2748) + 0.56238)                                                                         12          2.477e+03  1.431e-06  y = (cube(log(cube(-0.97281 + x₀) + 5.2748) + 0.56238) + 0.076...                                                                                               69)                                           19          2.477e+03  4.172e-07  y = (cube(log((cube(-0.97281 + x₀) + 0.07669) + (5.2748 + (-0....                                                                                               44174 + 0.24157))) + 0.56238) + log(1.1969))  20          2.474e+03  9.767e-04  y = ((((cube(log(cube(-1.1222 + x₀)) + square(-0.70567)) + 0.6...                                                                                               1186) + log(x₀)) + square(square(1.9519))) + 0.42766)                                                                         ---------------------------------------------------------------------------------------------------

# %%
registros_ = registros
file_pickle = 'dados_v2.pck'

# %%
for i in registros_:
  loss = i[1]
  score = i[2]
  complexity = i[0]
  w = (loss * score)/complexity
  if math.isnan(w):
    i.append(0)
  else:
    i.append(w)

lista_melhor_valor = max(registros_, key=lambda x: x[6])

# %% [markdown]
# ## Save result

# %%
def salvar_dados(dados, key, arquivo):
  if os.path.exists(arquivo):
    with open(arquivo, 'rb') as f:
      dados_exist = pickle.load(f)
  else:
    dados_exist = {}
    
  valor_original = dados_exist.get(key)
  if valor_original == None:
    dados_exist.update({key: [dados]})
  else:
    if isinstance(valor_original, list):
      valor_original.append(dados)
    else:
      dados_exist.update({key: [dados]})

  with open(arquivo, 'wb') as f:
    pickle.dump(dados_exist, f)

caminho_arquivo = file_pickle
novos_dados = lista_melhor_valor[0:3] + [lista_melhor_valor[4]]

salvar_dados(novos_dados, 'karatsuba_N^1.585', caminho_arquivo)

# %%
def carregar_dados(arquivo):
    # Carrega os dados do arquivo pickle
    with open(arquivo, 'rb') as f:
        dados = pickle.load(f)
    return dados

caminho_arquivo = file_pickle
dados_carregados = carregar_dados(caminho_arquivo)

print("Conteúdo do arquivo pickle:")
for k, v in dados_carregados.items():
  print('\u25CF', k)
  for index, item in enumerate(v):
    if index == len(v)-1:
       print('└─', item)
    else:
      print('├─', item)
  print('==========================')
# Out:
# Conteúdo do arquivo pickle:
# ● binary_search_logx
# ├─ [6, 1.2914093, 1.37589542429269, log(x0**6) + 5.574131]
# └─ [5, 1.5291592, 2.19479656667366, log(x0)**2 + 13.966276]
# ==========================
# ● boyer_moore_M_plus_N
# ├─ [9, 1729031400.0, 0.1972007458935316, 752018330.701125*(0.00603869219560025*x0 + 0.00603869219560025*x1 - 1)**4 + 601415.75]
# └─ [5, 15754614000.0, 0.3055240605113849, 3621132.2 - 28185.828*x1]
# ==========================
# ● bubblesort_N^2
# ├─ [4, 5910.4966, 3.4645076652491285, 1.5253483*x0**2]
# └─ [4, 8542.308, 3.303255717418494, 1.5552218*x0**2]
# ==========================
# ● fibonacci_interative_N
# ├─ [3, 0.20818244, 3.412549040667958, 2.058653*x0]
# └─ [3, 0.20818244, 3.412549040667958, 2.058653*x0]
# ==========================
# ● fibonacci_recursive_2^N
# ├─ [15, 111113150.0, 0.37865996607381686, x0**4*(0.0022606994*x0**2 - 0.714783)]
# └─ [15, 77371830.0, 0.38657145558895856, x0**2*(x0**2*(0.16452532*x0 - 3.8766947) + 297.9323)]
# ==========================
# ● heapsort_NlogN
# ├─ [9, 0.24989581, 1.1851428541960574, 4*x0 - 1.4897935]
# └─ [9, 0.24989575, 1.185128414350167, 4*x0 - 1.4897884]
# ==========================
# ● insertionsort_N^2
# ├─ [4, 12514.81, 0.5204699193332855, 7.19343672459889*(0.372847972767781*x0 - 1)**2]
# └─ [4, 11070.262, 0.6554198140129509, 9.54380044013764*(0.323697485019442*x0 - 1)**2]
# ==========================
# ● tower_hanoi_2^N
# ├─ [13, 4607.291, 0.98801217824901, 0.0050468594*x0**6]
# └─ [13, 4607.2915, 0.988012078856794, 0.005046889*x0**6]
# ==========================
# ● karatsuba_N^1.585
# ├─ [4, 535.7578, 1.123614036379079, 3.66931686122521*x0**2]
# └─ [4, 2839.5903, 1.7365954778975965, log(x0**3)**3]
# ==========================
# ● levenshtein_distance_MN
# ├─ [4, 1058.5413, 9.647410674646242, 3.52554060674929*x1**2]
# └─ [4, 1058.5277, 9.647423644638591, 3.5255728*x1**2]
# ==========================
# ● linear_search_x
# ├─ [14, 0.26546365, 0.9472618119882181, x0*log(log(log(1.97671752435621e-50*x0**18)**2))]
# └─ [3, 0.91324174, 3.3876830428181948, 2.0593598*x0]
# ==========================
# ● mergesort_NlogN
# ├─ [8, 40.208347, 0.542941641791251, (log(x0 + 4.4829993)**2 + 0.71281224)**2]
# └─ [8, 40.208347, 0.5429418585508976, (log(x0 + 4.4826865)**2 + 0.71286815)**2]
# ==========================
# ● quicksort_x^2
# ├─ [5, 4191.8745, 0.5370400329213452, 31.022936*x0 - 114.24918]
# └─ [5, 3799.3462, 0.5090052338906941, 30.326008*x0 - 105.0883]
# ==========================
# ● selectsort_N^2
# ├─ [7, 492.61688, 0.8252641931074596, 0.91222733*x0*log(x0)**3]
# └─ [7, 529.9843, 0.7728385969753846, 0.9116503*x0*log(x0)**3]
# ==========================
# ● shellsort_NlogN
# ├─ [6, 2333.781, 2.6158456057911406, 9.6421651223277*(0.469831154898539*log(x0**3) - 1)**3]
# └─ [6, 899.3794, 1.4964888960073477, 5.0019417*x0*log(x0)]
# ==========================
# ● strassen_N^2.81
# ├─ [9, 31317.309, 0.2847589231536684, log(2407.45008008753*(0.0372501681530186*(0.817895287156492*x0 + 1)**3 - 1)**2)**3]
# └─ [9, 33064.902, 0.11522887698339954, 1.80036936911294*(0.82201446811225*log(225.511129952784*(0.066591072481186*x0**3 - 1)**2) + 1)**3]
# ==========================
