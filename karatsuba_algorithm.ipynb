# %%
# https://the-algorithms.com/algorithm/karatsuba

import numpy as np
from line_profiler import LineProfiler
from pysr import PySRRegressor
import random
import os
import sys
import math
import pickle
# Out:
# Detected Jupyter notebook. Loading juliacall extension. Set `PYSR_AUTOLOAD_EXTENSIONS=no` to disable.

# %% [markdown]
# ## karatsuba Algorithm

# %%
def generate_random_numbers(num_digits):
    # Gerar o limite superior e inferior com base no número de dígitos
    lower_bound = 10 ** (num_digits - 1)
    upper_bound = (10 ** num_digits) - 1
    
    # Gerar dois números aleatórios dentro do intervalo especificado
    random_number1 = random.randint(lower_bound, upper_bound)
    random_number2 = random.randint(lower_bound, upper_bound)
    
    return random_number1, random_number2

def karatsuba(a: int, b: int) -> int:
    """
    >>> karatsuba(15463, 23489) == 15463 * 23489
    True
    >>> karatsuba(3, 9) == 3 * 9
    True
    """
    if len(str(a)) == 1 or len(str(b)) == 1:
        return a * b

    m1 = max(len(str(a)), len(str(b)))
    m2 = m1 // 2

    a1, a2 = divmod(a, 10**m2)
    b1, b2 = divmod(b, 10**m2)

    x = karatsuba(a2, b2)
    y = karatsuba((a1 + a2), (b1 + b2))
    z = karatsuba(a1, b1)

    return (z * 10 ** (2 * m2)) + ((y - z - x) * 10 ** (m2)) + (x)

# %% [markdown]
# ## Frequency Count Method

# %%
X_y = []
i=10
for n in range(2,i+1):
  lprofiler = LineProfiler()
  lp_wrapper = lprofiler(karatsuba)
  
  # create numbers with length n
  num1, num2 = generate_random_numbers(n)
  lp_wrapper(num1, num2)

  stats = lprofiler.get_stats()
  line_numbers = []
  hits = []

  for line in stats.timings.values():
    for i in line:
      line_numbers.append(i[0])
      hits.append(i[1])

  X_y.append([n, sum(hits)])

dados = np.array(X_y)

X = dados[:, 0]
y = dados[:, 1]
X_reshaped = X.reshape(-1, 1)

# %%
#resultados_com_menor_loss = []
repeat = 4
registros = []
unary_operators_list = ["log", "square", "cube", "sqrt", "round", "exp", "abs"]

original_stdout = sys.stdout

with open(os.devnull, 'w') as devnull:
  sys.stdout = devnull

  for i in range(repeat):

    reg1 = PySRRegressor(
      #binary_operators=["*", "+"],
      unary_operators=unary_operators_list
    )

    fit1 = reg1.fit(X_reshaped, y)
    best_program1 = fit1.get_best()

    registro1 = []
    for index, value in enumerate(best_program1):
      registro1.append(value)
      
    registros.append(registro1)
    
sys.stdout = original_stdout
# Out:
# [ Info: Started!
# 0.0%┣                                             ┫ 0/600 [00:00<-2:-13, -0s/it]Expressions evaluated per second: [.....]. Head worker occupation: 0.0%         Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           4.275e+04  1.594e+01  y = x₀                                        2           2.579e+04  5.054e-01  y = square(x₀)                                4           8.782e+02  1.690e+00  y = square(x₀ + x₀)                           6           8.670e+02  6.417e-03  y = square(x₀ + (x₀ - 0.12824))               8           8.616e+02  3.164e-03  y = (square((x₀ + x₀) + 0.078969) - 5.9031)   ---------------------------------------------------------------------------------------------------
# 0.3%┣▏                                              ┫ 2/600 [00:00<04:43, 2it/s]Expressions evaluated per second: [.....]. Head worker occupation: 71.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           4.275e+04  1.594e+01  y = x₀                                        2           2.579e+04  5.054e-01  y = square(x₀)                                4           8.782e+02  1.690e+00  y = square(x₀ + x₀)                           6           8.670e+02  6.417e-03  y = square(x₀ + (x₀ - 0.12824))               8           8.616e+02  3.164e-03  y = (square((x₀ + x₀) + 0.078969) - 5.9031)   11          6.971e+02  7.061e-02  y = sqrt(square(((x₀ * x₀) + x₀) / -0.83358) * x₀)                                                                            13          6.963e+02  5.392e-04  y = round(round(sqrt(square(((x₀ - -1.0084) * x₀) / -0.83358) ...                                                                                               * x₀)))                                       14          6.911e+02  7.554e-03  y = sqrt(square(((x₀ * x₀) + x₀) / -0.83358) * (round(x₀) + 0....                                                                                               25976))                                       15          6.805e+02  1.539e-02  y = sqrt(abs(square((((x₀ * x₀) + x₀) / abs(-0.83358)) - -1.23...                                                                                               71) * x₀))                                    16          6.802e+02  5.216e-04  y = sqrt(abs(abs(square((((x₀ * x₀) + x₀) / abs(-0.83358)) + 1...                                                                                               .3009) * x₀)))                                ---------------------------------------------------------------------------------------------------
# 1.0%┣▌                                              ┫ 6/600 [00:01<01:12, 8it/s]Expressions evaluated per second: [.....]. Head worker occupation: 49.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           4.275e+04  1.594e+01  y = x₀                                        2           2.579e+04  5.054e-01  y = square(x₀)                                3           2.340e+04  9.712e-02  y = sqrt(exp(x₀))                             4           8.782e+02  3.283e+00  y = square(x₀ + x₀)                           6           8.670e+02  6.417e-03  y = square(x₀ + (x₀ - 0.12824))               8           8.616e+02  3.164e-03  y = (square((x₀ + x₀) + 0.078969) - 5.9031)   11          6.971e+02  7.061e-02  y = sqrt(square(((x₀ * x₀) + x₀) / -0.83358) * x₀)                                                                            13          6.963e+02  5.392e-04  y = round(round(sqrt(square(((x₀ - -1.0084) * x₀) / -0.83358) ...                                                                                               * x₀)))                                       14          6.911e+02  7.554e-03  y = sqrt(square(((x₀ * x₀) + x₀) / -0.83358) * (round(x₀) + 0....                                                                                               25976))                                       15          6.805e+02  1.539e-02  y = sqrt(abs(square((((x₀ * x₀) + x₀) / abs(-0.83358)) - -1.23...                                                                                               71) * x₀))                                    16          6.802e+02  5.216e-04  y = sqrt(abs(abs(square((((x₀ * x₀) + x₀) / abs(-0.83358)) + 1...                                                                                               .3009) * x₀)))                                ---------------------------------------------------------------------------------------------------
# 1.5%┣▊                                             ┫ 9/600 [00:01<00:49, 12it/s]Expressions evaluated per second: [.....]. Head worker occupation: 44.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.758e+04  1.594e+01  y = 166.67                                    4           8.782e+02  9.988e-01  y = square(x₀ + x₀)                           6           8.670e+02  6.417e-03  y = square(x₀ + (x₀ - 0.12824))               8           8.616e+02  3.164e-03  y = (square((x₀ + x₀) + 0.078969) - 5.9031)   11          6.971e+02  7.061e-02  y = sqrt(square(((x₀ * x₀) + x₀) / -0.83358) * x₀)                                                                            13          4.966e+02  1.696e-01  y = abs((square(exp(sqrt((0.17384 + x₀) - 1.1753))) - -25.099)...                                                                                                + x₀)                                        14          4.793e+02  3.534e-02  y = (sqrt(exp((x₀ - -0.33946) - -1.0209)) + ((x₀ / square(-0.2...                                                                                               8568)) + x₀))                                 16          4.094e+02  7.886e-02  y = (sqrt(exp((x₀ - -0.33946) - -1.0209)) + (((x₀ / square(-0....                                                                                               28568)) + x₀) + x₀))                          18          3.983e+02  1.367e-02  y = ((abs(sqrt(exp((x₀ - -0.33946) - cube(-1.0209)))) + x₀) + ...                                                                                               ((x₀ / square(-0.28568)) + x₀))               ---------------------------------------------------------------------------------------------------
# 2.3%┣█                                            ┫ 14/600 [00:01<00:33, 18it/s]Expressions evaluated per second: [.....]. Head worker occupation: 39.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.758e+04  1.594e+01  y = 166.67                                    3           1.485e+04  8.426e-02  y = (x₀ / 0.021437)                           4           8.782e+02  2.828e+00  y = square(x₀ + x₀)                           6           8.670e+02  6.417e-03  y = square(x₀ + (x₀ - 0.12824))               8           8.616e+02  3.164e-03  y = (square((x₀ + x₀) + 0.078969) - 5.9031)   9           8.013e+02  7.255e-02  y = (cube(sqrt(x₀ - -1.144)) * (x₀ + 0.54122))                                                                                10          6.973e+02  1.390e-01  y = (cube(sqrt(x₀ - -1.144)) * round(x₀ + 0.54122))                                                                           11          6.971e+02  2.607e-04  y = sqrt(square(((x₀ * x₀) + x₀) / -0.83358) * x₀)                                                                            13          4.966e+02  1.696e-01  y = abs((square(exp(sqrt((0.17384 + x₀) - 1.1753))) - -25.099)...                                                                                                + x₀)                                        14          4.793e+02  3.534e-02  y = (sqrt(exp((x₀ - -0.33946) - -1.0209)) + ((x₀ / square(-0.2...                                                                                               8568)) + x₀))                                 16          4.094e+02  7.886e-02  y = (sqrt(exp((x₀ - -0.33946) - -1.0209)) + (((x₀ / square(-0....                                                                                               28568)) + x₀) + x₀))                          18          3.983e+02  1.367e-02  y = ((abs(sqrt(exp((x₀ - -0.33946) - cube(-1.0209)))) + x₀) + ...                                                                                               ((x₀ / square(-0.28568)) + x₀))               ---------------------------------------------------------------------------------------------------
# 3.3%┣█▌                                           ┫ 20/600 [00:01<00:24, 24it/s]Expressions evaluated per second: [.....]. Head worker occupation: 37.5%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.758e+04  1.594e+01  y = 166.67                                    3           1.485e+04  8.426e-02  y = (x₀ / 0.021437)                           4           8.782e+02  2.828e+00  y = square(x₀ + x₀)                           5           8.765e+02  1.978e-03  y = square(x₀ / abs(0.50155))                 6           8.658e+02  1.222e-02  y = (square(x₀ + x₀) - 5.9031)                8           8.616e+02  2.484e-03  y = (square((x₀ + x₀) + 0.078969) - 5.9031)   9           8.013e+02  7.255e-02  y = (cube(sqrt(x₀ - -1.144)) * (x₀ + 0.54122))                                                                                10          6.973e+02  1.390e-01  y = (cube(sqrt(x₀ - -1.144)) * round(x₀ + 0.54122))                                                                           11          6.971e+02  2.607e-04  y = sqrt(square(((x₀ * x₀) + x₀) / -0.83358) * x₀)                                                                            13          4.966e+02  1.696e-01  y = abs((square(exp(sqrt((0.17384 + x₀) - 1.1753))) - -25.099)...                                                                                                + x₀)                                        14          4.793e+02  3.534e-02  y = (sqrt(exp((x₀ - -0.33946) - -1.0209)) + ((x₀ / square(-0.2...                                                                                               8568)) + x₀))                                 16          4.094e+02  7.886e-02  y = (sqrt(exp((x₀ - -0.33946) - -1.0209)) + (((x₀ / square(-0....                                                                                               28568)) + x₀) + x₀))                          18          3.983e+02  1.367e-02  y = ((abs(sqrt(exp((x₀ - -0.33946) - cube(-1.0209)))) + x₀) + ...                                                                                               ((x₀ / square(-0.28568)) + x₀))               ---------------------------------------------------------------------------------------------------
# 4.3%┣██                                           ┫ 26/600 [00:01<00:20, 28it/s]Expressions evaluated per second: [.....]. Head worker occupation: 35.9%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.758e+04  1.594e+01  y = 166.67                                    3           1.485e+04  8.426e-02  y = (x₀ / 0.021437)                           4           8.782e+02  2.828e+00  y = square(x₀ + x₀)                           5           8.765e+02  1.978e-03  y = square(x₀ / abs(0.50155))                 6           8.658e+02  1.222e-02  y = (square(x₀ + x₀) - 5.9031)                8           8.616e+02  2.484e-03  y = (square((x₀ + x₀) + 0.078969) - 5.9031)   9           8.013e+02  7.255e-02  y = (cube(sqrt(x₀ - -1.144)) * (x₀ + 0.54122))                                                                                10          6.973e+02  1.390e-01  y = (cube(sqrt(x₀ - -1.144)) * round(x₀ + 0.54122))                                                                           11          6.953e+02  2.810e-03  y = sqrt(square(((x₀ * x₀) + x₀) / 0.83128) * x₀)                                                                             13          4.966e+02  1.683e-01  y = abs((square(exp(sqrt((0.17384 + x₀) - 1.1753))) - -25.099)...                                                                                                + x₀)                                        14          3.816e+02  2.634e-01  y = (abs(square(round(exp(sqrt((0.11577 + x₀) - 1.0406)))) + 1...                                                                                               4.005) - -13.328)                             ---------------------------------------------------------------------------------------------------
# 5.2%┣██▎                                          ┫ 31/600 [00:01<00:18, 32it/s]Expressions evaluated per second: [.....]. Head worker occupation: 34.3%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.758e+04  1.594e+01  y = 166.67                                    3           1.485e+04  8.426e-02  y = (x₀ / 0.021437)                           4           8.782e+02  2.828e+00  y = square(x₀ + x₀)                           5           8.765e+02  1.978e-03  y = square(x₀ / abs(0.50155))                 6           8.658e+02  1.222e-02  y = (square(x₀ + x₀) - 5.9031)                7           8.624e+02  3.958e-03  y = (square(x₀ + x₀) - square(2.1092))        8           8.616e+02  1.010e-03  y = (square((x₀ + x₀) + 0.078969) - 5.9031)   9           6.977e+02  2.109e-01  y = (cube(sqrt(x₀ - -1.0712)) * (x₀ - -1.0712))                                                                               10          6.973e+02  6.766e-04  y = (cube(sqrt(x₀ - -1.144)) * round(x₀ + 0.54122))                                                                           11          6.953e+02  2.810e-03  y = sqrt(square(((x₀ * x₀) + x₀) / 0.83128) * x₀)                                                                             12          6.451e+02  7.494e-02  y = (round(cube((x₀ + (3.0726 - 1.3282)) / 1.7269)) + square(x...                                                                                               ₀))                                           13          4.966e+02  2.617e-01  y = abs((square(exp(sqrt((0.17384 + x₀) - 1.1753))) - -25.099)...                                                                                                + x₀)                                        14          3.816e+02  2.634e-01  y = (abs(square(round(exp(sqrt((0.11577 + x₀) - 1.0406)))) + 1...                                                                                               4.005) - -13.328)                             ---------------------------------------------------------------------------------------------------
# 6.0%┣██▊                                          ┫ 36/600 [00:01<00:16, 35it/s]Expressions evaluated per second: 8.94e+04. Head worker occupation: 33.3%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.758e+04  1.594e+01  y = 166.67                                    3           1.485e+04  8.426e-02  y = (x₀ / 0.021437)                           4           8.765e+02  2.830e+00  y = square(x₀ / 0.50155)                      5           8.677e+02  1.011e-02  y = round(square(x₀ / 0.50155))               6           8.658e+02  2.103e-03  y = (square(x₀ + x₀) - 5.9031)                7           8.624e+02  3.958e-03  y = (square(x₀ + x₀) - square(2.1092))        8           8.597e+02  3.202e-03  y = (round(square(x₀ / 0.50155)) + round(-1.5935))                                                                            9           6.977e+02  2.087e-01  y = (cube(sqrt(x₀ - -1.0712)) * (x₀ - -1.0712))                                                                               10          6.973e+02  6.766e-04  y = (cube(sqrt(x₀ - -1.144)) * round(x₀ + 0.54122))                                                                           11          6.953e+02  2.810e-03  y = sqrt(square(((x₀ * x₀) + x₀) / 0.83128) * x₀)                                                                             12          6.017e+02  1.446e-01  y = sqrt(square(round(x₀ / 0.84481) * x₀) * (x₀ * 1.3373))                                                                    13          4.966e+02  1.921e-01  y = abs((square(exp(sqrt((0.17384 + x₀) - 1.1753))) - -25.099)...                                                                                                + x₀)                                        14          3.816e+02  2.634e-01  y = (abs(square(round(exp(sqrt((0.11577 + x₀) - 1.0406)))) + 1...                                                                                               4.005) - -13.328)                             ---------------------------------------------------------------------------------------------------
# 6.8%┣███                                          ┫ 41/600 [00:01<00:15, 37it/s]Expressions evaluated per second: 8.94e+04. Head worker occupation: 32.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.758e+04  1.594e+01  y = 166.67                                    3           1.485e+04  8.426e-02  y = (x₀ / 0.021437)                           4           8.765e+02  2.830e+00  y = square(x₀ / 0.50155)                      5           8.677e+02  1.011e-02  y = round(square(x₀ / 0.50155))               6           8.658e+02  2.103e-03  y = (square(x₀ + x₀) - 5.9031)                7           8.624e+02  3.958e-03  y = (square(x₀ + x₀) - square(2.1092))        8           8.597e+02  3.202e-03  y = (round(square(x₀ / 0.50155)) + round(-1.5935))                                                                            9           6.977e+02  2.087e-01  y = (cube(sqrt(x₀ - -1.0712)) * (x₀ - -1.0712))                                                                               10          6.973e+02  6.766e-04  y = (cube(sqrt(x₀ - -1.144)) * round(x₀ + 0.54122))                                                                           11          6.953e+02  2.810e-03  y = sqrt(square(((x₀ * x₀) + x₀) / 0.83128) * x₀)                                                                             12          6.017e+02  1.446e-01  y = sqrt(square(round(x₀ / 0.84481) * x₀) * (x₀ * 1.3373))                                                                    13          4.966e+02  1.921e-01  y = abs((square(exp(sqrt((0.17384 + x₀) - 1.1753))) - -25.099)...                                                                                                + x₀)                                        14          3.816e+02  2.634e-01  y = (abs(square(round(exp(sqrt((0.11577 + x₀) - 1.0406)))) + 1...                                                                                               4.005) - -13.328)                             19          3.776e+02  2.108e-03  y = round(round(abs(sqrt(round(exp(abs(x₀ - -1.4548)))) + (abs...                                                                                               (x₀ + -0.26493) / square(abs(-0.26482))))))   ---------------------------------------------------------------------------------------------------
# 7.5%┣███▍                                         ┫ 45/600 [00:01<00:14, 39it/s]Expressions evaluated per second: 8.94e+04. Head worker occupation: 32.3%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.758e+04  1.594e+01  y = 166.67                                    3           1.485e+04  8.426e-02  y = (x₀ / 0.021437)                           4           8.765e+02  2.830e+00  y = square(x₀ / 0.50155)                      5           8.677e+02  1.011e-02  y = round(square(x₀ / 0.50155))               6           8.658e+02  2.103e-03  y = (square(x₀ + x₀) - 5.9031)                7           8.624e+02  3.958e-03  y = (square(x₀ + x₀) - square(2.1092))        8           8.597e+02  3.202e-03  y = (round(square(x₀ / 0.50155)) + round(-1.5935))                                                                            9           6.977e+02  2.087e-01  y = (cube(sqrt(x₀ - -1.0712)) * (x₀ - -1.0712))                                                                               10          6.973e+02  6.766e-04  y = (cube(sqrt(x₀ - -1.144)) * round(x₀ + 0.54122))                                                                           11          6.953e+02  2.810e-03  y = sqrt(square(((x₀ * x₀) + x₀) / 0.83128) * x₀)                                                                             12          5.592e+02  2.179e-01  y = (abs(square(round(exp(sqrt((0.11577 + x₀) - 1.0406))))) + ...                                                                                               14.005)                                       13          4.966e+02  1.188e-01  y = abs((square(exp(sqrt((0.17384 + x₀) - 1.1753))) - -25.099)...                                                                                                + x₀)                                        14          3.816e+02  2.634e-01  y = (abs(square(round(exp(sqrt((0.11577 + x₀) - 1.0406)))) + 1...                                                                                               4.005) - -13.328)                             18          3.776e+02  2.623e-03  y = (abs(square(round(exp(sqrt((0.11577 + x₀) - 1.0406)))) + 1...                                                                                               4.005) - (round(-13.328) - log(x₀)))          19          3.734e+02  1.100e-02  y = round((abs(square(round(exp(sqrt((0.11577 + x₀) - 1.0406))...                                                                                               ))) + 14.005) - (-13.328 - log(abs(x₀))))     ---------------------------------------------------------------------------------------------------
# 8.3%┣███▊                                         ┫ 50/600 [00:01<00:13, 41it/s]Expressions evaluated per second: 8.94e+04. Head worker occupation: 31.3%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.758e+04  1.594e+01  y = 166.67                                    3           1.485e+04  8.426e-02  y = (x₀ / 0.021437)                           4           8.765e+02  2.830e+00  y = square(x₀ / 0.50155)                      5           8.677e+02  1.011e-02  y = round(square(x₀ / 0.50155))               6           8.658e+02  2.103e-03  y = (square(x₀ + x₀) - 5.9031)                7           6.971e+02  2.167e-01  y = (cube(sqrt(x₀ - -1.8898)) * x₀)           10          6.420e+02  2.749e-02  y = (round(cube(sqrt(x₀ - -1.0712))) * (x₀ - -1.0712))                                                                        12          5.592e+02  6.901e-02  y = (abs(square(round(exp(sqrt((0.11577 + x₀) - 1.0406))))) + ...                                                                                               14.005)                                       13          4.966e+02  1.188e-01  y = abs((square(exp(sqrt((0.17384 + x₀) - 1.1753))) - -25.099)...                                                                                                + x₀)                                        14          3.816e+02  2.634e-01  y = (abs(square(round(exp(sqrt((0.11577 + x₀) - 1.0406)))) + 1...                                                                                               4.005) - -13.328)                             18          3.776e+02  2.623e-03  y = (abs(square(round(exp(sqrt((0.11577 + x₀) - 1.0406)))) + 1...                                                                                               4.005) - (round(-13.328) - log(x₀)))          19          3.734e+02  1.100e-02  y = round((abs(square(round(exp(sqrt((0.11577 + x₀) - 1.0406))...                                                                                               ))) + 14.005) - (-13.328 - log(abs(x₀))))     ---------------------------------------------------------------------------------------------------
# 9.2%┣████▏                                        ┫ 55/600 [00:01<00:13, 42it/s]Expressions evaluated per second: 8.94e+04. Head worker occupation: 30.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.758e+04  1.594e+01  y = 166.67                                    3           1.485e+04  8.426e-02  y = (x₀ / 0.021437)                           4           8.765e+02  2.830e+00  y = square(x₀ / 0.50155)                      5           8.677e+02  1.011e-02  y = round(square(x₀ / 0.50155))               6           8.657e+02  2.284e-03  y = (square(x₀ + x₀) - 2.1386)                7           6.971e+02  2.165e-01  y = (cube(sqrt(x₀ - -1.8898)) * x₀)           10          6.420e+02  2.749e-02  y = (round(cube(sqrt(x₀ - -1.0712))) * (x₀ - -1.0712))                                                                        12          5.592e+02  6.901e-02  y = (abs(square(round(exp(sqrt((0.11577 + x₀) - 1.0406))))) + ...                                                                                               14.005)                                       13          4.966e+02  1.188e-01  y = abs((square(exp(sqrt((0.17384 + x₀) - 1.1753))) - -25.099)...                                                                                                + x₀)                                        14          3.816e+02  2.634e-01  y = (abs(square(round(exp(sqrt((0.11577 + x₀) - 1.0406)))) + 1...                                                                                               4.005) - -13.328)                             18          3.776e+02  2.623e-03  y = (abs(square(round(exp(sqrt((0.11577 + x₀) - 1.0406)))) + 1...                                                                                               4.005) - (round(-13.328) - log(x₀)))          19          3.734e+02  1.100e-02  y = round((abs(square(round(exp(sqrt((0.11577 + x₀) - 1.0406))...                                                                                               ))) + 14.005) - (-13.328 - log(abs(x₀))))     ---------------------------------------------------------------------------------------------------
# 10.0%┣████▍                                       ┫ 60/600 [00:01<00:12, 43it/s]Expressions evaluated per second: 8.94e+04. Head worker occupation: 30.4%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.758e+04  1.594e+01  y = 166.67                                    3           1.485e+04  8.426e-02  y = (x₀ / 0.021437)                           4           8.765e+02  2.830e+00  y = square(x₀ / 0.50155)                      5           8.677e+02  1.011e-02  y = round(square(x₀ / 0.50155))               6           8.657e+02  2.284e-03  y = (square(x₀ + x₀) - 2.1386)                7           6.971e+02  2.165e-01  y = (cube(sqrt(x₀ - -1.8898)) * x₀)           9           6.824e+02  1.070e-02  y = (cube(sqrt(x₀ - -1.0712)) * (x₀ / 0.88445))                                                                               10          6.420e+02  6.107e-02  y = (round(cube(sqrt(x₀ - -1.0712))) * (x₀ - -1.0712))                                                                        11          5.592e+02  1.380e-01  y = (square(round(exp(sqrt((0.11577 + x₀) - 1.0406)))) + 14.00...                                                                                               5)                                            13          4.966e+02  5.941e-02  y = abs((square(exp(sqrt((0.17384 + x₀) - 1.1753))) - -25.099)...                                                                                                + x₀)                                        14          3.816e+02  2.634e-01  y = (abs(square(round(exp(sqrt((0.11577 + x₀) - 1.0406)))) + 1...                                                                                               4.005) - -13.328)                             16          3.624e+02  2.569e-02  y = (((abs(square(round(exp(sqrt((0.11577 + x₀) - 1.0406))))) ...                                                                                               + x₀) - -17.204) + 4.1272)                    18          3.597e+02  3.753e-03  y = ((((abs(square(round(exp(sqrt((0.11577 + x₀) - 1.0406)))))...                                                                                                + x₀) - -13.328) + 0.25388) + x₀)            20          3.568e+02  4.070e-03  y = (((abs(square(round(exp(sqrt((0.11577 + x₀) - 1.0406))))) ...                                                                                               + x₀) - ((-13.328 + -0.57651) - 1.0406)) + x₀)                                                                                ---------------------------------------------------------------------------------------------------
# 11.0%┣████▉                                       ┫ 66/600 [00:01<00:12, 46it/s]Expressions evaluated per second: 8.94e+04. Head worker occupation: 30.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.758e+04  1.594e+01  y = 166.67                                    3           1.485e+04  8.426e-02  y = (x₀ / 0.021437)                           4           8.765e+02  2.830e+00  y = square(x₀ / 0.50155)                      5           8.677e+02  1.011e-02  y = round(square(x₀ / 0.50155))               6           8.657e+02  2.284e-03  y = (square(x₀ + x₀) - 2.1386)                7           6.971e+02  2.165e-01  y = (cube(sqrt(x₀ - -1.8898)) * x₀)           8           6.884e+02  1.255e-02  y = (round(cube(sqrt(x₀ - -1.8898))) * x₀)    9           6.824e+02  8.845e-03  y = (cube(sqrt(x₀ - -1.0712)) * (x₀ / 0.88445))                                                                               10          6.420e+02  6.107e-02  y = (round(cube(sqrt(x₀ - -1.0712))) * (x₀ - -1.0712))                                                                        11          5.592e+02  1.380e-01  y = (square(round(exp(sqrt((0.11577 + x₀) - 1.0406)))) + 14.00...                                                                                               5)                                            13          4.966e+02  5.941e-02  y = abs((square(exp(sqrt((0.17384 + x₀) - 1.1753))) - -25.099)...                                                                                                + x₀)                                        14          3.816e+02  2.634e-01  y = (abs(square(round(exp(sqrt((0.11577 + x₀) - 1.0406)))) + 1...                                                                                               4.005) - -13.328)                             16          3.624e+02  2.569e-02  y = (((abs(square(round(exp(sqrt((0.11577 + x₀) - 1.0406))))) ...                                                                                               + x₀) - -17.204) + 4.1272)                    18          3.597e+02  3.753e-03  y = ((((abs(square(round(exp(sqrt((0.11577 + x₀) - 1.0406)))))...                                                                                                + x₀) - -13.328) + 0.25388) + x₀)            20          3.568e+02  4.070e-03  y = (((abs(square(round(exp(sqrt((0.11577 + x₀) - 1.0406))))) ...                                                                                               + x₀) - ((-13.328 + -0.57651) - 1.0406)) + x₀)                                                                                ---------------------------------------------------------------------------------------------------
# 11.5%┣█████                                       ┫ 69/600 [00:01<00:12, 46it/s]Expressions evaluated per second: 8.94e+04. Head worker occupation: 29.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.758e+04  1.594e+01  y = 166.67                                    3           1.485e+04  8.426e-02  y = (x₀ / 0.021437)                           4           8.765e+02  2.830e+00  y = square(x₀ / 0.50155)                      5           8.677e+02  1.011e-02  y = round(square(x₀ / 0.50155))               6           8.657e+02  2.284e-03  y = (square(x₀ + x₀) - 2.1386)                7           6.971e+02  2.165e-01  y = (cube(sqrt(x₀ - -1.8898)) * x₀)           8           6.884e+02  1.255e-02  y = (round(cube(sqrt(x₀ - -1.8898))) * x₀)    9           6.824e+02  8.845e-03  y = (cube(sqrt(x₀ - -1.0712)) * (x₀ / 0.88445))                                                                               10          6.420e+02  6.107e-02  y = (round(cube(sqrt(x₀ - -1.0712))) * (x₀ - -1.0712))                                                                        11          5.592e+02  1.380e-01  y = (square(round(exp(sqrt((0.11577 + x₀) - 1.0406)))) + 14.00...                                                                                               5)                                            13          4.265e+02  1.354e-01  y = ((square(round(exp(sqrt((0.11577 + x₀) - 1.0406)))) + x₀) ...                                                                                               - -13.328)                                    14          3.816e+02  1.114e-01  y = (abs(square(round(exp(sqrt((0.11577 + x₀) - 1.0406)))) + 1...                                                                                               4.005) - -13.328)                             16          3.624e+02  2.569e-02  y = (((abs(square(round(exp(sqrt((0.11577 + x₀) - 1.0406))))) ...                                                                                               + x₀) - -17.204) + 4.1272)                    18          3.584e+02  5.593e-03  y = (((square(round(exp(sqrt((0.11577 + x₀) - sqrt(1.0406)))))...                                                                                                + x₀) + 14.005) - (-0.0070765 - x₀))         19          3.567e+02  4.837e-03  y = ((round(square(round(exp(sqrt(abs(0.11577 + x₀) - 1.0406))...                                                                                               ))) + 14.005) - ((-1.4553 - x₀) - x₀))        ---------------------------------------------------------------------------------------------------
# 12.5%┣█████▌                                      ┫ 75/600 [00:02<00:11, 48it/s]Expressions evaluated per second: 8.94e+04. Head worker occupation: 29.5%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.758e+04  1.594e+01  y = 166.67                                    3           1.485e+04  8.426e-02  y = (x₀ / 0.021437)                           4           8.765e+02  2.830e+00  y = square(x₀ / 0.50155)                      5           8.677e+02  1.011e-02  y = round(square(x₀ / 0.50155))               6           8.657e+02  2.284e-03  y = (square(x₀ + x₀) - 2.1386)                7           6.641e+02  2.651e-01  y = square(round(x₀ / (-0.62525 / -1.2845)))  10          6.420e+02  1.131e-02  y = (round(cube(sqrt(x₀ - -1.0712))) * (x₀ - -1.0712))                                                                        11          5.592e+02  1.380e-01  y = (square(round(exp(sqrt((0.11577 + x₀) - 1.0406)))) + 14.00...                                                                                               5)                                            12          4.966e+02  1.188e-01  y = ((square(exp(sqrt((0.17384 + x₀) - 1.1753))) - -25.099) + ...                                                                                               x₀)                                           13          4.176e+02  1.732e-01  y = ((square(round(exp(sqrt((0.11577 + x₀) - 1.0406)))) - -17....                                                                                               204) + 4.1272)                                14          3.816e+02  9.021e-02  y = (abs(square(round(exp(sqrt((0.11577 + x₀) - 1.0406)))) + 1...                                                                                               4.005) - -13.328)                             15          3.624e+02  5.139e-02  y = (((square(round(exp(sqrt((0.11577 + x₀) - 1.0406)))) + x₀)...                                                                                                - -17.204) + 4.1272)                         18          3.584e+02  3.729e-03  y = (((square(round(exp(sqrt((0.11577 + x₀) - sqrt(1.0406)))))...                                                                                                + x₀) + 14.005) - (-0.0070765 - x₀))         19          3.567e+02  4.837e-03  y = ((round(square(round(exp(sqrt(abs(0.11577 + x₀) - 1.0406))...                                                                                               ))) + 14.005) - ((-1.4553 - x₀) - x₀))        ---------------------------------------------------------------------------------------------------
# ...
# 96.5%┣█████████████████████████████████████████▌ ┫ 579/600 [00:08<00:00, 75it/s]Expressions evaluated per second: 1.88e+05. Head worker occupation: 21.9%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.758e+04  1.594e+01  y = 166.67                                    3           4.386e+03  6.941e-01  y = (x₀ / 0.032282)                           4           8.765e+02  1.610e+00  y = (square(x₀) / 0.25156)                    5           8.677e+02  1.011e-02  y = round(square(x₀) / 0.25156)               6           7.969e+02  8.507e-02  y = (square(x₀ - 0.70195) / 0.21143)          7           7.011e+02  1.281e-01  y = (cube(sqrt(x₀) + 0.3109) * x₀)            8           5.063e+02  3.256e-01  y = (sqrt(exp(x₀)) + (square(x₀) / 0.35062))  9           4.994e+02  1.373e-02  y = (sqrt(exp(x₀)) + round(square(x₀) / 0.34892))                                                                             10          4.710e+02  5.840e-02  y = (sqrt(exp(x₀)) + ((square(x₀) / 0.37037) - -10.04))                                                                       11          4.573e+02  2.948e-02  y = (sqrt(exp(x₀)) + (square(round(-6.5576 * x₀)) / 15.003))                                                                  12          4.524e+02  1.090e-02  y = (sqrt(exp(x₀)) + round(square(round(-6.5576 * x₀)) / 15.00...                                                                                               3))                                           13          4.420e+02  2.314e-02  y = (sqrt(exp(x₀)) + (square(round(-4.543 * x₀) + -2.9896) / 8...                                                                                               .4206))                                       14          4.419e+02  3.323e-04  y = (sqrt(exp(x₀)) + (square(round(-4.543 * x₀) + round(-2.989...                                                                                               6)) / 8.4206))                                15          4.328e+02  2.070e-02  y = ((sqrt(exp(x₀)) + (square(round(-6.5576 * x₀)) / 15.003)) ...                                                                                               - (x₀ + -6.5576))                             16          4.283e+02  1.054e-02  y = ((sqrt(exp(x₀)) + round(square(round(-6.5576 * x₀)) / 15.0...                                                                                               03)) - (x₀ + -6.5576))                        19          4.242e+02  3.195e-03  y = ((sqrt(exp(x₀)) + round((square(round(-6.5576 * x₀)) + sqr...                                                                                               t(x₀)) / 15.003)) - (x₀ + -6.5576))           ---------------------------------------------------------------------------------------------------
# 97.2%┣█████████████████████████████████████████▉ ┫ 583/600 [00:08<00:00, 75it/s]Expressions evaluated per second: 1.88e+05. Head worker occupation: 21.9%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.758e+04  1.594e+01  y = 166.67                                    3           4.386e+03  6.941e-01  y = (x₀ / 0.032282)                           4           8.765e+02  1.610e+00  y = (square(x₀) / 0.25156)                    5           8.677e+02  1.011e-02  y = round(square(x₀) / 0.25156)               6           7.969e+02  8.507e-02  y = (square(x₀ - 0.70195) / 0.21143)          7           7.011e+02  1.281e-01  y = (cube(sqrt(x₀) + 0.3109) * x₀)            8           5.063e+02  3.256e-01  y = (sqrt(exp(x₀)) + (square(x₀) / 0.35062))  9           4.994e+02  1.373e-02  y = (sqrt(exp(x₀)) + round(square(x₀) / 0.34892))                                                                             10          4.710e+02  5.840e-02  y = (sqrt(exp(x₀)) + ((square(x₀) / 0.37037) - -10.04))                                                                       11          4.573e+02  2.948e-02  y = (sqrt(exp(x₀)) + (square(round(-6.5576 * x₀)) / 15.003))                                                                  12          4.524e+02  1.090e-02  y = (sqrt(exp(x₀)) + round(square(round(-6.5576 * x₀)) / 15.00...                                                                                               3))                                           13          4.420e+02  2.314e-02  y = (sqrt(exp(x₀)) + (square(round(-4.543 * x₀) + -2.9896) / 8...                                                                                               .4206))                                       14          4.419e+02  3.323e-04  y = (sqrt(exp(x₀)) + (square(round(-4.543 * x₀) + round(-2.989...                                                                                               6)) / 8.4206))                                15          4.328e+02  2.070e-02  y = ((sqrt(exp(x₀)) + (square(round(-6.5576 * x₀)) / 15.003)) ...                                                                                               - (x₀ + -6.5576))                             16          4.283e+02  1.054e-02  y = ((sqrt(exp(x₀)) + round(square(round(-6.5576 * x₀)) / 15.0...                                                                                               03)) - (x₀ + -6.5576))                        19          4.242e+02  3.195e-03  y = ((sqrt(exp(x₀)) + round((square(round(-6.5576 * x₀)) + sqr...                                                                                               t(x₀)) / 15.003)) - (x₀ + -6.5576))           ---------------------------------------------------------------------------------------------------
# 98.5%┣██████████████████████████████████████████▍┫ 591/600 [00:08<00:00, 75it/s]Expressions evaluated per second: 1.88e+05. Head worker occupation: 22.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.758e+04  1.594e+01  y = 166.67                                    3           4.386e+03  6.941e-01  y = (x₀ / 0.032282)                           4           8.765e+02  1.610e+00  y = (square(x₀) / 0.25156)                    5           8.677e+02  1.011e-02  y = round(square(x₀) / 0.25156)               6           7.969e+02  8.507e-02  y = (square(x₀ - 0.70195) / 0.21143)          7           7.011e+02  1.281e-01  y = (cube(sqrt(x₀) + 0.3109) * x₀)            8           5.063e+02  3.256e-01  y = (sqrt(exp(x₀)) + (square(x₀) / 0.35062))  9           4.994e+02  1.373e-02  y = (sqrt(exp(x₀)) + round(square(x₀) / 0.34892))                                                                             10          4.710e+02  5.840e-02  y = (sqrt(exp(x₀)) + ((square(x₀) / 0.37037) - -10.04))                                                                       11          4.573e+02  2.948e-02  y = (sqrt(exp(x₀)) + (square(round(-6.5576 * x₀)) / 15.003))                                                                  12          4.524e+02  1.090e-02  y = (sqrt(exp(x₀)) + round(square(round(-6.5576 * x₀)) / 15.00...                                                                                               3))                                           13          4.420e+02  2.314e-02  y = (sqrt(exp(x₀)) + (square(round(-4.543 * x₀) + -2.9896) / 8...                                                                                               .4206))                                       14          4.419e+02  3.323e-04  y = (sqrt(exp(x₀)) + (square(round(-4.543 * x₀) + round(-2.989...                                                                                               6)) / 8.4206))                                15          4.328e+02  2.070e-02  y = ((sqrt(exp(x₀)) + (square(round(-6.5576 * x₀)) / 15.003)) ...                                                                                               - (x₀ + -6.5576))                             16          4.283e+02  1.054e-02  y = ((sqrt(exp(x₀)) + round(square(round(-6.5576 * x₀)) / 15.0...                                                                                               03)) - (x₀ + -6.5576))                        18          4.256e+02  3.196e-03  y = (((sqrt(exp(x₀)) + round(square(round(-6.5576 * x₀)) / 15....                                                                                               003)) - (x₀ + -6.5576)) + 0.64342)            19          4.185e+02  1.685e-02  y = (round((sqrt(exp(x₀)) + round(square(round(-6.5576 * x₀)) ...                                                                                               / 15.003)) - (x₀ + -6.5576)) - -1.0784)       ---------------------------------------------------------------------------------------------------
# 99.7%┣██████████████████████████████████████████▉┫ 598/600 [00:08<00:00, 76it/s]Expressions evaluated per second: 1.88e+05. Head worker occupation: 22.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.758e+04  1.594e+01  y = 166.67                                    3           4.386e+03  6.941e-01  y = (x₀ / 0.032282)                           4           8.765e+02  1.610e+00  y = (square(x₀) / 0.25156)                    5           8.677e+02  1.011e-02  y = round(square(x₀) / 0.25156)               6           7.969e+02  8.507e-02  y = (square(x₀ - 0.70195) / 0.21143)          7           7.011e+02  1.281e-01  y = (cube(sqrt(x₀) + 0.3109) * x₀)            8           5.063e+02  3.256e-01  y = (sqrt(exp(x₀)) + (square(x₀) / 0.35062))  9           4.994e+02  1.373e-02  y = (sqrt(exp(x₀)) + round(square(x₀) / 0.34892))                                                                             10          4.710e+02  5.840e-02  y = (sqrt(exp(x₀)) + ((square(x₀) / 0.37037) - -10.04))                                                                       11          4.573e+02  2.948e-02  y = (sqrt(exp(x₀)) + (square(round(-6.5576 * x₀)) / 15.003))                                                                  12          4.524e+02  1.090e-02  y = (sqrt(exp(x₀)) + round(square(round(-6.5576 * x₀)) / 15.00...                                                                                               3))                                           13          4.420e+02  2.314e-02  y = (sqrt(exp(x₀)) + (square(round(-4.543 * x₀) + -2.9896) / 8...                                                                                               .4206))                                       14          4.419e+02  3.323e-04  y = (sqrt(exp(x₀)) + (square(round(-4.543 * x₀) + round(-2.989...                                                                                               6)) / 8.4206))                                15          4.328e+02  2.070e-02  y = ((sqrt(exp(x₀)) + (square(round(-6.5576 * x₀)) / 15.003)) ...                                                                                               - (x₀ + -6.5576))                             16          4.283e+02  1.054e-02  y = ((sqrt(exp(x₀)) + round(square(round(-6.5576 * x₀)) / 15.0...                                                                                               03)) - (x₀ + -6.5576))                        18          4.256e+02  3.196e-03  y = (((sqrt(exp(x₀)) + round(square(round(-6.5576 * x₀)) / 15....                                                                                               003)) - (x₀ + -6.5576)) + 0.64342)            19          4.185e+02  1.685e-02  y = (round((sqrt(exp(x₀)) + round(square(round(-6.5576 * x₀)) ...                                                                                               / 15.003)) - (x₀ + -6.5576)) - -1.0784)       ---------------------------------------------------------------------------------------------------

# %%
registros_ = registros
file_pickle = 'dados_v2.pck'

# %%
for i in registros_:
  loss = i[1]
  score = i[2]
  complexity = i[0]
  w = (loss * score)/complexity
  if math.isnan(w):
    i.append(0)
  else:
    i.append(w)

lista_melhor_valor = max(registros_, key=lambda x: x[6])

# %% [markdown]
# ## Save result

# %%
def salvar_dados(dados, key, arquivo):
  if os.path.exists(arquivo):
    with open(arquivo, 'rb') as f:
      dados_exist = pickle.load(f)
  else:
    dados_exist = {}
    
  valor_original = dados_exist.get(key)
  if valor_original == None:
    dados_exist.update({key: [dados]})
  else:
    if isinstance(valor_original, list):
      valor_original.append(dados)
    else:
      dados_exist.update({key: [dados]})

  with open(arquivo, 'wb') as f:
    pickle.dump(dados_exist, f)

caminho_arquivo = file_pickle
novos_dados = lista_melhor_valor[0:3] + [lista_melhor_valor[4]]

salvar_dados(novos_dados, 'karatsuba_N^1.585', caminho_arquivo)

# %%
def carregar_dados(arquivo):
    # Carrega os dados do arquivo pickle
    with open(arquivo, 'rb') as f:
        dados = pickle.load(f)
    return dados

caminho_arquivo = file_pickle
dados_carregados = carregar_dados(caminho_arquivo)

print("Conteúdo do arquivo pickle:")
for k, v in dados_carregados.items():
  print('\u25CF', k)
  for index, item in enumerate(v):
    if index == len(v)-1:
       print('└─', item)
    else:
      print('├─', item)
  print('==========================')
# Out:
# Conteúdo do arquivo pickle:
# ● binary_search_logx
# ├─ [5, 1.5291587, 2.194796893650787, log(x0)**2 + 13.966388]
# ├─ [5, 1.2686663, 2.221314226989192, 10.953988*x0**(1/4)]
# └─ [5, 1.2686664, 2.221314062669807, 10.9540106810246*x0**(1/4)]
# ==========================
# ● karatsuba_N^1.585
# └─ [8, 506.257, 0.32556235249161525, 2.8521053871194*x0**2 + sqrt(exp(x0))]
# ==========================
