# %%
# https://rosettacode.org/wiki/Levenshtein_distance#Python

import numpy as np
from line_profiler import LineProfiler
from pysr import PySRRegressor
import random
import string
import os
import sys
import math
import pickle
# Out:
# Detected Jupyter notebook. Loading juliacall extension. Set `PYSR_AUTOLOAD_EXTENSIONS=no` to disable.

# %% [markdown]
# ## Levenshtein Distance Algorithm

# %%
def levenshteinDistance(str1, str2): # M*N
  m = len(str1)
  n = len(str2)
  d = [[i] for i in range(1, m + 1)]   # d matrix rows
  d.insert(0, list(range(0, n + 1)))   # d matrix columns
  for j in range(1, n + 1): # A 
    for i in range(1, m + 1): # B
      if str1[i - 1] == str2[j - 1]: # C     # Python (string) is 0-based
        substitutionCost = 0
      else: # D
        substitutionCost = 1
      d[i].insert(j, min(d[i - 1][j] + 1,
                          d[i][j - 1] + 1,
                          d[i - 1][j - 1] + substitutionCost))

# %%
def generate_random_string(length):
    return ''.join(random.choice(string.ascii_lowercase) for _ in range(length))

# %% [markdown]
# ## Frequency Count Method

# %%
X_y = []
x1 = []
x2 =[]
y = []
i=50
for n in range(2,i+1): # started with 2 itens until 50 itens in the list
  lprofiler = LineProfiler()
  lp_wrapper = lprofiler(levenshteinDistance)

  # create 2 random strings with diferents lenght
  string1 = generate_random_string(n)
  string2 = generate_random_string(n*2)

  lp_wrapper(string1, string2)

  stats = lprofiler.get_stats()
  line_numbers = []
  hits = []

  for line in stats.timings.values():
    for i in line:
      line_numbers.append(i[0])
      hits.append(i[1])

  x1.append(n)
  x2.append(n*2)
  y.append(sum(hits))

X_reshaped = np.column_stack((x1, x2))
y_np = np.array(y)

# %%
resultados_com_menor_loss = []
repeat = 5
registros = []

original_stdout = sys.stdout

with open(os.devnull, 'w') as devnull:
  sys.stdout = devnull

  for i in range(repeat):

    # first combination
    reg1 = PySRRegressor(
      binary_operators=["*", "+"],
      unary_operators=["log", "square", "cube"],
    )

    fit1 = reg1.fit(X_reshaped, y)
    best_program1 = fit1.get_best()

    registro1 = []
    for index, value in enumerate(best_program1):
      registro1.append(value)
      
    registros.append(registro1)

    # second combination
    reg2 = PySRRegressor(
      binary_operators=["*"],
      unary_operators=["log", "square", "cube"],
    )

    fit2 = reg2.fit(X_reshaped, y)
    best_program2 = fit2.get_best()

    registro2 = []
    for index, value in enumerate(best_program2):
      registro2.append(value)
    registros.append(registro2)

    # third combinarion
    reg3 = PySRRegressor(
      binary_operators=["+"],
      unary_operators=["log", "square", "cube"],
    )

    fit3 = reg3.fit(X_reshaped, y)
    best_program3 = fit3.get_best()

    registro3 = []
    for index, value in enumerate(best_program3):
      registro3.append(value)
    registros.append(registro3)
    
sys.stdout = original_stdout
# Out:
# [ Info: Started!
# 0.0%┣                                             ┫ 0/600 [00:00<-1:-47, -0s/it]Expressions evaluated per second: [.....]. Head worker occupation: 0.0%         Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.647e+08  1.594e+01  y = x₁                                        2           2.301e+08  1.401e-01  y = square(x₀)                                4           2.283e+08  3.788e-03  y = (x₁ + square(x₀))                         5           1.110e+08  7.209e-01  y = (square(x₁) + square(x₀))                 6           3.194e+07  1.246e+00  y = (square(square(log(x₀))) * x₁)            8           2.372e+07  1.489e-01  y = (square(square(log(x₀ + x₀))) * x₁)       9           2.553e+06  2.229e+00  y = (square(square(log(x₀)) + square(-1.5482)) * x₁)                                                                          11          1.544e+06  2.514e-01  y = (((square(square(log(x₀))) * x₁) + square(x₀)) * 1.4749)                                                                  12          3.067e+05  1.616e+00  y = ((square(square(log(x₀))) * ((x₁ + x₀) + 0.1025)) + x₀)                                                                   14          2.407e+05  1.212e-01  y = (((square(square(log(x₀)) + (-1.0046 * -0.17043)) * x₁) + ...                                                                                               -0.17043) * 1.4749)                           15          2.379e+05  1.160e-02  y = (((square(square(log(x₀)) + (-1.0046 * -0.17043)) * x₁) + ...                                                                                               square(1.4749)) * 1.4749)                     16          2.285e+05  4.042e-02  y = (((square(square(log(x₀)) + (-1.0046 * -0.17043)) * x₁) + ...                                                                                               cube(square(1.4749))) * 1.4749)               17          2.224e+05  2.685e-02  y = ((((square(square(log(x₀)) + (-1.0046 * -0.17043)) * x₁) +...                                                                                                square(1.4749)) * 1.4749) + x₀)              18          2.131e+05  4.283e-02  y = (((square((square(log(x₀)) + -1.3496) + 1.218) * x₁) + squ...                                                                                               are(log(square(cube(x₀))))) * 1.4749)         ---------------------------------------------------------------------------------------------------
# 0.3%┣▏                                              ┫ 2/600 [00:00<03:08, 3it/s]Expressions evaluated per second: [.....]. Head worker occupation: 0.0%         Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.647e+08  1.594e+01  y = x₁                                        2           1.368e+08  6.601e-01  y = square(x₁)                                5           1.110e+08  6.949e-02  y = (square(x₁) + square(x₀))                 6           9.494e+06  2.459e+00  y = ((square(-2.3917) * x₀) * x₁)             8           9.596e+04  2.297e+00  y = square(cube(log(x₀)) + (x₁ * 1.2565))     11          4.130e+04  2.810e-01  y = square(x₀ + (((x₁ * 0.084293) + x₁) * cube(1.08)))                                                                        16          1.108e+04  2.632e-01  y = square(x₀ + ((((square(-0.10505) + x₁) * 0.084293) + (1.09...                                                                                               18 + x₁)) * cube(1.08)))                      17          9.994e+03  1.027e-01  y = square(x₀ + (((((-0.10505 * 2.047) + x₁) * 0.084293) + (1....                                                                                               0918 + x₁)) * cube(1.08)))                    19          3.629e+02  1.658e+00  y = square(x₀ + ((((square(-0.10505 * cube(2.047)) + x₁) * 0.0...                                                                                               84293) + (0.65157 + x₁)) * cube(1.08)))       ---------------------------------------------------------------------------------------------------
# 1.2%┣▌                                             ┫ 7/600 [00:00<00:38, 15it/s]Expressions evaluated per second: [.....]. Head worker occupation: 9.5%         Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.647e+08  1.594e+01  y = x₁                                        2           1.368e+08  6.601e-01  y = square(x₁)                                4           3.489e+07  6.831e-01  y = square(x₀ + x₁)                           6           3.033e+06  1.221e+00  y = square(x₁ + (1.5494 * x₀))                8           9.596e+04  1.727e+00  y = square(cube(log(x₀)) + (x₁ * 1.2565))     11          4.130e+04  2.810e-01  y = square(x₀ + (((x₁ * 0.084293) + x₁) * cube(1.08)))                                                                        13          1.169e+04  6.310e-01  y = (((x₁ + x₁) + (x₀ * 1.2534)) * ((x₁ * 0.35067) + x₁))                                                                     15          4.121e+03  5.214e-01  y = ((x₀ + x₀) * (((0.36732 + ((x₁ + x₀) + 0.62314)) + x₁) + x...                                                                                               ₁))                                           18          2.087e+00  2.529e+00  y = ((square(((x₀ + ((x₀ + 1.0025) + cube(log(0.41197)))) * 1....                                                                                               0417) + x₀) + x₀) * 1.4719)                   ---------------------------------------------------------------------------------------------------
# 2.2%┣█                                            ┫ 13/600 [00:00<00:23, 26it/s]Expressions evaluated per second: [.....]. Head worker occupation: 8.0%         Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.647e+08  1.594e+01  y = x₁                                        2           1.368e+08  6.601e-01  y = square(x₁)                                3           1.134e+08  1.871e-01  y = (5820.5 + 6553.1)                         4           4.827e+06  3.157e+00  y = square(x₁ + x₁)                           6           3.033e+06  2.324e-01  y = square(x₁ + (1.5494 * x₀))                7           1.903e+05  2.769e+00  y = (square(1.9025 * x₁) + cube(0.093607))    8           9.596e+04  6.846e-01  y = square(cube(log(x₀)) + (x₁ * 1.2565))     11          2.211e+03  1.257e+00  y = (0.7808 * (square((1.9025 + 0.22466) * x₁) + log(0.093607)...                                                                                               ))                                            12          1.051e+03  7.436e-01  y = ((1.1654 + 1.6419) * (square((0.81135 + 0.30929) * x₁) + 0...                                                                                               .06786))                                      18          2.087e+00  1.037e+00  y = ((square(((x₀ + ((x₀ + 1.0025) + cube(log(0.41197)))) * 1....                                                                                               0417) + x₀) + x₀) * 1.4719)                   ---------------------------------------------------------------------------------------------------
# 3.2%┣█▍                                           ┫ 19/600 [00:01<00:17, 35it/s]Expressions evaluated per second: [.....]. Head worker occupation: 17.9%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.647e+08  1.594e+01  y = x₁                                        2           1.368e+08  6.601e-01  y = square(x₁)                                3           1.134e+08  1.871e-01  y = (5820.5 + 6553.1)                         4           4.827e+06  3.157e+00  y = square(x₁ + x₁)                           6           1.167e+06  7.100e-01  y = (square(x₁ * -1.8145) + 0.40556)          7           1.903e+05  1.813e+00  y = (square(1.9025 * x₁) + cube(0.093607))    8           9.596e+04  6.846e-01  y = square(cube(log(x₀)) + (x₁ * 1.2565))     10          1.059e+03  2.254e+00  y = (square(((x₀ + x₀) * 1.3005) + x₀) * 1.0875)                                                                              11          1.938e+00  6.303e+00  y = (((square(x₁ + 0.33752) * 2.4985) + square(x₁)) + x₀)                                                                     ---------------------------------------------------------------------------------------------------
# 4.0%┣█▉                                           ┫ 24/600 [00:01<00:15, 39it/s]Expressions evaluated per second: [.....]. Head worker occupation: 14.5%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.647e+08  1.594e+01  y = x₁                                        2           1.368e+08  6.601e-01  y = square(x₁)                                3           1.134e+08  1.871e-01  y = (5820.5 + 6553.1)                         4           4.827e+06  3.157e+00  y = square(x₁ + x₁)                           6           8.499e+05  8.685e-01  y = square(x₀ + (x₁ * 1.4299))                7           1.003e+04  4.440e+00  y = square(log(x₀) + (x₁ * 1.8322))           8           3.158e+02  3.458e+00  y = (square(x₁ + (1.7487 * x₀)) + x₁)         11          1.938e+00  1.698e+00  y = (((square(x₁ + 0.33752) * 2.4985) + square(x₁)) + x₀)                                                                     ---------------------------------------------------------------------------------------------------
# 5.2%┣██▎                                          ┫ 31/600 [00:01<00:12, 46it/s]Expressions evaluated per second: [.....]. Head worker occupation: 15.9%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.647e+08  1.594e+01  y = x₁                                        2           1.368e+08  6.601e-01  y = square(x₁)                                3           1.134e+08  1.871e-01  y = (5820.5 + 6553.1)                         4           1.903e+05  6.390e+00  y = square(1.9025 * x₁)                       7           7.087e+03  1.097e+00  y = (square(x₁ * -1.8145) + square(x₀))       8           5.223e+01  4.910e+00  y = (3.4379 * (square(-1.0096 * x₁) + x₀))    11          1.938e+00  1.098e+00  y = (((square(x₁ + 0.33752) * 2.4985) + square(x₁)) + x₀)                                                                     14          1.823e+00  2.039e-02  y = ((((square(x₁ + 0.33752) * 2.4985) + square(-0.42711)) + s...                                                                                               quare(x₁)) + x₀)                              15          1.780e+00  2.394e-02  y = ((((square(x₁ + 0.33752) * 2.4985) + 1.1647) + square(x₁))...                                                                                                + (x₀ + -0.84257))                           ---------------------------------------------------------------------------------------------------
# 5.8%┣██▋                                          ┫ 35/600 [00:01<00:12, 48it/s]Expressions evaluated per second: [.....]. Head worker occupation: 16.3%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.647e+08  1.594e+01  y = x₁                                        2           1.368e+08  6.601e-01  y = square(x₁)                                3           1.134e+08  1.871e-01  y = (5820.5 + 6553.1)                         4           1.059e+03  1.157e+01  y = square(3.7553 * x₀)                       6           1.059e+03  3.055e-05  y = square((3.6471 + 0.10824) * x₀)           8           1.944e+00  3.150e+00  y = square((0.58795 + x₁) + (1.7407 * x₀))    11          1.938e+00  8.948e-04  y = (((square(x₁ + 0.33752) * 2.4985) + square(x₁)) + x₀)                                                                     14          1.823e+00  2.039e-02  y = ((((square(x₁ + 0.33752) * 2.4985) + square(-0.42711)) + s...                                                                                               quare(x₁)) + x₀)                              15          1.780e+00  2.394e-02  y = ((((square(x₁ + 0.33752) * 2.4985) + 1.1647) + square(x₁))...                                                                                                + (x₀ + -0.84257))                           ---------------------------------------------------------------------------------------------------
# 7.0%┣███▏                                         ┫ 42/600 [00:01<00:11, 53it/s]Expressions evaluated per second: [.....]. Head worker occupation: 15.2%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.647e+08  1.594e+01  y = x₁                                        2           1.134e+08  8.472e-01  y = square(111.23)                            3           1.639e+07  1.935e+00  y = (267.18 * x₁)                             4           1.059e+03  9.645e+00  y = square(3.7553 * x₀)                       6           1.059e+03  3.055e-05  y = square((3.6471 + 0.10824) * x₀)           8           1.944e+00  3.150e+00  y = square((0.58795 + x₁) + (1.7407 * x₀))    11          1.938e+00  8.948e-04  y = (((square(x₁ + 0.33752) * 2.4985) + square(x₁)) + x₀)                                                                     14          1.823e+00  2.039e-02  y = ((((square(x₁ + 0.33752) * 2.4985) + square(-0.42711)) + s...                                                                                               quare(x₁)) + x₀)                              15          1.780e+00  2.394e-02  y = ((((square(x₁ + 0.33752) * 2.4985) + 1.1647) + square(x₁))...                                                                                                + (x₀ + -0.84257))                           ---------------------------------------------------------------------------------------------------
# 8.0%┣███▋                                         ┫ 48/600 [00:01<00:10, 56it/s]Expressions evaluated per second: [.....]. Head worker occupation: 14.3%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.647e+08  1.594e+01  y = x₁                                        2           1.134e+08  8.472e-01  y = square(111.23)                            3           1.639e+07  1.935e+00  y = (267.18 * x₁)                             4           1.059e+03  9.646e+00  y = square(x₁ * -1.8776)                      6           1.953e+00  3.148e+00  y = square((1.8704 * x₁) + 0.58731)           8           1.944e+00  2.467e-03  y = square((0.58795 + x₁) + (1.7407 * x₀))    11          1.938e+00  8.948e-04  y = (((square(x₁ + 0.33752) * 2.4985) + square(x₁)) + x₀)                                                                     14          1.823e+00  2.039e-02  y = ((((square(x₁ + 0.33752) * 2.4985) + square(-0.42711)) + s...                                                                                               quare(x₁)) + x₀)                              15          1.780e+00  2.394e-02  y = ((((square(x₁ + 0.33752) * 2.4985) + 1.1647) + square(x₁))...                                                                                                + (x₀ + -0.84257))                           20          9.749e-01  1.204e-01  y = (((square((((x₀ + x₀) * 0.99171) * -1.4243) + x₀) + (0.405...                                                                                               13 + x₀)) * 4.2023) + (0.038304 * x₁))        ---------------------------------------------------------------------------------------------------
# 9.0%┣████                                         ┫ 54/600 [00:01<00:09, 59it/s]Expressions evaluated per second: [.....]. Head worker occupation: 15.6%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.647e+08  1.594e+01  y = x₁                                        2           1.134e+08  8.472e-01  y = square(111.23)                            3           1.639e+07  1.935e+00  y = (267.18 * x₁)                             4           1.059e+03  9.646e+00  y = square(x₁ * -1.8776)                      6           1.953e+00  3.148e+00  y = square((1.8704 * x₁) + 0.58731)           8           1.944e+00  2.467e-03  y = square((0.58795 + x₁) + (1.7407 * x₀))    11          1.938e+00  8.948e-04  y = (((square(x₁ + 0.33752) * 2.4985) + square(x₁)) + x₀)                                                                     13          1.790e+00  3.968e-02  y = (((square(x₁ + 0.33752) * 2.4985) + (square(x₁) + 0.2743))...                                                                                                + x₀)                                        15          1.780e+00  2.869e-03  y = ((((square(x₁ + 0.33752) * 2.4985) + 1.1647) + square(x₁))...                                                                                                + (x₀ + -0.84257))                           20          9.749e-01  1.204e-01  y = (((square((((x₀ + x₀) * 0.99171) * -1.4243) + x₀) + (0.405...                                                                                               13 + x₀)) * 4.2023) + (0.038304 * x₁))        ---------------------------------------------------------------------------------------------------
# 9.8%┣████▍                                        ┫ 59/600 [00:01<00:09, 61it/s]Expressions evaluated per second: [.....]. Head worker occupation: 14.6%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     2           1.134e+08  -0.000e+00  y = square(111.23)                           3           1.639e+07  1.935e+00  y = (267.18 * x₁)                             4           1.059e+03  9.646e+00  y = square(x₁ * -1.8776)                      6           1.953e+00  3.148e+00  y = square((1.8704 * x₁) + 0.58731)           8           1.944e+00  2.467e-03  y = square((0.58795 + x₁) + (1.7407 * x₀))    11          1.938e+00  8.948e-04  y = (((square(x₁ + 0.33752) * 2.4985) + square(x₁)) + x₀)                                                                     13          1.790e+00  3.968e-02  y = (((square(x₁ + 0.33752) * 2.4985) + (square(x₁) + 0.2743))...                                                                                                + x₀)                                        15          1.780e+00  2.869e-03  y = ((((square(x₁ + 0.33752) * 2.4985) + 1.1647) + square(x₁))...                                                                                                + (x₀ + -0.84257))                           20          9.749e-01  1.204e-01  y = (((square((((x₀ + x₀) * 0.99171) * -1.4243) + x₀) + (0.405...                                                                                               13 + x₀)) * 4.2023) + (0.038304 * x₁))        ---------------------------------------------------------------------------------------------------
# 10.7%┣████▊                                       ┫ 64/600 [00:01<00:09, 62it/s]Expressions evaluated per second: 2.04e+05. Head worker occupation: 13.3%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     2           1.134e+08  -0.000e+00  y = square(111.23)                           3           1.639e+07  1.935e+00  y = (267.18 * x₁)                             4           1.059e+03  9.646e+00  y = square(x₁ * -1.8776)                      6           1.953e+00  3.148e+00  y = square((1.8704 * x₁) + 0.58731)           8           1.944e+00  2.467e-03  y = square((0.58795 + x₁) + (1.7407 * x₀))    10          1.876e+00  1.762e-02  y = (square((0.58795 + x₁) + (1.7407 * x₀)) + 0.35286)                                                                        13          1.790e+00  1.560e-02  y = (((square(x₁ + 0.33752) * 2.4985) + (square(x₁) + 0.2743))...                                                                                                + x₀)                                        15          1.780e+00  2.869e-03  y = ((((square(x₁ + 0.33752) * 2.4985) + 1.1647) + square(x₁))...                                                                                                + (x₀ + -0.84257))                           18          1.095e+00  1.620e-01  y = (((square((((x₀ + x₀) * 0.99171) * -1.4243) + x₀) + (0.405...                                                                                               13 + x₀)) * 4.2023) + 1.8616)                 20          9.749e-01  5.810e-02  y = (((square((((x₀ + x₀) * 0.99171) * -1.4243) + x₀) + (0.405...                                                                                               13 + x₀)) * 4.2023) + (0.038304 * x₁))        ---------------------------------------------------------------------------------------------------
# 11.2%┣█████                                       ┫ 67/600 [00:01<00:09, 62it/s]Expressions evaluated per second: 2.04e+05. Head worker occupation: 14.5%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     2           1.134e+08  -0.000e+00  y = square(111.23)                           3           1.639e+07  1.935e+00  y = (267.18 * x₁)                             4           1.059e+03  9.646e+00  y = square(x₁ * -1.8776)                      6           1.953e+00  3.148e+00  y = square((1.8704 * x₁) + 0.58731)           8           1.944e+00  2.467e-03  y = square((0.58795 + x₁) + (1.7407 * x₀))    10          1.876e+00  1.762e-02  y = (square((0.58795 + x₁) + (1.7407 * x₀)) + 0.35286)                                                                        13          1.790e+00  1.560e-02  y = (((square(x₁ + 0.33752) * 2.4985) + (square(x₁) + 0.2743))...                                                                                                + x₀)                                        15          1.780e+00  2.869e-03  y = ((((square(x₁ + 0.33752) * 2.4985) + 1.1647) + square(x₁))...                                                                                                + (x₀ + -0.84257))                           18          1.095e+00  1.620e-01  y = (((square((((x₀ + x₀) * 0.99171) * -1.4243) + x₀) + (0.405...                                                                                               13 + x₀)) * 4.2023) + 1.8616)                 20          9.749e-01  5.810e-02  y = (((square((((x₀ + x₀) * 0.99171) * -1.4243) + x₀) + (0.405...                                                                                               13 + x₀)) * 4.2023) + (0.038304 * x₁))        ---------------------------------------------------------------------------------------------------
# 12.2%┣█████▍                                      ┫ 73/600 [00:01<00:08, 64it/s]Expressions evaluated per second: 2.04e+05. Head worker occupation: 14.7%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     2           1.134e+08  -0.000e+00  y = square(111.23)                           3           1.639e+07  1.935e+00  y = (267.18 * x₁)                             4           1.059e+03  9.646e+00  y = square(x₁ * -1.8776)                      6           1.953e+00  3.148e+00  y = square((1.8704 * x₁) + 0.58731)           8           1.944e+00  2.467e-03  y = square((0.58795 + x₁) + (1.7407 * x₀))    10          1.876e+00  1.762e-02  y = (square((0.58795 + x₁) + (1.7407 * x₀)) + 0.35286)                                                                        13          1.790e+00  1.560e-02  y = (((square(x₁ + 0.33752) * 2.4985) + (square(x₁) + 0.2743))...                                                                                                + x₀)                                        15          1.780e+00  2.869e-03  y = ((((square(x₁ + 0.33752) * 2.4985) + 1.1647) + square(x₁))...                                                                                                + (x₀ + -0.84257))                           18          1.095e+00  1.620e-01  y = (((square((((x₀ + x₀) * 0.99171) * -1.4243) + x₀) + (0.405...                                                                                               13 + x₀)) * 4.2023) + 1.8616)                 20          9.749e-01  5.810e-02  y = (((square((((x₀ + x₀) * 0.99171) * -1.4243) + x₀) + (0.405...                                                                                               13 + x₀)) * 4.2023) + (0.038304 * x₁))        ---------------------------------------------------------------------------------------------------
# 13.0%┣█████▊                                      ┫ 78/600 [00:01<00:08, 65it/s]Expressions evaluated per second: 2.04e+05. Head worker occupation: 14.7%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     2           1.134e+08  -0.000e+00  y = square(111.23)                           3           1.639e+07  1.935e+00  y = (267.18 * x₁)                             4           1.059e+03  9.646e+00  y = square(x₁ * -1.8776)                      6           1.953e+00  3.148e+00  y = square((1.8704 * x₁) + 0.58731)           8           1.944e+00  2.467e-03  y = square((0.58795 + x₁) + (1.7407 * x₀))    10          1.876e+00  1.762e-02  y = (square((0.58795 + x₁) + (1.7407 * x₀)) + 0.35286)                                                                        13          1.790e+00  1.560e-02  y = (((square(x₁ + 0.33752) * 2.4985) + (square(x₁) + 0.2743))...                                                                                                + x₀)                                        15          1.780e+00  2.869e-03  y = ((((square(x₁ + 0.33752) * 2.4985) + 1.1647) + square(x₁))...                                                                                                + (x₀ + -0.84257))                           18          1.095e+00  1.620e-01  y = (((square((((x₀ + x₀) * 0.99171) * -1.4243) + x₀) + (0.405...                                                                                               13 + x₀)) * 4.2023) + 1.8616)                 20          9.749e-01  5.810e-02  y = (((square((((x₀ + x₀) * 0.99171) * -1.4243) + x₀) + (0.405...                                                                                               13 + x₀)) * 4.2023) + (0.038304 * x₁))        ---------------------------------------------------------------------------------------------------
# 14.0%┣██████▏                                     ┫ 84/600 [00:01<00:08, 67it/s]Expressions evaluated per second: 2.04e+05. Head worker occupation: 16.5%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     2           1.134e+08  -0.000e+00  y = square(111.23)                           3           1.639e+07  1.935e+00  y = (267.18 * x₁)                             4           1.059e+03  9.646e+00  y = square(x₁ * -1.8776)                      6           1.953e+00  3.148e+00  y = square((1.8704 * x₁) + 0.58731)           8           1.944e+00  2.467e-03  y = square((0.58795 + x₁) + (1.7407 * x₀))    10          1.876e+00  1.762e-02  y = (square((0.58795 + x₁) + (1.7407 * x₀)) + 0.35286)                                                                        12          1.385e+00  1.518e-01  y = (square(((1.8705 * x₁) + log(0.52214)) + 1.2145) + log(x₀)...                                                                                               )                                             17          1.159e+00  3.565e-02  y = (((square((((x₀ + x₀) * 0.99171) * -1.4243) + x₀) + x₀) * ...                                                                                               4.2023) + square(1.8616))                     18          1.095e+00  5.671e-02  y = (((square((((x₀ + x₀) * 0.99171) * -1.4243) + x₀) + (0.405...                                                                                               13 + x₀)) * 4.2023) + 1.8616)                 20          9.749e-01  5.810e-02  y = (((square((((x₀ + x₀) * 0.99171) * -1.4243) + x₀) + (0.405...                                                                                               13 + x₀)) * 4.2023) + (0.038304 * x₁))        ---------------------------------------------------------------------------------------------------
# 14.7%┣██████▌                                     ┫ 88/600 [00:01<00:08, 66it/s]Expressions evaluated per second: 2.04e+05. Head worker occupation: 17.1%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     2           1.134e+08  -0.000e+00  y = square(111.23)                           3           1.639e+07  1.935e+00  y = (267.18 * x₁)                             4           1.059e+03  9.646e+00  y = square(x₁ * -1.8776)                      6           1.953e+00  3.148e+00  y = square((1.8704 * x₁) + 0.58731)           8           1.944e+00  2.467e-03  y = square((0.58795 + x₁) + (1.7407 * x₀))    10          1.876e+00  1.762e-02  y = (square((0.58795 + x₁) + (1.7407 * x₀)) + 0.35286)                                                                        12          1.385e+00  1.518e-01  y = (square(((1.8705 * x₁) + log(0.52214)) + 1.2145) + log(x₀)...                                                                                               )                                             17          1.159e+00  3.565e-02  y = (((square((((x₀ + x₀) * 0.99171) * -1.4243) + x₀) + x₀) * ...                                                                                               4.2023) + square(1.8616))                     18          1.095e+00  5.671e-02  y = (((square((((x₀ + x₀) * 0.99171) * -1.4243) + x₀) + (0.405...                                                                                               13 + x₀)) * 4.2023) + 1.8616)                 20          9.749e-01  5.810e-02  y = (((square((((x₀ + x₀) * 0.99171) * -1.4243) + x₀) + (0.405...                                                                                               13 + x₀)) * 4.2023) + (0.038304 * x₁))        ---------------------------------------------------------------------------------------------------
# 15.3%┣██████▊                                     ┫ 92/600 [00:01<00:08, 66it/s]Expressions evaluated per second: 2.04e+05. Head worker occupation: 18.7%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     2           1.134e+08  -0.000e+00  y = square(111.23)                           3           1.639e+07  1.935e+00  y = (267.18 * x₁)                             4           1.059e+03  9.646e+00  y = square(x₁ * -1.8776)                      6           1.953e+00  3.148e+00  y = square((1.8704 * x₁) + 0.58731)           8           1.944e+00  2.467e-03  y = square((0.58795 + x₁) + (1.7407 * x₀))    10          1.876e+00  1.762e-02  y = (square((0.58795 + x₁) + (1.7407 * x₀)) + 0.35286)                                                                        12          1.385e+00  1.518e-01  y = (square(((1.8705 * x₁) + log(0.52214)) + 1.2145) + log(x₀)...                                                                                               )                                             17          1.159e+00  3.565e-02  y = (((square((((x₀ + x₀) * 0.99171) * -1.4243) + x₀) + x₀) * ...                                                                                               4.2023) + square(1.8616))                     18          1.095e+00  5.671e-02  y = (((square((((x₀ + x₀) * 0.99171) * -1.4243) + x₀) + (0.405...                                                                                               13 + x₀)) * 4.2023) + 1.8616)                 20          9.749e-01  5.810e-02  y = (((square((((x₀ + x₀) * 0.99171) * -1.4243) + x₀) + (0.405...                                                                                               13 + x₀)) * 4.2023) + (0.038304 * x₁))        ---------------------------------------------------------------------------------------------------
# 16.3%┣███████▏                                    ┫ 98/600 [00:01<00:07, 68it/s]Expressions evaluated per second: 2.04e+05. Head worker occupation: 18.1%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.639e+07  9.673e-01  y = (267.18 * x₁)                             4           1.059e+03  9.646e+00  y = square(x₁ * -1.8776)                      6           1.953e+00  3.148e+00  y = square((1.8704 * x₁) + 0.58731)           8           1.944e+00  2.467e-03  y = square((0.58795 + x₁) + (1.7407 * x₀))    10          1.876e+00  1.762e-02  y = (square((0.58795 + x₁) + (1.7407 * x₀)) + 0.35286)                                                                        12          1.385e+00  1.518e-01  y = (square(((1.8705 * x₁) + log(0.52214)) + 1.2145) + log(x₀)...                                                                                               )                                             17          1.159e+00  3.565e-02  y = (((square((((x₀ + x₀) * 0.99171) * -1.4243) + x₀) + x₀) * ...                                                                                               4.2023) + square(1.8616))                     18          1.095e+00  5.671e-02  y = (((square((((x₀ + x₀) * 0.99171) * -1.4243) + x₀) + (0.405...                                                                                               13 + x₀)) * 4.2023) + 1.8616)                 20          9.749e-01  5.810e-02  y = (((square((((x₀ + x₀) * 0.99171) * -1.4243) + x₀) + (0.405...                                                                                               13 + x₀)) * 4.2023) + (0.038304 * x₁))        ---------------------------------------------------------------------------------------------------
# 17.5%┣███████▌                                   ┫ 105/600 [00:02<00:07, 69it/s]Expressions evaluated per second: 2.04e+05. Head worker occupation: 17.4%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.639e+07  9.673e-01  y = (267.18 * x₁)                             4           1.059e+03  9.646e+00  y = square(x₁ * -1.8776)                      6           1.953e+00  3.148e+00  y = square((1.8704 * x₁) + 0.58731)           8           1.944e+00  2.467e-03  y = square((0.58795 + x₁) + (1.7407 * x₀))    10          1.876e+00  1.762e-02  y = (square((0.58795 + x₁) + (1.7407 * x₀)) + 0.35286)                                                                        12          1.385e+00  1.518e-01  y = (square(((1.8705 * x₁) + log(0.52214)) + 1.2145) + log(x₀)...                                                                                               )                                             17          1.159e+00  3.565e-02  y = (((square((((x₀ + x₀) * 0.99171) * -1.4243) + x₀) + x₀) * ...                                                                                               4.2023) + square(1.8616))                     18          1.095e+00  5.671e-02  y = (((square((((x₀ + x₀) * 0.99171) * -1.4243) + x₀) + (0.405...                                                                                               13 + x₀)) * 4.2023) + 1.8616)                 20          9.749e-01  5.810e-02  y = (((square((((x₀ + x₀) * 0.99171) * -1.4243) + x₀) + (0.405...                                                                                               13 + x₀)) * 4.2023) + (0.038304 * x₁))        ---------------------------------------------------------------------------------------------------
# 18.5%┣████████                                   ┫ 111/600 [00:02<00:07, 70it/s]Expressions evaluated per second: 2.04e+05. Head worker occupation: 17.9%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.639e+07  9.673e-01  y = (267.18 * x₁)                             4           1.059e+03  9.646e+00  y = square(x₁ * -1.8776)                      6           1.953e+00  3.148e+00  y = square((1.8704 * x₁) + 0.58731)           8           1.944e+00  2.467e-03  y = square((0.58795 + x₁) + (1.7407 * x₀))    10          1.876e+00  1.762e-02  y = (square((0.58795 + x₁) + (1.7407 * x₀)) + 0.35286)                                                                        12          1.385e+00  1.518e-01  y = (square(((1.8705 * x₁) + log(0.52214)) + 1.2145) + log(x₀)...                                                                                               )                                             17          1.159e+00  3.565e-02  y = (((square((((x₀ + x₀) * 0.99171) * -1.4243) + x₀) + x₀) * ...                                                                                               4.2023) + square(1.8616))                     18          1.095e+00  5.671e-02  y = (((square((((x₀ + x₀) * 0.99171) * -1.4243) + x₀) + (0.405...                                                                                               13 + x₀)) * 4.2023) + 1.8616)                 20          9.749e-01  5.810e-02  y = (((square((((x₀ + x₀) * 0.99171) * -1.4243) + x₀) + (0.405...                                                                                               13 + x₀)) * 4.2023) + (0.038304 * x₁))        ---------------------------------------------------------------------------------------------------
# 19.5%┣████████▍                                  ┫ 117/600 [00:02<00:07, 72it/s]Expressions evaluated per second: 2.04e+05. Head worker occupation: 17.5%       Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.639e+07  9.673e-01  y = (267.18 * x₁)                             4           1.059e+03  9.646e+00  y = square(x₁ * -1.8776)                      6           1.953e+00  3.148e+00  y = square((1.8704 * x₁) + 0.58731)           8           1.944e+00  2.467e-03  y = square((0.58795 + x₁) + (1.7407 * x₀))    10          1.876e+00  1.762e-02  y = (square((0.58795 + x₁) + (1.7407 * x₀)) + 0.35286)                                                                        12          1.385e+00  1.518e-01  y = (square(((1.8705 * x₁) + log(0.52214)) + 1.2145) + log(x₀)...                                                                                               )                                             17          1.159e+00  3.565e-02  y = (((square((((x₀ + x₀) * 0.99171) * -1.4243) + x₀) + x₀) * ...                                                                                               4.2023) + square(1.8616))                     18          1.095e+00  5.671e-02  y = (((square((((x₀ + x₀) * 0.99171) * -1.4243) + x₀) + (0.405...                                                                                               13 + x₀)) * 4.2023) + 1.8616)                 20          9.749e-01  5.810e-02  y = (((square((((x₀ + x₀) * 0.99171) * -1.4243) + x₀) + (0.405...                                                                                               13 + x₀)) * 4.2023) + (0.038304 * x₁))        ---------------------------------------------------------------------------------------------------
# ...
# 93.5%┣████████████████████████████████████████▏  ┫ 561/600 [00:07<00:00, 78it/s]Expressions evaluated per second: 2.07e+05. Head worker occupation: 31.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.128e+08  2.584e-03  y = (x₁ + 12321)                              4           4.827e+06  3.152e+00  y = square(x₁ + x₁)                           6           3.008e+05  1.388e+00  y = square(x₁ + (-9.3441 + x₁))               8           1.278e+05  4.278e-01  y = (square(x₁ + (-12.501 + x₁)) + 800.78)    9           9.289e+04  3.193e-01  y = (square(x₁ + (x₀ + 6.7321)) + square(x₁)) 10          1.508e+04  1.818e+00  y = (square(x₁ + x₀) + (square(x₁) + square(x₀)))                                                                             12          2.031e-01  5.603e+00  y = (square(x₁ + x₀) + (square(x₁) + square(x₀ + 2.0143)))                                                                    14          4.874e-08  7.420e+00  y = ((square(x₁ + (0.66667 + x₀)) + (square(x₁) + square(x₀)))...                                                                                                + 4.5549)                                    ---------------------------------------------------------------------------------------------------
# 94.5%┣████████████████████████████████████████▋  ┫ 567/600 [00:07<00:00, 78it/s]Expressions evaluated per second: 2.07e+05. Head worker occupation: 31.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.128e+08  2.584e-03  y = (x₁ + 12321)                              4           4.827e+06  3.152e+00  y = square(x₁ + x₁)                           6           3.008e+05  1.388e+00  y = square(x₁ + (-9.3441 + x₁))               8           1.278e+05  4.278e-01  y = (square(x₁ + (-12.501 + x₁)) + 800.78)    9           9.289e+04  3.193e-01  y = (square(x₁ + (x₀ + 6.7321)) + square(x₁)) 10          1.508e+04  1.818e+00  y = (square(x₁ + x₀) + (square(x₁) + square(x₀)))                                                                             12          2.031e-01  5.603e+00  y = (square(x₁ + x₀) + (square(x₁) + square(x₀ + 2.0143)))                                                                    14          4.874e-08  7.420e+00  y = ((square(x₁ + (0.66667 + x₀)) + (square(x₁) + square(x₀)))...                                                                                                + 4.5549)                                    ---------------------------------------------------------------------------------------------------
# 95.3%┣█████████████████████████████████████████  ┫ 572/600 [00:07<00:00, 78it/s]Expressions evaluated per second: 2.07e+05. Head worker occupation: 31.5%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.128e+08  2.584e-03  y = (x₁ + 12321)                              4           4.827e+06  3.152e+00  y = square(x₁ + x₁)                           6           3.008e+05  1.388e+00  y = square(x₁ + (-9.3441 + x₁))               8           1.278e+05  4.278e-01  y = (square(x₁ + (-12.501 + x₁)) + 800.78)    9           9.289e+04  3.193e-01  y = (square(x₁ + (x₀ + 6.7321)) + square(x₁)) 10          1.508e+04  1.818e+00  y = (square(x₁ + x₀) + (square(x₁) + square(x₀)))                                                                             12          2.031e-01  5.603e+00  y = (square(x₁ + x₀) + (square(x₁) + square(x₀ + 2.0143)))                                                                    14          4.874e-08  7.420e+00  y = ((square(x₁ + (0.66667 + x₀)) + (square(x₁) + square(x₀)))...                                                                                                + 4.5549)                                    ---------------------------------------------------------------------------------------------------
# 96.2%┣█████████████████████████████████████████▍ ┫ 577/600 [00:07<00:00, 78it/s]Expressions evaluated per second: 2.07e+05. Head worker occupation: 31.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.128e+08  2.584e-03  y = (x₁ + 12321)                              4           4.827e+06  3.152e+00  y = square(x₁ + x₁)                           6           3.008e+05  1.388e+00  y = square(x₁ + (-9.3441 + x₁))               8           1.278e+05  4.278e-01  y = (square(x₁ + (-12.501 + x₁)) + 800.78)    9           9.289e+04  3.193e-01  y = (square(x₁ + (x₀ + 6.7321)) + square(x₁)) 10          1.508e+04  1.818e+00  y = (square(x₁ + x₀) + (square(x₁) + square(x₀)))                                                                             12          2.031e-01  5.603e+00  y = (square(x₁ + x₀) + (square(x₁) + square(x₀ + 2.0143)))                                                                    14          4.874e-08  7.420e+00  y = ((square(x₁ + (0.66667 + x₀)) + (square(x₁) + square(x₀)))...                                                                                                + 4.5549)                                    ---------------------------------------------------------------------------------------------------
# 96.8%┣█████████████████████████████████████████▋ ┫ 581/600 [00:07<00:00, 78it/s]Expressions evaluated per second: 2.07e+05. Head worker occupation: 31.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.128e+08  2.584e-03  y = (x₁ + 12321)                              4           4.827e+06  3.152e+00  y = square(x₁ + x₁)                           6           3.008e+05  1.388e+00  y = square(x₁ + (-9.3441 + x₁))               8           1.278e+05  4.278e-01  y = (square(x₁ + (-12.501 + x₁)) + 800.78)    9           9.289e+04  3.193e-01  y = (square(x₁ + (x₀ + 6.7321)) + square(x₁)) 10          1.508e+04  1.818e+00  y = (square(x₁ + x₀) + (square(x₁) + square(x₀)))                                                                             12          2.031e-01  5.603e+00  y = (square(x₁ + x₀) + (square(x₁) + square(x₀ + 2.0143)))                                                                    14          4.874e-08  7.420e+00  y = ((square(x₁ + (0.66667 + x₀)) + (square(x₁) + square(x₀)))...                                                                                                + 4.5549)                                    ---------------------------------------------------------------------------------------------------
# 98.0%┣██████████████████████████████████████████▏┫ 588/600 [00:07<00:00, 79it/s]Expressions evaluated per second: 2.07e+05. Head worker occupation: 31.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.128e+08  2.584e-03  y = (x₁ + 12321)                              4           4.827e+06  3.152e+00  y = square(x₁ + x₁)                           6           3.008e+05  1.388e+00  y = square(x₁ + (-9.3441 + x₁))               8           1.278e+05  4.278e-01  y = (square(x₁ + (-12.501 + x₁)) + 800.78)    9           9.289e+04  3.193e-01  y = (square(x₁ + (x₀ + 6.7321)) + square(x₁)) 10          1.508e+04  1.818e+00  y = (square(x₁ + x₀) + (square(x₁) + square(x₀)))                                                                             12          2.031e-01  5.603e+00  y = (square(x₁ + x₀) + (square(x₁) + square(x₀ + 2.0143)))                                                                    14          4.874e-08  7.420e+00  y = ((square(x₁ + (0.66667 + x₀)) + (square(x₁) + square(x₀)))...                                                                                                + 4.5549)                                    ---------------------------------------------------------------------------------------------------
# 98.8%┣██████████████████████████████████████████▌┫ 593/600 [00:08<00:00, 79it/s]Expressions evaluated per second: 2.07e+05. Head worker occupation: 31.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.128e+08  2.584e-03  y = (x₁ + 12321)                              4           4.827e+06  3.152e+00  y = square(x₁ + x₁)                           6           3.008e+05  1.388e+00  y = square(x₁ + (-9.3441 + x₁))               8           1.278e+05  4.278e-01  y = (square(x₁ + (-12.501 + x₁)) + 800.78)    9           9.289e+04  3.193e-01  y = (square(x₁ + (x₀ + 6.7321)) + square(x₁)) 10          1.508e+04  1.818e+00  y = (square(x₁ + x₀) + (square(x₁) + square(x₀)))                                                                             12          2.031e-01  5.603e+00  y = (square(x₁ + x₀) + (square(x₁) + square(x₀ + 2.0143)))                                                                    14          4.874e-08  7.420e+00  y = ((square(x₁ + (0.66667 + x₀)) + (square(x₁) + square(x₀)))...                                                                                                + 4.5549)                                    ---------------------------------------------------------------------------------------------------
# 99.5%┣██████████████████████████████████████████▉┫ 597/600 [00:08<00:00, 78it/s]Expressions evaluated per second: 2.07e+05. Head worker occupation: 31.3%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.128e+08  2.584e-03  y = (x₁ + 12321)                              4           4.827e+06  3.152e+00  y = square(x₁ + x₁)                           6           3.008e+05  1.388e+00  y = square(x₁ + (-9.3441 + x₁))               8           1.278e+05  4.278e-01  y = (square(x₁ + (-12.501 + x₁)) + 800.78)    9           9.289e+04  3.193e-01  y = (square(x₁ + (x₀ + 6.7321)) + square(x₁)) 10          1.508e+04  1.818e+00  y = (square(x₁ + x₀) + (square(x₁) + square(x₀)))                                                                             12          2.031e-01  5.603e+00  y = (square(x₁ + x₀) + (square(x₁) + square(x₀ + 2.0143)))                                                                    14          4.874e-08  7.420e+00  y = ((square(x₁ + (0.66667 + x₀)) + (square(x₁) + square(x₀)))...                                                                                                + 4.5549)                                    ---------------------------------------------------------------------------------------------------

# %%
registros_ = registros

# %%
for i in registros_:
  loss = i[1]
  score = i[2]
  complexity = i[0]
  w = (loss * score)/complexity
  if math.isnan(w):
    i.append(0)
  else:
    i.append(w)

lista_melhor_valor = max(registros_, key=lambda x: x[6])
# Out:
# C:\Users\rafae\AppData\Local\Temp\ipykernel_19564\2759937347.py:5: RuntimeWarning: invalid value encountered in scalar multiply
#   w = (loss * score)/complexity

# %% [markdown]
# ## Save result

# %%
def salvar_dados(dados, arquivo):
  if os.path.exists(arquivo):
    with open(arquivo, 'rb') as f:
      dados_exist = pickle.load(f)

    dados_exist.update(dados)
  else:
    dados_exist = dados
  
  with open(arquivo, 'wb') as f:
    pickle.dump(dados_exist, f)
  
novos_dados = {'levenshtein_distance_MN': lista_melhor_valor[4]}
caminho_arquivo = 'dados.pickle'

salvar_dados(novos_dados, caminho_arquivo)

# %%
def carregar_dados(arquivo):
    # Carrega os dados do arquivo pickle
    with open(arquivo, 'rb') as f:
        dados = pickle.load(f)
    return dados

caminho_arquivo = 'dados.pickle'
dados_carregados = carregar_dados(caminho_arquivo)

print("Conteúdo do arquivo pickle:")
for k, v in dados_carregados.items(): print(k, ' = ',v)
# Out:
# Conteúdo do arquivo pickle:
# {'shellsort_NlogN': 4.862569*x0*log(x0), 'mergesort_NlogN': 5.5040717*x0 + 8.03698770358715, 'bubblesort_x^2': 1.517833856016*x0**2, 'levenshtein_distance_MN': 3.52552934090449*x1**2}
