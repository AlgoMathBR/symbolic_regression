# %%
# https://rosettacode.org/wiki/Levenshtein_distance#Python

import numpy as np
from line_profiler import LineProfiler
from pysr import PySRRegressor
import random
import string
import os
import sys
import math
import pickle

# %% [markdown]
# ## Levenshtein Distance Algorithm

# %%
def levenshteinDistance(str1, str2): # M*N
  m = len(str1)
  n = len(str2)
  d = [[i] for i in range(1, m + 1)]   # d matrix rows
  d.insert(0, list(range(0, n + 1)))   # d matrix columns
  for j in range(1, n + 1): # A 
    for i in range(1, m + 1): # B
      if str1[i - 1] == str2[j - 1]: # C     # Python (string) is 0-based
        substitutionCost = 0
      else: # D
        substitutionCost = 1
      d[i].insert(j, min(d[i - 1][j] + 1,
                          d[i][j - 1] + 1,
                          d[i - 1][j - 1] + substitutionCost))

# %%
def generate_random_string(length):
    return ''.join(random.choice(string.ascii_lowercase) for _ in range(length))

# %% [markdown]
# ## Frequency Count Method

# %%
X_y = []
x1 = []
x2 =[]
y = []
i=50
for n in range(2,i+1): # started with 2 itens until 50 itens in the list
  lprofiler = LineProfiler()
  lp_wrapper = lprofiler(levenshteinDistance)

  # create 2 random strings with diferents lenght
  string1 = generate_random_string(n)
  string2 = generate_random_string(n*2)

  lp_wrapper(string1, string2)

  stats = lprofiler.get_stats()
  line_numbers = []
  hits = []

  for line in stats.timings.values():
    for i in line:
      line_numbers.append(i[0])
      hits.append(i[1])

  x1.append(n)
  x2.append(n*2)
  y.append(sum(hits))

X_reshaped = np.column_stack((x1, x2))
y_np = np.array(y)

# %%
resultados_com_menor_loss = []
repeat = 5
registros = []
unary_operators_list = ["log", "square", "cube", "sqrt", "round", "exp", "abs"]

original_stdout = sys.stdout

with open(os.devnull, 'w') as devnull:
  sys.stdout = devnull

  for i in range(repeat):

    # first combination
    reg1 = PySRRegressor(
      unary_operators=unary_operators_list
    )

    fit1 = reg1.fit(X_reshaped, y)
    best_program1 = fit1.get_best()

    registro1 = []
    for index, value in enumerate(best_program1):
      registro1.append(value)
      
    registros.append(registro1)
    
sys.stdout = original_stdout
# Out:
# [ Info: Started!
# 0.0%┣                                             ┫ 0/600 [00:00<00:-42, -0s/it]Expressions evaluated per second: [.....]. Head worker occupation: 0.0%         Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.647e+08  1.594e+01  y = x₁                                        2           2.301e+08  1.401e-01  y = square(x₀)                                3           1.963e+08  1.588e-01  y = (x₀ * x₁)                                 6           9.494e+06  1.010e+00  y = ((square(-2.3917) * x₀) * x₁)             8           2.658e+06  6.365e-01  y = square((x₀ + (x₁ + -2.5348)) + x₀)        10          1.312e+06  3.531e-01  y = square(((x₀ + (x₁ + -2.5348)) + x₀) + -2.3101)                                                                            12          2.988e+05  7.397e-01  y = (square(((x₀ + (x₁ + -2.5084)) + x₀) + -7.1079) + x₁)                                                                     19          2.475e+05  2.689e-02  y = ((square(((x₀ + ((x₁ + x₀) + -2.5348)) + x₀) + -2.3101) + ...                                                                                               cube(-2.3101 * 1.3612)) * 0.60819)            ---------------------------------------------------------------------------------------------------
# 0.8%┣▍                                             ┫ 5/600 [00:00<00:19, 31it/s]Expressions evaluated per second: [.....]. Head worker occupation: 14.9%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.647e+08  1.594e+01  y = x₁                                        2           1.368e+08  6.601e-01  y = square(x₁)                                4           3.489e+07  6.831e-01  y = square(x₁ + x₀)                           6           3.033e+06  1.221e+00  y = square(x₁ + (1.5494 * x₀))                8           2.231e+06  1.535e-01  y = square(x₀ + (x₀ + (-3.1676 + x₁)))        9           6.434e+05  1.243e+00  y = square((1.5494 * (x₀ + cube(1.4471))) + x₁)                                                                               10          1.278e+05  1.616e+00  y = (square((x₁ + (x₀ + -12.5)) + x₀) + 800.78)                                                                               11          1.508e+04  2.137e+00  y = ((square(x₁ + x₀) + (x₁ * x₁)) + square(x₀))                                                                              13          1.059e+03  1.328e+00  y = square((((1.5543 * x₀) + (cube(0.58582) * x₀)) + x₀) + x₀)                                                                15          3.161e+02  6.044e-01  y = (square((((1.5494 * x₀) + (cube(0.58419) * x₀)) + x₀) + x₀...                                                                                               ) + x₁)                                       ---------------------------------------------------------------------------------------------------
# 1.7%┣▊                                            ┫ 10/600 [00:00<00:12, 49it/s]Expressions evaluated per second: [.....]. Head worker occupation: 16.4%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.647e+08  1.594e+01  y = x₁                                        2           1.368e+08  6.601e-01  y = square(x₁)                                4           1.903e+05  3.289e+00  y = square(1.9025 * x₁)                       6           2.984e+04  9.263e-01  y = square(1.9025 * (x₁ + -0.73004))          8           2.039e+04  1.905e-01  y = square(1.9025 * ((x₁ + -0.50294) + -0.39171))                                                                             9           1.508e+04  3.014e-01  y = (((x₁ + (x₀ + x₁)) + x₁) * x₁)            10          1.161e+01  7.169e+00  y = (square((-0.88682 * -2.1083) * (x₁ + 0.20012)) + x₁)                                                                      14          4.010e+00  2.657e-01  y = (((square(x₁) + (x₀ * x₁)) + square(x₁)) + square(x₁ + 1.0...                                                                                               35))                                          18          3.313e+00  4.774e-02  y = (((square(x₀) + ((x₁ * (x₁ + x₁)) + x₁)) * 1.555) + (log(s...                                                                                               quare(x₁)) + x₀))                             ---------------------------------------------------------------------------------------------------
# 2.8%┣█▎                                           ┫ 17/600 [00:00<00:09, 65it/s]Expressions evaluated per second: [.....]. Head worker occupation: 18.9%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           2.647e+08  1.594e+01  y = x₁                                        2           1.368e+08  6.601e-01  y = square(x₁)                                4           1.903e+05  3.289e+00  y = square(1.9025 * x₁)                       6           2.984e+04  9.263e-01  y = square(1.9025 * (x₁ + -0.73004))          8           2.039e+04  1.905e-01  y = square(1.9025 * ((x₁ + -0.50294) + -0.39171))                                                                             9           1.508e+04  3.014e-01  y = (((x₁ + (x₀ + x₁)) + x₁) * x₁)            10          1.161e+01  7.169e+00  y = (square((-0.88682 * -2.1083) * (x₁ + 0.20012)) + x₁)                                                                      14          4.010e+00  2.657e-01  y = (((square(x₁) + (x₀ * x₁)) + square(x₁)) + square(x₁ + 1.0...                                                                                               35))                                          16          1.894e+00  3.751e-01  y = square(x₀ + ((square(cube(-0.38812) * -0.19534) + 0.5844) ...                                                                                               + (x₁ + (x₀ * 0.74083))))                     ---------------------------------------------------------------------------------------------------
# 3.7%┣█▋                                           ┫ 22/600 [00:00<00:09, 68it/s]Expressions evaluated per second: [.....]. Head worker occupation: 25.5%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     4           1.903e+05  2.130e+00  y = square(1.9025 * x₁)                       6           2.984e+04  9.263e-01  y = square(1.9025 * (x₁ + -0.73004))          8           1.893e+00  4.832e+00  y = (square(x₁ + (x₁ + 0.62433)) * 0.87462)   20          9.961e-01  5.349e-02  y = (((square(x₁ + x₀) + (x₁ * x₁)) + x₁) + (square(x₀) + ((0....                                                                                               65292 + log(x₁)) + x₁)))                      ---------------------------------------------------------------------------------------------------
# 4.7%┣██                                           ┫ 28/600 [00:00<00:08, 74it/s]Expressions evaluated per second: [.....]. Head worker occupation: 24.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     4           1.903e+05  2.130e+00  y = square(1.9025 * x₁)                       6           1.997e+04  1.127e+00  y = square(1.9025 * (x₁ + -1.0349))           8           1.893e+00  4.631e+00  y = (square(x₁ + (x₁ + 0.62433)) * 0.87462)   20          9.961e-01  5.349e-02  y = (((square(x₁ + x₀) + (x₁ * x₁)) + x₁) + (square(x₀) + ((0....                                                                                               65292 + log(x₁)) + x₁)))                      ---------------------------------------------------------------------------------------------------
# 5.5%┣██▌                                          ┫ 33/600 [00:00<00:08, 74it/s]Expressions evaluated per second: [.....]. Head worker occupation: 23.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     4           1.903e+05  2.130e+00  y = square(1.9025 * x₁)                       6           1.997e+04  1.127e+00  y = square(1.9025 * (x₁ + -1.0349))           8           1.893e+00  4.631e+00  y = (square(x₁ + (x₁ + 0.62433)) * 0.87462)   20          9.961e-01  5.349e-02  y = (((square(x₁ + x₀) + (x₁ * x₁)) + x₁) + (square(x₀) + ((0....                                                                                               65292 + log(x₁)) + x₁)))                      ---------------------------------------------------------------------------------------------------
# 6.2%┣██▊                                          ┫ 37/600 [00:00<00:08, 74it/s]Expressions evaluated per second: [.....]. Head worker occupation: 28.5%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     4           1.903e+05  2.130e+00  y = square(1.9025 * x₁)                       6           1.680e+04  1.214e+00  y = (square(x₁ + x₁) * 0.87462)               8           1.893e+00  4.545e+00  y = (square(x₁ + (x₁ + 0.62433)) * 0.87462)   20          9.961e-01  5.349e-02  y = (((square(x₁ + x₀) + (x₁ * x₁)) + x₁) + (square(x₀) + ((0....                                                                                               65292 + log(x₁)) + x₁)))                      ---------------------------------------------------------------------------------------------------
# 7.0%┣███▏                                         ┫ 42/600 [00:01<00:07, 76it/s]Expressions evaluated per second: [.....]. Head worker occupation: 27.5%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.128e+08  2.572e-03  y = (12373 + x₁)                              4           1.574e+05  6.575e+00  y = square(-1.8548 * x₁)                      6           1.680e+04  1.119e+00  y = (square(x₁ + x₁) * 0.87462)               7           1.001e+02  5.123e+00  y = square(cube(1.2316) * (x₁ + 0.4075))      8           1.893e+00  3.968e+00  y = (square(x₁ + (x₁ + 0.62433)) * 0.87462)   20          9.961e-01  5.349e-02  y = (((square(x₁ + x₀) + (x₁ * x₁)) + x₁) + (square(x₀) + ((0....                                                                                               65292 + log(x₁)) + x₁)))                      ---------------------------------------------------------------------------------------------------
# 7.7%┣███▌                                         ┫ 46/600 [00:01<00:07, 76it/s]Expressions evaluated per second: [.....]. Head worker occupation: 26.3%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.128e+08  2.572e-03  y = (12373 + x₁)                              4           1.574e+05  6.575e+00  y = square(-1.8548 * x₁)                      6           3.158e+02  3.106e+00  y = (square(1.8744 * x₁) + x₁)                7           1.001e+02  1.149e+00  y = square(cube(1.2316) * (x₁ + 0.4075))      8           1.893e+00  3.968e+00  y = (square(x₁ + (x₁ + 0.62433)) * 0.87462)   20          9.961e-01  5.349e-02  y = (((square(x₁ + x₀) + (x₁ * x₁)) + x₁) + (square(x₀) + ((0....                                                                                               65292 + log(x₁)) + x₁)))                      ---------------------------------------------------------------------------------------------------
# 8.8%┣████                                         ┫ 53/600 [00:01<00:07, 80it/s]Expressions evaluated per second: [.....]. Head worker occupation: 25.9%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.128e+08  2.572e-03  y = (12373 + x₁)                              4           1.059e+03  1.156e+01  y = square(1.8776 * x₁)                       6           4.873e+00  2.691e+00  y = square(1.8701 * (x₁ + 0.32695))           8           1.893e+00  4.728e-01  y = (square(x₁ + (x₁ + 0.62433)) * 0.87462)   20          9.961e-01  5.349e-02  y = (((square(x₁ + x₀) + (x₁ * x₁)) + x₁) + (square(x₀) + ((0....                                                                                               65292 + log(x₁)) + x₁)))                      ---------------------------------------------------------------------------------------------------
# 10.0%┣████▍                                       ┫ 60/600 [00:01<00:06, 84it/s]Expressions evaluated per second: [.....]. Head worker occupation: 26.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.639e+07  9.673e-01  y = (x₁ * 267.18)                             4           1.059e+03  9.646e+00  y = square(1.8776 * x₁)                       6           4.873e+00  2.690e+00  y = square(1.8701 * (x₁ + 0.32695))           8           1.893e+00  4.728e-01  y = (square(x₁ + (x₁ + 0.62433)) * 0.87462)   20          9.961e-01  5.349e-02  y = (((square(x₁ + x₀) + (x₁ * x₁)) + x₁) + (square(x₀) + ((0....                                                                                               65292 + log(x₁)) + x₁)))                      ---------------------------------------------------------------------------------------------------
# 11.2%┣█████                                       ┫ 67/600 [00:01<00:06, 87it/s]Expressions evaluated per second: [.....]. Head worker occupation: 25.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.639e+07  9.673e-01  y = (x₁ * 267.18)                             4           1.059e+03  9.646e+00  y = square(1.8776 * x₁)                       6           4.873e+00  2.690e+00  y = square(1.8701 * (x₁ + 0.32695))           8           1.893e+00  4.728e-01  y = (square(x₁ + (x₁ + 0.62433)) * 0.87462)   20          9.961e-01  5.349e-02  y = (((square(x₁ + x₀) + (x₁ * x₁)) + x₁) + (square(x₀) + ((0....                                                                                               65292 + log(x₁)) + x₁)))                      ---------------------------------------------------------------------------------------------------
# 12.2%┣█████▍                                      ┫ 73/600 [00:01<00:06, 87it/s]Expressions evaluated per second: [.....]. Head worker occupation: 25.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.639e+07  9.673e-01  y = (x₁ * 267.18)                             4           1.059e+03  9.646e+00  y = square(1.8776 * x₁)                       6           2.263e+00  3.074e+00  y = square((1.8703 * x₁) + 0.59365)           8           1.893e+00  8.941e-02  y = (square(x₁ + (x₁ + 0.62433)) * 0.87462)   10          1.777e+00  3.158e-02  y = ((square((x₁ + 0.62433) + x₁) + 0.21305) * 0.87462)                                                                       20          9.961e-01  5.788e-02  y = (((square(x₁ + x₀) + (x₁ * x₁)) + x₁) + (square(x₀) + ((0....                                                                                               65292 + log(x₁)) + x₁)))                      ---------------------------------------------------------------------------------------------------
# 13.3%┣█████▉                                      ┫ 80/600 [00:01<00:06, 90it/s]Expressions evaluated per second: [.....]. Head worker occupation: 24.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.639e+07  9.673e-01  y = (x₁ * 267.18)                             4           1.059e+03  9.646e+00  y = square(1.8776 * x₁)                       6           2.263e+00  3.074e+00  y = square((1.8703 * x₁) + 0.59365)           8           1.893e+00  8.941e-02  y = (square(x₁ + (x₁ + 0.62433)) * 0.87462)   10          1.777e+00  3.158e-02  y = ((square((x₁ + 0.62433) + x₁) + 0.21305) * 0.87462)                                                                       20          9.961e-01  5.788e-02  y = (((square(x₁ + x₀) + (x₁ * x₁)) + x₁) + (square(x₀) + ((0....                                                                                               65292 + log(x₁)) + x₁)))                      ---------------------------------------------------------------------------------------------------
# 14.5%┣██████▍                                     ┫ 87/600 [00:01<00:06, 92it/s]Expressions evaluated per second: [.....]. Head worker occupation: 24.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.639e+07  9.673e-01  y = (x₁ * 267.18)                             4           1.059e+03  9.646e+00  y = square(1.8776 * x₁)                       6           2.263e+00  3.074e+00  y = square((1.8703 * x₁) + 0.59365)           8           1.893e+00  8.941e-02  y = (square(x₁ + (x₁ + 0.62433)) * 0.87462)   10          1.777e+00  3.158e-02  y = ((square((x₁ + 0.62433) + x₁) + 0.21305) * 0.87462)                                                                       20          9.961e-01  5.788e-02  y = (((square(x₁ + x₀) + (x₁ * x₁)) + x₁) + (square(x₀) + ((0....                                                                                               65292 + log(x₁)) + x₁)))                      ---------------------------------------------------------------------------------------------------
# 15.3%┣██████▊                                     ┫ 92/600 [00:01<00:06, 91it/s]Expressions evaluated per second: [.....]. Head worker occupation: 23.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.639e+07  9.673e-01  y = (x₁ * 267.18)                             4           1.059e+03  9.646e+00  y = square(1.8776 * x₁)                       6           2.263e+00  3.074e+00  y = square((1.8703 * x₁) + 0.59365)           8           1.893e+00  8.941e-02  y = (square(x₁ + (x₁ + 0.62433)) * 0.87462)   10          1.777e+00  3.158e-02  y = ((square((x₁ + 0.62433) + x₁) + 0.21305) * 0.87462)                                                                       20          9.961e-01  5.788e-02  y = (((square(x₁ + x₀) + (x₁ * x₁)) + x₁) + (square(x₀) + ((0....                                                                                               65292 + log(x₁)) + x₁)))                      ---------------------------------------------------------------------------------------------------
# 16.0%┣███████                                     ┫ 96/600 [00:01<00:06, 88it/s]Expressions evaluated per second: 2.62e+05. Head worker occupation: 23.5%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.639e+07  9.673e-01  y = (x₁ * 267.18)                             4           1.059e+03  9.646e+00  y = square(1.8776 * x₁)                       6           2.263e+00  3.074e+00  y = square((1.8703 * x₁) + 0.59365)           8           1.893e+00  8.941e-02  y = (square(x₁ + (x₁ + 0.62433)) * 0.87462)   10          1.777e+00  3.158e-02  y = ((square((x₁ + 0.62433) + x₁) + 0.21305) * 0.87462)                                                                       15          1.142e+00  8.846e-02  y = (((square(x₁ + x₁) * 0.87485) + log(x₁ * x₁)) + (x₁ + x₁))                                                                20          9.961e-01  2.730e-02  y = (((square(x₁ + x₀) + (x₁ * x₁)) + x₁) + (square(x₀) + ((0....                                                                                               65292 + log(x₁)) + x₁)))                      ---------------------------------------------------------------------------------------------------
# 17.0%┣███████▎                                   ┫ 102/600 [00:01<00:06, 87it/s]Expressions evaluated per second: 2.62e+05. Head worker occupation: 22.9%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.639e+07  9.673e-01  y = (x₁ * 267.18)                             4           1.059e+03  9.646e+00  y = square(1.8776 * x₁)                       6           2.263e+00  3.074e+00  y = square((1.8703 * x₁) + 0.59365)           8           1.893e+00  8.941e-02  y = (square(x₁ + (x₁ + 0.62433)) * 0.87462)   10          1.777e+00  3.158e-02  y = ((square((x₁ + 0.62433) + x₁) + 0.21305) * 0.87462)                                                                       14          1.717e+00  8.582e-03  y = (((square((x₁ + (0.62433 * 0.76309)) + x₁) + 0.87462) * 0....                                                                                               87462) + x₀)                                  15          1.142e+00  4.080e-01  y = (((square(x₁ + x₁) * 0.87485) + log(x₁ * x₁)) + (x₁ + x₁))                                                                20          9.961e-01  2.730e-02  y = (((square(x₁ + x₀) + (x₁ * x₁)) + x₁) + (square(x₀) + ((0....                                                                                               65292 + log(x₁)) + x₁)))                      ---------------------------------------------------------------------------------------------------
# 18.0%┣███████▊                                   ┫ 108/600 [00:01<00:06, 88it/s]Expressions evaluated per second: 2.62e+05. Head worker occupation: 22.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.639e+07  9.673e-01  y = (x₁ * 267.18)                             4           1.059e+03  9.646e+00  y = square(1.8776 * x₁)                       5           1.059e+03  8.941e-07  y = (7.0511 * (x₁ * x₀))                      6           2.263e+00  6.148e+00  y = square((1.8703 * x₁) + 0.59365)           8           1.893e+00  8.941e-02  y = (square(x₁ + (x₁ + 0.62433)) * 0.87462)   10          1.777e+00  3.158e-02  y = ((square((x₁ + 0.62433) + x₁) + 0.21305) * 0.87462)                                                                       14          1.717e+00  8.582e-03  y = (((square((x₁ + (0.62433 * 0.76309)) + x₁) + 0.87462) * 0....                                                                                               87462) + x₀)                                  15          1.142e+00  4.080e-01  y = (((square(x₁ + x₁) * 0.87485) + log(x₁ * x₁)) + (x₁ + x₁))                                                                20          9.961e-01  2.730e-02  y = (((square(x₁ + x₀) + (x₁ * x₁)) + x₁) + (square(x₀) + ((0....                                                                                               65292 + log(x₁)) + x₁)))                      ---------------------------------------------------------------------------------------------------
# 19.2%┣████████▎                                  ┫ 115/600 [00:01<00:05, 89it/s]Expressions evaluated per second: 2.62e+05. Head worker occupation: 22.5%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.639e+07  9.673e-01  y = (x₁ * 267.18)                             4           1.059e+03  9.646e+00  y = square(1.8776 * x₁)                       5           1.059e+03  8.941e-07  y = (7.0511 * (x₁ * x₀))                      6           2.263e+00  6.148e+00  y = square((1.8703 * x₁) + 0.59365)           8           1.893e+00  8.941e-02  y = (square(x₁ + (x₁ + 0.62433)) * 0.87462)   10          1.777e+00  3.158e-02  y = ((square((x₁ + 0.62433) + x₁) + 0.21305) * 0.87462)                                                                       14          4.583e-01  3.388e-01  y = (((square(x₁ + x₁) * 0.6249) + square(x₁ + 1.0138)) + log(...                                                                                               x₁))                                          ---------------------------------------------------------------------------------------------------
# 20.2%┣████████▊                                  ┫ 121/600 [00:01<00:05, 89it/s]Expressions evaluated per second: 2.62e+05. Head worker occupation: 22.5%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.639e+07  9.673e-01  y = (x₁ * 267.18)                             4           1.059e+03  9.646e+00  y = square(1.8776 * x₁)                       5           1.059e+03  8.941e-07  y = (7.0511 * (x₁ * x₀))                      6           2.263e+00  6.148e+00  y = square((1.8703 * x₁) + 0.59365)           8           1.893e+00  8.941e-02  y = (square(x₁ + (x₁ + 0.62433)) * 0.87462)   10          1.777e+00  3.158e-02  y = ((square((x₁ + 0.62433) + x₁) + 0.21305) * 0.87462)                                                                       14          4.583e-01  3.388e-01  y = (((square(x₁ + x₁) * 0.6249) + square(x₁ + 1.0138)) + log(...                                                                                               x₁))                                          ---------------------------------------------------------------------------------------------------
# 21.2%┣█████████                                  ┫ 127/600 [00:01<00:05, 90it/s]Expressions evaluated per second: 2.62e+05. Head worker occupation: 22.4%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.639e+07  9.673e-01  y = (x₁ * 267.18)                             4           1.059e+03  9.646e+00  y = square(1.8776 * x₁)                       5           1.059e+03  8.941e-07  y = (7.0511 * (x₁ * x₀))                      6           2.263e+00  6.148e+00  y = square((1.8703 * x₁) + 0.59365)           8           1.893e+00  8.941e-02  y = (square(x₁ + (x₁ + 0.62433)) * 0.87462)   10          1.777e+00  3.158e-02  y = ((square((x₁ + 0.62433) + x₁) + 0.21305) * 0.87462)                                                                       14          4.583e-01  3.388e-01  y = (((square(x₁ + x₁) * 0.6249) + square(x₁ + 1.0138)) + log(...                                                                                               x₁))                                          ---------------------------------------------------------------------------------------------------
# 22.5%┣█████████▊                                 ┫ 135/600 [00:01<00:05, 92it/s]Expressions evaluated per second: 2.62e+05. Head worker occupation: 22.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.639e+07  9.673e-01  y = (x₁ * 267.18)                             4           1.059e+03  9.646e+00  y = square(1.8776 * x₁)                       5           1.059e+03  8.941e-07  y = (7.0511 * (x₁ * x₀))                      6           2.263e+00  6.148e+00  y = square((1.8703 * x₁) + 0.59365)           8           1.893e+00  8.941e-02  y = (square(x₁ + (x₁ + 0.62433)) * 0.87462)   10          1.777e+00  3.158e-02  y = ((square((x₁ + 0.62433) + x₁) + 0.21305) * 0.87462)                                                                       14          4.583e-01  3.388e-01  y = (((square(x₁ + x₁) * 0.6249) + square(x₁ + 1.0138)) + log(...                                                                                               x₁))                                          ---------------------------------------------------------------------------------------------------
# 23.5%┣██████████                                 ┫ 141/600 [00:02<00:05, 93it/s]Expressions evaluated per second: 2.62e+05. Head worker occupation: 22.3%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.639e+07  9.673e-01  y = (x₁ * 267.18)                             4           1.059e+03  9.646e+00  y = square(1.8776 * x₁)                       5           1.059e+03  8.941e-07  y = (7.0511 * (x₁ * x₀))                      6           2.263e+00  6.148e+00  y = square((1.8703 * x₁) + 0.59365)           8           1.893e+00  8.941e-02  y = (square(x₁ + (x₁ + 0.62433)) * 0.87462)   10          1.777e+00  3.158e-02  y = ((square((x₁ + 0.62433) + x₁) + 0.21305) * 0.87462)                                                                       14          4.583e-01  3.388e-01  y = (((square(x₁ + x₁) * 0.6249) + square(x₁ + 1.0138)) + log(...                                                                                               x₁))                                          ---------------------------------------------------------------------------------------------------
# 24.3%┣██████████▌                                ┫ 146/600 [00:02<00:05, 92it/s]Expressions evaluated per second: 2.62e+05. Head worker occupation: 23.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.639e+07  9.673e-01  y = (x₁ * 267.18)                             4           1.059e+03  9.646e+00  y = square(1.8776 * x₁)                       5           1.059e+03  8.941e-07  y = (7.0511 * (x₁ * x₀))                      6           2.263e+00  6.148e+00  y = square((1.8703 * x₁) + 0.59365)           8           1.893e+00  8.941e-02  y = (square(x₁ + (x₁ + 0.62433)) * 0.87462)   10          1.777e+00  3.158e-02  y = ((square((x₁ + 0.62433) + x₁) + 0.21305) * 0.87462)                                                                       14          4.583e-01  3.388e-01  y = (((square(x₁ + x₁) * 0.6249) + square(x₁ + 1.0138)) + log(...                                                                                               x₁))                                          ---------------------------------------------------------------------------------------------------
# 25.2%┣██████████▉                                ┫ 151/600 [00:02<00:05, 92it/s]Expressions evaluated per second: 2.62e+05. Head worker occupation: 23.5%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.639e+07  9.673e-01  y = (x₁ * 267.18)                             4           1.059e+03  9.646e+00  y = square(1.8776 * x₁)                       5           1.059e+03  8.941e-07  y = (7.0511 * (x₁ * x₀))                      6           2.263e+00  6.148e+00  y = square((1.8703 * x₁) + 0.59365)           8           1.893e+00  8.941e-02  y = (square(x₁ + (x₁ + 0.62433)) * 0.87462)   10          1.777e+00  3.158e-02  y = ((square((x₁ + 0.62433) + x₁) + 0.21305) * 0.87462)                                                                       14          4.583e-01  3.388e-01  y = (((square(x₁ + x₁) * 0.6249) + square(x₁ + 1.0138)) + log(...                                                                                               x₁))                                          ---------------------------------------------------------------------------------------------------
# 26.3%┣███████████▎                               ┫ 158/600 [00:02<00:05, 92it/s]Expressions evaluated per second: 2.62e+05. Head worker occupation: 23.3%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.639e+07  9.673e-01  y = (x₁ * 267.18)                             4           1.059e+03  9.646e+00  y = square(1.8776 * x₁)                       5           1.059e+03  8.941e-07  y = (7.0511 * (x₁ * x₀))                      6           2.196e+00  6.178e+00  y = square((1.8703 * x₁) + 0.59322)           8           1.893e+00  7.435e-02  y = (square(x₁ + (x₁ + 0.62433)) * 0.87462)   10          1.777e+00  3.158e-02  y = ((square((x₁ + 0.62433) + x₁) + 0.21305) * 0.87462)                                                                       14          4.583e-01  3.388e-01  y = (((square(x₁ + x₁) * 0.6249) + square(x₁ + 1.0138)) + log(...                                                                                               x₁))                                          ---------------------------------------------------------------------------------------------------
# 27.2%┣███████████▊                               ┫ 163/600 [00:02<00:05, 92it/s]Expressions evaluated per second: 2.62e+05. Head worker occupation: 23.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.639e+07  9.673e-01  y = (x₁ * 267.18)                             4           1.059e+03  9.646e+00  y = square(1.8776 * x₁)                       5           1.059e+03  8.941e-07  y = (7.0511 * (x₁ * x₀))                      6           2.196e+00  6.178e+00  y = square((1.8703 * x₁) + 0.59322)           8           1.893e+00  7.435e-02  y = (square(x₁ + (x₁ + 0.62433)) * 0.87462)   10          1.777e+00  3.158e-02  y = ((square((x₁ + 0.62433) + x₁) + 0.21305) * 0.87462)                                                                       14          4.583e-01  3.388e-01  y = (((square(x₁ + x₁) * 0.6249) + square(x₁ + 1.0138)) + log(...                                                                                               x₁))                                          ---------------------------------------------------------------------------------------------------
# ...
# 94.2%┣████████████████████████████████████████▌  ┫ 565/600 [00:06<00:00, 88it/s]Expressions evaluated per second: 2.35e+05. Head worker occupation: 20.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.128e+08  2.584e-03  y = (x₁ + 12324)                              4           4.827e+06  3.152e+00  y = square(x₁ + x₁)                           6           3.008e+05  1.388e+00  y = square((x₁ + -9.3444) + x₁)               8           1.278e+05  4.278e-01  y = (square((x₁ + -12.5) + x₁) + 800.72)      9           9.289e+04  3.193e-01  y = (square((x₁ + 6.7321) + x₀) + square(x₁)) 10          1.508e+04  1.818e+00  y = ((square(x₁ + x₀) + square(x₁)) + square(x₀))                                                                             12          2.131e-01  5.579e+00  y = ((square(x₁ + x₀) + square(x₁)) + square(x₀ + 2.0158))                                                                    13          2.031e-01  4.783e-02  y = ((square(x₁ + x₀) + square(x₁)) + square(x₀ + square(1.419...                                                                                               2)))                                          15          1.609e-01  1.164e-01  y = ((square(x₁ + x₀) + (square(x₁) + 0.18977)) + square(x₀ + ...                                                                                               square(1.4192)))                              16          0.000e+00  1.594e+01  y = (((square(x₁ + x₀) + (square(x₁ + 0.75) + 4.4375)) + squar...                                                                                               e(x₀)) + x₀)                                  ---------------------------------------------------------------------------------------------------
# 95.0%┣████████████████████████████████████████▉  ┫ 570/600 [00:06<00:00, 88it/s]Expressions evaluated per second: 2.35e+05. Head worker occupation: 20.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.128e+08  2.584e-03  y = (x₁ + 12324)                              4           4.827e+06  3.152e+00  y = square(x₁ + x₁)                           6           3.008e+05  1.388e+00  y = square((x₁ + -9.3444) + x₁)               8           1.278e+05  4.278e-01  y = (square((x₁ + -12.5) + x₁) + 800.72)      9           9.289e+04  3.193e-01  y = (square((x₁ + 6.7321) + x₀) + square(x₁)) 10          1.508e+04  1.818e+00  y = ((square(x₁ + x₀) + square(x₁)) + square(x₀))                                                                             12          2.131e-01  5.579e+00  y = ((square(x₁ + x₀) + square(x₁)) + square(x₀ + 2.0158))                                                                    13          2.031e-01  4.783e-02  y = ((square(x₁ + x₀) + square(x₁)) + square(x₀ + square(1.419...                                                                                               2)))                                          15          1.609e-01  1.164e-01  y = ((square(x₁ + x₀) + (square(x₁) + 0.18977)) + square(x₀ + ...                                                                                               square(1.4192)))                              16          0.000e+00  1.594e+01  y = (((square(x₁ + x₀) + (square(x₁ + 0.75) + 4.4375)) + squar...                                                                                               e(x₀)) + x₀)                                  ---------------------------------------------------------------------------------------------------
# 96.3%┣█████████████████████████████████████████▍ ┫ 578/600 [00:07<00:00, 88it/s]Expressions evaluated per second: 2.35e+05. Head worker occupation: 21.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.128e+08  2.584e-03  y = (x₁ + 12324)                              4           4.827e+06  3.152e+00  y = square(x₁ + x₁)                           6           3.008e+05  1.388e+00  y = square((x₁ + -9.3444) + x₁)               8           1.278e+05  4.278e-01  y = (square((x₁ + -12.5) + x₁) + 800.72)      9           9.289e+04  3.193e-01  y = (square((x₁ + 6.7321) + x₀) + square(x₁)) 10          1.508e+04  1.818e+00  y = ((square(x₁ + x₀) + square(x₁)) + square(x₀))                                                                             12          2.131e-01  5.579e+00  y = ((square(x₁ + x₀) + square(x₁)) + square(x₀ + 2.0158))                                                                    13          2.031e-01  4.783e-02  y = ((square(x₁ + x₀) + square(x₁)) + square(x₀ + square(1.419...                                                                                               2)))                                          15          1.609e-01  1.164e-01  y = ((square(x₁ + x₀) + (square(x₁) + 0.18977)) + square(x₀ + ...                                                                                               square(1.4192)))                              16          0.000e+00  1.594e+01  y = (((square(x₁ + x₀) + (square(x₁ + 0.75) + 4.4375)) + squar...                                                                                               e(x₀)) + x₀)                                  ---------------------------------------------------------------------------------------------------
# 97.7%┣██████████████████████████████████████████ ┫ 586/600 [00:07<00:00, 89it/s]Expressions evaluated per second: 2.35e+05. Head worker occupation: 21.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.128e+08  2.584e-03  y = (x₁ + 12324)                              4           4.827e+06  3.152e+00  y = square(x₁ + x₁)                           6           3.008e+05  1.388e+00  y = square((x₁ + -9.3444) + x₁)               8           1.278e+05  4.278e-01  y = (square((x₁ + -12.5) + x₁) + 800.72)      9           9.289e+04  3.193e-01  y = (square((x₁ + 6.7321) + x₀) + square(x₁)) 10          1.508e+04  1.818e+00  y = ((square(x₁ + x₀) + square(x₁)) + square(x₀))                                                                             12          2.131e-01  5.579e+00  y = ((square(x₁ + x₀) + square(x₁)) + square(x₀ + 2.0158))                                                                    13          2.031e-01  4.783e-02  y = ((square(x₁ + x₀) + square(x₁)) + square(x₀ + square(1.419...                                                                                               2)))                                          15          1.609e-01  1.164e-01  y = ((square(x₁ + x₀) + (square(x₁) + 0.18977)) + square(x₀ + ...                                                                                               square(1.4192)))                              16          0.000e+00  1.594e+01  y = (((square(x₁ + x₀) + (square(x₁ + 0.75) + 4.4375)) + squar...                                                                                               e(x₀)) + x₀)                                  ---------------------------------------------------------------------------------------------------
# 98.5%┣██████████████████████████████████████████▍┫ 591/600 [00:07<00:00, 89it/s]Expressions evaluated per second: 2.35e+05. Head worker occupation: 21.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.128e+08  2.584e-03  y = (x₁ + 12324)                              4           4.827e+06  3.152e+00  y = square(x₁ + x₁)                           6           3.008e+05  1.388e+00  y = square((x₁ + -9.3444) + x₁)               8           1.278e+05  4.278e-01  y = (square((x₁ + -12.5) + x₁) + 800.72)      9           9.289e+04  3.193e-01  y = (square((x₁ + 6.7321) + x₀) + square(x₁)) 10          1.508e+04  1.818e+00  y = ((square(x₁ + x₀) + square(x₁)) + square(x₀))                                                                             12          2.131e-01  5.579e+00  y = ((square(x₁ + x₀) + square(x₁)) + square(x₀ + 2.0158))                                                                    13          2.031e-01  4.783e-02  y = ((square(x₁ + x₀) + square(x₁)) + square(x₀ + square(1.419...                                                                                               2)))                                          15          1.609e-01  1.164e-01  y = ((square(x₁ + x₀) + (square(x₁) + 0.18977)) + square(x₀ + ...                                                                                               square(1.4192)))                              16          0.000e+00  1.594e+01  y = (((square(x₁ + x₀) + (square(x₁ + 0.75) + 4.4375)) + squar...                                                                                               e(x₀)) + x₀)                                  ---------------------------------------------------------------------------------------------------
# 99.2%┣██████████████████████████████████████████▋┫ 595/600 [00:07<00:00, 88it/s]Expressions evaluated per second: 2.35e+05. Head worker occupation: 21.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           1.134e+08  1.594e+01  y = 12373                                     3           1.128e+08  2.584e-03  y = (x₁ + 12324)                              4           4.827e+06  3.152e+00  y = square(x₁ + x₁)                           6           3.008e+05  1.388e+00  y = square((x₁ + -9.3444) + x₁)               8           1.278e+05  4.278e-01  y = (square((x₁ + -12.5) + x₁) + 800.72)      9           9.289e+04  3.193e-01  y = (square((x₁ + 6.7321) + x₀) + square(x₁)) 10          1.508e+04  1.818e+00  y = ((square(x₁ + x₀) + square(x₁)) + square(x₀))                                                                             12          2.131e-01  5.579e+00  y = ((square(x₁ + x₀) + square(x₁)) + square(x₀ + 2.0158))                                                                    13          2.031e-01  4.783e-02  y = ((square(x₁ + x₀) + square(x₁)) + square(x₀ + square(1.419...                                                                                               2)))                                          15          1.609e-01  1.164e-01  y = ((square(x₁ + x₀) + (square(x₁) + 0.18977)) + square(x₀ + ...                                                                                               square(1.4192)))                              16          0.000e+00  1.594e+01  y = (((square(x₁ + x₀) + (square(x₁ + 0.75) + 4.4375)) + squar...                                                                                               e(x₀)) + x₀)                                  ---------------------------------------------------------------------------------------------------

# %%
registros_ = registros
file_pickle = 'dados_v3.pck'

# %%
for i in registros_:
  loss = i[1]
  score = i[2]
  complexity = i[0]
  w = (loss * score)/complexity
  if math.isnan(w):
    i.append(0)
  else:
    i.append(w)

lista_melhor_valor = max(registros_, key=lambda x: x[6])
# Out:
# C:\Users\rafae\AppData\Local\Temp\ipykernel_20780\2759937347.py:5: RuntimeWarning: invalid value encountered in scalar multiply
#   w = (loss * score)/complexity

# %% [markdown]
# ## Save result

# %%
def salvar_dados(dados, key, arquivo):
  if os.path.exists(arquivo):
    with open(arquivo, 'rb') as f:
      dados_exist = pickle.load(f)
  else:
    dados_exist = {}
    
  valor_original = dados_exist.get(key)
  if valor_original == None:
    dados_exist.update({key: [dados]})
  else:
    if isinstance(valor_original, list):
      valor_original.append(dados)
    else:
      dados_exist.update({key: [dados]})

  with open(arquivo, 'wb') as f:
    pickle.dump(dados_exist, f)

caminho_arquivo = file_pickle
novos_dados = lista_melhor_valor[0:3] + [lista_melhor_valor[4]]

salvar_dados(novos_dados, 'levenshtein_distance_MN', caminho_arquivo)

# %%
def carregar_dados(arquivo):
    # Carrega os dados do arquivo pickle
    with open(arquivo, 'rb') as f:
        dados = pickle.load(f)
    return dados

caminho_arquivo = file_pickle
dados_carregados = carregar_dados(caminho_arquivo)

print("Conteúdo do arquivo pickle:")
for k, v in dados_carregados.items():
  print('\u25CF', k)
  for index, item in enumerate(v):
    if index == len(v)-1:
       print('└─', item)
    else:
      print('├─', item)
  print('==========================')
# Out:
# Conteúdo do arquivo pickle:
# ● binary_search_logx
# ├─ [6, 1.2914093, 1.37589542429269, log(x0**6) + 5.574131]
# └─ [5, 1.5291592, 2.19479656667366, log(x0)**2 + 13.966276]
# ==========================
# ● boyer_moore_M_plus_N
# ├─ [9, 1729031400.0, 0.1972007458935316, 752018330.701125*(0.00603869219560025*x0 + 0.00603869219560025*x1 - 1)**4 + 601415.75]
# └─ [5, 15754614000.0, 0.3055240605113849, 3621132.2 - 28185.828*x1]
# ==========================
# ● bubblesort_N^2
# ├─ [4, 5910.4966, 3.4645076652491285, 1.5253483*x0**2]
# └─ [4, 8542.308, 3.303255717418494, 1.5552218*x0**2]
# ==========================
# ● fibonacci_interative_N
# ├─ [3, 0.20818244, 3.412549040667958, 2.058653*x0]
# └─ [3, 0.20818244, 3.412549040667958, 2.058653*x0]
# ==========================
# ● fibonacci_recursive_2^N
# ├─ [15, 111113150.0, 0.37865996607381686, x0**4*(0.0022606994*x0**2 - 0.714783)]
# └─ [15, 77371830.0, 0.38657145558895856, x0**2*(x0**2*(0.16452532*x0 - 3.8766947) + 297.9323)]
# ==========================
# ● heapsort_NlogN
# ├─ [9, 0.24989581, 1.1851428541960574, 4*x0 - 1.4897935]
# └─ [9, 0.24989575, 1.185128414350167, 4*x0 - 1.4897884]
# ==========================
# ● insertionsort_N^2
# ├─ [4, 12514.81, 0.5204699193332855, 7.19343672459889*(0.372847972767781*x0 - 1)**2]
# └─ [4, 11070.262, 0.6554198140129509, 9.54380044013764*(0.323697485019442*x0 - 1)**2]
# ==========================
# ● tower_hanoi_2^N
# ├─ [13, 4607.291, 0.98801217824901, 0.0050468594*x0**6]
# └─ [13, 4607.2915, 0.988012078856794, 0.005046889*x0**6]
# ==========================
# ● karatsuba_N^1.585
# └─ [4, 535.7578, 1.123614036379079, 3.66931686122521*x0**2]
# ==========================
# ● levenshtein_distance_MN
# ├─ [4, 1058.5413, 9.647410674646242, 3.52554060674929*x1**2]
# └─ [4, 1058.5277, 9.647423644638591, 3.5255728*x1**2]
# ==========================
# ● linear_search_x
# ├─ [14, 0.26546365, 0.9472618119882181, x0*log(log(log(1.97671752435621e-50*x0**18)**2))]
# └─ [3, 0.91324174, 3.3876830428181948, 2.0593598*x0]
# ==========================
# ● mergesort_NlogN
# ├─ [8, 40.208347, 0.542941641791251, (log(x0 + 4.4829993)**2 + 0.71281224)**2]
# └─ [8, 40.208347, 0.5429418585508976, (log(x0 + 4.4826865)**2 + 0.71286815)**2]
# ==========================
# ● quicksort_x^2
# ├─ [5, 4191.8745, 0.5370400329213452, 31.022936*x0 - 114.24918]
# └─ [5, 3799.3462, 0.5090052338906941, 30.326008*x0 - 105.0883]
# ==========================
# ● selectsort_N^2
# ├─ [7, 492.61688, 0.8252641931074596, 0.91222733*x0*log(x0)**3]
# └─ [7, 529.9843, 0.7728385969753846, 0.9116503*x0*log(x0)**3]
# ==========================
# ● shellsort_NlogN
# ├─ [6, 2333.781, 2.6158456057911406, 9.6421651223277*(0.469831154898539*log(x0**3) - 1)**3]
# └─ [6, 899.3794, 1.4964888960073477, 5.0019417*x0*log(x0)]
# ==========================
# ● strassen_N^2.81
# ├─ [9, 31317.309, 0.2847589231536684, log(2407.45008008753*(0.0372501681530186*(0.817895287156492*x0 + 1)**3 - 1)**2)**3]
# └─ [9, 33064.902, 0.11522887698339954, 1.80036936911294*(0.82201446811225*log(225.511129952784*(0.066591072481186*x0**3 - 1)**2) + 1)**3]
# ==========================
