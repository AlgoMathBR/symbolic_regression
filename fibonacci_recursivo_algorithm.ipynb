# %%
# https://www.geeksforgeeks.org/python-program-to-print-the-fibonacci-sequence/?ref=header_search

import numpy as np
from line_profiler import LineProfiler
from pysr import PySRRegressor
import os
import sys
import math
import pickle

# %% [markdown]
# ## Fibonacci Recursive Algorithm

# %%
def fibonacci_recursive(n): # 2^N
  if n == 1 or n == 2:
    return 1
  else:
    return fibonacci_recursive(n-1) + fibonacci_recursive(n-2)

# %% [markdown]
# ## Frequency Count Method

# %%
X_y = []
i=25
for n in range(2,i+1):
  lprofiler = LineProfiler()
  lp_wrapper = lprofiler(fibonacci_recursive)

  lp_wrapper(n)

  stats = lprofiler.get_stats()
  line_numbers = []
  hits = []

  for line in stats.timings.values():
    for i in line:
      line_numbers.append(i[0])
      hits.append(i[1])

  X_y.append([n, sum(hits)])

dados = np.array(X_y)

X = dados[:, 0]
y = dados[:, 1]
X_reshaped = X.reshape(-1, 1)

# %%
resultados_com_menor_loss = []
repeat = 5
registros = []
unary_operators_list = ["log", "square", "cube", "sqrt", "round", "exp", "abs"]

original_stdout = sys.stdout

with open(os.devnull, 'w') as devnull:
  sys.stdout = devnull

  for i in range(repeat):

    # first combination
    reg1 = PySRRegressor(
      #binary_operators=["*", "+"],
      unary_operators=unary_operators_list
    )

    fit1 = reg1.fit(X_reshaped, y)
    best_program1 = fit1.get_best()

    registro1 = []
    for index, value in enumerate(best_program1):
      registro1.append(value)
      
    registros.append(registro1)

    # second combination
    #reg2 = PySRRegressor(
    #  binary_operators=["*"],
    #  unary_operators=unary_operators_list
    #)
#
    #fit2 = reg2.fit(X_reshaped, y)
    #best_program2 = fit2.get_best()
#
    #registro2 = []
    #for index, value in enumerate(best_program2):
    #  registro2.append(value)
    #registros.append(registro2)
#
    ## third combinarion
    #reg3 = PySRRegressor(
    #  binary_operators=["+"],
    #  unary_operators=unary_operators_list
    #)
#
    #fit3 = reg3.fit(X_reshaped, y)
    #best_program3 = fit3.get_best()
#
    #registro3 = []
    #for index, value in enumerate(best_program3):
    #  registro3.append(value)
    #registros.append(registro3)
    
sys.stdout = original_stdout
# Out:
# [ Info: Started!
# 0.0%┣                                              ┫ 0/600 [00:00<00:-4, -0s/it]Expressions evaluated per second: [.....]. Head worker occupation: 0.0%         Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.070e+09  1.594e+01  y = x₀                                        3           5.258e+09  7.181e-02  y = round(cube(x₀))                           4           5.174e+09  1.604e-02  y = cube(x₀ - -0.84077)                       7           5.054e+09  7.823e-03  y = cube(sqrt(square(abs(x₀))) - -1.9759)     8           1.846e+09  1.007e+00  y = cube(sqrt(square((-0.84077 - x₀) - x₀)))  9           1.846e+09  1.788e-07  y = round(cube(sqrt(square((-0.84077 - x₀) - x₀))))                                                                           10          1.817e+09  1.621e-02  y = cube(sqrt(square((-0.76148 - x₀) - x₀)) - -1.9759)                                                                        11          1.813e+09  1.991e-03  y = abs(cube(abs(((-0.84077 - x₀) - square(1.1778)) - x₀)))                                                                   12          1.813e+09  4.411e-06  y = abs(cube(abs(sqrt(square(((-0.84077 - x₀) - 1.4872) - x₀))...                                                                                               )))                                           14          1.813e+09  4.018e-05  y = (cube(sqrt(abs(square(((-0.84077 - x₀) - square(1.1778)) -...                                                                                                x₀)))) - x₀)                                 15          1.812e+09  2.531e-04  y = (round(cube(sqrt(square(((-0.84077 - x₀) - 1.1778) - x₀) +...                                                                                                x₀))) + -0.11959)                            ---------------------------------------------------------------------------------------------------
# 1.0%┣▌                                             ┫ 6/600 [00:00<00:11, 56it/s]Expressions evaluated per second: [.....]. Head worker occupation: 20.9%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.070e+09  1.594e+01  y = x₀                                        2           5.258e+09  1.436e-01  y = cube(x₀)                                  3           8.330e+07  4.145e+00  y = sqrt(exp(x₀))                             4           8.330e+07  5.364e-07  y = round(sqrt(exp(x₀)))                      5           7.138e+06  2.457e+00  y = sqrt(exp(x₀ - -0.30298))                  6           3.261e+06  7.834e-01  y = abs(sqrt(exp(x₀ * 1.01)))                 7           2.167e+06  4.088e-01  y = (sqrt(exp(x₀)) * sqrt(square(-1.126)))    10          2.053e+06  1.793e-02  y = abs(round(sqrt(exp(abs(x₀))) * cube(sqrt(1.0854))))                                                                       ---------------------------------------------------------------------------------------------------
# 2.3%┣█                                            ┫ 14/600 [00:00<00:07, 78it/s]Expressions evaluated per second: [.....]. Head worker occupation: 24.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.070e+09  1.594e+01  y = x₀                                        2           5.258e+09  1.436e-01  y = cube(x₀)                                  3           8.330e+07  4.145e+00  y = sqrt(exp(x₀))                             4           8.330e+07  5.364e-07  y = round(sqrt(exp(x₀)))                      5           5.042e+06  2.805e+00  y = sqrt(exp(x₀) / 0.7484)                    6           3.261e+06  4.358e-01  y = abs(sqrt(exp(x₀ * 1.01)))                 7           2.053e+06  4.625e-01  y = abs(round(sqrt(exp(x₀))) / 0.88433)       10          2.053e+06  8.921e-06  y = abs(round(sqrt(exp(abs(x₀))) * cube(sqrt(1.0854))))                                                                       ---------------------------------------------------------------------------------------------------
# 3.2%┣█▍                                           ┫ 19/600 [00:00<00:07, 79it/s]Expressions evaluated per second: [.....]. Head worker occupation: 21.5%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.070e+09  1.594e+01  y = x₀                                        2           5.258e+09  1.436e-01  y = cube(x₀)                                  3           8.330e+07  4.145e+00  y = sqrt(exp(x₀))                             4           8.330e+07  5.364e-07  y = round(sqrt(exp(x₀)))                      5           3.261e+06  3.241e+00  y = sqrt(exp(x₀ * 1.01))                      6           3.260e+06  1.732e-04  y = sqrt(exp(abs(x₀) * 1.01))                 7           2.053e+06  4.624e-01  y = abs(round(sqrt(exp(x₀))) / 0.88433)       10          2.053e+06  8.921e-06  y = abs(round(sqrt(exp(abs(x₀))) * cube(sqrt(1.0854))))                                                                       19          8.146e+05  1.027e-01  y = ((x₀ + (x₀ - round(log(abs(x₀))))) + sqrt(x₀ + (exp(x₀ - -...                                                                                               1.4069) / log(x₀))))                          ---------------------------------------------------------------------------------------------------
# 4.0%┣█▉                                           ┫ 24/600 [00:00<00:07, 79it/s]Expressions evaluated per second: [.....]. Head worker occupation: 22.9%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.070e+09  1.594e+01  y = x₀                                        2           5.258e+09  1.436e-01  y = cube(x₀)                                  3           8.330e+07  4.145e+00  y = sqrt(exp(x₀))                             4           8.330e+07  5.364e-07  y = round(sqrt(exp(x₀)))                      5           2.058e+06  3.701e+00  y = (sqrt(exp(x₀)) / 0.88504)                 6           2.053e+06  2.082e-03  y = (sqrt(exp(abs(x₀))) / 0.88433)            7           2.030e+06  1.131e-02  y = ((sqrt(exp(x₀)) / 0.88441) + x₀)          8           2.030e+06  4.292e-06  y = ((sqrt(exp(x₀)) + round(x₀)) / 0.88504)   11          2.004e+06  4.425e-03  y = (((sqrt(exp(round(abs(x₀)))) + x₀) + x₀) / 0.88504)                                                                       19          8.146e+05  1.125e-01  y = ((x₀ + (x₀ - round(log(abs(x₀))))) + sqrt(x₀ + (exp(x₀ - -...                                                                                               1.4069) / log(x₀))))                          ---------------------------------------------------------------------------------------------------
# 5.2%┣██▎                                          ┫ 31/600 [00:00<00:07, 86it/s]Expressions evaluated per second: [.....]. Head worker occupation: 23.4%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.070e+09  1.594e+01  y = x₀                                        2           5.258e+09  1.436e-01  y = cube(x₀)                                  3           8.330e+07  4.145e+00  y = sqrt(exp(x₀))                             4           8.330e+07  5.364e-07  y = round(sqrt(exp(x₀)))                      5           2.053e+06  3.703e+00  y = sqrt(exp(x₀ - -0.24594))                  7           2.030e+06  5.652e-03  y = ((sqrt(exp(x₀)) / 0.88441) + x₀)          8           2.030e+06  4.292e-06  y = ((sqrt(exp(x₀)) + round(x₀)) / 0.88504)   11          2.004e+06  4.425e-03  y = (((sqrt(exp(round(abs(x₀)))) + x₀) + x₀) / 0.88504)                                                                       19          8.146e+05  1.125e-01  y = ((x₀ + (x₀ - round(log(abs(x₀))))) + sqrt(x₀ + (exp(x₀ - -...                                                                                               1.4069) / log(x₀))))                          ---------------------------------------------------------------------------------------------------
# 6.3%┣██▉                                          ┫ 38/600 [00:00<00:06, 90it/s]Expressions evaluated per second: [.....]. Head worker occupation: 23.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.070e+09  1.594e+01  y = x₀                                        2           5.258e+09  1.436e-01  y = cube(x₀)                                  3           8.330e+07  4.145e+00  y = sqrt(exp(x₀))                             4           8.330e+07  5.364e-07  y = round(sqrt(exp(x₀)))                      5           2.053e+06  3.703e+00  y = sqrt(exp(x₀ - -0.24594))                  7           1.960e+06  2.330e-02  y = square(sqrt(sqrt(exp(x₀))) + x₀)          19          8.146e+05  7.317e-02  y = ((x₀ + (x₀ - round(log(abs(x₀))))) + sqrt(x₀ + (exp(x₀ - -...                                                                                               1.4069) / log(x₀))))                          ---------------------------------------------------------------------------------------------------
# 7.2%┣███▎                                         ┫ 43/600 [00:00<00:06, 90it/s]Expressions evaluated per second: [.....]. Head worker occupation: 23.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.070e+09  1.594e+01  y = x₀                                        2           5.258e+09  1.436e-01  y = cube(x₀)                                  3           8.330e+07  4.145e+00  y = sqrt(exp(x₀))                             4           8.330e+07  5.364e-07  y = round(sqrt(exp(x₀)))                      5           2.053e+06  3.703e+00  y = sqrt(exp(x₀ - -0.24594))                  7           1.960e+06  2.330e-02  y = square(sqrt(sqrt(exp(x₀))) + x₀)          8           8.410e+05  8.461e-01  y = sqrt(exp(x₀ - -1.4069) / log(x₀))         10          8.410e+05  2.384e-07  y = sqrt(x₀ + (exp(x₀ - -1.4069) / log(x₀)))  11          8.408e+05  2.066e-04  y = sqrt(cube(x₀) + (exp(x₀ - -1.4069) / log(x₀)))                                                                            12          8.265e+05  1.714e-02  y = (x₀ + sqrt(-1.4069 + (exp(x₀ - -1.4069) / log(x₀))))                                                                      13          8.264e+05  6.271e-05  y = round(x₀ + sqrt(x₀ + (exp(x₀ - -1.4069) / log(x₀))))                                                                      14          6.408e+05  2.545e-01  y = round(square(x₀) + sqrt(x₀ + (exp(x₀ - -1.4069) / log(x₀))...                                                                                               ))                                            ---------------------------------------------------------------------------------------------------
# 8.0%┣███▋                                         ┫ 48/600 [00:01<00:06, 90it/s]Expressions evaluated per second: [.....]. Head worker occupation: 22.4%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.070e+09  1.594e+01  y = x₀                                        2           5.258e+09  1.436e-01  y = cube(x₀)                                  3           8.330e+07  4.145e+00  y = sqrt(exp(x₀))                             4           8.330e+07  5.364e-07  y = round(sqrt(exp(x₀)))                      5           2.053e+06  3.703e+00  y = sqrt(exp(x₀ - -0.24594))                  6           2.053e+06  1.109e-04  y = (round(sqrt(exp(x₀))) / 0.88429)          7           1.960e+06  4.649e-02  y = square(sqrt(sqrt(exp(x₀))) + x₀)          8           8.410e+05  8.461e-01  y = sqrt(exp(x₀ - -1.4069) / log(x₀))         10          8.410e+05  2.384e-07  y = sqrt(x₀ + (exp(x₀ - -1.4069) / log(x₀)))  11          8.408e+05  2.066e-04  y = sqrt(cube(x₀) + (exp(x₀ - -1.4069) / log(x₀)))                                                                            12          8.265e+05  1.714e-02  y = (x₀ + sqrt(-1.4069 + (exp(x₀ - -1.4069) / log(x₀))))                                                                      13          8.264e+05  6.271e-05  y = round(x₀ + sqrt(x₀ + (exp(x₀ - -1.4069) / log(x₀))))                                                                      14          6.408e+05  2.545e-01  y = round(square(x₀) + sqrt(x₀ + (exp(x₀ - -1.4069) / log(x₀))...                                                                                               ))                                            ---------------------------------------------------------------------------------------------------
# 8.7%┣████                                         ┫ 52/600 [00:01<00:06, 87it/s]Expressions evaluated per second: [.....]. Head worker occupation: 21.9%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.070e+09  1.594e+01  y = x₀                                        2           5.258e+09  1.436e-01  y = cube(x₀)                                  3           8.330e+07  4.145e+00  y = sqrt(exp(x₀))                             4           8.330e+07  5.364e-07  y = round(sqrt(exp(x₀)))                      5           2.053e+06  3.703e+00  y = sqrt(exp(x₀ - -0.24594))                  6           2.053e+06  1.109e-04  y = (round(sqrt(exp(x₀))) / 0.88429)          7           1.960e+06  4.649e-02  y = square(sqrt(sqrt(exp(x₀))) + x₀)          8           8.410e+05  8.461e-01  y = sqrt(exp(x₀ - -1.4069) / log(x₀))         10          8.410e+05  2.384e-07  y = sqrt(x₀ + (exp(x₀ - -1.4069) / log(x₀)))  11          8.408e+05  2.066e-04  y = sqrt(cube(x₀) + (exp(x₀ - -1.4069) / log(x₀)))                                                                            12          8.265e+05  1.714e-02  y = (x₀ + sqrt(-1.4069 + (exp(x₀ - -1.4069) / log(x₀))))                                                                      13          8.264e+05  6.271e-05  y = round(x₀ + sqrt(x₀ + (exp(x₀ - -1.4069) / log(x₀))))                                                                      14          6.408e+05  2.545e-01  y = round(square(x₀) + sqrt(x₀ + (exp(x₀ - -1.4069) / log(x₀))...                                                                                               ))                                            ---------------------------------------------------------------------------------------------------
# 9.5%┣████▎                                        ┫ 57/600 [00:01<00:07, 83it/s]Expressions evaluated per second: [.....]. Head worker occupation: 24.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.070e+09  1.594e+01  y = x₀                                        2           5.258e+09  1.436e-01  y = cube(x₀)                                  3           8.330e+07  4.145e+00  y = sqrt(exp(x₀))                             4           8.330e+07  5.364e-07  y = round(sqrt(exp(x₀)))                      5           2.053e+06  3.703e+00  y = sqrt(exp(x₀ - -0.24594))                  6           2.053e+06  1.109e-04  y = (round(sqrt(exp(x₀))) / 0.88429)          7           1.960e+06  4.649e-02  y = square(sqrt(sqrt(exp(x₀))) + x₀)          8           8.410e+05  8.461e-01  y = sqrt(exp(x₀ - -1.4069) / log(x₀))         10          8.410e+05  2.384e-07  y = sqrt(x₀ + (exp(x₀ - -1.4069) / log(x₀)))  11          8.408e+05  2.066e-04  y = sqrt(cube(x₀) + (exp(x₀ - -1.4069) / log(x₀)))                                                                            12          8.265e+05  1.714e-02  y = (x₀ + sqrt(-1.4069 + (exp(x₀ - -1.4069) / log(x₀))))                                                                      13          3.516e+05  8.547e-01  y = (sqrt(exp(round(x₀) * 1.0066)) + round(square(square(x₀ * ...                                                                                               -0.39329))))                                  ---------------------------------------------------------------------------------------------------
# 10.5%┣████▋                                       ┫ 63/600 [00:01<00:06, 85it/s]Expressions evaluated per second: [.....]. Head worker occupation: 24.3%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.070e+09  1.594e+01  y = x₀                                        2           5.258e+09  1.436e-01  y = cube(x₀)                                  3           8.330e+07  4.145e+00  y = sqrt(exp(x₀))                             4           8.330e+07  5.364e-07  y = round(sqrt(exp(x₀)))                      5           2.053e+06  3.703e+00  y = sqrt(exp(x₀ - -0.24594))                  6           2.053e+06  1.109e-04  y = (round(sqrt(exp(x₀))) / 0.88429)          7           1.960e+06  4.649e-02  y = square(sqrt(sqrt(exp(x₀))) + x₀)          8           8.410e+05  8.461e-01  y = sqrt(exp(x₀ - -1.4069) / log(x₀))         10          8.410e+05  2.384e-07  y = sqrt(x₀ + (exp(x₀ - -1.4069) / log(x₀)))  11          8.408e+05  2.066e-04  y = sqrt(cube(x₀) + (exp(x₀ - -1.4069) / log(x₀)))                                                                            12          8.265e+05  1.714e-02  y = (x₀ + sqrt(-1.4069 + (exp(x₀ - -1.4069) / log(x₀))))                                                                      13          3.516e+05  8.547e-01  y = (sqrt(exp(round(x₀) * 1.0066)) + round(square(square(x₀ * ...                                                                                               -0.39329))))                                  ---------------------------------------------------------------------------------------------------
# 11.7%┣█████▏                                      ┫ 70/600 [00:01<00:06, 88it/s]Expressions evaluated per second: [.....]. Head worker occupation: 24.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.024e+09  1.594e+01  y = 735.64                                    2           5.258e+09  1.360e-01  y = cube(x₀)                                  3           8.330e+07  4.145e+00  y = sqrt(exp(x₀))                             4           8.330e+07  5.364e-07  y = round(sqrt(exp(x₀)))                      5           2.053e+06  3.703e+00  y = sqrt(exp(x₀ - -0.24594))                  6           2.053e+06  1.109e-04  y = (round(sqrt(exp(x₀))) / 0.88429)          7           1.960e+06  4.649e-02  y = square(sqrt(sqrt(exp(x₀))) + x₀)          8           8.410e+05  8.461e-01  y = sqrt(exp(x₀ - -1.4069) / log(x₀))         9           8.409e+05  6.253e-05  y = round(sqrt(exp(x₀ - -1.4069) / log(x₀)))  10          8.265e+05  1.729e-02  y = (sqrt(exp(x₀ - -1.4069) / log(x₀)) + x₀)  11          8.264e+05  6.354e-05  y = (round(sqrt(exp(x₀ - -1.4069) / log(x₀))) + x₀)                                                                           12          6.408e+05  2.545e-01  y = round(square(x₀) + sqrt(exp(x₀ - -1.4069) / log(x₀)))                                                                     13          3.516e+05  6.002e-01  y = (sqrt(exp(round(x₀) * 1.0066)) + round(square(square(x₀ * ...                                                                                               -0.39329))))                                  ---------------------------------------------------------------------------------------------------
# 12.5%┣█████▌                                      ┫ 75/600 [00:01<00:06, 86it/s]Expressions evaluated per second: [.....]. Head worker occupation: 23.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.024e+09  1.594e+01  y = 735.64                                    2           5.258e+09  1.360e-01  y = cube(x₀)                                  3           8.330e+07  4.145e+00  y = sqrt(exp(x₀))                             4           8.330e+07  5.364e-07  y = round(sqrt(exp(x₀)))                      5           2.053e+06  3.703e+00  y = sqrt(exp(x₀ - -0.24594))                  6           2.053e+06  1.109e-04  y = (round(sqrt(exp(x₀))) / 0.88429)          7           1.960e+06  4.649e-02  y = square(sqrt(sqrt(exp(x₀))) + x₀)          8           8.410e+05  8.461e-01  y = sqrt(exp(x₀ - -1.4069) / log(x₀))         9           8.406e+05  4.174e-04  y = sqrt(round(exp(x₀ - -1.4074)) / log(x₀))  10          8.265e+05  1.693e-02  y = (sqrt(exp(x₀ - -1.4069) / log(x₀)) + x₀)  11          8.264e+05  6.354e-05  y = (round(sqrt(exp(x₀ - -1.4069) / log(x₀))) + x₀)                                                                           12          6.408e+05  2.545e-01  y = round(square(x₀) + sqrt(exp(x₀ - -1.4069) / log(x₀)))                                                                     13          3.516e+05  6.002e-01  y = (sqrt(exp(round(x₀) * 1.0066)) + round(square(square(x₀ * ...                                                                                               -0.39329))))                                  15          3.494e+05  3.140e-03  y = (sqrt(exp(round(x₀) * 1.0066)) + round(square(square(x₀ * ...                                                                                               -0.39329)) - x₀))                             ---------------------------------------------------------------------------------------------------
# 13.2%┣█████▉                                      ┫ 79/600 [00:01<00:06, 85it/s]Expressions evaluated per second: [.....]. Head worker occupation: 23.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.024e+09  1.594e+01  y = 735.64                                    2           5.258e+09  1.360e-01  y = cube(x₀)                                  3           8.330e+07  4.145e+00  y = sqrt(exp(x₀))                             4           8.330e+07  5.364e-07  y = round(sqrt(exp(x₀)))                      5           2.053e+06  3.703e+00  y = sqrt(exp(x₀ - -0.24594))                  6           2.053e+06  1.109e-04  y = (round(sqrt(exp(x₀))) / 0.88429)          7           1.960e+06  4.649e-02  y = square(sqrt(sqrt(exp(x₀))) + x₀)          8           8.410e+05  8.461e-01  y = sqrt(exp(x₀ - -1.4069) / log(x₀))         9           8.406e+05  4.174e-04  y = sqrt(round(exp(x₀ - -1.4074)) / log(x₀))  10          8.265e+05  1.693e-02  y = (sqrt(exp(x₀ - -1.4069) / log(x₀)) + x₀)  11          8.264e+05  6.354e-05  y = (round(sqrt(exp(x₀ - -1.4069) / log(x₀))) + x₀)                                                                           12          6.408e+05  2.545e-01  y = round(square(x₀) + sqrt(exp(x₀ - -1.4069) / log(x₀)))                                                                     13          3.516e+05  6.002e-01  y = (sqrt(exp(round(x₀) * 1.0066)) + round(square(square(x₀ * ...                                                                                               -0.39329))))                                  15          3.494e+05  3.140e-03  y = (sqrt(exp(round(x₀) * 1.0066)) + round(square(square(x₀ * ...                                                                                               -0.39329)) - x₀))                             ---------------------------------------------------------------------------------------------------
# 14.3%┣██████▎                                     ┫ 86/600 [00:01<00:06, 87it/s]Expressions evaluated per second: [.....]. Head worker occupation: 23.5%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.024e+09  1.594e+01  y = 735.64                                    2           5.258e+09  1.360e-01  y = cube(x₀)                                  3           8.330e+07  4.145e+00  y = sqrt(exp(x₀))                             4           8.330e+07  5.364e-07  y = round(sqrt(exp(x₀)))                      5           2.053e+06  3.703e+00  y = sqrt(exp(x₀ - -0.24594))                  6           2.053e+06  1.109e-04  y = (round(sqrt(exp(x₀))) / 0.88429)          7           1.960e+06  4.649e-02  y = square(sqrt(sqrt(exp(x₀))) + x₀)          8           8.410e+05  8.461e-01  y = sqrt(exp(x₀ - -1.4069) / log(x₀))         9           8.406e+05  4.174e-04  y = sqrt(round(exp(x₀ - -1.4074)) / log(x₀))  10          8.265e+05  1.693e-02  y = (sqrt(exp(x₀ - -1.4069) / log(x₀)) + x₀)  11          8.264e+05  6.354e-05  y = (round(sqrt(exp(x₀ - -1.4069) / log(x₀))) + x₀)                                                                           12          6.408e+05  2.545e-01  y = round(square(x₀) + sqrt(exp(x₀ - -1.4069) / log(x₀)))                                                                     13          3.516e+05  6.002e-01  y = (sqrt(exp(round(x₀) * 1.0066)) + round(square(square(x₀ * ...                                                                                               -0.39329))))                                  14          5.578e+04  1.841e+00  y = sqrt(((exp(abs(abs(x₀ - -3.4398))) - x₀) / abs(x₀)) + x₀)                                                                 17          3.800e+04  1.280e-01  y = sqrt(((exp(abs(abs(x₀ - -0.53068))) - -0.087569) / abs(log...                                                                                               (x₀ * 0.15516))) + x₀)                        ---------------------------------------------------------------------------------------------------
# 15.0%┣██████▋                                     ┫ 90/600 [00:01<00:06, 86it/s]Expressions evaluated per second: 2.40e+05. Head worker occupation: 23.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.024e+09  1.594e+01  y = 735.64                                    2           5.258e+09  1.360e-01  y = cube(x₀)                                  3           8.330e+07  4.145e+00  y = sqrt(exp(x₀))                             4           8.330e+07  5.364e-07  y = round(sqrt(exp(x₀)))                      5           2.053e+06  3.703e+00  y = sqrt(exp(x₀ - -0.24594))                  6           2.053e+06  1.109e-04  y = (round(sqrt(exp(x₀))) / 0.88429)          7           1.960e+06  4.649e-02  y = square(sqrt(sqrt(exp(x₀))) + x₀)          8           8.406e+05  8.466e-01  y = sqrt(exp(x₀ - -1.4074) / log(x₀))         9           8.406e+05  -0.000e+00  y = sqrt(round(exp(x₀ - -1.4074)) / log(x₀)) 10          8.265e+05  1.693e-02  y = (sqrt(exp(x₀ - -1.4069) / log(x₀)) + x₀)  11          8.264e+05  6.354e-05  y = (round(sqrt(exp(x₀ - -1.4069) / log(x₀))) + x₀)                                                                           12          6.408e+05  2.545e-01  y = round(square(x₀) + sqrt(exp(x₀ - -1.4069) / log(x₀)))                                                                     13          3.516e+05  6.002e-01  y = (sqrt(exp(round(x₀) * 1.0066)) + round(square(square(x₀ * ...                                                                                               -0.39329))))                                  14          5.578e+04  1.841e+00  y = sqrt(((exp(abs(abs(x₀ - -3.4398))) - x₀) / abs(x₀)) + x₀)                                                                 17          3.800e+04  1.280e-01  y = sqrt(((exp(abs(abs(x₀ - -0.53068))) - -0.087569) / abs(log...                                                                                               (x₀ * 0.15516))) + x₀)                        ---------------------------------------------------------------------------------------------------
# 15.7%┣███████                                     ┫ 94/600 [00:01<00:06, 85it/s]Expressions evaluated per second: 2.40e+05. Head worker occupation: 22.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.024e+09  1.594e+01  y = 735.64                                    2           5.258e+09  1.360e-01  y = cube(x₀)                                  3           8.330e+07  4.145e+00  y = sqrt(exp(x₀))                             4           8.330e+07  5.364e-07  y = round(sqrt(exp(x₀)))                      5           2.053e+06  3.703e+00  y = sqrt(exp(x₀ - -0.24594))                  6           2.053e+06  1.109e-04  y = (round(sqrt(exp(x₀))) / 0.88429)          7           1.960e+06  4.649e-02  y = square(sqrt(sqrt(exp(x₀))) + x₀)          8           8.406e+05  8.466e-01  y = sqrt(exp(x₀ - -1.4074) / log(x₀))         9           8.406e+05  -0.000e+00  y = sqrt(round(exp(x₀ - -1.4074)) / log(x₀)) 10          8.265e+05  1.693e-02  y = (sqrt(exp(x₀ - -1.4069) / log(x₀)) + x₀)  11          8.264e+05  6.354e-05  y = (round(sqrt(exp(x₀ - -1.4069) / log(x₀))) + x₀)                                                                           12          6.408e+05  2.545e-01  y = round(square(x₀) + sqrt(exp(x₀ - -1.4069) / log(x₀)))                                                                     13          3.516e+05  6.002e-01  y = (sqrt(exp(round(x₀) * 1.0066)) + round(square(square(x₀ * ...                                                                                               -0.39329))))                                  14          5.578e+04  1.841e+00  y = sqrt(((exp(abs(abs(x₀ - -3.4398))) - x₀) / abs(x₀)) + x₀)                                                                 17          3.800e+04  1.280e-01  y = sqrt(((exp(abs(abs(x₀ - -0.53068))) - -0.087569) / abs(log...                                                                                               (x₀ * 0.15516))) + x₀)                        ---------------------------------------------------------------------------------------------------
# 16.7%┣███████▏                                   ┫ 100/600 [00:01<00:06, 86it/s]Expressions evaluated per second: 2.40e+05. Head worker occupation: 23.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.024e+09  1.594e+01  y = 735.64                                    2           5.258e+09  1.360e-01  y = cube(x₀)                                  3           8.330e+07  4.145e+00  y = sqrt(exp(x₀))                             4           8.330e+07  5.364e-07  y = round(sqrt(exp(x₀)))                      5           2.053e+06  3.703e+00  y = sqrt(exp(x₀ - -0.24594))                  6           2.053e+06  1.109e-04  y = (round(sqrt(exp(x₀))) / 0.88429)          7           1.960e+06  4.649e-02  y = square(sqrt(sqrt(exp(x₀))) + x₀)          8           8.406e+05  8.466e-01  y = sqrt(exp(x₀ - -1.4074) / log(x₀))         9           8.406e+05  -0.000e+00  y = sqrt(round(exp(x₀ - -1.4074)) / log(x₀)) 10          8.265e+05  1.693e-02  y = (sqrt(exp(x₀ - -1.4069) / log(x₀)) + x₀)  11          8.264e+05  6.354e-05  y = (round(sqrt(exp(x₀ - -1.4069) / log(x₀))) + x₀)                                                                           12          6.408e+05  2.545e-01  y = round(square(x₀) + sqrt(exp(x₀ - -1.4069) / log(x₀)))                                                                     13          3.516e+05  6.002e-01  y = (sqrt(exp(round(x₀) * 1.0066)) + round(square(square(x₀ * ...                                                                                               -0.39329))))                                  14          3.795e+04  2.226e+00  y = round(sqrt(abs(exp(x₀ - -0.53068) / abs(log(round(x₀) * 0....                                                                                               15516)))))                                    17          3.791e+04  3.647e-04  y = round(sqrt((exp(abs(round(x₀) - -0.53068)) - square(x₀)) /...                                                                                                abs(log(x₀ * 0.15516))))                     18          3.742e+04  1.296e-02  y = (round(sqrt(abs((exp(x₀ - -0.53068) + x₀) / abs(log(round(...                                                                                               x₀) * 0.15516))))) + x₀)                      19          3.742e+04  5.669e-05  y = (round(sqrt(((exp(abs(x₀ - -0.53068)) - x₀) / abs(log(x₀ *...                                                                                                0.15516))) + -0.2471)) + x₀)                 ---------------------------------------------------------------------------------------------------
# 17.5%┣███████▌                                   ┫ 105/600 [00:01<00:06, 86it/s]Expressions evaluated per second: 2.40e+05. Head worker occupation: 22.9%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.024e+09  1.594e+01  y = 735.64                                    2           5.258e+09  1.360e-01  y = cube(x₀)                                  3           8.330e+07  4.145e+00  y = sqrt(exp(x₀))                             4           8.330e+07  5.364e-07  y = round(sqrt(exp(x₀)))                      5           2.053e+06  3.703e+00  y = sqrt(exp(x₀ - -0.24594))                  6           2.053e+06  1.109e-04  y = (round(sqrt(exp(x₀))) / 0.88429)          7           1.960e+06  4.649e-02  y = square(sqrt(sqrt(exp(x₀))) + x₀)          8           8.406e+05  8.466e-01  y = sqrt(exp(x₀ - -1.4074) / log(x₀))         9           8.406e+05  -0.000e+00  y = sqrt(round(exp(x₀ - -1.4074)) / log(x₀)) 10          8.265e+05  1.693e-02  y = (sqrt(exp(x₀ - -1.4069) / log(x₀)) + x₀)  11          8.264e+05  6.354e-05  y = (round(sqrt(exp(x₀ - -1.4069) / log(x₀))) + x₀)                                                                           12          6.408e+05  2.545e-01  y = round(square(x₀) + sqrt(exp(x₀ - -1.4069) / log(x₀)))                                                                     13          3.516e+05  6.002e-01  y = (sqrt(exp(round(x₀) * 1.0066)) + round(square(square(x₀ * ...                                                                                               -0.39329))))                                  14          3.795e+04  2.226e+00  y = round(sqrt(abs(exp(x₀ - -0.53068) / abs(log(round(x₀) * 0....                                                                                               15516)))))                                    17          3.791e+04  3.647e-04  y = round(sqrt((exp(abs(round(x₀) - -0.53068)) - square(x₀)) /...                                                                                                abs(log(x₀ * 0.15516))))                     18          3.742e+04  1.296e-02  y = (round(sqrt(abs((exp(x₀ - -0.53068) + x₀) / abs(log(round(...                                                                                               x₀) * 0.15516))))) + x₀)                      19          3.742e+04  5.669e-05  y = (round(sqrt(((exp(abs(x₀ - -0.53068)) - x₀) / abs(log(x₀ *...                                                                                                0.15516))) + -0.2471)) + x₀)                 ---------------------------------------------------------------------------------------------------
# 18.3%┣███████▉                                   ┫ 110/600 [00:01<00:06, 86it/s]Expressions evaluated per second: 2.40e+05. Head worker occupation: 22.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.024e+09  1.594e+01  y = 735.64                                    2           5.258e+09  1.360e-01  y = cube(x₀)                                  3           8.330e+07  4.145e+00  y = sqrt(exp(x₀))                             4           8.330e+07  5.364e-07  y = round(sqrt(exp(x₀)))                      5           2.053e+06  3.703e+00  y = sqrt(exp(x₀ - -0.24594))                  6           2.053e+06  1.109e-04  y = (round(sqrt(exp(x₀))) / 0.88429)          7           1.960e+06  4.649e-02  y = square(sqrt(sqrt(exp(x₀))) + x₀)          8           8.406e+05  8.466e-01  y = sqrt(exp(x₀ - -1.4074) / log(x₀))         9           8.406e+05  -0.000e+00  y = sqrt(round(exp(x₀ - -1.4074)) / log(x₀)) 10          8.265e+05  1.693e-02  y = (sqrt(exp(x₀ - -1.4069) / log(x₀)) + x₀)  11          6.408e+05  2.544e-01  y = (square(x₀) + sqrt(exp(x₀ - -1.4069) / log(x₀)))                                                                          12          6.408e+05  9.597e-05  y = round(square(x₀) + sqrt(exp(x₀ - -1.4069) / log(x₀)))                                                                     13          3.516e+05  6.002e-01  y = (sqrt(exp(round(x₀) * 1.0066)) + round(square(square(x₀ * ...                                                                                               -0.39329))))                                  14          3.795e+04  2.226e+00  y = round(sqrt(abs(exp(x₀ - -0.53068) / abs(log(round(x₀) * 0....                                                                                               15516)))))                                    17          3.791e+04  3.647e-04  y = round(sqrt((exp(abs(round(x₀) - -0.53068)) - square(x₀)) /...                                                                                                abs(log(x₀ * 0.15516))))                     18          3.742e+04  1.296e-02  y = (round(sqrt(abs((exp(x₀ - -0.53068) + x₀) / abs(log(round(...                                                                                               x₀) * 0.15516))))) + x₀)                      19          3.742e+04  5.669e-05  y = (round(sqrt(((exp(abs(x₀ - -0.53068)) - x₀) / abs(log(x₀ *...                                                                                                0.15516))) + -0.2471)) + x₀)                 ---------------------------------------------------------------------------------------------------
# ...
# 95.3%┣█████████████████████████████████████████  ┫ 572/600 [00:07<00:00, 82it/s]Expressions evaluated per second: 2.14e+05. Head worker occupation: 22.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           5.000e+09  1.594e+01  y = 32735                                     3           8.330e+07  2.047e+00  y = sqrt(exp(x₀))                             4           8.330e+07  5.364e-07  y = round(sqrt(exp(x₀)))                      5           2.053e+06  3.703e+00  y = sqrt(exp(x₀ - -0.2459))                   6           2.053e+06  1.342e-04  y = round(sqrt(exp(x₀ - -0.2459)))            7           5.578e+04  3.606e+00  y = sqrt((exp(x₀) * 31.183) / x₀)             8           5.574e+04  6.393e-04  y = round(sqrt((exp(x₀) * 31.183) / x₀))      9           3.821e+03  2.680e+00  y = sqrt((exp(x₀) * 35.727) / (x₀ - -3.5473)) 10          3.815e+03  1.423e-03  y = round(sqrt((exp(x₀) * 35.727) / (x₀ - -3.5473)))                                                                          11          3.132e+03  1.975e-01  y = (sqrt((exp(x₀) * 35.551) / (x₀ - -3.401)) - x₀)                                                                           12          2.728e+03  1.380e-01  y = (sqrt((exp(x₀) * 35.551) / (x₀ - -3.401)) - abs(35.551))                                                                  13          2.728e+03  2.384e-06  y = (sqrt(round(exp(x₀) * 35.551) / (x₀ - -3.401)) - abs(35.55...                                                                                               1))                                           14          2.630e+03  3.668e-02  y = abs(sqrt((exp(x₀) * 35.551) / (abs(x₀) - -3.401)) - abs(35...                                                                                               .551))                                        15          2.610e+03  7.393e-03  y = (sqrt(abs(exp(abs(round(round(x₀)))) * 35.351) / (x₀ - -3....                                                                                               2415)) + -41.594)                             17          2.610e+03  5.472e-05  y = (sqrt((abs(exp(abs(round(round(x₀)))) * 35.351) + x₀) / (x...                                                                                               ₀ - -3.2415)) + -41.594)                      18          2.560e+03  1.939e-02  y = ((sqrt((((exp(x₀) - x₀) + -1.1039) * abs(35.388)) / (x₀ - ...                                                                                               -3.2674)) - x₀) - x₀)                         19          2.560e+03  7.999e-05  y = ((sqrt((((exp(x₀) - log(x₀)) + -1.1039) * abs(35.388)) / (...                                                                                               x₀ - -3.2674)) - x₀) - x₀)                    ---------------------------------------------------------------------------------------------------
# 96.3%┣█████████████████████████████████████████▍ ┫ 578/600 [00:07<00:00, 83it/s]Expressions evaluated per second: 2.14e+05. Head worker occupation: 22.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           5.000e+09  1.594e+01  y = 32735                                     3           8.330e+07  2.047e+00  y = sqrt(exp(x₀))                             4           8.330e+07  5.364e-07  y = round(sqrt(exp(x₀)))                      5           2.053e+06  3.703e+00  y = sqrt(exp(x₀ - -0.2459))                   6           2.053e+06  1.342e-04  y = round(sqrt(exp(x₀ - -0.2459)))            7           5.578e+04  3.606e+00  y = sqrt((exp(x₀) * 31.183) / x₀)             8           5.574e+04  6.393e-04  y = round(sqrt((exp(x₀) * 31.183) / x₀))      9           3.821e+03  2.680e+00  y = sqrt((exp(x₀) * 35.727) / (x₀ - -3.5473)) 10          3.815e+03  1.423e-03  y = round(sqrt((exp(x₀) * 35.727) / (x₀ - -3.5473)))                                                                          11          3.132e+03  1.975e-01  y = (sqrt((exp(x₀) * 35.551) / (x₀ - -3.401)) - x₀)                                                                           12          2.728e+03  1.380e-01  y = (sqrt((exp(x₀) * 35.551) / (x₀ - -3.401)) - abs(35.551))                                                                  13          2.630e+03  3.668e-02  y = abs(sqrt((exp(x₀) * 35.551) / (x₀ - -3.401)) - abs(35.551)...                                                                                               )                                             15          2.610e+03  3.697e-03  y = (sqrt(abs(exp(abs(round(round(x₀)))) * 35.351) / (x₀ - -3....                                                                                               2415)) + -41.594)                             17          2.610e+03  5.472e-05  y = (sqrt((abs(exp(abs(round(round(x₀)))) * 35.351) + x₀) / (x...                                                                                               ₀ - -3.2415)) + -41.594)                      18          2.560e+03  1.939e-02  y = ((sqrt((((exp(x₀) - x₀) + -1.1039) * abs(35.388)) / (x₀ - ...                                                                                               -3.2674)) - x₀) - x₀)                         19          2.560e+03  7.999e-05  y = ((sqrt((((exp(x₀) - log(x₀)) + -1.1039) * abs(35.388)) / (...                                                                                               x₀ - -3.2674)) - x₀) - x₀)                    ---------------------------------------------------------------------------------------------------
# 97.3%┣█████████████████████████████████████████▉ ┫ 584/600 [00:07<00:00, 83it/s]Expressions evaluated per second: 2.14e+05. Head worker occupation: 22.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           5.000e+09  1.594e+01  y = 32735                                     3           8.330e+07  2.047e+00  y = sqrt(exp(x₀))                             4           8.330e+07  5.364e-07  y = round(sqrt(exp(x₀)))                      5           2.053e+06  3.703e+00  y = sqrt(exp(x₀ - -0.2459))                   6           2.053e+06  1.342e-04  y = round(sqrt(exp(x₀ - -0.2459)))            7           5.578e+04  3.606e+00  y = sqrt((exp(x₀) * 31.183) / x₀)             8           5.574e+04  6.393e-04  y = round(sqrt((exp(x₀) * 31.183) / x₀))      9           3.821e+03  2.680e+00  y = sqrt((exp(x₀) * 35.727) / (x₀ - -3.5473)) 10          3.815e+03  1.423e-03  y = round(sqrt((exp(x₀) * 35.727) / (x₀ - -3.5473)))                                                                          11          3.132e+03  1.975e-01  y = (sqrt((exp(x₀) * 35.551) / (x₀ - -3.401)) - x₀)                                                                           12          2.728e+03  1.380e-01  y = (sqrt((exp(x₀) * 35.551) / (x₀ - -3.401)) - abs(35.551))                                                                  13          2.630e+03  3.668e-02  y = abs(sqrt((exp(x₀) * 35.551) / (x₀ - -3.401)) - abs(35.551)...                                                                                               )                                             15          2.610e+03  3.697e-03  y = (sqrt(abs(exp(abs(round(round(x₀)))) * 35.351) / (x₀ - -3....                                                                                               2415)) + -41.594)                             17          2.610e+03  5.472e-05  y = (sqrt((abs(exp(abs(round(round(x₀)))) * 35.351) + x₀) / (x...                                                                                               ₀ - -3.2415)) + -41.594)                      18          2.560e+03  1.939e-02  y = ((sqrt((((exp(x₀) - x₀) + -1.1039) * abs(35.388)) / (x₀ - ...                                                                                               -3.2674)) - x₀) - x₀)                         19          2.560e+03  7.999e-05  y = ((sqrt((((exp(x₀) - log(x₀)) + -1.1039) * abs(35.388)) / (...                                                                                               x₀ - -3.2674)) - x₀) - x₀)                    ---------------------------------------------------------------------------------------------------
# 98.3%┣██████████████████████████████████████████▎┫ 590/600 [00:07<00:00, 83it/s]Expressions evaluated per second: 2.14e+05. Head worker occupation: 22.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           5.000e+09  1.594e+01  y = 32735                                     3           8.330e+07  2.047e+00  y = sqrt(exp(x₀))                             4           8.330e+07  5.364e-07  y = round(sqrt(exp(x₀)))                      5           2.053e+06  3.703e+00  y = sqrt(exp(x₀ - -0.2459))                   6           2.053e+06  1.342e-04  y = round(sqrt(exp(x₀ - -0.2459)))            7           5.578e+04  3.606e+00  y = sqrt((exp(x₀) * 31.183) / x₀)             8           5.574e+04  6.393e-04  y = round(sqrt((exp(x₀) * 31.183) / x₀))      9           3.821e+03  2.680e+00  y = sqrt((exp(x₀) * 35.727) / (x₀ - -3.5473)) 10          3.815e+03  1.423e-03  y = round(sqrt((exp(x₀) * 35.727) / (x₀ - -3.5473)))                                                                          11          3.132e+03  1.975e-01  y = (sqrt((exp(x₀) * 35.551) / (x₀ - -3.401)) - x₀)                                                                           12          2.728e+03  1.380e-01  y = (sqrt((exp(x₀) * 35.551) / (x₀ - -3.401)) - abs(35.551))                                                                  13          2.630e+03  3.668e-02  y = abs(sqrt((exp(x₀) * 35.551) / (x₀ - -3.401)) - abs(35.551)...                                                                                               )                                             15          2.610e+03  3.697e-03  y = (sqrt(abs(exp(abs(round(round(x₀)))) * 35.351) / (x₀ - -3....                                                                                               2415)) + -41.594)                             17          2.610e+03  5.472e-05  y = (sqrt((abs(exp(abs(round(round(x₀)))) * 35.351) + x₀) / (x...                                                                                               ₀ - -3.2415)) + -41.594)                      18          2.465e+03  5.718e-02  y = abs(sqrt((abs(exp(abs(round(round(x₀)))) * 35.351) + x₀) /...                                                                                                (x₀ - -3.2415)) + -41.594)                   ---------------------------------------------------------------------------------------------------
# 99.3%┣██████████████████████████████████████████▊┫ 596/600 [00:07<00:00, 83it/s]Expressions evaluated per second: 2.14e+05. Head worker occupation: 22.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           5.000e+09  1.594e+01  y = 32735                                     3           8.330e+07  2.047e+00  y = sqrt(exp(x₀))                             4           8.330e+07  5.364e-07  y = round(sqrt(exp(x₀)))                      5           2.053e+06  3.703e+00  y = sqrt(exp(x₀ - -0.2459))                   6           2.053e+06  1.342e-04  y = round(sqrt(exp(x₀ - -0.2459)))            7           5.578e+04  3.606e+00  y = sqrt((exp(x₀) * 31.183) / x₀)             8           5.572e+04  1.090e-03  y = round(sqrt((exp(x₀) * 31.182) / x₀))      9           3.821e+03  2.680e+00  y = sqrt((exp(x₀) * 35.727) / (x₀ - -3.5473)) 10          3.815e+03  1.423e-03  y = round(sqrt((exp(x₀) * 35.727) / (x₀ - -3.5473)))                                                                          11          3.132e+03  1.975e-01  y = (sqrt((exp(x₀) * 35.551) / (x₀ - -3.401)) - x₀)                                                                           12          2.728e+03  1.380e-01  y = (sqrt((exp(x₀) * 35.551) / (x₀ - -3.401)) - abs(35.551))                                                                  13          2.630e+03  3.668e-02  y = abs(sqrt((exp(x₀) * 35.551) / (x₀ - -3.401)) - abs(35.551)...                                                                                               )                                             15          2.610e+03  3.697e-03  y = (sqrt(abs(exp(abs(round(round(x₀)))) * 35.351) / (x₀ - -3....                                                                                               2415)) + -41.594)                             17          2.610e+03  5.472e-05  y = (sqrt((abs(exp(abs(round(round(x₀)))) * 35.351) + x₀) / (x...                                                                                               ₀ - -3.2415)) + -41.594)                      18          2.465e+03  5.718e-02  y = abs(sqrt((abs(exp(abs(round(round(x₀)))) * 35.351) + x₀) /...                                                                                                (x₀ - -3.2415)) + -41.594)                   ---------------------------------------------------------------------------------------------------

# %%
registros_ = registros
file_pickle = 'dados_v3.pck'

# %%
for i in registros_:
  loss = i[1]
  score = i[2]
  complexity = i[0]
  w = (loss * score)/complexity
  if math.isnan(w):
    i.append(0)
  else:
    i.append(w)

lista_melhor_valor = max(registros_, key=lambda x: x[6])

# %% [markdown]
# ## Save result

# %%
def salvar_dados(dados, key, arquivo):
  if os.path.exists(arquivo):
    with open(arquivo, 'rb') as f:
      dados_exist = pickle.load(f)
  else:
    dados_exist = {}

  valor_original = dados_exist.get(key)
  if valor_original == None:
    dados_exist.update({key: [dados]})
  else:
    if isinstance(valor_original, list):
      valor_original.append(dados)
    else:
      dados_exist.update({key: [dados]})

  with open(arquivo, 'wb') as f:
    pickle.dump(dados_exist, f)

caminho_arquivo = file_pickle
novos_dados = lista_melhor_valor[0:3] + [lista_melhor_valor[4]]

salvar_dados(novos_dados, 'fibonacci_recursive_2^N', caminho_arquivo)

# %%
def carregar_dados(arquivo):
    # Carrega os dados do arquivo pickle
    with open(arquivo, 'rb') as f:
        dados = pickle.load(f)
    return dados

caminho_arquivo = file_pickle
dados_carregados = carregar_dados(caminho_arquivo)

print("Conteúdo do arquivo pickle:")
for k, v in dados_carregados.items():
  if k == 'fibonacci_recursive_2^N':
    print('\u25CF', k)
    for index, item in enumerate(v):
      if index == len(v)-1:
        print('└─', item)
      else:
        print('├─', item)
    print('==========================')
# Out:
# Conteúdo do arquivo pickle:
# ● binary_search_logx
# ├─ [5, 1.2686663, 2.221314141492738, 10.9540097681169*x0**(1/4)]
# ├─ [5, 1.2686663, 2.221314226989192, 10.953988*x0**(1/4)]
# ├─ [5, 1.2686664, 2.221314062669807, 10.9540015519444*x0**(1/4)]
# ├─ [5, 1.2686663, 2.221314141492738, 10.9539924228566*x0**(1/4)]
# ├─ [5, 1.529159, 1.8543049601950847, log(x0)**2 + 13.966406]
# ├─ [6, 1.2914093, 1.37589542429269, log(x0**6) + 5.574101]
# ├─ [6, 1.2914089, 2.2426865508550637, log(263.542115096131*x0**6)]
# ├─ [5, 1.529159, 2.1947966974644983, log(x0)**2 + 13.966284]
# ├─ [6, 1.1680324, 1.0235737900855137, 5.549138*log(x0) + 6.9403343]
# ├─ [6, 1.1680324, 1.0235737900855137, log(x0**5.54914) + 6.9403296]
# ├─ [6, 1.1680324, 1.0235737285617819, log(x0**5.5494156) + 6.939477]
# ├─ [6, 1.1680325, 1.023573642947722, 5.5491385*log(x0) + 6.9403334]
# ├─ [5, 1.2575216, 0.6898708588950153, 10.73528*x0**0.25614613]
# ├─ [5, 1.2573884, 0.6898973409560284, 10.721785*x0**0.25653192]
# ├─ [5, 1.2574341, 0.6898882548276822, 10.728042*x0**0.25637504]
# ├─ [5, 1.5291592, 1.926918133635409, log(x0)**2 + 13.966279]
# ├─ [6, 1.2914094, 1.7561717269086738, log(263.534084566108*x0**6)]
# ├─ [5, 1.529159, 0.9995292924809458, log(x0)**2 + 13.96628]
# ├─ [5, 1.5291587, 2.0927697036128956, log(x0)**2 + 13.966388]
# ├─ [5, 1.2686663, 2.221314226989192, 10.953958*x0**(1/4)]
# ├─ [5, 1.268667, 2.221313931718125, 10.953733947166*x0**(1/4)]
# ├─ [6, 1.2914094, 1.3637020620294669, log(263.483322383443*x0**6)]
# └─ [6, 1.2914089, 2.5034278126835927, log(263.542115096131*x0**6)]
# ==========================
# ● boyer_moore_M_plus_N
# ├─ [5, 41023510000.0, 0.4794504369070467, 8175646.5 - 142375.69*x0]
# ├─ [4, 94650974000.0, 0.0881588594086032, x1**3 - 259378.23]
# ├─ [12, 3321374200.0, 0.9673029464629557, -470330.78 + 90396593.4757658/ceiling(0.084435575*x1 - 0.5)**2]
# └─ [6, 45754343000.0, 0.2338013971269299, -x1**3 + 100798770.0/x0]
# ==========================
# ● bubblesort_N^2
# ├─ [4, 8852.063, 3.0590604362839233, 1.50680191334596*x0**2]
# ├─ [4, 5128.0835, 3.642640187153609, 1.52424506145024*x0**2]
# └─ [4, 4277.703, 3.8711305169312804, 1.52647621087573*x0**2]
# ==========================
# ● fibonacci_interative_N
# ├─ [5, 0.0, inf, 2*x0 + 1.0]
# └─ [5, 0.0, inf, 2*x0 + 1.0]
# ==========================
# ● fibonacci_recursive_2^N
# ├─ [16, 5633.222, 0.7489516929694855, -x0**2 + 5.77206533798804*sqrt(exp(x0)/(x0 + 1.53713216928298))]
# ├─ [11, 6370.929, 2.083940911486501, -x0**2 + 5.59942934419901*sqrt(exp(x0)/x0)]
# ├─ [18, 2378.4333, 0.8539930488788458, -x0**2 + 5.72978128794491*sqrt(exp(x0)/(x0 + 1.1332979)) + 1]
# ├─ [9, 3823.7625, 2.6795446366214595, 5.97979263854525*sqrt(exp(x0)/(x0 + 3.5690694))]
# ├─ [17, 62390.31, 0.6809550097211553, 1.33379368719454*sqrt(x0**2 - x0 + 0.562111777500869*ceiling(31.1176120643231*exp(x0) + 22.4592276509109)/x0)]
# └─ [9, 4003.084, 2.6338235569876463, 5.95223690901148*sqrt(exp(x0)/(x0 + 3.3130178))]
# ==========================
