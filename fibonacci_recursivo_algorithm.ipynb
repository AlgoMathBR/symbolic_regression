# %%
# https://www.geeksforgeeks.org/python-program-to-print-the-fibonacci-sequence/?ref=header_search

import numpy as np
from line_profiler import LineProfiler
from pysr import PySRRegressor
import os
import sys
import math
import pickle

# %% [markdown]
# ## Fibonacci Recursive Algorithm

# %%
def fibonacci_recursive(n): # 2^N
  if n == 1 or n == 2:
    return 1
  else:
    return fibonacci_recursive(n-1) + fibonacci_recursive(n-2)

# %% [markdown]
# ## Frequency Count Method

# %%
X_y = []
i=25
for n in range(2,i+1):
  lprofiler = LineProfiler()
  lp_wrapper = lprofiler(fibonacci_recursive)

  lp_wrapper(n)

  stats = lprofiler.get_stats()
  line_numbers = []
  hits = []

  for line in stats.timings.values():
    for i in line:
      line_numbers.append(i[0])
      hits.append(i[1])

  X_y.append([n, sum(hits)])

dados = np.array(X_y)

X = dados[:, 0]
y = dados[:, 1]
X_reshaped = X.reshape(-1, 1)

# %%
resultados_com_menor_loss = []
repeat = 5
registros = []
unary_operators_list = ["log", "square", "cube", "sqrt", "round", "exp", "abs"]

original_stdout = sys.stdout

with open(os.devnull, 'w') as devnull:
  sys.stdout = devnull

  for i in range(repeat):

    # first combination
    reg1 = PySRRegressor(
      binary_operators=["*", "+"],
      unary_operators=unary_operators_list
    )

    fit1 = reg1.fit(X_reshaped, y)
    best_program1 = fit1.get_best()

    registro1 = []
    for index, value in enumerate(best_program1):
      registro1.append(value)
      
    registros.append(registro1)

    # second combination
    reg2 = PySRRegressor(
      binary_operators=["*"],
      unary_operators=unary_operators_list
    )

    fit2 = reg2.fit(X_reshaped, y)
    best_program2 = fit2.get_best()

    registro2 = []
    for index, value in enumerate(best_program2):
      registro2.append(value)
    registros.append(registro2)

    # third combinarion
    reg3 = PySRRegressor(
      binary_operators=["+"],
      unary_operators=unary_operators_list
    )

    fit3 = reg3.fit(X_reshaped, y)
    best_program3 = fit3.get_best()

    registro3 = []
    for index, value in enumerate(best_program3):
      registro3.append(value)
    registros.append(registro3)
    
sys.stdout = original_stdout
# Out:
# [ Info: Started!
# 0.0%┣                                              ┫ 0/600 [00:00<00:-6, -0s/it]Expressions evaluated per second: [.....]. Head worker occupation: 0.0%         Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.070e+09  1.594e+01  y = x₀                                        3           6.036e+09  2.846e-03  y = (x₀ * x₀)                                 5           5.258e+09  6.896e-02  y = (x₀ * (x₀ * x₀))                          7           4.528e+09  7.478e-02  y = (x₀ * ((x₀ + x₀) * x₀))                   9           2.981e+09  2.090e-01  y = ((x₀ + x₀) * (2.34 * (x₀ * x₀)))          11          2.439e+09  1.004e-01  y = ((x₀ + (x₀ + x₀)) * ((x₀ + x₀) * x₀))     13          1.893e+09  1.265e-01  y = ((x₀ + ((x₀ + x₀) + x₀)) * ((x₀ + x₀) * x₀))                                                                              15          1.681e+09  5.941e-02  y = ((x₀ + (((x₀ + x₀) + x₀) + x₀)) * ((x₀ + x₀) * x₀))                                                                       17          7.185e+08  4.251e-01  y = ((x₀ + ((((x₀ * 16.375) + x₀) + x₀) + -310.96)) * ((x₀ + x...                                                                                               ₀) * x₀))                                     ---------------------------------------------------------------------------------------------------
# 1.2%┣▌                                             ┫ 7/600 [00:00<00:08, 75it/s]Expressions evaluated per second: [.....]. Head worker occupation: 18.5%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.070e+09  1.594e+01  y = x₀                                        3           6.036e+09  2.846e-03  y = (x₀ * x₀)                                 5           5.258e+09  6.896e-02  y = (x₀ * (x₀ * x₀))                          7           4.528e+09  7.478e-02  y = (x₀ * ((x₀ + x₀) * x₀))                   9           2.447e+09  3.077e-01  y = ((((x₀ * 198.97) + x₀) + x₀) * x₀)        11          1.893e+09  1.281e-01  y = (((x₀ + x₀) * (x₀ + x₀)) * (x₀ + x₀))     13          1.678e+09  6.034e-02  y = ((((((x₀ + x₀) * 1.1262) * 1.303) * x₀) * 3.5008) * x₀)                                                                   15          1.129e+09  1.982e-01  y = ((((x₀ + x₀) * x₀) * (((x₀ * -1.7575) + x₀) + x₀)) * x₀)                                                                  17          7.185e+08  2.260e-01  y = ((x₀ + ((((x₀ * 16.375) + x₀) + x₀) + -310.96)) * ((x₀ + x...                                                                                               ₀) * x₀))                                     ---------------------------------------------------------------------------------------------------
# 1.7%┣▊                                            ┫ 10/600 [00:00<00:09, 64it/s]Expressions evaluated per second: [.....]. Head worker occupation: 10.0%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.070e+09  1.594e+01  y = x₀                                        3           6.036e+09  2.846e-03  y = (x₀ * x₀)                                 5           5.258e+09  6.896e-02  y = (x₀ * (x₀ * x₀))                          7           4.528e+09  7.478e-02  y = (x₀ * ((x₀ + x₀) * x₀))                   9           2.447e+09  3.077e-01  y = ((((x₀ * 198.97) + x₀) + x₀) * x₀)        11          1.893e+09  1.281e-01  y = (((x₀ + x₀) * (x₀ + x₀)) * (x₀ + x₀))     13          1.247e+09  2.087e-01  y = (((x₀ * (x₀ * 0.14727)) * (x₀ * (x₀ + x₀))) * 1.3918)                                                                     15          1.129e+09  4.986e-02  y = ((((x₀ + x₀) * x₀) * (((x₀ * -1.7575) + x₀) + x₀)) * x₀)                                                                  17          7.185e+08  2.260e-01  y = ((x₀ + ((((x₀ * 16.375) + x₀) + x₀) + -310.96)) * ((x₀ + x...                                                                                               ₀) * x₀))                                     ---------------------------------------------------------------------------------------------------
# 2.8%┣█▎                                           ┫ 17/600 [00:00<00:07, 79it/s]Expressions evaluated per second: [.....]. Head worker occupation: 15.3%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.070e+09  1.594e+01  y = x₀                                        3           6.036e+09  2.846e-03  y = (x₀ * x₀)                                 5           2.447e+09  4.514e-01  y = ((x₀ * 198.97) * x₀)                      9           1.217e+09  1.746e-01  y = (x₀ * ((x₀ * (x₀ * x₀)) * 0.54984))       11          1.059e+09  6.945e-02  y = ((x₀ + -2.9265) * ((x₀ * (x₀ * x₀)) * 0.54984))                                                                           13          4.830e+08  3.927e-01  y = ((((x₀ * -319.1) + ((x₀ * x₀) * x₀)) + 1147.6) * x₀)                                                                      ---------------------------------------------------------------------------------------------------
# 3.8%┣█▊                                           ┫ 23/600 [00:00<00:07, 82it/s]Expressions evaluated per second: [.....]. Head worker occupation: 14.7%        Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.070e+09  1.594e+01  y = x₀                                        3           6.036e+09  2.846e-03  y = (x₀ * x₀)                                 5           2.447e+09  4.514e-01  y = ((x₀ * 198.97) * x₀)                      7           2.447e+09  7.496e-05  y = (((x₀ + x₀) * x₀) * 100.48)               9           1.217e+09  3.490e-01  y = (x₀ * ((x₀ * (x₀ * x₀)) * 0.54984))       11          1.059e+09  6.945e-02  y = ((x₀ + -2.9265) * ((x₀ * (x₀ * x₀)) * 0.54984))                                                                           13          4.830e+08  3.927e-01  y = ((((x₀ * -319.1) + ((x₀ * x₀) * x₀)) + 1147.6) * x₀)                                                                      ---------------------------------------------------------------------------------------------------
# 5.0%┣██▎                                          ┫ 30/600 [00:00<00:06, 89it/s]Expressions evaluated per second: [.....]. Head worker occupation: 20.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.070e+09  1.594e+01  y = x₀                                        3           3.526e+09  2.716e-01  y = (3325.5 * x₀)                             5           2.447e+09  1.827e-01  y = ((x₀ * 198.97) * x₀)                      7           1.678e+09  1.886e-01  y = (x₀ * ((x₀ * x₀) * 10.274))               9           1.129e+09  1.982e-01  y = (x₀ * ((x₀ * (x₀ * x₀)) * 0.48505))       11          6.885e+08  2.473e-01  y = (x₀ * (((x₀ * (x₀ * x₀)) * 0.73651) + -2772.4))                                                                           13          4.830e+08  1.772e-01  y = ((((x₀ * -319.1) + ((x₀ * x₀) * x₀)) + 1147.6) * x₀)                                                                      ---------------------------------------------------------------------------------------------------
# 6.0%┣██▊                                          ┫ 36/600 [00:00<00:06, 90it/s]Expressions evaluated per second: [.....]. Head worker occupation: 20.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           6.059e+09  1.594e+01  y = 198.97                                    3           3.526e+09  2.706e-01  y = (3325.5 * x₀)                             5           2.447e+09  1.828e-01  y = ((x₀ * x₀) * 200.99)                      7           1.678e+09  1.885e-01  y = (x₀ * ((x₀ * x₀) * 10.274))               9           1.010e+09  2.537e-01  y = ((((x₀ * x₀) * 19.472) + -4266.2) * x₀)   11          6.885e+08  1.918e-01  y = (x₀ * (((x₀ * (x₀ * x₀)) * 0.73651) + -2772.4))                                                                           13          4.830e+08  1.772e-01  y = ((((x₀ * -319.1) + ((x₀ * x₀) * x₀)) + 1147.6) * x₀)                                                                      ---------------------------------------------------------------------------------------------------
# 7.0%┣███▏                                         ┫ 42/600 [00:00<00:06, 92it/s]Expressions evaluated per second: [.....]. Head worker occupation: 21.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           5.000e+09  1.594e+01  y = 32734                                     3           3.526e+09  1.746e-01  y = (3325.5 * x₀)                             5           2.447e+09  1.828e-01  y = ((x₀ * x₀) * 200.99)                      7           1.678e+09  1.885e-01  y = (x₀ * ((x₀ * x₀) * 10.274))               9           1.010e+09  2.537e-01  y = ((((x₀ * x₀) * 19.472) + -4266.2) * x₀)   11          6.885e+08  1.918e-01  y = (x₀ * (((x₀ * (x₀ * x₀)) * 0.73651) + -2772.4))                                                                           13          4.830e+08  1.772e-01  y = ((((x₀ * -319.1) + ((x₀ * x₀) * x₀)) + 1147.6) * x₀)                                                                      ---------------------------------------------------------------------------------------------------
# 8.0%┣███▋                                         ┫ 48/600 [00:01<00:06, 93it/s]Expressions evaluated per second: [.....]. Head worker occupation: 20.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           5.000e+09  1.594e+01  y = 32734                                     3           3.526e+09  1.746e-01  y = (3325.5 * x₀)                             5           2.447e+09  1.828e-01  y = ((x₀ * x₀) * 200.99)                      7           1.456e+09  2.596e-01  y = (x₀ * ((x₀ * 608.94) + -8318.1))          9           1.010e+09  1.825e-01  y = ((((x₀ * x₀) * 19.472) + -4266.2) * x₀)   11          6.885e+08  1.918e-01  y = (x₀ * (((x₀ * (x₀ * x₀)) * 0.73651) + -2772.4))                                                                           13          4.830e+08  1.772e-01  y = ((((x₀ * -319.1) + ((x₀ * x₀) * x₀)) + 1147.6) * x₀)                                                                      ---------------------------------------------------------------------------------------------------
# 8.8%┣████                                         ┫ 53/600 [00:01<00:06, 92it/s]Expressions evaluated per second: [.....]. Head worker occupation: 26.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           5.000e+09  1.594e+01  y = 32734                                     3           3.526e+09  1.746e-01  y = (3325.5 * x₀)                             5           2.447e+09  1.828e-01  y = ((x₀ * x₀) * 200.99)                      7           1.456e+09  2.596e-01  y = (x₀ * ((x₀ * 608.94) + -8318.1))          9           1.010e+09  1.825e-01  y = ((((x₀ * x₀) * 19.472) + -4266.2) * x₀)   11          6.885e+08  1.918e-01  y = (x₀ * (((x₀ * (x₀ * x₀)) * 0.73651) + -2772.4))                                                                           13          4.830e+08  1.772e-01  y = ((((x₀ * -319.1) + ((x₀ * x₀) * x₀)) + 1147.6) * x₀)                                                                      ---------------------------------------------------------------------------------------------------
# 9.8%┣████▍                                        ┫ 59/600 [00:01<00:06, 92it/s]Expressions evaluated per second: [.....]. Head worker occupation: 28.3%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           5.000e+09  1.594e+01  y = 32734                                     3           3.526e+09  1.746e-01  y = (3325.5 * x₀)                             5           2.447e+09  1.828e-01  y = ((x₀ * x₀) * 200.99)                      7           1.456e+09  2.596e-01  y = (x₀ * ((x₀ * 608.94) + -8318.1))          9           1.010e+09  1.825e-01  y = ((((x₀ * x₀) * 19.472) + -4266.2) * x₀)   11          6.885e+08  1.918e-01  y = (x₀ * (((x₀ * (x₀ * x₀)) * 0.73651) + -2772.4))                                                                           13          4.830e+08  1.772e-01  y = ((((x₀ * -319.1) + ((x₀ * x₀) * x₀)) + 1147.6) * x₀)                                                                      ---------------------------------------------------------------------------------------------------
# 10.7%┣████▊                                       ┫ 64/600 [00:01<00:06, 92it/s]Expressions evaluated per second: [.....]. Head worker occupation: 27.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           5.000e+09  1.594e+01  y = 32734                                     3           3.526e+09  1.746e-01  y = (3325.5 * x₀)                             5           2.447e+09  1.828e-01  y = ((x₀ * x₀) * 200.99)                      7           1.456e+09  2.596e-01  y = (x₀ * ((x₀ * 608.94) + -8318.1))          9           1.010e+09  1.825e-01  y = ((((x₀ * x₀) * 19.472) + -4266.2) * x₀)   11          6.885e+08  1.918e-01  y = (x₀ * (((x₀ * (x₀ * x₀)) * 0.73651) + -2772.4))                                                                           13          4.830e+08  1.772e-01  y = ((((x₀ * -319.1) + ((x₀ * x₀) * x₀)) + 1147.6) * x₀)                                                                      17          4.825e+08  2.793e-04  y = (((((x₀ * -319.1) + (((x₀ + 0.093899) * x₀) * x₀)) + 1147....                                                                                               6) * x₀) + x₀)                                19          4.599e+08  2.392e-02  y = ((((((x₀ * -319.1) + ((x₀ * x₀) * x₀)) * 1.0641) + 1147.6)...                                                                                                + (x₀ * -1.6477)) * x₀)                      ---------------------------------------------------------------------------------------------------
# 11.5%┣█████                                       ┫ 69/600 [00:01<00:06, 91it/s]Expressions evaluated per second: [.....]. Head worker occupation: 26.3%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           5.000e+09  1.594e+01  y = 32734                                     3           3.526e+09  1.746e-01  y = (3325.5 * x₀)                             5           2.447e+09  1.828e-01  y = ((x₀ * x₀) * 200.99)                      7           1.456e+09  2.596e-01  y = (x₀ * ((x₀ * 608.94) + -8318.1))          9           1.010e+09  1.825e-01  y = ((((x₀ * x₀) * 19.472) + -4266.2) * x₀)   11          6.885e+08  1.918e-01  y = (x₀ * (((x₀ * (x₀ * x₀)) * 0.73651) + -2772.4))                                                                           13          4.830e+08  1.772e-01  y = ((((x₀ * -319.1) + ((x₀ * x₀) * x₀)) + 1147.6) * x₀)                                                                      17          4.825e+08  2.793e-04  y = (((((x₀ * -319.1) + (((x₀ + 0.093899) * x₀) * x₀)) + 1147....                                                                                               6) * x₀) + x₀)                                19          4.599e+08  2.392e-02  y = ((((((x₀ * -319.1) + ((x₀ * x₀) * x₀)) * 1.0641) + 1147.6)...                                                                                                + (x₀ * -1.6477)) * x₀)                      ---------------------------------------------------------------------------------------------------
# 12.5%┣█████▌                                      ┫ 75/600 [00:01<00:06, 91it/s]Expressions evaluated per second: [.....]. Head worker occupation: 26.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           5.000e+09  1.594e+01  y = 32734                                     3           3.526e+09  1.746e-01  y = (3325.5 * x₀)                             5           2.447e+09  1.828e-01  y = ((x₀ * x₀) * 200.99)                      7           1.456e+09  2.596e-01  y = (x₀ * ((x₀ * 608.94) + -8318.1))          9           1.010e+09  1.825e-01  y = ((((x₀ * x₀) * 19.472) + -4266.2) * x₀)   11          6.885e+08  1.918e-01  y = (x₀ * (((x₀ * (x₀ * x₀)) * 0.73651) + -2772.4))                                                                           13          4.830e+08  1.772e-01  y = ((((x₀ * -319.1) + ((x₀ * x₀) * x₀)) + 1147.6) * x₀)                                                                      15          4.830e+08  8.345e-07  y = (((((x₀ * -319.1) + ((x₀ * x₀) * x₀)) + 1147.6) * x₀) + 0....                                                                                               41413)                                        17          4.824e+08  5.747e-04  y = (((((x₀ * -319.1) + (((x₀ + 0.093221) * x₀) * x₀)) + 1147....                                                                                               6) * x₀) + 0.41413)                           19          4.599e+08  2.390e-02  y = ((((((x₀ * -319.1) + ((x₀ * x₀) * x₀)) * 1.0641) + 1147.6)...                                                                                                + (x₀ * -1.6477)) * x₀)                      ---------------------------------------------------------------------------------------------------
# 13.5%┣██████                                      ┫ 81/600 [00:01<00:06, 92it/s]Expressions evaluated per second: [.....]. Head worker occupation: 26.2%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           5.000e+09  1.594e+01  y = 32734                                     3           3.526e+09  1.746e-01  y = (3325.5 * x₀)                             5           2.447e+09  1.828e-01  y = ((x₀ * x₀) * 200.99)                      7           1.456e+09  2.596e-01  y = (x₀ * ((x₀ * 608.94) + -8318.1))          9           1.010e+09  1.825e-01  y = ((((x₀ * x₀) * 19.472) + -4266.2) * x₀)   11          6.885e+08  1.918e-01  y = (x₀ * (((x₀ * (x₀ * x₀)) * 0.73651) + -2772.4))                                                                           13          4.830e+08  1.772e-01  y = ((((x₀ * -319.1) + ((x₀ * x₀) * x₀)) + 1147.6) * x₀)                                                                      15          4.824e+08  5.763e-04  y = ((((x₀ * -319.1) + (((x₀ + 0.093899) * x₀) * x₀)) + 1147.6...                                                                                               ) * x₀)                                       17          4.809e+08  1.610e-03  y = ((((x₀ + -6.6278) * -402.37) + (((x₀ * x₀) * x₀) + x₀)) * ...                                                                                               (x₀ * 1.2075))                                19          4.599e+08  2.229e-02  y = ((((((x₀ * -319.1) + ((x₀ * x₀) * x₀)) * 1.0641) + 1147.6)...                                                                                                + (x₀ * -1.6477)) * x₀)                      ---------------------------------------------------------------------------------------------------
# 14.5%┣██████▍                                     ┫ 87/600 [00:01<00:06, 93it/s]Expressions evaluated per second: [.....]. Head worker occupation: 27.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                                Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           5.000e+09  1.594e+01  y = 32734                                     3           3.526e+09  1.746e-01  y = (3325.5 * x₀)                             5           2.447e+09  1.828e-01  y = ((x₀ * x₀) * 200.99)                      7           1.456e+09  2.596e-01  y = (x₀ * ((x₀ * 608.94) + -8318.1))          9           1.010e+09  1.825e-01  y = ((((x₀ * x₀) * 19.472) + -4266.2) * x₀)   11          6.885e+08  1.918e-01  y = (x₀ * (((x₀ * (x₀ * x₀)) * 0.73651) + -2772.4))                                                                           13          4.830e+08  1.772e-01  y = ((((x₀ * -319.1) + ((x₀ * x₀) * x₀)) + 1147.6) * x₀)                                                                      15          2.171e+08  3.999e-01  y = (((((((x₀ * 3.1334) + -68.843) * x₀) + x₀) * x₀) + 3834.8)...                                                                                                * x₀)                                        ---------------------------------------------------------------------------------------------------
# 15.7%┣███████                                     ┫ 94/600 [00:01<00:06, 92it/s]Expressions evaluated per second: 2.55e+05. Head worker occupation: 26.9%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           5.000e+09  1.594e+01  y = 32734                                     3           3.526e+09  1.746e-01  y = (3325.5 * x₀)                             5           2.447e+09  1.828e-01  y = ((x₀ * x₀) * 200.99)                      7           1.456e+09  2.596e-01  y = (x₀ * ((x₀ * 608.94) + -8318.1))          9           1.010e+09  1.825e-01  y = ((((x₀ * x₀) * 19.472) + -4266.2) * x₀)   11          6.885e+08  1.918e-01  y = (x₀ * (((x₀ * (x₀ * x₀)) * 0.73651) + -2772.4))                                                                           13          4.830e+08  1.772e-01  y = ((((x₀ * -319.1) + ((x₀ * x₀) * x₀)) + 1147.6) * x₀)                                                                      15          2.171e+08  3.999e-01  y = (((((((x₀ * 3.1334) + -68.843) * x₀) + x₀) * x₀) + 3834.8)...                                                                                                * x₀)                                        ---------------------------------------------------------------------------------------------------
# 16.5%┣███████▎                                    ┫ 99/600 [00:01<00:06, 91it/s]Expressions evaluated per second: 2.55e+05. Head worker occupation: 25.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           5.000e+09  1.594e+01  y = 32734                                     3           3.526e+09  1.746e-01  y = (3325.5 * x₀)                             5           2.447e+09  1.828e-01  y = ((x₀ * x₀) * 200.99)                      7           1.456e+09  2.596e-01  y = (x₀ * ((x₀ * 608.94) + -8318.1))          9           6.887e+08  3.742e-01  y = ((((x₀ + -12.021) * x₀) * x₀) * x₀)       11          6.870e+08  1.217e-03  y = ((((x₀ + -12.021) * (x₀ + 1.7691)) * x₀) * x₀)                                                                            13          4.830e+08  1.762e-01  y = ((((x₀ * -319.1) + ((x₀ * x₀) * x₀)) + 1147.6) * x₀)                                                                      15          2.171e+08  3.999e-01  y = (((((((x₀ * 3.1334) + -68.843) * x₀) + x₀) * x₀) + 3834.8)...                                                                                                * x₀)                                        ---------------------------------------------------------------------------------------------------
# 17.3%┣███████▌                                   ┫ 104/600 [00:01<00:05, 91it/s]Expressions evaluated per second: 2.55e+05. Head worker occupation: 26.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           5.000e+09  1.594e+01  y = 32734                                     3           3.526e+09  1.746e-01  y = (3325.5 * x₀)                             5           2.447e+09  1.828e-01  y = ((x₀ * x₀) * 200.99)                      7           1.456e+09  2.596e-01  y = (x₀ * ((x₀ * 608.94) + -8318.1))          9           6.887e+08  3.742e-01  y = ((((x₀ + -12.021) * x₀) * x₀) * x₀)       11          6.870e+08  1.217e-03  y = ((((x₀ + -12.021) * (x₀ + 1.7691)) * x₀) * x₀)                                                                            13          4.830e+08  1.762e-01  y = ((((x₀ * -319.1) + ((x₀ * x₀) * x₀)) + 1147.6) * x₀)                                                                      15          2.170e+08  4.001e-01  y = ((((((x₀ * 3.1329) + -67.819) * x₀) * x₀) + (3807 + x₀)) *...                                                                                                x₀)                                          17          2.170e+08  8.822e-06  y = (((((((x₀ * 3.1333) + -68.854) * x₀) + x₀) * x₀) + (3819.6...                                                                                                + x₀)) * x₀)                                 19          2.098e+08  1.674e-02  y = (((((((x₀ * 3.1334) + -68.843) * x₀) + x₀) * x₀) + (3834.8...                                                                                                + x₀)) * (x₀ + -0.86135))                    ---------------------------------------------------------------------------------------------------
# 18.3%┣███████▉                                   ┫ 110/600 [00:01<00:05, 92it/s]Expressions evaluated per second: 2.55e+05. Head worker occupation: 27.0%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           5.000e+09  1.594e+01  y = 32734                                     3           3.526e+09  1.746e-01  y = (3325.5 * x₀)                             5           2.447e+09  1.828e-01  y = ((x₀ * x₀) * 200.99)                      7           1.456e+09  2.596e-01  y = (x₀ * ((x₀ * 608.94) + -8318.1))          9           6.887e+08  3.742e-01  y = ((((x₀ + -12.021) * x₀) * x₀) * x₀)       11          6.870e+08  1.217e-03  y = ((((x₀ + -12.021) * (x₀ + 1.7691)) * x₀) * x₀)                                                                            13          2.584e+08  4.888e-01  y = ((((((x₀ * 3.1334) + -68.843) * x₀) * x₀) + 3834.8) * x₀)                                                                 15          2.170e+08  8.746e-02  y = ((((((x₀ * 3.1329) + -67.819) * x₀) * x₀) + (3807 + x₀)) *...                                                                                                x₀)                                          17          2.170e+08  8.822e-06  y = (((((((x₀ * 3.1333) + -68.854) * x₀) + x₀) * x₀) + (3819.6...                                                                                                + x₀)) * x₀)                                 19          2.098e+08  1.674e-02  y = (((((((x₀ * 3.1334) + -68.843) * x₀) + x₀) * x₀) + (3834.8...                                                                                                + x₀)) * (x₀ + -0.86135))                    ---------------------------------------------------------------------------------------------------
# 19.7%┣████████▌                                  ┫ 118/600 [00:01<00:05, 92it/s]Expressions evaluated per second: 2.55e+05. Head worker occupation: 26.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           5.000e+09  1.594e+01  y = 32734                                     3           3.526e+09  1.746e-01  y = (3325.5 * x₀)                             5           2.447e+09  1.828e-01  y = ((x₀ * x₀) * 200.99)                      7           1.456e+09  2.596e-01  y = (x₀ * ((x₀ * 608.94) + -8318.1))          9           6.887e+08  3.742e-01  y = ((((x₀ + -12.021) * x₀) * x₀) * x₀)       11          6.870e+08  1.217e-03  y = ((((x₀ + -12.021) * (x₀ + 1.7691)) * x₀) * x₀)                                                                            13          2.584e+08  4.888e-01  y = ((((((x₀ * 3.1334) + -68.843) * x₀) * x₀) + 3834.8) * x₀)                                                                 15          1.055e+08  4.481e-01  y = (((((((x₀ * 0.12773) + -2.6087) * x₀) * x₀) * x₀) + 1827.7...                                                                                               ) * x₀)                                       17          7.695e+07  1.577e-01  y = (((((((x₀ * 0.16562) + -3.9352) * x₀) * x₀) + (292.53 + x₀...                                                                                               )) * x₀) * x₀)                                ---------------------------------------------------------------------------------------------------
# 20.5%┣████████▉                                  ┫ 123/600 [00:01<00:05, 91it/s]Expressions evaluated per second: 2.55e+05. Head worker occupation: 26.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           5.000e+09  1.594e+01  y = 32734                                     3           3.526e+09  1.746e-01  y = (3325.5 * x₀)                             5           2.447e+09  1.828e-01  y = ((x₀ * x₀) * 200.99)                      7           1.456e+09  2.596e-01  y = (x₀ * ((x₀ * 608.94) + -8318.1))          9           6.887e+08  3.742e-01  y = ((((x₀ + -12.021) * x₀) * x₀) * x₀)       11          6.870e+08  1.217e-03  y = ((((x₀ + -12.021) * (x₀ + 1.7691)) * x₀) * x₀)                                                                            13          2.171e+08  5.759e-01  y = ((((((x₀ * 3.1329) + -67.819) * x₀) * x₀) + 3807) * x₀)                                                                   15          1.055e+08  3.610e-01  y = (((((((x₀ * 0.12773) + -2.6087) * x₀) * x₀) * x₀) + 1827.7...                                                                                               ) * x₀)                                       17          7.695e+07  1.577e-01  y = (((((((x₀ * 0.16562) + -3.9352) * x₀) * x₀) + (292.53 + x₀...                                                                                               )) * x₀) * x₀)                                ---------------------------------------------------------------------------------------------------
# 21.3%┣█████████▏                                 ┫ 128/600 [00:01<00:05, 91it/s]Expressions evaluated per second: 2.55e+05. Head worker occupation: 25.5%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           5.000e+09  1.594e+01  y = 32734                                     3           3.526e+09  1.746e-01  y = (3325.5 * x₀)                             5           2.447e+09  1.828e-01  y = ((x₀ * x₀) * 200.99)                      7           1.456e+09  2.596e-01  y = (x₀ * ((x₀ * 608.94) + -8318.1))          9           6.887e+08  3.742e-01  y = ((((x₀ + -12.021) * x₀) * x₀) * x₀)       11          6.571e+08  2.346e-02  y = (((((x₀ + -11.206) * x₀) * x₀) * x₀) + -7684.3)                                                                           13          2.171e+08  5.537e-01  y = ((((((x₀ * 3.1329) + -67.819) * x₀) * x₀) + 3807) * x₀)                                                                   15          1.055e+08  3.610e-01  y = (((((((x₀ * 0.12773) + -2.6087) * x₀) * x₀) * x₀) + 1827.7...                                                                                               ) * x₀)                                       17          7.695e+07  1.577e-01  y = (((((((x₀ * 0.16562) + -3.9352) * x₀) * x₀) + (292.53 + x₀...                                                                                               )) * x₀) * x₀)                                ---------------------------------------------------------------------------------------------------
# 22.3%┣█████████▋                                 ┫ 134/600 [00:01<00:05, 91it/s]Expressions evaluated per second: 2.55e+05. Head worker occupation: 26.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           5.000e+09  1.594e+01  y = 32734                                     3           3.526e+09  1.746e-01  y = (3325.5 * x₀)                             5           2.447e+09  1.828e-01  y = ((x₀ * x₀) * 200.99)                      7           1.456e+09  2.596e-01  y = (x₀ * ((x₀ * 608.94) + -8318.1))          9           6.887e+08  3.742e-01  y = ((((x₀ + -12.021) * x₀) * x₀) * x₀)       11          6.571e+08  2.346e-02  y = (((((x₀ + -11.206) * x₀) * x₀) * x₀) + -7684.3)                                                                           13          2.171e+08  5.537e-01  y = ((((((x₀ * 3.1329) + -67.819) * x₀) * x₀) + 3807) * x₀)                                                                   15          1.055e+08  3.610e-01  y = (((((((x₀ * 0.12773) + -2.6087) * x₀) * x₀) * x₀) + 1827.7...                                                                                               ) * x₀)                                       17          7.695e+07  1.577e-01  y = (((((((x₀ * 0.16562) + -3.9352) * x₀) * x₀) + (292.53 + x₀...                                                                                               )) * x₀) * x₀)                                ---------------------------------------------------------------------------------------------------
# 23.2%┣██████████                                 ┫ 139/600 [00:02<00:05, 91it/s]Expressions evaluated per second: 2.55e+05. Head worker occupation: 27.1%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           5.000e+09  1.594e+01  y = 32734                                     3           3.526e+09  1.746e-01  y = (3325.5 * x₀)                             5           2.447e+09  1.828e-01  y = ((x₀ * x₀) * 200.99)                      7           1.456e+09  2.596e-01  y = (x₀ * ((x₀ * 608.94) + -8318.1))          9           6.887e+08  3.742e-01  y = ((((x₀ + -12.021) * x₀) * x₀) * x₀)       11          5.019e+08  1.582e-01  y = (((x₀ * -262.82) + ((x₀ * x₀) * x₀)) * x₀)                                                                                13          2.171e+08  4.189e-01  y = ((((((x₀ * 3.1329) + -67.819) * x₀) * x₀) + 3807) * x₀)                                                                   15          1.055e+08  3.610e-01  y = (((((((x₀ * 0.12773) + -2.6087) * x₀) * x₀) * x₀) + 1827.7...                                                                                               ) * x₀)                                       17          7.695e+07  1.577e-01  y = (((((((x₀ * 0.16562) + -3.9352) * x₀) * x₀) + (292.53 + x₀...                                                                                               )) * x₀) * x₀)                                ---------------------------------------------------------------------------------------------------
# 23.7%┣██████████▏                                ┫ 142/600 [00:02<00:05, 89it/s]Expressions evaluated per second: 2.55e+05. Head worker occupation: 27.4%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           5.000e+09  1.594e+01  y = 32734                                     3           3.526e+09  1.746e-01  y = (3325.5 * x₀)                             5           2.447e+09  1.828e-01  y = ((x₀ * x₀) * 200.99)                      7           1.456e+09  2.596e-01  y = (x₀ * ((x₀ * 608.94) + -8318.1))          9           6.887e+08  3.742e-01  y = ((((x₀ + -12.021) * x₀) * x₀) * x₀)       11          5.019e+08  1.582e-01  y = (((x₀ * -262.82) + ((x₀ * x₀) * x₀)) * x₀)                                                                                13          2.171e+08  4.189e-01  y = ((((((x₀ * 3.1329) + -67.819) * x₀) * x₀) + 3807) * x₀)                                                                   15          1.055e+08  3.610e-01  y = (((((((x₀ * 0.12773) + -2.6087) * x₀) * x₀) * x₀) + 1827.7...                                                                                               ) * x₀)                                       17          7.695e+07  1.577e-01  y = (((((((x₀ * 0.16562) + -3.9352) * x₀) * x₀) + (292.53 + x₀...                                                                                               )) * x₀) * x₀)                                ---------------------------------------------------------------------------------------------------
# ...
# 92.5%┣███████████████████████████████████████▊   ┫ 555/600 [00:07<00:01, 78it/s]Expressions evaluated per second: 1.76e+05. Head worker occupation: 30.6%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           5.000e+09  1.594e+01  y = 32725                                     3           4.999e+09  6.468e-05  y = (x₀ + 32723)                              5           4.999e+09  6.462e-05  y = ((x₀ + x₀) + 32706)                       7           4.998e+09  6.468e-05  y = (((x₀ + x₀) + 32695) + x₀)                9           4.997e+09  6.459e-05  y = (x₀ + ((x₀ + (32678 + x₀)) + x₀))         11          4.997e+09  6.471e-05  y = ((((x₀ + (x₀ + x₀)) + x₀) + 32667) + x₀)  13          4.996e+09  6.459e-05  y = (((x₀ + x₀) + (((x₀ + x₀) + x₀) + x₀)) + 32647)                                                                           15          4.996e+09  6.462e-05  y = ((((x₀ + ((x₀ + x₀) + (x₀ + x₀))) + x₀) + x₀) + 32628)                                                                    17          4.995e+09  6.468e-05  y = ((x₀ + (((x₀ + x₀) + 32625) + x₀)) + (((x₀ + x₀) + x₀) + x...                                                                                               ₀))                                           19          4.994e+09  6.462e-05  y = ((((x₀ + x₀) + (x₀ + (x₀ + x₀))) + ((x₀ + 32617) + x₀)) + ...                                                                                               (x₀ + x₀))                                    ---------------------------------------------------------------------------------------------------
# 93.5%┣████████████████████████████████████████▏  ┫ 561/600 [00:07<00:01, 78it/s]Expressions evaluated per second: 1.76e+05. Head worker occupation: 30.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           5.000e+09  1.594e+01  y = 32725                                     3           4.999e+09  6.468e-05  y = (x₀ + 32723)                              5           4.999e+09  6.462e-05  y = ((x₀ + x₀) + 32706)                       7           4.998e+09  6.468e-05  y = (((x₀ + x₀) + 32695) + x₀)                9           4.997e+09  6.459e-05  y = (x₀ + ((x₀ + (32678 + x₀)) + x₀))         11          4.997e+09  6.471e-05  y = ((((x₀ + (x₀ + x₀)) + x₀) + 32667) + x₀)  13          4.996e+09  6.459e-05  y = (((x₀ + x₀) + (((x₀ + x₀) + x₀) + x₀)) + 32647)                                                                           15          4.996e+09  6.462e-05  y = ((((x₀ + ((x₀ + x₀) + (x₀ + x₀))) + x₀) + x₀) + 32628)                                                                    17          4.995e+09  6.468e-05  y = ((x₀ + (((x₀ + x₀) + 32625) + x₀)) + (((x₀ + x₀) + x₀) + x...                                                                                               ₀))                                           19          4.994e+09  6.462e-05  y = ((((x₀ + x₀) + (x₀ + (x₀ + x₀))) + ((x₀ + 32617) + x₀)) + ...                                                                                               (x₀ + x₀))                                    ---------------------------------------------------------------------------------------------------
# 95.0%┣████████████████████████████████████████▉  ┫ 570/600 [00:07<00:00, 78it/s]Expressions evaluated per second: 1.76e+05. Head worker occupation: 30.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           5.000e+09  1.594e+01  y = 32725                                     3           4.999e+09  6.468e-05  y = (x₀ + 32723)                              5           4.999e+09  6.462e-05  y = ((x₀ + x₀) + 32706)                       7           4.998e+09  6.468e-05  y = (((x₀ + x₀) + 32695) + x₀)                9           4.997e+09  6.459e-05  y = (x₀ + ((x₀ + (32678 + x₀)) + x₀))         11          4.997e+09  6.471e-05  y = ((((x₀ + (x₀ + x₀)) + x₀) + 32667) + x₀)  13          4.996e+09  6.459e-05  y = (((x₀ + x₀) + (((x₀ + x₀) + x₀) + x₀)) + 32647)                                                                           15          4.996e+09  6.462e-05  y = ((((x₀ + ((x₀ + x₀) + (x₀ + x₀))) + x₀) + x₀) + 32628)                                                                    17          4.995e+09  6.468e-05  y = ((x₀ + (((x₀ + x₀) + 32625) + x₀)) + (((x₀ + x₀) + x₀) + x...                                                                                               ₀))                                           19          4.994e+09  6.462e-05  y = ((((x₀ + x₀) + (x₀ + (x₀ + x₀))) + ((x₀ + 32617) + x₀)) + ...                                                                                               (x₀ + x₀))                                    ---------------------------------------------------------------------------------------------------
# 96.0%┣█████████████████████████████████████████▎ ┫ 576/600 [00:07<00:00, 78it/s]Expressions evaluated per second: 1.76e+05. Head worker occupation: 30.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           5.000e+09  1.594e+01  y = 32725                                     3           4.999e+09  6.468e-05  y = (x₀ + 32723)                              5           4.999e+09  6.462e-05  y = ((x₀ + x₀) + 32706)                       7           4.998e+09  6.468e-05  y = (((x₀ + x₀) + 32695) + x₀)                9           4.997e+09  6.459e-05  y = (x₀ + ((x₀ + (32678 + x₀)) + x₀))         11          4.997e+09  6.471e-05  y = ((((x₀ + (x₀ + x₀)) + x₀) + 32667) + x₀)  13          4.996e+09  6.459e-05  y = (((x₀ + x₀) + (((x₀ + x₀) + x₀) + x₀)) + 32647)                                                                           15          4.996e+09  6.462e-05  y = ((((x₀ + ((x₀ + x₀) + (x₀ + x₀))) + x₀) + x₀) + 32628)                                                                    17          4.995e+09  6.468e-05  y = ((x₀ + (((x₀ + x₀) + 32625) + x₀)) + (((x₀ + x₀) + x₀) + x...                                                                                               ₀))                                           19          4.994e+09  6.462e-05  y = ((((x₀ + x₀) + (x₀ + (x₀ + x₀))) + ((x₀ + 32617) + x₀)) + ...                                                                                               (x₀ + x₀))                                    ---------------------------------------------------------------------------------------------------
# 96.8%┣█████████████████████████████████████████▋ ┫ 581/600 [00:07<00:00, 78it/s]Expressions evaluated per second: 1.76e+05. Head worker occupation: 30.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           5.000e+09  1.594e+01  y = 32725                                     3           4.999e+09  6.468e-05  y = (x₀ + 32723)                              5           4.999e+09  6.462e-05  y = ((x₀ + x₀) + 32706)                       7           4.998e+09  6.468e-05  y = (((x₀ + x₀) + 32695) + x₀)                9           4.997e+09  6.459e-05  y = (x₀ + ((x₀ + (32678 + x₀)) + x₀))         11          4.997e+09  6.471e-05  y = ((((x₀ + (x₀ + x₀)) + x₀) + 32667) + x₀)  13          4.996e+09  6.459e-05  y = (((x₀ + x₀) + (((x₀ + x₀) + x₀) + x₀)) + 32647)                                                                           15          4.996e+09  6.462e-05  y = ((((x₀ + ((x₀ + x₀) + (x₀ + x₀))) + x₀) + x₀) + 32628)                                                                    17          4.995e+09  6.468e-05  y = ((x₀ + (((x₀ + x₀) + 32625) + x₀)) + (((x₀ + x₀) + x₀) + x...                                                                                               ₀))                                           19          4.994e+09  6.462e-05  y = ((((x₀ + x₀) + (x₀ + (x₀ + x₀))) + ((x₀ + 32617) + x₀)) + ...                                                                                               (x₀ + x₀))                                    ---------------------------------------------------------------------------------------------------
# 97.8%┣██████████████████████████████████████████ ┫ 587/600 [00:07<00:00, 78it/s]Expressions evaluated per second: 1.76e+05. Head worker occupation: 30.7%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           5.000e+09  1.594e+01  y = 32725                                     3           4.999e+09  6.468e-05  y = (x₀ + 32723)                              5           4.999e+09  6.462e-05  y = ((x₀ + x₀) + 32706)                       7           4.998e+09  6.468e-05  y = (((x₀ + x₀) + 32695) + x₀)                9           4.997e+09  6.459e-05  y = (x₀ + ((x₀ + (32678 + x₀)) + x₀))         11          4.997e+09  6.471e-05  y = ((((x₀ + (x₀ + x₀)) + x₀) + 32667) + x₀)  13          4.996e+09  6.459e-05  y = (((x₀ + x₀) + (((x₀ + x₀) + x₀) + x₀)) + 32647)                                                                           15          4.996e+09  6.462e-05  y = ((((x₀ + ((x₀ + x₀) + (x₀ + x₀))) + x₀) + x₀) + 32628)                                                                    17          4.995e+09  6.468e-05  y = ((x₀ + (((x₀ + x₀) + 32625) + x₀)) + (((x₀ + x₀) + x₀) + x...                                                                                               ₀))                                           19          4.994e+09  6.462e-05  y = ((((x₀ + x₀) + (x₀ + (x₀ + x₀))) + ((x₀ + 32617) + x₀)) + ...                                                                                               (x₀ + x₀))                                    ---------------------------------------------------------------------------------------------------
# 99.2%┣██████████████████████████████████████████▋┫ 595/600 [00:08<00:00, 79it/s]Expressions evaluated per second: 1.76e+05. Head worker occupation: 30.8%. This is high, and will prevent efficient resource usage. Increase `ncyclesperiteration` to reduce load on head worker.                                               Press 'q' and then <enter> to stop execution early.                             Hall of Fame:                                                                   ---------------------------------------------------------------------------------------------------                                                             Complexity  Loss       Score     Equation                                       1           5.000e+09  1.594e+01  y = 32725                                     3           4.999e+09  6.468e-05  y = (x₀ + 32723)                              5           4.999e+09  6.462e-05  y = ((x₀ + x₀) + 32706)                       7           4.998e+09  6.468e-05  y = (((x₀ + x₀) + 32695) + x₀)                9           4.997e+09  6.459e-05  y = (x₀ + ((x₀ + (32678 + x₀)) + x₀))         11          4.997e+09  6.471e-05  y = ((((x₀ + (x₀ + x₀)) + x₀) + 32667) + x₀)  13          4.996e+09  6.459e-05  y = (((x₀ + x₀) + (((x₀ + x₀) + x₀) + x₀)) + 32647)                                                                           15          4.996e+09  6.462e-05  y = ((((x₀ + ((x₀ + x₀) + (x₀ + x₀))) + x₀) + x₀) + 32628)                                                                    17          4.995e+09  6.468e-05  y = ((x₀ + (((x₀ + x₀) + 32625) + x₀)) + (((x₀ + x₀) + x₀) + x...                                                                                               ₀))                                           19          4.994e+09  6.462e-05  y = ((((x₀ + x₀) + (x₀ + (x₀ + x₀))) + ((x₀ + 32617) + x₀)) + ...                                                                                               (x₀ + x₀))                                    ---------------------------------------------------------------------------------------------------

# %%
registros_ = registros
file_pickle = 'dados_v2.pck'

# %%
for i in registros_:
  loss = i[1]
  score = i[2]
  complexity = i[0]
  w = (loss * score)/complexity
  if math.isnan(w):
    i.append(0)
  else:
    i.append(w)

lista_melhor_valor = max(registros_, key=lambda x: x[6])

# %% [markdown]
# ## Save result

# %%
def salvar_dados(dados, key, arquivo):
  if os.path.exists(arquivo):
    with open(arquivo, 'rb') as f:
      dados_exist = pickle.load(f)
  else:
    dados_exist = {}

  valor_original = dados_exist.get(key)
  if valor_original == None:
    dados_exist.update({key: [dados]})
  else:
    if isinstance(valor_original, list):
      valor_original.append(dados)
    else:
      dados_exist.update({key: [dados]})

  with open(arquivo, 'wb') as f:
    pickle.dump(dados_exist, f)

caminho_arquivo = file_pickle
novos_dados = lista_melhor_valor[0:3] + [lista_melhor_valor[4]]

salvar_dados(novos_dados, 'fibonacci_recursive_2^N', caminho_arquivo)

# %%
def carregar_dados(arquivo):
    # Carrega os dados do arquivo pickle
    with open(arquivo, 'rb') as f:
        dados = pickle.load(f)
    return dados

caminho_arquivo = file_pickle
dados_carregados = carregar_dados(caminho_arquivo)

print("Conteúdo do arquivo pickle:")
for k, v in dados_carregados.items():
  print('\u25CF', k)
  for index, item in enumerate(v):
    if index == len(v)-1:
       print('└─', item)
    else:
      print('├─', item)
  print('==========================')
# Out:
# Conteúdo do arquivo pickle:
# ● binary_search_logx
# ├─ [6, 1.2914093, 1.37589542429269, log(x0**6) + 5.574131]
# └─ [5, 1.5291592, 2.19479656667366, log(x0)**2 + 13.966276]
# ==========================
# ● boyer_moore_M_plus_N
# ├─ [9, 1729031400.0, 0.1972007458935316, 752018330.701125*(0.00603869219560025*x0 + 0.00603869219560025*x1 - 1)**4 + 601415.75]
# └─ [5, 15754614000.0, 0.3055240605113849, 3621132.2 - 28185.828*x1]
# ==========================
# ● bubblesort_N^2
# ├─ [4, 5910.4966, 3.4645076652491285, 1.5253483*x0**2]
# └─ [4, 8542.308, 3.303255717418494, 1.5552218*x0**2]
# ==========================
# ● fibonacci_interative_N
# ├─ [3, 0.20818244, 3.412549040667958, 2.058653*x0]
# └─ [3, 0.20818244, 3.412549040667958, 2.058653*x0]
# ==========================
# ● fibonacci_recursive_2^N
# ├─ [15, 111113150.0, 0.37865996607381686, x0**4*(0.0022606994*x0**2 - 0.714783)]
# └─ [15, 77371830.0, 0.38657145558895856, x0**2*(x0**2*(0.16452532*x0 - 3.8766947) + 297.9323)]
# ==========================
